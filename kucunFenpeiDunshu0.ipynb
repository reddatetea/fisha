# %%
import re
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_excel(r'F:\a00nutstore\008\zw08\原材料实时流水账\库存商品分配.xlsx',dtype = {'单据号':str})

# %%
def dunshu(x):
    pattern = r'(?P<ke>\d{2,3})g(?:\w+?)(?P<chang>\d{3,4})\*(?P<kuan>\d{3,4})'
    regexp = re.compile(pattern)
    dunshu = x['吨数']
    if x['计量单位']=='令':
        string = x['品名']
        mat = regexp.search(string)
    
        if mat == None :
            ke, chang, kuan = 0, 0, 0
            dunshu = x['吨数']
        
        else:
            # 克重
            ke = int(mat.group('ke'))
            # 长和宽
            chang= int(mat.group('chang'))
            kuan = int(mat.group('kuan'))
            dunshu = round(ke/1000/1000*chang/1000*kuan/1000*500*x['入库数量'],3)
    else:
        pass
    return dunshu

# %%
df['吨数'] = 0
df['吨价'] = 0
df['金额'] = 0
df['吨数'] = np.where(df['计量单位'].isin(['kg','公斤']),df['入库数量']/1000, 0) #如果计量单位是'kg'or'公斤",吨数是公斤数/1000
df['吨价'] = np.where(df['计量单位'].isin(['kg','公斤']),df['入库单价']*1000, 0)
df['金额'] = df['入库金额']
df
# Out:
#        存货大类名称                   品名 计量单位  期末结存数量         日期         单据号  \
# 0       AA有光纸       40g有光纸787*1092    令   246.0 2021-04-02    90035500
# 1       AB双胶纸     100g华劲双胶787*1092    令     9.5 2023-12-05  0000003177
# 2       AB双胶纸  100g龙丰全木浆双胶889*1194    令     9.7 2022-12-09  0000001440
# 3       AB双胶纸     100g轻型双胶889*1194    令    24.2 2022-10-09  0000001159
# 4       AB双胶纸     110g素描双胶770*1070    令    89.5 2023-11-10  0000002980
# ...       ...                  ...  ...     ...        ...         ...
# 1327  BX联动线版材      法文R5联动柔版900*345    块     3.0 2024-03-07  0000003604
# 1328  BX联动线版材     法文联动线内芯HH885*345    块     5.0 2024-01-21  0000003456
# 1329  BX联动线版材  宏富来铁订A5-16P联605*848    块     1.0 2016-03-04    90025135
# 1330  BX联动线版材     新锐RJL16内芯780*365    张     3.0 2020-08-21    90034272
# 1331  BX联动线版材     新锐RJL16内芯780*365    张     3.0 2018-07-16    90030181
#
#              供货单位   入库数量      入库单价      入库金额               cwName  \
# 0        武汉义利包装材料  246.0  140.9500  34673.70             40g有光纸正度
# 1     武汉市紫星纸业有限公司    9.5  279.3000   2653.35             100g双胶正度
# 2          濮阳龙丰纸业    9.7  333.2059   3232.10             100g双胶大度
# 3        昇伦纸业有限公司   24.2    0.0000      0.00             100g双胶大度
# 4        昇伦纸业有限公司   89.5    0.0000      0.00             110g双胶正度
# ...           ...    ...       ...       ...                  ...
# 1327       武汉辉盈包装    1.0  452.2700    452.27      法文R5联动柔版900*345
# 1328       武汉辉盈包装    5.0  444.8160   2224.08     法文联动线内芯HH885*345
# 1329         信华制版    1.0  947.0000    947.00  宏富来铁订A5-16P联605*848
# 1330         信华制版    1.0  444.0000    444.00     新锐RJL16内芯780*365
# 1331         信华制版    2.0  474.0000    948.00     新锐RJL16内芯780*365
#
#                 priceName   累加数量  剩余数量   吨数   吨价        金额
# 0                  40g有光纸  246.0   0.0  0.0  0.0  34673.70
# 1                  100g双胶    9.5   0.0  0.0  0.0   2653.35
# 2                  100g双胶    9.7   0.0  0.0  0.0   3232.10
# 3                  100g双胶   24.2   0.0  0.0  0.0      0.00
# 4                  110g双胶   89.5   0.0  0.0  0.0      0.00
# ...                   ...    ...   ...  ...  ...       ...
# 1327      法文R5联动柔版900*345    3.0   0.0  0.0  0.0    452.27
# 1328     法文联动线内芯HH885*345    5.0   0.0  0.0  0.0   2224.08
# 1329  宏富来铁订A5-16P联605*848    1.0   0.0  0.0  0.0    947.00
# 1330     新锐RJL16内芯780*365    1.0   2.0  0.0  0.0    444.00
# 1331     新锐RJL16内芯780*365    3.0   0.0  0.0  0.0    948.00
#
# [1332 rows x 17 columns]

# %%
df = df.assign(吨数=df.apply(lambda x: dunshu(x), axis=1))
df
# Out:
#        存货大类名称                   品名 计量单位  期末结存数量         日期         单据号  \
# 0       AA有光纸       40g有光纸787*1092    令   246.0 2021-04-02    90035500
# 1       AB双胶纸     100g华劲双胶787*1092    令     9.5 2023-12-05  0000003177
# 2       AB双胶纸  100g龙丰全木浆双胶889*1194    令     9.7 2022-12-09  0000001440
# 3       AB双胶纸     100g轻型双胶889*1194    令    24.2 2022-10-09  0000001159
# 4       AB双胶纸     110g素描双胶770*1070    令    89.5 2023-11-10  0000002980
# ...       ...                  ...  ...     ...        ...         ...
# 1327  BX联动线版材      法文R5联动柔版900*345    块     3.0 2024-03-07  0000003604
# 1328  BX联动线版材     法文联动线内芯HH885*345    块     5.0 2024-01-21  0000003456
# 1329  BX联动线版材  宏富来铁订A5-16P联605*848    块     1.0 2016-03-04    90025135
# 1330  BX联动线版材     新锐RJL16内芯780*365    张     3.0 2020-08-21    90034272
# 1331  BX联动线版材     新锐RJL16内芯780*365    张     3.0 2018-07-16    90030181
#
#              供货单位   入库数量      入库单价      入库金额               cwName  \
# 0        武汉义利包装材料  246.0  140.9500  34673.70             40g有光纸正度
# 1     武汉市紫星纸业有限公司    9.5  279.3000   2653.35             100g双胶正度
# 2          濮阳龙丰纸业    9.7  333.2059   3232.10             100g双胶大度
# 3        昇伦纸业有限公司   24.2    0.0000      0.00             100g双胶大度
# 4        昇伦纸业有限公司   89.5    0.0000      0.00             110g双胶正度
# ...           ...    ...       ...       ...                  ...
# 1327       武汉辉盈包装    1.0  452.2700    452.27      法文R5联动柔版900*345
# 1328       武汉辉盈包装    5.0  444.8160   2224.08     法文联动线内芯HH885*345
# 1329         信华制版    1.0  947.0000    947.00  宏富来铁订A5-16P联605*848
# 1330         信华制版    1.0  444.0000    444.00     新锐RJL16内芯780*365
# 1331         信华制版    2.0  474.0000    948.00     新锐RJL16内芯780*365
#
#                 priceName   累加数量  剩余数量     吨数   吨价        金额
# 0                  40g有光纸  246.0   0.0  4.228  0.0  34673.70
# 1                  100g双胶    9.5   0.0  0.408  0.0   2653.35
# 2                  100g双胶    9.7   0.0  0.515  0.0   3232.10
# 3                  100g双胶   24.2   0.0  1.284  0.0      0.00
# 4                  110g双胶   89.5   0.0  4.056  0.0      0.00
# ...                   ...    ...   ...    ...  ...       ...
# 1327      法文R5联动柔版900*345    3.0   0.0  0.000  0.0    452.27
# 1328     法文联动线内芯HH885*345    5.0   0.0  0.000  0.0   2224.08
# 1329  宏富来铁订A5-16P联605*848    1.0   0.0  0.000  0.0    947.00
# 1330     新锐RJL16内芯780*365    1.0   2.0  0.000  0.0    444.00
# 1331     新锐RJL16内芯780*365    3.0   0.0  0.000  0.0    948.00
#
# [1332 rows x 17 columns]

# %%
df.to_excel('bbbb.xlsx')
os.startfile('bbbb.xlsx')

# %%
df_zhi = pd.read_excel(r"F:\a00nutstore\006\zw\else\2020入库.xlsx",'入库',dtype={'单号':str})
df_zhi = df_zhi.loc[:,['单号','材料','吨价']]
df_zhi
# Out:
#               单号            材料      吨价
# 0       90034886      202101折扣  5504.0
# 1       90033327     70g林源道林卷筒  5800.0
# 2       90033327     70g林源道林卷筒  5800.0
# 3       00033361     70g林源道林卷筒  5800.0
# 4       00033361     70g林源道林卷筒  5800.0
# ...          ...           ...     ...
# 3772  0000003761    54g兴泰卷筒900  5200.0
# 3773  0000003762    54g兴泰卷筒885  5200.0
# 3774  0000003762    54g兴泰卷筒900  5200.0
# 3775  0000003762  63g兴泰米黄卷筒775  5050.0
# 3776  0000003762  63g兴泰米黄卷筒815  5050.0
#
# [3777 rows x 3 columns]

# %%
def mergeKucunZhi(left,right):
    columns = ['存货大类名称',
 '品名',
 '计量单位',
 '期末结存数量',
 '日期',
 '单据号',
 '供货单位',
 '入库数量',
 '入库单价',
 '入库金额',
 'cwName',
 'priceName',
 '累加数量',
 '剩余数量',
 '吨数',
 '吨价',
 '金额',
]
    right.columns = ['单据号', '品名', 'dunjia']
    merge_left_right = pd.merge(left,right,on = ['单据号','品名'],how = 'left')
    merge_left_right['吨价'] = np.where(merge_left_right['吨价'] == 0,merge_left_right.dunjia,merge_left_right['吨价'])
    merge_left_right = merge_left_right.loc[:,columns]
    return merge_left_right

# %%
mergedf =  mergeKucunZhi(df,df_zhi)
mergedf.to_excel('ggg.xlsx')
os.startfile('ggg.xlsx')

# %%
df_by = pd.read_excel(r"F:\a00nutstore\006\zw\baiyun\2020白云入库.xlsx",'2020',dtype = {'入库单号':str})
df_baiyun = df_by.loc[:,['入库单号','仓库材料','单价']]
df_baiyun
# Out:
#             入库单号           仓库材料    单价
# 0       90033372          78g双胶  6496
# 1       90033373         63g卷筒纸  6246
# 2       90033382     2019年第3季返利  6296
# 3       90033382         55g卷筒纸  6296
# 4       90033382         55g卷筒纸  6296
# ...          ...            ...   ...
# 3365  0000003628  68g白云云时代卷筒885  5789
# 3366  0000003628   68g白云雅云卷筒788  5539
# 3367  0000003628   68g白云雅云卷筒848  5589
# 3368  0000003629  68g白云云时代卷筒885  5739
# 3369  0000003629  68g白云云时代卷筒805  5789
#
# [3370 rows x 3 columns]

# %%
merge_kucun_zhi_baiyun = mergeKucunZhi(mergedf ,df_baiyun)
merge_kucun_zhi_baiyun
# Out:
#        存货大类名称                   品名 计量单位  期末结存数量         日期         单据号  \
# 0       AA有光纸       40g有光纸787*1092    令   246.0 2021-04-02    90035500
# 1       AB双胶纸     100g华劲双胶787*1092    令     9.5 2023-12-05  0000003177
# 2       AB双胶纸  100g龙丰全木浆双胶889*1194    令     9.7 2022-12-09  0000001440
# 3       AB双胶纸     100g轻型双胶889*1194    令    24.2 2022-10-09  0000001159
# 4       AB双胶纸     110g素描双胶770*1070    令    89.5 2023-11-10  0000002980
# ...       ...                  ...  ...     ...        ...         ...
# 1354  BX联动线版材      法文R5联动柔版900*345    块     3.0 2024-03-07  0000003604
# 1355  BX联动线版材     法文联动线内芯HH885*345    块     5.0 2024-01-21  0000003456
# 1356  BX联动线版材  宏富来铁订A5-16P联605*848    块     1.0 2016-03-04    90025135
# 1357  BX联动线版材     新锐RJL16内芯780*365    张     3.0 2020-08-21    90034272
# 1358  BX联动线版材     新锐RJL16内芯780*365    张     3.0 2018-07-16    90030181
#
#              供货单位   入库数量      入库单价      入库金额               cwName  \
# 0        武汉义利包装材料  246.0  140.9500  34673.70             40g有光纸正度
# 1     武汉市紫星纸业有限公司    9.5  279.3000   2653.35             100g双胶正度
# 2          濮阳龙丰纸业    9.7  333.2059   3232.10             100g双胶大度
# 3        昇伦纸业有限公司   24.2    0.0000      0.00             100g双胶大度
# 4        昇伦纸业有限公司   89.5    0.0000      0.00             110g双胶正度
# ...           ...    ...       ...       ...                  ...
# 1354       武汉辉盈包装    1.0  452.2700    452.27      法文R5联动柔版900*345
# 1355       武汉辉盈包装    5.0  444.8160   2224.08     法文联动线内芯HH885*345
# 1356         信华制版    1.0  947.0000    947.00  宏富来铁订A5-16P联605*848
# 1357         信华制版    1.0  444.0000    444.00     新锐RJL16内芯780*365
# 1358         信华制版    2.0  474.0000    948.00     新锐RJL16内芯780*365
#
#                 priceName   累加数量  剩余数量     吨数      吨价        金额
# 0                  40g有光纸  246.0   0.0  4.228  8200.0  34673.70
# 1                  100g双胶    9.5   0.0  0.408  6501.0   2653.35
# 2                  100g双胶    9.7   0.0  0.515  7250.0   3232.10
# 3                  100g双胶   24.2   0.0  1.284  5950.0      0.00
# 4                  110g双胶   89.5   0.0  4.056  5450.0      0.00
# ...                   ...    ...   ...    ...     ...       ...
# 1354      法文R5联动柔版900*345    3.0   0.0  0.000     NaN    452.27
# 1355     法文联动线内芯HH885*345    5.0   0.0  0.000     NaN   2224.08
# 1356  宏富来铁订A5-16P联605*848    1.0   0.0  0.000     NaN    947.00
# 1357     新锐RJL16内芯780*365    1.0   2.0  0.000     NaN    444.00
# 1358     新锐RJL16内芯780*365    3.0   0.0  0.000     NaN    948.00
#
# [1359 rows x 17 columns]

# %%
merge_kucun_zhi_baiyun.to_excel('eee.xlsx')
os.startfile('eee.xlsx')

# %%
zhis = ['AA有光纸', 'AB双胶纸', 'AD白卡纸', 'AE涂布纸', 'AF铜版纸', 'AG牛皮纸', 'AH特种纸',
       'AI复写纸', 'AJ不干胶', 'AK灰板', 'AP卷筒纸']

# %%
df8 = merge_kucun_zhi_baiyun.copy()
df8
# Out:
#        存货大类名称                   品名 计量单位  期末结存数量         日期         单据号  \
# 0       AA有光纸       40g有光纸787*1092    令   246.0 2021-04-02    90035500
# 1       AB双胶纸     100g华劲双胶787*1092    令     9.5 2023-12-05  0000003177
# 2       AB双胶纸  100g龙丰全木浆双胶889*1194    令     9.7 2022-12-09  0000001440
# 3       AB双胶纸     100g轻型双胶889*1194    令    24.2 2022-10-09  0000001159
# 4       AB双胶纸     110g素描双胶770*1070    令    89.5 2023-11-10  0000002980
# ...       ...                  ...  ...     ...        ...         ...
# 1354  BX联动线版材      法文R5联动柔版900*345    块     3.0 2024-03-07  0000003604
# 1355  BX联动线版材     法文联动线内芯HH885*345    块     5.0 2024-01-21  0000003456
# 1356  BX联动线版材  宏富来铁订A5-16P联605*848    块     1.0 2016-03-04    90025135
# 1357  BX联动线版材     新锐RJL16内芯780*365    张     3.0 2020-08-21    90034272
# 1358  BX联动线版材     新锐RJL16内芯780*365    张     3.0 2018-07-16    90030181
#
#              供货单位   入库数量      入库单价      入库金额               cwName  \
# 0        武汉义利包装材料  246.0  140.9500  34673.70             40g有光纸正度
# 1     武汉市紫星纸业有限公司    9.5  279.3000   2653.35             100g双胶正度
# 2          濮阳龙丰纸业    9.7  333.2059   3232.10             100g双胶大度
# 3        昇伦纸业有限公司   24.2    0.0000      0.00             100g双胶大度
# 4        昇伦纸业有限公司   89.5    0.0000      0.00             110g双胶正度
# ...           ...    ...       ...       ...                  ...
# 1354       武汉辉盈包装    1.0  452.2700    452.27      法文R5联动柔版900*345
# 1355       武汉辉盈包装    5.0  444.8160   2224.08     法文联动线内芯HH885*345
# 1356         信华制版    1.0  947.0000    947.00  宏富来铁订A5-16P联605*848
# 1357         信华制版    1.0  444.0000    444.00     新锐RJL16内芯780*365
# 1358         信华制版    2.0  474.0000    948.00     新锐RJL16内芯780*365
#
#                 priceName   累加数量  剩余数量     吨数      吨价        金额
# 0                  40g有光纸  246.0   0.0  4.228  8200.0  34673.70
# 1                  100g双胶    9.5   0.0  0.408  6501.0   2653.35
# 2                  100g双胶    9.7   0.0  0.515  7250.0   3232.10
# 3                  100g双胶   24.2   0.0  1.284  5950.0      0.00
# 4                  110g双胶   89.5   0.0  4.056  5450.0      0.00
# ...                   ...    ...   ...    ...     ...       ...
# 1354      法文R5联动柔版900*345    3.0   0.0  0.000     NaN    452.27
# 1355     法文联动线内芯HH885*345    5.0   0.0  0.000     NaN   2224.08
# 1356  宏富来铁订A5-16P联605*848    1.0   0.0  0.000     NaN    947.00
# 1357     新锐RJL16内芯780*365    1.0   2.0  0.000     NaN    444.00
# 1358     新锐RJL16内芯780*365    3.0   0.0  0.000     NaN    948.00
#
# [1359 rows x 17 columns]

# %%
df8['金额'] = np.where(df8['存货大类名称'].isin(zhis),df8['吨数']*df8['吨价'],df8['金额'])
df8
# Out:
#        存货大类名称                   品名 计量单位  期末结存数量         日期         单据号  \
# 0       AA有光纸       40g有光纸787*1092    令   246.0 2021-04-02    90035500
# 1       AB双胶纸     100g华劲双胶787*1092    令     9.5 2023-12-05  0000003177
# 2       AB双胶纸  100g龙丰全木浆双胶889*1194    令     9.7 2022-12-09  0000001440
# 3       AB双胶纸     100g轻型双胶889*1194    令    24.2 2022-10-09  0000001159
# 4       AB双胶纸     110g素描双胶770*1070    令    89.5 2023-11-10  0000002980
# ...       ...                  ...  ...     ...        ...         ...
# 1354  BX联动线版材      法文R5联动柔版900*345    块     3.0 2024-03-07  0000003604
# 1355  BX联动线版材     法文联动线内芯HH885*345    块     5.0 2024-01-21  0000003456
# 1356  BX联动线版材  宏富来铁订A5-16P联605*848    块     1.0 2016-03-04    90025135
# 1357  BX联动线版材     新锐RJL16内芯780*365    张     3.0 2020-08-21    90034272
# 1358  BX联动线版材     新锐RJL16内芯780*365    张     3.0 2018-07-16    90030181
#
#              供货单位   入库数量      入库单价      入库金额               cwName  \
# 0        武汉义利包装材料  246.0  140.9500  34673.70             40g有光纸正度
# 1     武汉市紫星纸业有限公司    9.5  279.3000   2653.35             100g双胶正度
# 2          濮阳龙丰纸业    9.7  333.2059   3232.10             100g双胶大度
# 3        昇伦纸业有限公司   24.2    0.0000      0.00             100g双胶大度
# 4        昇伦纸业有限公司   89.5    0.0000      0.00             110g双胶正度
# ...           ...    ...       ...       ...                  ...
# 1354       武汉辉盈包装    1.0  452.2700    452.27      法文R5联动柔版900*345
# 1355       武汉辉盈包装    5.0  444.8160   2224.08     法文联动线内芯HH885*345
# 1356         信华制版    1.0  947.0000    947.00  宏富来铁订A5-16P联605*848
# 1357         信华制版    1.0  444.0000    444.00     新锐RJL16内芯780*365
# 1358         信华制版    2.0  474.0000    948.00     新锐RJL16内芯780*365
#
#                 priceName   累加数量  剩余数量     吨数      吨价         金额
# 0                  40g有光纸  246.0   0.0  4.228  8200.0  34669.600
# 1                  100g双胶    9.5   0.0  0.408  6501.0   2652.408
# 2                  100g双胶    9.7   0.0  0.515  7250.0   3733.750
# 3                  100g双胶   24.2   0.0  1.284  5950.0   7639.800
# 4                  110g双胶   89.5   0.0  4.056  5450.0  22105.200
# ...                   ...    ...   ...    ...     ...        ...
# 1354      法文R5联动柔版900*345    3.0   0.0  0.000     NaN    452.270
# 1355     法文联动线内芯HH885*345    5.0   0.0  0.000     NaN   2224.080
# 1356  宏富来铁订A5-16P联605*848    1.0   0.0  0.000     NaN    947.000
# 1357     新锐RJL16内芯780*365    1.0   2.0  0.000     NaN    444.000
# 1358     新锐RJL16内芯780*365    3.0   0.0  0.000     NaN    948.000
#
# [1359 rows x 17 columns]

# %%
df8.to_excel('hhh.xlsx')
os.startfile('hhh.xlsx')
