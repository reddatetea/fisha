# %%
import pandas as pd
import numpy as np
import easygui
import openpyxl
import os
import re

# %%
lst = ['图片',
 '商品编码',
 '款式编码',
 '商品标签',
 '供应商',
 '供应商款号',
 '供应商商品编码',
 '颜色规格',
 '商品简称',
 '商品名称',
 '商品品牌',
 '产品分类',
 '虚拟分类',
 '成本价',
 '销售数量',
 '价格为零的商品数量',
 '实发数量',
 '实发金额',
 '销售金额',
 '销售成本',
 '实发成本',
 '销售毛利',
 '销售毛利率',
 '销售均价',
 '退货数量',
 '实退数量',
 '退货金额',
 '退货成本',
 '实退成本',
 '实退金额',
 '退货毛利',
 '净销量',
 '净销售额',
 '净销售成本',
 '净销售毛利',
 '基本金额',
 '已付金额',
 '优惠金额',
 '运费收入',
 '运费支出',
 '净毛利率',
 '其它价格1',
 '其它价格2',
 '其它价格3',
 '其它价格4',
 '其它价格5',
 '其它属性1',
 '其它属性2',
 '其它属性3',
 '其它属性4',
 '其它属性5',
 '基本售价']
lst1 = [ '商品编码',
 '商品名称',
 '净销量',
 '净销售额',
 '净销售成本',
 '净销售毛利',
]
names = ['shangpinbianma','name','xiaoshouliang','xiaoshoue','xiaoshouchengben','maoli']
dic = dict(zip(lst1,names))
dic
# Out:
# {'商品编码': 'shangpinbianma',
#  '商品名称': 'name',
#  '净销量': 'xiaoshouliang',
#  '净销售额': 'xiaoshoue',
#  '净销售成本': 'xiaoshouchengben',
#  '净销售毛利': 'maoli'}

# %%
path = r'F:\a00nutstore\008\zw08\电商\聚水潭\202412'
lst_file = [i for i in os.listdir(path) if  (i.startswith('~') == False) and (i.endswith('.xlsx') == True)] # and i.startswith('~') == Fasle
lst_file
# Out:
# ['销售主题分析_按商品_2025-01-04_10-30-11-京东.xlsx',
#  '销售主题分析_按商品_2025-01-04_10-51-58-拼多多.xlsx',
#  '销售主题分析_按商品_2025-01-04_11-01-03-淘宝.xlsx',
#  '销售主题分析_按商品_2025-01-04_11-02-57-阿里巴巴.xlsx',
#  '销售主题分析_按商品_2025-01-04_11-09-09-京东荣佳.xlsx',
#  '销售主题分析_按商品_2025-01-04_13-34-46-全平台.xlsx']

# %%
def getXiaoshou(file):
    df = pd.read_excel(os.path.join(path,file),dtype =  {'商品编码':str,'其它属性4':str}) 
    df = df[~df['商品编码'].isnull()]
    return df

# %%
dfs = []
pingtais = []
pingtai_df  = {}
pattern = re.compile(r'(?<=-)(\w+)(?=\.xlsx)')
for file in lst_file:
    
    mat = pattern.search(file)
    df = getXiaoshou(file)
    
    
    if mat :
        pingtai = mat.group(1)
        if pingtai == '全平台':
            df_quanpingtai = df
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
        
           

        elif pingtai == '拼多多':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
  
        elif pingtai == '阿里巴巴':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
           
        elif pingtai == '淘宝':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
 
        elif pingtai == '京东':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
  
        elif pingtai == '京东商城':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
         
        elif pingtai == '京东荣佳':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
 
        elif pingtai == '分销商':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
        else :
            continue
    else :
        continue
# Out:
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
pingtais
# Out:
# ['京东', '拼多多', '淘宝', '阿里巴巴', '京东荣佳', '全平台']

# %%
dfs
# Out:
# [    图片             商品编码            款式编码    商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
#  0  NaN     EJYBB520-红米字       硬笔书法纸及定位纸  分销-常规款  NaN    NaN      NaN   NaN
#  1  NaN     EJYBB520-绿田字       硬笔书法纸及定位纸  分销-常规款  NaN    NaN      NaN   NaN
#  2  NaN       EFZW3260NA  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  3  NaN            N0795  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  4  NaN            N0792  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  5  NaN     EJYBB520-红田字       硬笔书法纸及定位纸  分销-常规款  NaN    NaN      NaN   NaN
#  6  NaN            N0793  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  7  NaN    EFC3260N（方格）A  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  8  NaN     EJYBB520-绿米字       硬笔书法纸及定位纸  分销-常规款  NaN    NaN      NaN   NaN
#  9  NaN        EFHP3260N  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  10 NaN            N0821         32K办公软抄  分销-常规款  NaN    NaN      NaN   NaN
#  11 NaN            N0796  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  12 NaN  EFSX3260N（双竖线）A  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  13 NaN            N0823         32K办公软抄  分销-常规款  NaN    NaN      NaN   NaN
#  14 NaN            N0791  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  15 NaN            N0826         32K办公软抄  分销-常规款  NaN    NaN      NaN   NaN
#
#             商品简称                     商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5  \
#  0     C1-5/C3-7            硬笔书法纸-红米字格20张  ...    NaN    NaN    NaN    NaN
#  1          C1-6            硬笔书法纸-绿田字格20张  ...    NaN    NaN    NaN    NaN
#  2          D6-4       32K60型牛卡缝线作文簿(36P)  ...    NaN    NaN    NaN    NaN
#  3         D6-15            32K60型牛卡缝线练习本  ...    NaN    NaN    NaN    NaN
#  4         D5-13          32K60型牛卡缝线作业登记本  ...    NaN    NaN    NaN    NaN
#  5          C1-5            硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN    NaN
#  6         D6-13            32K60型牛卡缝线英语本  ...    NaN    NaN    NaN    NaN
#  7         D6-10   32K60型牛卡缝线语文簿（方格）(36P)  ...    NaN    NaN    NaN    NaN
#  8          C1-7            硬笔书法纸-绿米字格20张  ...    NaN    NaN    NaN    NaN
#  9         D5-11     32K60型牛卡缝线汉语拼音本(36P)  ...    NaN    NaN    NaN    NaN
#  10        D2-17            D32K40型卡面办公软抄  ...    NaN    NaN    NaN    NaN
#  11        D6-14           32K60型牛卡缝线读书笔记  ...    NaN    NaN    NaN    NaN
#  12  D6-11/D6-12  32K60型牛卡缝线数学簿（双竖线）(36P)  ...    NaN    NaN    NaN    NaN
#  13        D2-20            D32K80型卡面办公软抄  ...    NaN    NaN    NaN    NaN
#  14        D5-14           32K60型牛卡缝线学生日记  ...    NaN    NaN    NaN    NaN
#  15        D2-18           D32K150型卡面办公软抄  ...    NaN    NaN    NaN    NaN
#
#         其它属性1     其它属性2  其它属性3         其它属性4  其它属性5  基本售价
#  0        NaN     10本/包     收缩           NaN    NaN  0.36
#  1        NaN     10本/包     收缩           NaN    NaN  0.36
#  2   320/360t      5本/包     收缩  6.936281e+12    NaN  0.55
#  3        320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
#  4        320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
#  5        NaN     10本/包     收缩           NaN    NaN  0.36
#  6        320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
#  7   320/360t      5本/包     收缩  6.936281e+12    NaN  0.55
#  8        NaN     10本/包     收缩           NaN    NaN  0.36
#  9   320/360t      5本/包     收缩  6.936281e+12    NaN  0.55
#  10       560        10    NaN  6.936281e+12    NaN  0.39
#  11       320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
#  12  320/360t      5本/包     收缩  6.936281e+12    NaN  0.55
#  13       320        10    NaN  6.936281e+12    NaN  0.70
#  14       320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
#  15       180         5    NaN  6.936281e+12    NaN  1.39
#
#  [16 rows x 52 columns],
#       图片          商品编码       款式编码      商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
#  0   NaN  EJYBB520-红米字  硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  1   NaN  EJYBB520-红田字  硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  2   NaN  EJYBB520-绿田字  硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  3   NaN  EJYBB520-绿米字  硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  4   NaN     EJZBA5128    牛皮胶装直背本    分销-常规款  NaN    NaN      NaN   NaN
#  ..   ..           ...        ...       ...  ...    ...      ...   ...
#  199 NaN         N0654       办公硬抄    分销-常规款  NaN    NaN      NaN   NaN
#  200 NaN         N0817    32K卡通软抄    分销-常规款  NaN    NaN      NaN   NaN
#  201 NaN     RJL-16200     16K胶套本    分销-常规款  NaN    NaN      NaN   NaN
#  202 NaN      RJL-3280     32K胶套本    分销-常规款  NaN    NaN      NaN   NaN
#  203 NaN    SMA340S-寂静      上翻素描本  分销-锐意-账本  NaN    NaN      NaN   NaN
#
#                   商品简称                   商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5  \
#  0           C1-5/C3-7          硬笔书法纸-红米字格20张  ...    NaN    NaN    NaN    NaN
#  1                C1-5          硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN    NaN
#  2                C1-6          硬笔书法纸-绿田字格20张  ...    NaN    NaN    NaN    NaN
#  3                C1-7          硬笔书法纸-绿米字格20张  ...    NaN    NaN    NaN    NaN
#  4    D8-16/D7-16/C3-8  A5128页胶装直背本（空白）（128p）  ...    NaN    NaN    NaN    NaN
#  ..                ...                    ...  ...    ...    ...    ...    ...
#  199              D4-3           D32K200型办公硬抄  ...    NaN    NaN    NaN    NaN
#  200             D2-14           D32K60型卡面英语本  ...    NaN    NaN    NaN    NaN
#  201                待定        16K200型胶套本 156P  ...    NaN    NaN    NaN    NaN
#  202             B1-20          32K80型胶套本 60P  ...    NaN    NaN    NaN    NaN
#  203             B7-11   A3-40型精品卡面带手提素描本（上翻）  ...    NaN    NaN    NaN    NaN
#
#       其它属性1  其它属性2  其它属性3         其它属性4  其它属性5  基本售价
#  0      NaN  10本/包     收缩           NaN    NaN  0.36
#  1      NaN  10本/包     收缩           NaN    NaN  0.36
#  2      NaN  10本/包     收缩           NaN    NaN  0.36
#  3      NaN  10本/包     收缩           NaN    NaN  0.36
#  4      120   1本/包     收缩  6.936281e+12    NaN  1.75
#  ..     ...    ...    ...           ...    ...   ...
#  199     84      1    NaN  6.936281e+12    NaN  3.52
#  200    480     10    NaN  6.936281e+12    NaN  0.54
#  201     60      5    NaN  6.936281e+12    NaN  5.47
#  202    160     10    NaN  6.936281e+12    NaN  1.80
#  203     30      1    NaN  6.936281e+12    NaN  6.51
#
#  [204 rows x 52 columns],
#      图片           商品编码          款式编码      商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
#  0  NaN      ETCG1630N           草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  1  NaN   EJYBB520-红米字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  2  NaN  EJCG1630N（分区）           草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  3  NaN           6106         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  4  NaN    EJDWB550-英初     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  5  NaN      EJCG1630N           草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  6  NaN          N0835       32K卡通软抄    分销-常规款  NaN    NaN      NaN   NaN
#  7  NaN           6124         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  8  NaN        FYP1660        牛皮缝线科目  分销-锐意-账本  NaN    NaN      NaN   NaN
#  9  NaN   EJYBB520-绿米字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  10 NaN        EHBA560  A5活页芯（左侧20孔）    分销-常规款  NaN    NaN      NaN   NaN
#  11 NaN           2001            凭证  分销-锐意-账本  NaN    NaN      NaN   NaN
#  12 NaN           5139      无碳复写多联单据  分销-锐意-账本  NaN    NaN      NaN   NaN
#  13 NaN    EJDWB550-英高     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  14 NaN   EJYBB520-绿田字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  15 NaN          J1602           材料纸    分销-常规款  NaN    NaN      NaN   NaN
#  16 NaN          N0836       32K卡通软抄    分销-常规款  NaN    NaN      NaN   NaN
#  17 NaN          J1601           材料纸    分销-常规款  NaN    NaN      NaN   NaN
#  18 NaN           6128         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  19 NaN       DWXA540N       无线胶装办公本  分销-锐意-账本  NaN    NaN      NaN   NaN
#  20 NaN   EJYBB520-红田字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  21 NaN           6120         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  22 NaN  DL-1660C-青春故事          道林软抄  分销-锐意-账本  NaN    NaN      NaN   NaN
#  23 NaN        EHBB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
#  24 NaN        EHLB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
#  25 NaN     EWTHA430NA           图画本    分销-常规款  NaN    NaN      NaN   NaN
#  26 NaN           6206         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  27 NaN           6208         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  28 NaN        EHYA560  A5活页芯（左侧20孔）    分销-常规款  NaN    NaN      NaN   NaN
#  29 NaN           1602           材料纸  分销-锐意-账本  NaN    NaN      NaN   NaN
#  30 NaN           6107         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  31 NaN           6123         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  32 NaN           6211         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  33 NaN           6215         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  34 NaN        EHDA560  A5活页芯（左侧20孔）    分销-常规款  NaN    NaN      NaN   NaN
#  35 NaN        EHDB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
#  36 NaN       EHKNB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
#  37 NaN           6003         订本式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  38 NaN           6005         订本式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  39 NaN           6116         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  40 NaN       EHJCB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
#  41 NaN        EHYB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
#  42 NaN          N0816       32K卡通软抄    分销-常规款  NaN    NaN      NaN   NaN
#  43 NaN      RJL-16200        16K胶套本    分销-常规款  NaN    NaN      NaN   NaN
#  44 NaN       RJL-3280        32K胶套本    分销-常规款  NaN    NaN      NaN   NaN
#
#                        商品简称                  商品名称  ...  其它价格2  其它价格3  其它价格4  \
#  0                     B6-1         16K30页牛皮铁钉草稿本  ...    NaN    NaN    NaN
#  1                C1-5/C3-7         硬笔书法纸-红米字格20张  ...    NaN    NaN    NaN
#  2                     B6-5       16K30页牛皮胶装分区草稿本  ...    NaN    NaN    NaN
#  3   A1-50-1/A4-9-2/A1-50-2              三栏式明细分类账  ...    NaN    NaN    NaN
#  4                     C3-4        英语定位书写纸-初级版50张  ...    NaN    NaN    NaN
#  5                     B5-5         16K30页牛皮胶装草稿本  ...    NaN    NaN    NaN
#  6                    D2-25         D32K40型卡面学生日记  ...    NaN    NaN    NaN
#  7                  A1-48-2             16K材料明细账本  ...    NaN    NaN    NaN
#  8                     C1-8     16K60型精品缝线乐谱本 36P  ...    NaN    NaN    NaN
#  9                     C1-7         硬笔书法纸-绿米字格20张  ...    NaN    NaN    NaN
#  10                   D2-13     A560页活页芯（空白）(60P)  ...    NaN    NaN    NaN
#  11                   B7-14                  记账凭证  ...    NaN    NaN    NaN
#  12                 A1-33-2     48K工商服务业收据（三联、多栏）  ...    NaN    NaN    NaN
#  13                    C3-1        英语定位书写纸-高级版50张  ...    NaN    NaN    NaN
#  14                    C1-6         硬笔书法纸-绿田字格20张  ...    NaN    NaN    NaN
#  15                  A1-7-1               简装单行材料纸  ...    NaN    NaN    NaN
#  16                   D2-19         D32K80型卡面学生日记  ...    NaN    NaN    NaN
#  17                  A1-8-1               简装双行材料纸  ...    NaN    NaN    NaN
#  18                 A1-43-2                 实物出入账  ...    NaN    NaN    NaN
#  19                   B3-13       A540张牛卡无线胶装办公软抄  ...    NaN    NaN    NaN
#  20                    C1-5         硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN
#  21                 A1-47-3               商品明细分类账  ...    NaN    NaN    NaN
#  22                      待定   16K60型精品道林卡面软抄C2402  ...    NaN    NaN    NaN
#  23                    D3-9     B560页活页芯（空白）(60P)  ...    NaN    NaN    NaN
#  24                   D3-21     B560页活页芯（线条）(60P)  ...    NaN    NaN    NaN
#  25                    B1-2  A4-30张无线胶装牛卡图画本（30p)  ...    NaN    NaN    NaN
#  26                 A1-42-3              三栏式明细分类账  ...    NaN    NaN    NaN
#  27                 A1-43-3               商品明细分类账  ...    NaN    NaN    NaN
#  28                   D5-26     A560页活页芯（英语）(60P)  ...    NaN    NaN    NaN
#  29                 A2-16-2                 单行材料纸  ...    NaN    NaN    NaN
#  30                 A1-41-2             固定资产明细分类账  ...    NaN    NaN    NaN
#  31                 A1-42-2              进销存明细分类账  ...    NaN    NaN    NaN
#  32                 A1-51-3                  总分类账  ...    NaN    NaN    NaN
#  33                 A1-44-3                 现金日记账  ...    NaN    NaN    NaN
#  34                   D2-12     A560页活页芯（点阵）(60P)  ...    NaN    NaN    NaN
#  35                   D4-20     B560页活页芯（点阵）(60P)  ...    NaN    NaN    NaN
#  36                   D3-18    B560页活页芯（康奈尔）(60P)  ...    NaN    NaN    NaN
#  37                 A1-50-1               银行存款日记账  ...    NaN    NaN    NaN
#  38                 A1-49-1                 现金日记账  ...    NaN    NaN    NaN
#  39                 A1-46-2             16栏式明细分类账  ...    NaN    NaN    NaN
#  40                   D4-22     B560页活页芯（纠错）(60P)  ...    NaN    NaN    NaN
#  41                   D3-19     B560页活页芯（英语）(60P)  ...    NaN    NaN    NaN
#  42                   D2-22         D32K60型卡面学生日记  ...    NaN    NaN    NaN
#  43                      待定       16K200型胶套本 156P  ...    NaN    NaN    NaN
#  44                   B1-20         32K80型胶套本 60P  ...    NaN    NaN    NaN
#
#      其它价格5  其它属性1  其它属性2  其它属性3         其它属性4     其它属性5  基本售价
#  0     NaN  240.0  10本/包     收缩  6.936281e+12       NaN  0.68
#  1     NaN    NaN  10本/包     收缩           NaN       NaN  0.36
#  2     NaN  240.0  10本/包     收缩  6.936281e+12       NaN  0.85
#  3     NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  4     NaN    NaN     1本     套袋           NaN       NaN  0.97
#  5     NaN  240.0  10本/包     收缩  6.936281e+12       NaN  0.85
#  6     NaN  640.0     10    NaN  6.936281e+12       NaN  0.38
#  7     NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  8     NaN  160.0     10    NaN  6.936281e+12       NaN  1.58
#  9     NaN    NaN  10本/包     收缩           NaN       NaN  0.36
#  10    NaN  220.0   1本/包     套袋  6.936281e+12       NaN  0.80
#  11    NaN  270.0      5    NaN  6.936281e+12  35开*100型  1.48
#  12    NaN  360.0     10    NaN  6.936281e+12   48开*75型  1.33
#  13    NaN    NaN     1本     套袋           NaN       NaN  0.97
#  14    NaN    NaN  10本/包     收缩           NaN       NaN  0.36
#  15    NaN  270.0      3    NaN  6.936281e+12       NaN  0.86
#  16    NaN  360.0     10    NaN  6.936281e+12       NaN  0.66
#  17    NaN  270.0      3    NaN  6.936281e+12       NaN  0.86
#  18    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  19    NaN  240.0     10    NaN  6.936281e+12       NaN  1.26
#  20    NaN    NaN  10本/包     收缩           NaN       NaN  0.36
#  21    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  22    NaN  160.0     10    NaN  6.936281e+12       NaN  1.66
#  23    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
#  24    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
#  25    NaN  160.0  10本/包     收缩  6.936281e+12       NaN  1.20
#  26    NaN   50.0      1    NaN  6.936281e+12  25开*100型  6.24
#  27    NaN   50.0      1    NaN  6.936281e+12  25开*100型  6.24
#  28    NaN  220.0   1本/包     套袋  6.936281e+12       NaN  0.80
#  29    NaN  220.0      2    NaN  6.936281e+12   16开*40型  1.33
#  30    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  31    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  32    NaN   70.0      1    NaN  6.936281e+12   25开*50型  4.61
#  33    NaN   70.0      1    NaN  6.936281e+12   25开*50型  4.61
#  34    NaN  220.0   1本/包     套袋  6.936281e+12       NaN  0.80
#  35    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
#  36    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
#  37    NaN   60.0      1    NaN  6.936281e+12   16开*48型  6.24
#  38    NaN   60.0      1    NaN  6.936281e+12   16开*48型  6.24
#  39    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  40    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
#  41    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
#  42    NaN  480.0     10    NaN  6.936281e+12       NaN  0.54
#  43    NaN   60.0      5    NaN  6.936281e+12       NaN  5.47
#  44    NaN  160.0     10    NaN  6.936281e+12       NaN  1.80
#
#  [45 rows x 52 columns],
#       图片          商品编码            款式编码      商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
#  0   NaN        BQ1640             草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  1   NaN       CGN1640             草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  2   NaN   EXLA580NB-C            勤问系列       NaN  NaN    NaN      NaN   NaN
#  3   NaN   EFLB560K-盐系  马卡龙缝线本及甜系盐系缝线本    分销-常规款  NaN    NaN      NaN   NaN
#  4   NaN  EJYBB520-红田字       硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  ..   ..           ...             ...       ...  ...    ...      ...   ...
#  263 NaN     EXA4PP-紫色    A4五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  264 NaN     EXA4PP-绿色    A4五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  265 NaN     EXB5PP-粉色    B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  266 NaN     EXB5PP-蓝色    B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  267 NaN  SMA440S-野生探险    SMA440S-野生探险  分销-锐意-账本  NaN    NaN      NaN   NaN
#
#        商品简称                   商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5     其它属性1  \
#  0     B5-4  16K40型白色草稿本（便签本）/白胶上翻  ...    NaN    NaN    NaN    NaN  280/240t
#  1     B6-3       16K40型牛皮草稿本/铁钉上翻  ...    NaN    NaN    NaN    NaN  280/200t
#  2     E2-4      A5-80 型牛卡线环横线本-侧翻  ...    NaN    NaN    NaN    NaN       NaN
#  3     D5-8      B560型卡面缝线本（盐系）40p  ...    NaN    NaN    NaN    NaN       160
#  4     C1-5          硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN    NaN       NaN
#  ..     ...                    ...  ...    ...    ...    ...    ...       ...
#  263     E区              EXA4PP-紫色  ...    NaN    NaN    NaN    NaN       NaN
#  264   E3-6              EXA4PP-绿色  ...    NaN    NaN    NaN    NaN       NaN
#  265   E3-8              EXB5PP-粉色  ...    NaN    NaN    NaN    NaN       NaN
#  266   E3-8              EXB5PP-蓝色  ...    NaN    NaN    NaN    NaN       NaN
#  267  B5-10         A440型精品卡面手提素描本  ...    NaN    NaN    NaN    NaN        60
#
#       其它属性2  其它属性3         其它属性4  其它属性5  基本售价
#  0    10本/包     收缩  6.936281e+12    NaN  0.58
#  1    10本/包     收缩  6.936281e+12    NaN  0.58
#  2    4 本/包     收缩           NaN    NaN  1.10
#  3     4本/包     收缩  6.936281e+12    NaN  1.30
#  4    10本/包     收缩           NaN    NaN  0.36
#  ..     ...    ...           ...    ...   ...
#  263    NaN    NaN           NaN    NaN  2.01
#  264    NaN    NaN           NaN    NaN  2.01
#  265    NaN    NaN           NaN    NaN  1.66
#  266    NaN    NaN           NaN    NaN  1.66
#  267      1    NaN  6.936281e+12    NaN  3.49
#
#  [268 rows x 52 columns],
#     图片   商品编码            款式编码    商品标签  供应商  供应商款号  供应商商品编码  颜色规格   商品简称  \
#  0 NaN  N0795  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN  D6-15
#  1 NaN  N0796  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN  D6-14
#
#               商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5  其它属性1     其它属性2  其它属性3  \
#  0   32K60型牛卡缝线练习本  ...    NaN    NaN    NaN    NaN  320.0  5本/10本/包     收缩
#  1  32K60型牛卡缝线读书笔记  ...    NaN    NaN    NaN    NaN  320.0  5本/10本/包     收缩
#
#            其它属性4  其它属性5  基本售价
#  0  6.936281e+12    NaN  0.55
#  1  6.936281e+12    NaN  0.55
#
#  [2 rows x 52 columns],
#       图片          商品编码          款式编码      商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
#  0   NaN  EJYBB520-红米字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  1   NaN  EJYBB520-红田字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  2   NaN        BQ1640           草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  3   NaN       CGN1640           草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  4   NaN  EJYBB520-绿田字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  ..   ..           ...           ...       ...  ...    ...      ...   ...
#  359 NaN     EXA4PP-绿色  A4五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  360 NaN     EXB5PP-粉色  B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  361 NaN     EXB5PP-蓝色  B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  362 NaN         N0654          办公硬抄    分销-常规款  NaN    NaN      NaN   NaN
#  363 NaN    SMA340S-寂静         上翻素描本  分销-锐意-账本  NaN    NaN      NaN   NaN
#
#            商品简称                   商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5  \
#  0    C1-5/C3-7          硬笔书法纸-红米字格20张  ...    NaN    NaN    NaN    NaN
#  1         C1-5          硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN    NaN
#  2         B5-4  16K40型白色草稿本（便签本）/白胶上翻  ...    NaN    NaN    NaN    NaN
#  3         B6-3       16K40型牛皮草稿本/铁钉上翻  ...    NaN    NaN    NaN    NaN
#  4         C1-6          硬笔书法纸-绿田字格20张  ...    NaN    NaN    NaN    NaN
#  ..         ...                    ...  ...    ...    ...    ...    ...
#  359       E3-6              EXA4PP-绿色  ...    NaN    NaN    NaN    NaN
#  360       E3-8              EXB5PP-粉色  ...    NaN    NaN    NaN    NaN
#  361       E3-8              EXB5PP-蓝色  ...    NaN    NaN    NaN    NaN
#  362       D4-3           D32K200型办公硬抄  ...    NaN    NaN    NaN    NaN
#  363      B7-11   A3-40型精品卡面带手提素描本（上翻）  ...    NaN    NaN    NaN    NaN
#
#          其它属性1  其它属性2  其它属性3         其它属性4  其它属性5  基本售价
#  0         NaN  10本/包     收缩           NaN    NaN  0.36
#  1         NaN  10本/包     收缩           NaN    NaN  0.36
#  2    280/240t  10本/包     收缩  6.936281e+12    NaN  0.58
#  3    280/200t  10本/包     收缩  6.936281e+12    NaN  0.58
#  4         NaN  10本/包     收缩           NaN    NaN  0.36
#  ..        ...    ...    ...           ...    ...   ...
#  359       NaN    NaN    NaN           NaN    NaN  2.01
#  360       NaN    NaN    NaN           NaN    NaN  1.66
#  361       NaN    NaN    NaN           NaN    NaN  1.66
#  362        84      1    NaN  6.936281e+12    NaN  3.52
#  363        30      1    NaN  6.936281e+12    NaN  6.51
#
#  [364 rows x 52 columns]]

# %%
pingtai_df

# %%
#双佳平台
pingtais_shuang = [i for i in pingtais if (i != '京东荣佳') and (i != '全平台')]
pingtais_shuang
# Out:
# ['京东', '拼多多', '淘宝', '阿里巴巴']

# %%
#双佳平台数据
dfs_shuangjia = [pingtai_df.get(i) for i in pingtais]
dfs_shuangjia
# Out:
# [    图片             商品编码            款式编码    商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
#  0  NaN     EJYBB520-红米字       硬笔书法纸及定位纸  分销-常规款  NaN    NaN      NaN   NaN
#  1  NaN     EJYBB520-绿田字       硬笔书法纸及定位纸  分销-常规款  NaN    NaN      NaN   NaN
#  2  NaN       EFZW3260NA  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  3  NaN            N0795  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  4  NaN            N0792  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  5  NaN     EJYBB520-红田字       硬笔书法纸及定位纸  分销-常规款  NaN    NaN      NaN   NaN
#  6  NaN            N0793  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  7  NaN    EFC3260N（方格）A  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  8  NaN     EJYBB520-绿米字       硬笔书法纸及定位纸  分销-常规款  NaN    NaN      NaN   NaN
#  9  NaN        EFHP3260N  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  10 NaN            N0821         32K办公软抄  分销-常规款  NaN    NaN      NaN   NaN
#  11 NaN            N0796  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  12 NaN  EFSX3260N（双竖线）A  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  13 NaN            N0823         32K办公软抄  分销-常规款  NaN    NaN      NaN   NaN
#  14 NaN            N0791  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
#  15 NaN            N0826         32K办公软抄  分销-常规款  NaN    NaN      NaN   NaN
#
#             商品简称                     商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5  \
#  0     C1-5/C3-7            硬笔书法纸-红米字格20张  ...    NaN    NaN    NaN    NaN
#  1          C1-6            硬笔书法纸-绿田字格20张  ...    NaN    NaN    NaN    NaN
#  2          D6-4       32K60型牛卡缝线作文簿(36P)  ...    NaN    NaN    NaN    NaN
#  3         D6-15            32K60型牛卡缝线练习本  ...    NaN    NaN    NaN    NaN
#  4         D5-13          32K60型牛卡缝线作业登记本  ...    NaN    NaN    NaN    NaN
#  5          C1-5            硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN    NaN
#  6         D6-13            32K60型牛卡缝线英语本  ...    NaN    NaN    NaN    NaN
#  7         D6-10   32K60型牛卡缝线语文簿（方格）(36P)  ...    NaN    NaN    NaN    NaN
#  8          C1-7            硬笔书法纸-绿米字格20张  ...    NaN    NaN    NaN    NaN
#  9         D5-11     32K60型牛卡缝线汉语拼音本(36P)  ...    NaN    NaN    NaN    NaN
#  10        D2-17            D32K40型卡面办公软抄  ...    NaN    NaN    NaN    NaN
#  11        D6-14           32K60型牛卡缝线读书笔记  ...    NaN    NaN    NaN    NaN
#  12  D6-11/D6-12  32K60型牛卡缝线数学簿（双竖线）(36P)  ...    NaN    NaN    NaN    NaN
#  13        D2-20            D32K80型卡面办公软抄  ...    NaN    NaN    NaN    NaN
#  14        D5-14           32K60型牛卡缝线学生日记  ...    NaN    NaN    NaN    NaN
#  15        D2-18           D32K150型卡面办公软抄  ...    NaN    NaN    NaN    NaN
#
#         其它属性1     其它属性2  其它属性3         其它属性4  其它属性5  基本售价
#  0        NaN     10本/包     收缩           NaN    NaN  0.36
#  1        NaN     10本/包     收缩           NaN    NaN  0.36
#  2   320/360t      5本/包     收缩  6.936281e+12    NaN  0.55
#  3        320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
#  4        320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
#  5        NaN     10本/包     收缩           NaN    NaN  0.36
#  6        320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
#  7   320/360t      5本/包     收缩  6.936281e+12    NaN  0.55
#  8        NaN     10本/包     收缩           NaN    NaN  0.36
#  9   320/360t      5本/包     收缩  6.936281e+12    NaN  0.55
#  10       560        10    NaN  6.936281e+12    NaN  0.39
#  11       320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
#  12  320/360t      5本/包     收缩  6.936281e+12    NaN  0.55
#  13       320        10    NaN  6.936281e+12    NaN  0.70
#  14       320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
#  15       180         5    NaN  6.936281e+12    NaN  1.39
#
#  [16 rows x 52 columns],
#       图片          商品编码       款式编码      商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
#  0   NaN  EJYBB520-红米字  硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  1   NaN  EJYBB520-红田字  硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  2   NaN  EJYBB520-绿田字  硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  3   NaN  EJYBB520-绿米字  硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  4   NaN     EJZBA5128    牛皮胶装直背本    分销-常规款  NaN    NaN      NaN   NaN
#  ..   ..           ...        ...       ...  ...    ...      ...   ...
#  199 NaN         N0654       办公硬抄    分销-常规款  NaN    NaN      NaN   NaN
#  200 NaN         N0817    32K卡通软抄    分销-常规款  NaN    NaN      NaN   NaN
#  201 NaN     RJL-16200     16K胶套本    分销-常规款  NaN    NaN      NaN   NaN
#  202 NaN      RJL-3280     32K胶套本    分销-常规款  NaN    NaN      NaN   NaN
#  203 NaN    SMA340S-寂静      上翻素描本  分销-锐意-账本  NaN    NaN      NaN   NaN
#
#                   商品简称                   商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5  \
#  0           C1-5/C3-7          硬笔书法纸-红米字格20张  ...    NaN    NaN    NaN    NaN
#  1                C1-5          硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN    NaN
#  2                C1-6          硬笔书法纸-绿田字格20张  ...    NaN    NaN    NaN    NaN
#  3                C1-7          硬笔书法纸-绿米字格20张  ...    NaN    NaN    NaN    NaN
#  4    D8-16/D7-16/C3-8  A5128页胶装直背本（空白）（128p）  ...    NaN    NaN    NaN    NaN
#  ..                ...                    ...  ...    ...    ...    ...    ...
#  199              D4-3           D32K200型办公硬抄  ...    NaN    NaN    NaN    NaN
#  200             D2-14           D32K60型卡面英语本  ...    NaN    NaN    NaN    NaN
#  201                待定        16K200型胶套本 156P  ...    NaN    NaN    NaN    NaN
#  202             B1-20          32K80型胶套本 60P  ...    NaN    NaN    NaN    NaN
#  203             B7-11   A3-40型精品卡面带手提素描本（上翻）  ...    NaN    NaN    NaN    NaN
#
#       其它属性1  其它属性2  其它属性3         其它属性4  其它属性5  基本售价
#  0      NaN  10本/包     收缩           NaN    NaN  0.36
#  1      NaN  10本/包     收缩           NaN    NaN  0.36
#  2      NaN  10本/包     收缩           NaN    NaN  0.36
#  3      NaN  10本/包     收缩           NaN    NaN  0.36
#  4      120   1本/包     收缩  6.936281e+12    NaN  1.75
#  ..     ...    ...    ...           ...    ...   ...
#  199     84      1    NaN  6.936281e+12    NaN  3.52
#  200    480     10    NaN  6.936281e+12    NaN  0.54
#  201     60      5    NaN  6.936281e+12    NaN  5.47
#  202    160     10    NaN  6.936281e+12    NaN  1.80
#  203     30      1    NaN  6.936281e+12    NaN  6.51
#
#  [204 rows x 52 columns],
#      图片           商品编码          款式编码      商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
#  0  NaN      ETCG1630N           草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  1  NaN   EJYBB520-红米字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  2  NaN  EJCG1630N（分区）           草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  3  NaN           6106         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  4  NaN    EJDWB550-英初     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  5  NaN      EJCG1630N           草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  6  NaN          N0835       32K卡通软抄    分销-常规款  NaN    NaN      NaN   NaN
#  7  NaN           6124         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  8  NaN        FYP1660        牛皮缝线科目  分销-锐意-账本  NaN    NaN      NaN   NaN
#  9  NaN   EJYBB520-绿米字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  10 NaN        EHBA560  A5活页芯（左侧20孔）    分销-常规款  NaN    NaN      NaN   NaN
#  11 NaN           2001            凭证  分销-锐意-账本  NaN    NaN      NaN   NaN
#  12 NaN           5139      无碳复写多联单据  分销-锐意-账本  NaN    NaN      NaN   NaN
#  13 NaN    EJDWB550-英高     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  14 NaN   EJYBB520-绿田字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  15 NaN          J1602           材料纸    分销-常规款  NaN    NaN      NaN   NaN
#  16 NaN          N0836       32K卡通软抄    分销-常规款  NaN    NaN      NaN   NaN
#  17 NaN          J1601           材料纸    分销-常规款  NaN    NaN      NaN   NaN
#  18 NaN           6128         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  19 NaN       DWXA540N       无线胶装办公本  分销-锐意-账本  NaN    NaN      NaN   NaN
#  20 NaN   EJYBB520-红田字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  21 NaN           6120         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  22 NaN  DL-1660C-青春故事          道林软抄  分销-锐意-账本  NaN    NaN      NaN   NaN
#  23 NaN        EHBB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
#  24 NaN        EHLB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
#  25 NaN     EWTHA430NA           图画本    分销-常规款  NaN    NaN      NaN   NaN
#  26 NaN           6206         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  27 NaN           6208         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  28 NaN        EHYA560  A5活页芯（左侧20孔）    分销-常规款  NaN    NaN      NaN   NaN
#  29 NaN           1602           材料纸  分销-锐意-账本  NaN    NaN      NaN   NaN
#  30 NaN           6107         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  31 NaN           6123         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  32 NaN           6211         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  33 NaN           6215         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  34 NaN        EHDA560  A5活页芯（左侧20孔）    分销-常规款  NaN    NaN      NaN   NaN
#  35 NaN        EHDB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
#  36 NaN       EHKNB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
#  37 NaN           6003         订本式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  38 NaN           6005         订本式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  39 NaN           6116         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
#  40 NaN       EHJCB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
#  41 NaN        EHYB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
#  42 NaN          N0816       32K卡通软抄    分销-常规款  NaN    NaN      NaN   NaN
#  43 NaN      RJL-16200        16K胶套本    分销-常规款  NaN    NaN      NaN   NaN
#  44 NaN       RJL-3280        32K胶套本    分销-常规款  NaN    NaN      NaN   NaN
#
#                        商品简称                  商品名称  ...  其它价格2  其它价格3  其它价格4  \
#  0                     B6-1         16K30页牛皮铁钉草稿本  ...    NaN    NaN    NaN
#  1                C1-5/C3-7         硬笔书法纸-红米字格20张  ...    NaN    NaN    NaN
#  2                     B6-5       16K30页牛皮胶装分区草稿本  ...    NaN    NaN    NaN
#  3   A1-50-1/A4-9-2/A1-50-2              三栏式明细分类账  ...    NaN    NaN    NaN
#  4                     C3-4        英语定位书写纸-初级版50张  ...    NaN    NaN    NaN
#  5                     B5-5         16K30页牛皮胶装草稿本  ...    NaN    NaN    NaN
#  6                    D2-25         D32K40型卡面学生日记  ...    NaN    NaN    NaN
#  7                  A1-48-2             16K材料明细账本  ...    NaN    NaN    NaN
#  8                     C1-8     16K60型精品缝线乐谱本 36P  ...    NaN    NaN    NaN
#  9                     C1-7         硬笔书法纸-绿米字格20张  ...    NaN    NaN    NaN
#  10                   D2-13     A560页活页芯（空白）(60P)  ...    NaN    NaN    NaN
#  11                   B7-14                  记账凭证  ...    NaN    NaN    NaN
#  12                 A1-33-2     48K工商服务业收据（三联、多栏）  ...    NaN    NaN    NaN
#  13                    C3-1        英语定位书写纸-高级版50张  ...    NaN    NaN    NaN
#  14                    C1-6         硬笔书法纸-绿田字格20张  ...    NaN    NaN    NaN
#  15                  A1-7-1               简装单行材料纸  ...    NaN    NaN    NaN
#  16                   D2-19         D32K80型卡面学生日记  ...    NaN    NaN    NaN
#  17                  A1-8-1               简装双行材料纸  ...    NaN    NaN    NaN
#  18                 A1-43-2                 实物出入账  ...    NaN    NaN    NaN
#  19                   B3-13       A540张牛卡无线胶装办公软抄  ...    NaN    NaN    NaN
#  20                    C1-5         硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN
#  21                 A1-47-3               商品明细分类账  ...    NaN    NaN    NaN
#  22                      待定   16K60型精品道林卡面软抄C2402  ...    NaN    NaN    NaN
#  23                    D3-9     B560页活页芯（空白）(60P)  ...    NaN    NaN    NaN
#  24                   D3-21     B560页活页芯（线条）(60P)  ...    NaN    NaN    NaN
#  25                    B1-2  A4-30张无线胶装牛卡图画本（30p)  ...    NaN    NaN    NaN
#  26                 A1-42-3              三栏式明细分类账  ...    NaN    NaN    NaN
#  27                 A1-43-3               商品明细分类账  ...    NaN    NaN    NaN
#  28                   D5-26     A560页活页芯（英语）(60P)  ...    NaN    NaN    NaN
#  29                 A2-16-2                 单行材料纸  ...    NaN    NaN    NaN
#  30                 A1-41-2             固定资产明细分类账  ...    NaN    NaN    NaN
#  31                 A1-42-2              进销存明细分类账  ...    NaN    NaN    NaN
#  32                 A1-51-3                  总分类账  ...    NaN    NaN    NaN
#  33                 A1-44-3                 现金日记账  ...    NaN    NaN    NaN
#  34                   D2-12     A560页活页芯（点阵）(60P)  ...    NaN    NaN    NaN
#  35                   D4-20     B560页活页芯（点阵）(60P)  ...    NaN    NaN    NaN
#  36                   D3-18    B560页活页芯（康奈尔）(60P)  ...    NaN    NaN    NaN
#  37                 A1-50-1               银行存款日记账  ...    NaN    NaN    NaN
#  38                 A1-49-1                 现金日记账  ...    NaN    NaN    NaN
#  39                 A1-46-2             16栏式明细分类账  ...    NaN    NaN    NaN
#  40                   D4-22     B560页活页芯（纠错）(60P)  ...    NaN    NaN    NaN
#  41                   D3-19     B560页活页芯（英语）(60P)  ...    NaN    NaN    NaN
#  42                   D2-22         D32K60型卡面学生日记  ...    NaN    NaN    NaN
#  43                      待定       16K200型胶套本 156P  ...    NaN    NaN    NaN
#  44                   B1-20         32K80型胶套本 60P  ...    NaN    NaN    NaN
#
#      其它价格5  其它属性1  其它属性2  其它属性3         其它属性4     其它属性5  基本售价
#  0     NaN  240.0  10本/包     收缩  6.936281e+12       NaN  0.68
#  1     NaN    NaN  10本/包     收缩           NaN       NaN  0.36
#  2     NaN  240.0  10本/包     收缩  6.936281e+12       NaN  0.85
#  3     NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  4     NaN    NaN     1本     套袋           NaN       NaN  0.97
#  5     NaN  240.0  10本/包     收缩  6.936281e+12       NaN  0.85
#  6     NaN  640.0     10    NaN  6.936281e+12       NaN  0.38
#  7     NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  8     NaN  160.0     10    NaN  6.936281e+12       NaN  1.58
#  9     NaN    NaN  10本/包     收缩           NaN       NaN  0.36
#  10    NaN  220.0   1本/包     套袋  6.936281e+12       NaN  0.80
#  11    NaN  270.0      5    NaN  6.936281e+12  35开*100型  1.48
#  12    NaN  360.0     10    NaN  6.936281e+12   48开*75型  1.33
#  13    NaN    NaN     1本     套袋           NaN       NaN  0.97
#  14    NaN    NaN  10本/包     收缩           NaN       NaN  0.36
#  15    NaN  270.0      3    NaN  6.936281e+12       NaN  0.86
#  16    NaN  360.0     10    NaN  6.936281e+12       NaN  0.66
#  17    NaN  270.0      3    NaN  6.936281e+12       NaN  0.86
#  18    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  19    NaN  240.0     10    NaN  6.936281e+12       NaN  1.26
#  20    NaN    NaN  10本/包     收缩           NaN       NaN  0.36
#  21    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  22    NaN  160.0     10    NaN  6.936281e+12       NaN  1.66
#  23    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
#  24    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
#  25    NaN  160.0  10本/包     收缩  6.936281e+12       NaN  1.20
#  26    NaN   50.0      1    NaN  6.936281e+12  25开*100型  6.24
#  27    NaN   50.0      1    NaN  6.936281e+12  25开*100型  6.24
#  28    NaN  220.0   1本/包     套袋  6.936281e+12       NaN  0.80
#  29    NaN  220.0      2    NaN  6.936281e+12   16开*40型  1.33
#  30    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  31    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  32    NaN   70.0      1    NaN  6.936281e+12   25开*50型  4.61
#  33    NaN   70.0      1    NaN  6.936281e+12   25开*50型  4.61
#  34    NaN  220.0   1本/包     套袋  6.936281e+12       NaN  0.80
#  35    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
#  36    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
#  37    NaN   60.0      1    NaN  6.936281e+12   16开*48型  6.24
#  38    NaN   60.0      1    NaN  6.936281e+12   16开*48型  6.24
#  39    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
#  40    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
#  41    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
#  42    NaN  480.0     10    NaN  6.936281e+12       NaN  0.54
#  43    NaN   60.0      5    NaN  6.936281e+12       NaN  5.47
#  44    NaN  160.0     10    NaN  6.936281e+12       NaN  1.80
#
#  [45 rows x 52 columns],
#       图片          商品编码            款式编码      商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
#  0   NaN        BQ1640             草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  1   NaN       CGN1640             草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  2   NaN   EXLA580NB-C            勤问系列       NaN  NaN    NaN      NaN   NaN
#  3   NaN   EFLB560K-盐系  马卡龙缝线本及甜系盐系缝线本    分销-常规款  NaN    NaN      NaN   NaN
#  4   NaN  EJYBB520-红田字       硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  ..   ..           ...             ...       ...  ...    ...      ...   ...
#  263 NaN     EXA4PP-紫色    A4五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  264 NaN     EXA4PP-绿色    A4五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  265 NaN     EXB5PP-粉色    B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  266 NaN     EXB5PP-蓝色    B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  267 NaN  SMA440S-野生探险    SMA440S-野生探险  分销-锐意-账本  NaN    NaN      NaN   NaN
#
#        商品简称                   商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5     其它属性1  \
#  0     B5-4  16K40型白色草稿本（便签本）/白胶上翻  ...    NaN    NaN    NaN    NaN  280/240t
#  1     B6-3       16K40型牛皮草稿本/铁钉上翻  ...    NaN    NaN    NaN    NaN  280/200t
#  2     E2-4      A5-80 型牛卡线环横线本-侧翻  ...    NaN    NaN    NaN    NaN       NaN
#  3     D5-8      B560型卡面缝线本（盐系）40p  ...    NaN    NaN    NaN    NaN       160
#  4     C1-5          硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN    NaN       NaN
#  ..     ...                    ...  ...    ...    ...    ...    ...       ...
#  263     E区              EXA4PP-紫色  ...    NaN    NaN    NaN    NaN       NaN
#  264   E3-6              EXA4PP-绿色  ...    NaN    NaN    NaN    NaN       NaN
#  265   E3-8              EXB5PP-粉色  ...    NaN    NaN    NaN    NaN       NaN
#  266   E3-8              EXB5PP-蓝色  ...    NaN    NaN    NaN    NaN       NaN
#  267  B5-10         A440型精品卡面手提素描本  ...    NaN    NaN    NaN    NaN        60
#
#       其它属性2  其它属性3         其它属性4  其它属性5  基本售价
#  0    10本/包     收缩  6.936281e+12    NaN  0.58
#  1    10本/包     收缩  6.936281e+12    NaN  0.58
#  2    4 本/包     收缩           NaN    NaN  1.10
#  3     4本/包     收缩  6.936281e+12    NaN  1.30
#  4    10本/包     收缩           NaN    NaN  0.36
#  ..     ...    ...           ...    ...   ...
#  263    NaN    NaN           NaN    NaN  2.01
#  264    NaN    NaN           NaN    NaN  2.01
#  265    NaN    NaN           NaN    NaN  1.66
#  266    NaN    NaN           NaN    NaN  1.66
#  267      1    NaN  6.936281e+12    NaN  3.49
#
#  [268 rows x 52 columns],
#     图片   商品编码            款式编码    商品标签  供应商  供应商款号  供应商商品编码  颜色规格   商品简称  \
#  0 NaN  N0795  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN  D6-15
#  1 NaN  N0796  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN  D6-14
#
#               商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5  其它属性1     其它属性2  其它属性3  \
#  0   32K60型牛卡缝线练习本  ...    NaN    NaN    NaN    NaN  320.0  5本/10本/包     收缩
#  1  32K60型牛卡缝线读书笔记  ...    NaN    NaN    NaN    NaN  320.0  5本/10本/包     收缩
#
#            其它属性4  其它属性5  基本售价
#  0  6.936281e+12    NaN  0.55
#  1  6.936281e+12    NaN  0.55
#
#  [2 rows x 52 columns],
#       图片          商品编码          款式编码      商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
#  0   NaN  EJYBB520-红米字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  1   NaN  EJYBB520-红田字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  2   NaN        BQ1640           草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  3   NaN       CGN1640           草稿本    分销-常规款  NaN    NaN      NaN   NaN
#  4   NaN  EJYBB520-绿田字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
#  ..   ..           ...           ...       ...  ...    ...      ...   ...
#  359 NaN     EXA4PP-绿色  A4五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  360 NaN     EXB5PP-粉色  B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  361 NaN     EXB5PP-蓝色  B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
#  362 NaN         N0654          办公硬抄    分销-常规款  NaN    NaN      NaN   NaN
#  363 NaN    SMA340S-寂静         上翻素描本  分销-锐意-账本  NaN    NaN      NaN   NaN
#
#            商品简称                   商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5  \
#  0    C1-5/C3-7          硬笔书法纸-红米字格20张  ...    NaN    NaN    NaN    NaN
#  1         C1-5          硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN    NaN
#  2         B5-4  16K40型白色草稿本（便签本）/白胶上翻  ...    NaN    NaN    NaN    NaN
#  3         B6-3       16K40型牛皮草稿本/铁钉上翻  ...    NaN    NaN    NaN    NaN
#  4         C1-6          硬笔书法纸-绿田字格20张  ...    NaN    NaN    NaN    NaN
#  ..         ...                    ...  ...    ...    ...    ...    ...
#  359       E3-6              EXA4PP-绿色  ...    NaN    NaN    NaN    NaN
#  360       E3-8              EXB5PP-粉色  ...    NaN    NaN    NaN    NaN
#  361       E3-8              EXB5PP-蓝色  ...    NaN    NaN    NaN    NaN
#  362       D4-3           D32K200型办公硬抄  ...    NaN    NaN    NaN    NaN
#  363      B7-11   A3-40型精品卡面带手提素描本（上翻）  ...    NaN    NaN    NaN    NaN
#
#          其它属性1  其它属性2  其它属性3         其它属性4  其它属性5  基本售价
#  0         NaN  10本/包     收缩           NaN    NaN  0.36
#  1         NaN  10本/包     收缩           NaN    NaN  0.36
#  2    280/240t  10本/包     收缩  6.936281e+12    NaN  0.58
#  3    280/200t  10本/包     收缩  6.936281e+12    NaN  0.58
#  4         NaN  10本/包     收缩           NaN    NaN  0.36
#  ..        ...    ...    ...           ...    ...   ...
#  359       NaN    NaN    NaN           NaN    NaN  2.01
#  360       NaN    NaN    NaN           NaN    NaN  1.66
#  361       NaN    NaN    NaN           NaN    NaN  1.66
#  362        84      1    NaN  6.936281e+12    NaN  3.52
#  363        30      1    NaN  6.936281e+12    NaN  6.51
#
#  [364 rows x 52 columns]]

# %%
pingtais
# Out:
# ['京东', '拼多多', '淘宝', '阿里巴巴', '京东荣佳', '全平台']

# %%
zhong = []
for pingtai in pingtais:
    
    df = pingtai_df.get(pingtai)
    print(pingtai,df)
    df.insert(0,'pingtai',pingtai)
    # print(df)
    zhong.append(df)
    df = pd.DataFrame()
df_zhong = pd.concat(zhong)
df_zhong
# Out:
# 京东     图片             商品编码            款式编码    商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
# 0  NaN     EJYBB520-红米字       硬笔书法纸及定位纸  分销-常规款  NaN    NaN      NaN   NaN
# 1  NaN     EJYBB520-绿田字       硬笔书法纸及定位纸  分销-常规款  NaN    NaN      NaN   NaN
# 2  NaN       EFZW3260NA  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
# 3  NaN            N0795  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
# 4  NaN            N0792  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
# 5  NaN     EJYBB520-红田字       硬笔书法纸及定位纸  分销-常规款  NaN    NaN      NaN   NaN
# 6  NaN            N0793  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
# 7  NaN    EFC3260N（方格）A  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
# 8  NaN     EJYBB520-绿米字       硬笔书法纸及定位纸  分销-常规款  NaN    NaN      NaN   NaN
# 9  NaN        EFHP3260N  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
# 10 NaN            N0821         32K办公软抄  分销-常规款  NaN    NaN      NaN   NaN
# 11 NaN            N0796  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
# 12 NaN  EFSX3260N（双竖线）A  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
# 13 NaN            N0823         32K办公软抄  分销-常规款  NaN    NaN      NaN   NaN
# 14 NaN            N0791  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN
# 15 NaN            N0826         32K办公软抄  分销-常规款  NaN    NaN      NaN   NaN
#
#            商品简称                     商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5  \
# 0     C1-5/C3-7            硬笔书法纸-红米字格20张  ...    NaN    NaN    NaN    NaN
# 1          C1-6            硬笔书法纸-绿田字格20张  ...    NaN    NaN    NaN    NaN
# 2          D6-4       32K60型牛卡缝线作文簿(36P)  ...    NaN    NaN    NaN    NaN
# 3         D6-15            32K60型牛卡缝线练习本  ...    NaN    NaN    NaN    NaN
# 4         D5-13          32K60型牛卡缝线作业登记本  ...    NaN    NaN    NaN    NaN
# 5          C1-5            硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN    NaN
# 6         D6-13            32K60型牛卡缝线英语本  ...    NaN    NaN    NaN    NaN
# 7         D6-10   32K60型牛卡缝线语文簿（方格）(36P)  ...    NaN    NaN    NaN    NaN
# 8          C1-7            硬笔书法纸-绿米字格20张  ...    NaN    NaN    NaN    NaN
# 9         D5-11     32K60型牛卡缝线汉语拼音本(36P)  ...    NaN    NaN    NaN    NaN
# 10        D2-17            D32K40型卡面办公软抄  ...    NaN    NaN    NaN    NaN
# 11        D6-14           32K60型牛卡缝线读书笔记  ...    NaN    NaN    NaN    NaN
# 12  D6-11/D6-12  32K60型牛卡缝线数学簿（双竖线）(36P)  ...    NaN    NaN    NaN    NaN
# 13        D2-20            D32K80型卡面办公软抄  ...    NaN    NaN    NaN    NaN
# 14        D5-14           32K60型牛卡缝线学生日记  ...    NaN    NaN    NaN    NaN
# 15        D2-18           D32K150型卡面办公软抄  ...    NaN    NaN    NaN    NaN
#
#        其它属性1     其它属性2  其它属性3         其它属性4  其它属性5  基本售价
# 0        NaN     10本/包     收缩           NaN    NaN  0.36
# 1        NaN     10本/包     收缩           NaN    NaN  0.36
# 2   320/360t      5本/包     收缩  6.936281e+12    NaN  0.55
# 3        320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
# 4        320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
# 5        NaN     10本/包     收缩           NaN    NaN  0.36
# 6        320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
# 7   320/360t      5本/包     收缩  6.936281e+12    NaN  0.55
# 8        NaN     10本/包     收缩           NaN    NaN  0.36
# 9   320/360t      5本/包     收缩  6.936281e+12    NaN  0.55
# 10       560        10    NaN  6.936281e+12    NaN  0.39
# 11       320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
# 12  320/360t      5本/包     收缩  6.936281e+12    NaN  0.55
# 13       320        10    NaN  6.936281e+12    NaN  0.70
# 14       320  5本/10本/包     收缩  6.936281e+12    NaN  0.55
# 15       180         5    NaN  6.936281e+12    NaN  1.39
#
# [16 rows x 52 columns]
# 拼多多      图片          商品编码       款式编码      商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
# 0   NaN  EJYBB520-红米字  硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# 1   NaN  EJYBB520-红田字  硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# 2   NaN  EJYBB520-绿田字  硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# 3   NaN  EJYBB520-绿米字  硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# 4   NaN     EJZBA5128    牛皮胶装直背本    分销-常规款  NaN    NaN      NaN   NaN
# ..   ..           ...        ...       ...  ...    ...      ...   ...
# 199 NaN         N0654       办公硬抄    分销-常规款  NaN    NaN      NaN   NaN
# 200 NaN         N0817    32K卡通软抄    分销-常规款  NaN    NaN      NaN   NaN
# 201 NaN     RJL-16200     16K胶套本    分销-常规款  NaN    NaN      NaN   NaN
# 202 NaN      RJL-3280     32K胶套本    分销-常规款  NaN    NaN      NaN   NaN
# 203 NaN    SMA340S-寂静      上翻素描本  分销-锐意-账本  NaN    NaN      NaN   NaN
#
#                  商品简称                   商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5  \
# 0           C1-5/C3-7          硬笔书法纸-红米字格20张  ...    NaN    NaN    NaN    NaN
# 1                C1-5          硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN    NaN
# 2                C1-6          硬笔书法纸-绿田字格20张  ...    NaN    NaN    NaN    NaN
# 3                C1-7          硬笔书法纸-绿米字格20张  ...    NaN    NaN    NaN    NaN
# 4    D8-16/D7-16/C3-8  A5128页胶装直背本（空白）（128p）  ...    NaN    NaN    NaN    NaN
# ..                ...                    ...  ...    ...    ...    ...    ...
# 199              D4-3           D32K200型办公硬抄  ...    NaN    NaN    NaN    NaN
# 200             D2-14           D32K60型卡面英语本  ...    NaN    NaN    NaN    NaN
# 201                待定        16K200型胶套本 156P  ...    NaN    NaN    NaN    NaN
# 202             B1-20          32K80型胶套本 60P  ...    NaN    NaN    NaN    NaN
# 203             B7-11   A3-40型精品卡面带手提素描本（上翻）  ...    NaN    NaN    NaN    NaN
#
#      其它属性1  其它属性2  其它属性3         其它属性4  其它属性5  基本售价
# 0      NaN  10本/包     收缩           NaN    NaN  0.36
# 1      NaN  10本/包     收缩           NaN    NaN  0.36
# 2      NaN  10本/包     收缩           NaN    NaN  0.36
# 3      NaN  10本/包     收缩           NaN    NaN  0.36
# 4      120   1本/包     收缩  6.936281e+12    NaN  1.75
# ..     ...    ...    ...           ...    ...   ...
# 199     84      1    NaN  6.936281e+12    NaN  3.52
# 200    480     10    NaN  6.936281e+12    NaN  0.54
# 201     60      5    NaN  6.936281e+12    NaN  5.47
# 202    160     10    NaN  6.936281e+12    NaN  1.80
# 203     30      1    NaN  6.936281e+12    NaN  6.51
#
# [204 rows x 52 columns]
# 淘宝     图片           商品编码          款式编码      商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
# 0  NaN      ETCG1630N           草稿本    分销-常规款  NaN    NaN      NaN   NaN
# 1  NaN   EJYBB520-红米字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# 2  NaN  EJCG1630N（分区）           草稿本    分销-常规款  NaN    NaN      NaN   NaN
# 3  NaN           6106         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
# 4  NaN    EJDWB550-英初     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# 5  NaN      EJCG1630N           草稿本    分销-常规款  NaN    NaN      NaN   NaN
# 6  NaN          N0835       32K卡通软抄    分销-常规款  NaN    NaN      NaN   NaN
# 7  NaN           6124         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
# 8  NaN        FYP1660        牛皮缝线科目  分销-锐意-账本  NaN    NaN      NaN   NaN
# 9  NaN   EJYBB520-绿米字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# 10 NaN        EHBA560  A5活页芯（左侧20孔）    分销-常规款  NaN    NaN      NaN   NaN
# 11 NaN           2001            凭证  分销-锐意-账本  NaN    NaN      NaN   NaN
# 12 NaN           5139      无碳复写多联单据  分销-锐意-账本  NaN    NaN      NaN   NaN
# 13 NaN    EJDWB550-英高     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# 14 NaN   EJYBB520-绿田字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# 15 NaN          J1602           材料纸    分销-常规款  NaN    NaN      NaN   NaN
# 16 NaN          N0836       32K卡通软抄    分销-常规款  NaN    NaN      NaN   NaN
# 17 NaN          J1601           材料纸    分销-常规款  NaN    NaN      NaN   NaN
# 18 NaN           6128         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
# 19 NaN       DWXA540N       无线胶装办公本  分销-锐意-账本  NaN    NaN      NaN   NaN
# 20 NaN   EJYBB520-红田字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# 21 NaN           6120         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
# 22 NaN  DL-1660C-青春故事          道林软抄  分销-锐意-账本  NaN    NaN      NaN   NaN
# 23 NaN        EHBB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
# 24 NaN        EHLB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
# 25 NaN     EWTHA430NA           图画本    分销-常规款  NaN    NaN      NaN   NaN
# 26 NaN           6206         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
# 27 NaN           6208         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
# 28 NaN        EHYA560  A5活页芯（左侧20孔）    分销-常规款  NaN    NaN      NaN   NaN
# 29 NaN           1602           材料纸  分销-锐意-账本  NaN    NaN      NaN   NaN
# 30 NaN           6107         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
# 31 NaN           6123         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
# 32 NaN           6211         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
# 33 NaN           6215         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
# 34 NaN        EHDA560  A5活页芯（左侧20孔）    分销-常规款  NaN    NaN      NaN   NaN
# 35 NaN        EHDB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
# 36 NaN       EHKNB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
# 37 NaN           6003         订本式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
# 38 NaN           6005         订本式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
# 39 NaN           6116         活页式账簿  分销-锐意-账本  NaN    NaN      NaN   NaN
# 40 NaN       EHJCB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
# 41 NaN        EHYB560  B5活页芯（左侧26孔）    分销-常规款  NaN    NaN      NaN   NaN
# 42 NaN          N0816       32K卡通软抄    分销-常规款  NaN    NaN      NaN   NaN
# 43 NaN      RJL-16200        16K胶套本    分销-常规款  NaN    NaN      NaN   NaN
# 44 NaN       RJL-3280        32K胶套本    分销-常规款  NaN    NaN      NaN   NaN
#
#                       商品简称                  商品名称  ...  其它价格2  其它价格3  其它价格4  \
# 0                     B6-1         16K30页牛皮铁钉草稿本  ...    NaN    NaN    NaN
# 1                C1-5/C3-7         硬笔书法纸-红米字格20张  ...    NaN    NaN    NaN
# 2                     B6-5       16K30页牛皮胶装分区草稿本  ...    NaN    NaN    NaN
# 3   A1-50-1/A4-9-2/A1-50-2              三栏式明细分类账  ...    NaN    NaN    NaN
# 4                     C3-4        英语定位书写纸-初级版50张  ...    NaN    NaN    NaN
# 5                     B5-5         16K30页牛皮胶装草稿本  ...    NaN    NaN    NaN
# 6                    D2-25         D32K40型卡面学生日记  ...    NaN    NaN    NaN
# 7                  A1-48-2             16K材料明细账本  ...    NaN    NaN    NaN
# 8                     C1-8     16K60型精品缝线乐谱本 36P  ...    NaN    NaN    NaN
# 9                     C1-7         硬笔书法纸-绿米字格20张  ...    NaN    NaN    NaN
# 10                   D2-13     A560页活页芯（空白）(60P)  ...    NaN    NaN    NaN
# 11                   B7-14                  记账凭证  ...    NaN    NaN    NaN
# 12                 A1-33-2     48K工商服务业收据（三联、多栏）  ...    NaN    NaN    NaN
# 13                    C3-1        英语定位书写纸-高级版50张  ...    NaN    NaN    NaN
# 14                    C1-6         硬笔书法纸-绿田字格20张  ...    NaN    NaN    NaN
# 15                  A1-7-1               简装单行材料纸  ...    NaN    NaN    NaN
# 16                   D2-19         D32K80型卡面学生日记  ...    NaN    NaN    NaN
# 17                  A1-8-1               简装双行材料纸  ...    NaN    NaN    NaN
# 18                 A1-43-2                 实物出入账  ...    NaN    NaN    NaN
# 19                   B3-13       A540张牛卡无线胶装办公软抄  ...    NaN    NaN    NaN
# 20                    C1-5         硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN
# 21                 A1-47-3               商品明细分类账  ...    NaN    NaN    NaN
# 22                      待定   16K60型精品道林卡面软抄C2402  ...    NaN    NaN    NaN
# 23                    D3-9     B560页活页芯（空白）(60P)  ...    NaN    NaN    NaN
# 24                   D3-21     B560页活页芯（线条）(60P)  ...    NaN    NaN    NaN
# 25                    B1-2  A4-30张无线胶装牛卡图画本（30p)  ...    NaN    NaN    NaN
# 26                 A1-42-3              三栏式明细分类账  ...    NaN    NaN    NaN
# 27                 A1-43-3               商品明细分类账  ...    NaN    NaN    NaN
# 28                   D5-26     A560页活页芯（英语）(60P)  ...    NaN    NaN    NaN
# 29                 A2-16-2                 单行材料纸  ...    NaN    NaN    NaN
# 30                 A1-41-2             固定资产明细分类账  ...    NaN    NaN    NaN
# 31                 A1-42-2              进销存明细分类账  ...    NaN    NaN    NaN
# 32                 A1-51-3                  总分类账  ...    NaN    NaN    NaN
# 33                 A1-44-3                 现金日记账  ...    NaN    NaN    NaN
# 34                   D2-12     A560页活页芯（点阵）(60P)  ...    NaN    NaN    NaN
# 35                   D4-20     B560页活页芯（点阵）(60P)  ...    NaN    NaN    NaN
# 36                   D3-18    B560页活页芯（康奈尔）(60P)  ...    NaN    NaN    NaN
# 37                 A1-50-1               银行存款日记账  ...    NaN    NaN    NaN
# 38                 A1-49-1                 现金日记账  ...    NaN    NaN    NaN
# 39                 A1-46-2             16栏式明细分类账  ...    NaN    NaN    NaN
# 40                   D4-22     B560页活页芯（纠错）(60P)  ...    NaN    NaN    NaN
# 41                   D3-19     B560页活页芯（英语）(60P)  ...    NaN    NaN    NaN
# 42                   D2-22         D32K60型卡面学生日记  ...    NaN    NaN    NaN
# 43                      待定       16K200型胶套本 156P  ...    NaN    NaN    NaN
# 44                   B1-20         32K80型胶套本 60P  ...    NaN    NaN    NaN
#
#     其它价格5  其它属性1  其它属性2  其它属性3         其它属性4     其它属性5  基本售价
# 0     NaN  240.0  10本/包     收缩  6.936281e+12       NaN  0.68
# 1     NaN    NaN  10本/包     收缩           NaN       NaN  0.36
# 2     NaN  240.0  10本/包     收缩  6.936281e+12       NaN  0.85
# 3     NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
# 4     NaN    NaN     1本     套袋           NaN       NaN  0.97
# 5     NaN  240.0  10本/包     收缩  6.936281e+12       NaN  0.85
# 6     NaN  640.0     10    NaN  6.936281e+12       NaN  0.38
# 7     NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
# 8     NaN  160.0     10    NaN  6.936281e+12       NaN  1.58
# 9     NaN    NaN  10本/包     收缩           NaN       NaN  0.36
# 10    NaN  220.0   1本/包     套袋  6.936281e+12       NaN  0.80
# 11    NaN  270.0      5    NaN  6.936281e+12  35开*100型  1.48
# 12    NaN  360.0     10    NaN  6.936281e+12   48开*75型  1.33
# 13    NaN    NaN     1本     套袋           NaN       NaN  0.97
# 14    NaN    NaN  10本/包     收缩           NaN       NaN  0.36
# 15    NaN  270.0      3    NaN  6.936281e+12       NaN  0.86
# 16    NaN  360.0     10    NaN  6.936281e+12       NaN  0.66
# 17    NaN  270.0      3    NaN  6.936281e+12       NaN  0.86
# 18    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
# 19    NaN  240.0     10    NaN  6.936281e+12       NaN  1.26
# 20    NaN    NaN  10本/包     收缩           NaN       NaN  0.36
# 21    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
# 22    NaN  160.0     10    NaN  6.936281e+12       NaN  1.66
# 23    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
# 24    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
# 25    NaN  160.0  10本/包     收缩  6.936281e+12       NaN  1.20
# 26    NaN   50.0      1    NaN  6.936281e+12  25开*100型  6.24
# 27    NaN   50.0      1    NaN  6.936281e+12  25开*100型  6.24
# 28    NaN  220.0   1本/包     套袋  6.936281e+12       NaN  0.80
# 29    NaN  220.0      2    NaN  6.936281e+12   16开*40型  1.33
# 30    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
# 31    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
# 32    NaN   70.0      1    NaN  6.936281e+12   25开*50型  4.61
# 33    NaN   70.0      1    NaN  6.936281e+12   25开*50型  4.61
# 34    NaN  220.0   1本/包     套袋  6.936281e+12       NaN  0.80
# 35    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
# 36    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
# 37    NaN   60.0      1    NaN  6.936281e+12   16开*48型  6.24
# 38    NaN   60.0      1    NaN  6.936281e+12   16开*48型  6.24
# 39    NaN   40.0      1    NaN  6.936281e+12  16开*100型  8.86
# 40    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
# 41    NaN  132.0   1本/包     套袋  6.936281e+12       NaN  1.32
# 42    NaN  480.0     10    NaN  6.936281e+12       NaN  0.54
# 43    NaN   60.0      5    NaN  6.936281e+12       NaN  5.47
# 44    NaN  160.0     10    NaN  6.936281e+12       NaN  1.80
#
# [45 rows x 52 columns]
# 阿里巴巴      图片          商品编码            款式编码      商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
# 0   NaN        BQ1640             草稿本    分销-常规款  NaN    NaN      NaN   NaN
# 1   NaN       CGN1640             草稿本    分销-常规款  NaN    NaN      NaN   NaN
# 2   NaN   EXLA580NB-C            勤问系列       NaN  NaN    NaN      NaN   NaN
# 3   NaN   EFLB560K-盐系  马卡龙缝线本及甜系盐系缝线本    分销-常规款  NaN    NaN      NaN   NaN
# 4   NaN  EJYBB520-红田字       硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# ..   ..           ...             ...       ...  ...    ...      ...   ...
# 263 NaN     EXA4PP-紫色    A4五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
# 264 NaN     EXA4PP-绿色    A4五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
# 265 NaN     EXB5PP-粉色    B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
# 266 NaN     EXB5PP-蓝色    B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
# 267 NaN  SMA440S-野生探险    SMA440S-野生探险  分销-锐意-账本  NaN    NaN      NaN   NaN
#
#       商品简称                   商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5     其它属性1  \
# 0     B5-4  16K40型白色草稿本（便签本）/白胶上翻  ...    NaN    NaN    NaN    NaN  280/240t
# 1     B6-3       16K40型牛皮草稿本/铁钉上翻  ...    NaN    NaN    NaN    NaN  280/200t
# 2     E2-4      A5-80 型牛卡线环横线本-侧翻  ...    NaN    NaN    NaN    NaN       NaN
# 3     D5-8      B560型卡面缝线本（盐系）40p  ...    NaN    NaN    NaN    NaN       160
# 4     C1-5          硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN    NaN       NaN
# ..     ...                    ...  ...    ...    ...    ...    ...       ...
# 263     E区              EXA4PP-紫色  ...    NaN    NaN    NaN    NaN       NaN
# 264   E3-6              EXA4PP-绿色  ...    NaN    NaN    NaN    NaN       NaN
# 265   E3-8              EXB5PP-粉色  ...    NaN    NaN    NaN    NaN       NaN
# 266   E3-8              EXB5PP-蓝色  ...    NaN    NaN    NaN    NaN       NaN
# 267  B5-10         A440型精品卡面手提素描本  ...    NaN    NaN    NaN    NaN        60
#
#      其它属性2  其它属性3         其它属性4  其它属性5  基本售价
# 0    10本/包     收缩  6.936281e+12    NaN  0.58
# 1    10本/包     收缩  6.936281e+12    NaN  0.58
# 2    4 本/包     收缩           NaN    NaN  1.10
# 3     4本/包     收缩  6.936281e+12    NaN  1.30
# 4    10本/包     收缩           NaN    NaN  0.36
# ..     ...    ...           ...    ...   ...
# 263    NaN    NaN           NaN    NaN  2.01
# 264    NaN    NaN           NaN    NaN  2.01
# 265    NaN    NaN           NaN    NaN  1.66
# 266    NaN    NaN           NaN    NaN  1.66
# 267      1    NaN  6.936281e+12    NaN  3.49
#
# [268 rows x 52 columns]
# 京东荣佳    图片   商品编码            款式编码    商品标签  供应商  供应商款号  供应商商品编码  颜色规格   商品简称  \
# 0 NaN  N0795  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN  D6-15
# 1 NaN  N0796  32K牛卡缝线本（79系列）  分销-常规款  NaN    NaN      NaN   NaN  D6-14
#
#              商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5  其它属性1     其它属性2  其它属性3  \
# 0   32K60型牛卡缝线练习本  ...    NaN    NaN    NaN    NaN  320.0  5本/10本/包     收缩
# 1  32K60型牛卡缝线读书笔记  ...    NaN    NaN    NaN    NaN  320.0  5本/10本/包     收缩
#
#           其它属性4  其它属性5  基本售价
# 0  6.936281e+12    NaN  0.55
# 1  6.936281e+12    NaN  0.55
#
# [2 rows x 52 columns]
# 全平台      图片          商品编码          款式编码      商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
# 0   NaN  EJYBB520-红米字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# 1   NaN  EJYBB520-红田字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# 2   NaN        BQ1640           草稿本    分销-常规款  NaN    NaN      NaN   NaN
# 3   NaN       CGN1640           草稿本    分销-常规款  NaN    NaN      NaN   NaN
# 4   NaN  EJYBB520-绿田字     硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN   NaN
# ..   ..           ...           ...       ...  ...    ...      ...   ...
# 359 NaN     EXA4PP-绿色  A4五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
# 360 NaN     EXB5PP-粉色  B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
# 361 NaN     EXB5PP-蓝色  B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN   NaN
# 362 NaN         N0654          办公硬抄    分销-常规款  NaN    NaN      NaN   NaN
# 363 NaN    SMA340S-寂静         上翻素描本  分销-锐意-账本  NaN    NaN      NaN   NaN
#
#           商品简称                   商品名称  ...  其它价格2  其它价格3  其它价格4  其它价格5  \
# 0    C1-5/C3-7          硬笔书法纸-红米字格20张  ...    NaN    NaN    NaN    NaN
# 1         C1-5          硬笔书法纸-红田字格20张  ...    NaN    NaN    NaN    NaN
# 2         B5-4  16K40型白色草稿本（便签本）/白胶上翻  ...    NaN    NaN    NaN    NaN
# 3         B6-3       16K40型牛皮草稿本/铁钉上翻  ...    NaN    NaN    NaN    NaN
# 4         C1-6          硬笔书法纸-绿田字格20张  ...    NaN    NaN    NaN    NaN
# ..         ...                    ...  ...    ...    ...    ...    ...
# 359       E3-6              EXA4PP-绿色  ...    NaN    NaN    NaN    NaN
# 360       E3-8              EXB5PP-粉色  ...    NaN    NaN    NaN    NaN
# 361       E3-8              EXB5PP-蓝色  ...    NaN    NaN    NaN    NaN
# 362       D4-3           D32K200型办公硬抄  ...    NaN    NaN    NaN    NaN
# 363      B7-11   A3-40型精品卡面带手提素描本（上翻）  ...    NaN    NaN    NaN    NaN
#
#         其它属性1  其它属性2  其它属性3         其它属性4  其它属性5  基本售价
# 0         NaN  10本/包     收缩           NaN    NaN  0.36
# 1         NaN  10本/包     收缩           NaN    NaN  0.36
# 2    280/240t  10本/包     收缩  6.936281e+12    NaN  0.58
# 3    280/200t  10本/包     收缩  6.936281e+12    NaN  0.58
# 4         NaN  10本/包     收缩           NaN    NaN  0.36
# ..        ...    ...    ...           ...    ...   ...
# 359       NaN    NaN    NaN           NaN    NaN  2.01
# 360       NaN    NaN    NaN           NaN    NaN  1.66
# 361       NaN    NaN    NaN           NaN    NaN  1.66
# 362        84      1    NaN  6.936281e+12    NaN  3.52
# 363        30      1    NaN  6.936281e+12    NaN  6.51
#
# [364 rows x 52 columns]
#     pingtai  图片          商品编码            款式编码      商品标签  供应商  供应商款号  供应商商品编码  \
# 0        京东 NaN  EJYBB520-红米字       硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN
# 1        京东 NaN  EJYBB520-绿田字       硬笔书法纸及定位纸    分销-常规款  NaN    NaN      NaN
# 2        京东 NaN    EFZW3260NA  32K牛卡缝线本（79系列）    分销-常规款  NaN    NaN      NaN
# 3        京东 NaN         N0795  32K牛卡缝线本（79系列）    分销-常规款  NaN    NaN      NaN
# 4        京东 NaN         N0792  32K牛卡缝线本（79系列）    分销-常规款  NaN    NaN      NaN
# ..      ...  ..           ...             ...       ...  ...    ...      ...
# 359     全平台 NaN     EXA4PP-绿色    A4五齿塑料线环封面套装       NaN  NaN    NaN      NaN
# 360     全平台 NaN     EXB5PP-粉色    B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN
# 361     全平台 NaN     EXB5PP-蓝色    B5五齿塑料线环封面套装       NaN  NaN    NaN      NaN
# 362     全平台 NaN         N0654            办公硬抄    分销-常规款  NaN    NaN      NaN
# 363     全平台 NaN    SMA340S-寂静           上翻素描本  分销-锐意-账本  NaN    NaN      NaN
#
#      颜色规格       商品简称  ... 其它价格2  其它价格3  其它价格4  其它价格5     其它属性1     其它属性2  \
# 0     NaN  C1-5/C3-7  ...   NaN    NaN    NaN    NaN       NaN     10本/包
# 1     NaN       C1-6  ...   NaN    NaN    NaN    NaN       NaN     10本/包
# 2     NaN       D6-4  ...   NaN    NaN    NaN    NaN  320/360t      5本/包
# 3     NaN      D6-15  ...   NaN    NaN    NaN    NaN       320  5本/10本/包
# 4     NaN      D5-13  ...   NaN    NaN    NaN    NaN       320  5本/10本/包
# ..    ...        ...  ...   ...    ...    ...    ...       ...       ...
# 359   NaN       E3-6  ...   NaN    NaN    NaN    NaN       NaN       NaN
# 360   NaN       E3-8  ...   NaN    NaN    NaN    NaN       NaN       NaN
# 361   NaN       E3-8  ...   NaN    NaN    NaN    NaN       NaN       NaN
# 362   NaN       D4-3  ...   NaN    NaN    NaN    NaN        84         1
# 363   NaN      B7-11  ...   NaN    NaN    NaN    NaN        30         1
#
#      其它属性3         其它属性4  其它属性5  基本售价
# 0       收缩           NaN    NaN  0.36
# 1       收缩           NaN    NaN  0.36
# 2       收缩  6.936281e+12    NaN  0.55
# 3       收缩  6.936281e+12    NaN  0.55
# 4       收缩  6.936281e+12    NaN  0.55
# ..     ...           ...    ...   ...
# 359    NaN           NaN    NaN  2.01
# 360    NaN           NaN    NaN  1.66
# 361    NaN           NaN    NaN  1.66
# 362    NaN  6.936281e+12    NaN  3.52
# 363    NaN  6.936281e+12    NaN  6.51
#
# [899 rows x 53 columns]

# %%
#请输入期间
qijian = easygui.enterbox('请输入期间，"2024-01"')
df_zhong.insert(0,'期间',qijian)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 3
#       1 #请输入期间
#       2 qijian = easygui.enterbox('请输入期间，"2024-01"')
# ----> 3 df_zhong.insert(0,'期间',qijian)
#       4 df_zhong.to_excel(f'各平台总销售{qijian}.xlsx',index = False)
#
# File ~\.conda\envs\py313\Lib\site-packages\pandas\core\frame.py:5158, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    5152     raise ValueError(
#    5153         "Cannot specify 'allow_duplicates=True' when "
#    5154         "'self.flags.allows_duplicate_labels' is False."
#    5155     )
#    5156 if not allow_duplicates and column in self.columns:
#    5157     # Should this be a different kind of error??
# -> 5158     raise ValueError(f"cannot insert {column}, already exists")
#    5159 if not is_integer(loc):
#    5160     raise TypeError("loc must be int")
#
# ValueError: cannot insert 期间, already exists

# %%
df_zhong.to_excel(f'各平台总销售{qijian}.xlsx',index = False)

# %%
#请输入期间
qijian = easygui.enterbox('请输入期间，"2024-12"')
df_zhong.insert(0,'期间',qijian)
df_zhong.to_excel(f'各平台总销售{qijian}.xlsx',index = False)

# %%
#是否附加到原始数据中
isno = easygui.boolbox('是否将本期销售数据添加到原始数据中去')
if isno:
    fname = r"F:\a00nutstore\008\zw08\电商\聚水潭\各平台总销售.xlsx"
    df = pd.read_excel(fname,sheet_name = '原始数据',dtype =  {'商品编码':str,'其它属性4':str}) 
else :
    df0.to_excel(f'各平台总销售{qijian}.xlsx',index = False)

# %%
max_row = df.shape[0]
max_row
# Out:
# 899

# %%
df0 = df.iloc[-1:]
df0
# Out:
#           期间   平台  图片        商品编码   款式编码      商品标签  供应商  供应商款号  供应商商品编码  颜色规格  \
# 898  2024-12  全平台 NaN  SMA340S-寂静  上翻素描本  分销-锐意-账本  NaN    NaN      NaN   NaN
#
#      ... 其它价格2 其它价格3  其它价格4  其它价格5  其它属性1  其它属性2  其它属性3          其它属性4  其它属性5  \
# 898  ...   NaN   NaN    NaN    NaN     30      1    NaN  6936281409949    NaN
#
#      基本售价
# 898  6.51
#
# [1 rows x 54 columns]

# %%
with pd.ExcelWriter(fname, engine='openpyxl',mode='a',if_sheet_exists='overlay')  as writer:
    df0.to_excel(writer, sheet_name = '原始数据',startrow=max_row +1, header = False,index = False)

# %%
'''
计算聚水潭中各平台销售
文件夹下各文件的命名应准确
拼多多、京东、京东荣佳、阿里巴巴、淘宝、天猫、分销商、京东商城
全平台（不包括分销部）

'''

import pandas as pd
import numpy as np
import easygui
import openpyxl
import os
import re

lst = ['图片',
 '商品编码',
 '款式编码',
 '商品标签',
 '供应商',
 '供应商款号',
 '供应商商品编码',
 '颜色规格',
 '商品简称',
 '商品名称',
 '商品品牌',
 '产品分类',
 '虚拟分类',
 '成本价',
 '销售数量',
 '价格为零的商品数量',
 '实发数量',
 '实发金额',
 '销售金额',
 '销售成本',
 '实发成本',
 '销售毛利',
 '销售毛利率',
 '销售均价',
 '退货数量',
 '实退数量',
 '退货金额',
 '退货成本',
 '实退成本',
 '实退金额',
 '退货毛利',
 '净销量',
 '净销售额',
 '净销售成本',
 '净销售毛利',
 '基本金额',
 '已付金额',
 '优惠金额',
 '运费收入',
 '运费支出',
 '净毛利率',
 '其它价格1',
 '其它价格2',
 '其它价格3',
 '其它价格4',
 '其它价格5',
 '其它属性1',
 '其它属性2',
 '其它属性3',
 '其它属性4',
 '其它属性5',
 '基本售价']
lst1 = [ '商品编码',
 '商品名称',
 '净销量',
 '净销售额',
 '净销售成本',
 '净销售毛利',
]
names = ['shangpinbianma','name','xiaoshouliang','xiaoshoue','xiaoshouchengben','maoli']
dic = dict(zip(lst1,names))

# fname = r"F:\a00nutstore\008\zww08\电商\聚水潭\各平台总销售.xlsx"
path = easygui.diropenbox('请点选聚水潭各平台销售所在文件夹')
# os.chdir(path)
# path = r'F:\a00nutstore\008\zw08\电商\聚水潭\202412'
lst_file = [i for i in os.listdir(path) if  (i.startswith('~') == False) and (i.endswith('.xlsx') == True)] # and i.startswith('~') == Fasle


def getXiaoshou(file):
    df = pd.read_excel(os.path.join(path,file),dtype =  {'商品编码':str,'其它属性4':str}) 
    df = df[~df['商品编码'].isnull()]
    return df 

dfs = []
pingtais = []
pingtai_df  = {}
pattern = re.compile(r'(?<=-)(\w+)(?=\.xlsx)')
for file in lst_file:

    mat = pattern.search(file)
    df = getXiaoshou(file)
    
    
    if mat :
        pingtai = mat.group(1)
        if pingtai == '全平台':
            df_quanpingtai = df
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
        
           

        elif pingtai == '拼多多':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
  
        elif pingtai == '阿里巴巴':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
           
        elif pingtai == '淘宝':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
        elif pingtai == '天猫':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
        elif pingtai == '抖音':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
 
        elif pingtai == '京东':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
  
        elif pingtai == '京东商城':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
         
        elif pingtai == '京东荣佳':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)
 
        elif pingtai == '分销商':
            pingtais.append(pingtai)
            pingtai_df[pingtai] = df
            dfs.append(df)

        else :
            continue
    else :
        continue
    

#双佳平台
pingtais_shuang = [i for i in pingtais if (i != '京东荣佳') and (i != '全平台')]
# Out:
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\redda\.conda\envs\py313\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
#双佳平台数据
dfs_shuangjia = [pingtai_df.get(i) for i in pingtais]

# %%
dfs_shuangjia
# Out:
# []
