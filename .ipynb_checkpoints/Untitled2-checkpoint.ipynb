# %%
import pandas as pd

# %%
datas = []
fname1 = r"F:\a00nutstore\006\zw\2024\2024-1盘存表002.xlsx"
kucun = pd.read_excel(fname1,'UFPrn20240127154825' ,usecols=[0, 1, 6])
kucun_cailiao = kucun[kucun['期末结存数量']!=0]
kucun_cailiao = kucun_cailiao.dropna(subset=['存货名称'])
cailiaos = kucun_cailiao['存货名称'].to_list()
for cailiao in cailiaos:
    kucun = kucun_cailiao[kucun_cailiao['存货名称']==cailiao]
    kucun_shuliang = kucun.iloc[-1][-1]  # 提取库存数
    caigou = getCaigou(caigous,pinmings,cailiao,kucun_shuliang)
    df11 = lianjie(kucun,kucun_shuliang,caigou,early_riqi)
    datas.append(df11)
datas
# Out:
# C:\Users\redda\AppData\Local\Temp\ipykernel_16084\3511244161.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   kucun_shuliang = kucun.iloc[-1][-1]  # 提取库存数
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       8 kucun = kucun_cailiao[kucun_cailiao['存货名称']==cailiao]
#       9 kucun_shuliang = kucun.iloc[-1][-1]  # 提取库存数
# ---> 10 caigou = getCaigou(caigous,pinmings,cailiao,kucun_shuliang)
#      11 df11 = lianjie(kucun,kucun_shuliang,caigou,early_riqi)
#      12 datas.append(df11)
#
# NameError: name 'getCaigou' is not defined

# %%
fname = r'F:\a00nutstore\006\zw\原材料实时流水账\原材料实时流水账.xlsx'
caigous = pd.read_excel(fname, '流水账',usecols=[0, 1, 2, 3, 5, 6, 7, 8, 9], index_col=0)
caigous = caigous.sort_index(ascending=False)
early_riqi = caigous.index.to_list()[-1]
caigous = caigous.reset_index()
pinmings = list(caigous['品名'].unique())

# %%
caigous
# Out:
#               日期       单据号         供货单位                品名     入库数量    入库单价  \
# 0     2024-02-27      3555      武汉金源恒商贸    190g白卡895*1110     47.0    0.00
# 1     2024-02-27      3550  驻马店白云纸业有限公司   75g白云双胶787*1092    -42.0    0.00
# 2     2024-02-27      3548       湖北佰晟包装       RJL3280新锐内箱    112.0    0.00
# 3     2024-02-27      3548       湖北佰晟包装       RJL3280新锐外箱     56.0    0.00
# 4     2024-02-27      3548       湖北佰晟包装       DRXLA6100内箱     48.0    0.00
# ...          ...       ...          ...               ...      ...     ...
# 52065 2014-03-25  90021131  驻马店白云纸业有限公司  55白云R级双胶787*1092   1230.0  120.77
# 52066 2014-03-24  90021130  驻马店白云纸业有限公司    55白云双胶787*1092    180.0  124.08
# 52067 2014-03-24  90021129  驻马店白云纸业有限公司       55白云R级卷筒815  28665.0    5.11
# 52068 2014-03-24  90021130  驻马店白云纸业有限公司    72白云双胶787*1092    352.0  167.06
# 52069 2014-03-24  90021129  驻马店白云纸业有限公司  55白云R级双胶787*1092    300.0  118.40
#
#             入库金额    cwName priceName
# 0           0.00  190g白卡大度    190g白卡
# 1           0.00   75g双胶正度     75g双胶
# 2           0.00        纸箱        纸箱
# 3           0.00        纸箱        纸箱
# 4           0.00        纸箱        纸箱
# ...          ...       ...       ...
# 52065  148542.59   55g双胶正度     55g双胶
# 52066   22333.50   55g双胶正度     55g双胶
# 52067  146478.15       卷筒纸    55g卷筒纸
# 52068   58806.00   72g双胶正度     72g双胶
# 52069   35520.90   55g双胶正度     55g双胶
#
# [52070 rows x 9 columns]

# %%
early_riqi
# Out:
# Timestamp('2014-03-24 00:00:00')

# %%
caigous
# Out:
#               日期       单据号         供货单位                品名     入库数量    入库单价  \
# 0     2024-02-27      3555      武汉金源恒商贸    190g白卡895*1110     47.0    0.00
# 1     2024-02-27      3550  驻马店白云纸业有限公司   75g白云双胶787*1092    -42.0    0.00
# 2     2024-02-27      3548       湖北佰晟包装       RJL3280新锐内箱    112.0    0.00
# 3     2024-02-27      3548       湖北佰晟包装       RJL3280新锐外箱     56.0    0.00
# 4     2024-02-27      3548       湖北佰晟包装       DRXLA6100内箱     48.0    0.00
# ...          ...       ...          ...               ...      ...     ...
# 52065 2014-03-25  90021131  驻马店白云纸业有限公司  55白云R级双胶787*1092   1230.0  120.77
# 52066 2014-03-24  90021130  驻马店白云纸业有限公司    55白云双胶787*1092    180.0  124.08
# 52067 2014-03-24  90021129  驻马店白云纸业有限公司       55白云R级卷筒815  28665.0    5.11
# 52068 2014-03-24  90021130  驻马店白云纸业有限公司    72白云双胶787*1092    352.0  167.06
# 52069 2014-03-24  90021129  驻马店白云纸业有限公司  55白云R级双胶787*1092    300.0  118.40
#
#             入库金额    cwName priceName
# 0           0.00  190g白卡大度    190g白卡
# 1           0.00   75g双胶正度     75g双胶
# 2           0.00        纸箱        纸箱
# 3           0.00        纸箱        纸箱
# 4           0.00        纸箱        纸箱
# ...          ...       ...       ...
# 52065  148542.59   55g双胶正度     55g双胶
# 52066   22333.50   55g双胶正度     55g双胶
# 52067  146478.15       卷筒纸    55g卷筒纸
# 52068   58806.00   72g双胶正度     72g双胶
# 52069   35520.90   55g双胶正度     55g双胶
#
# [52070 rows x 9 columns]

# %%
pinmings
# Out:
# ['190g白卡895*1110',
#  '75g白云双胶787*1092',
#  'RJL3280新锐内箱',
#  'RJL3280新锐外箱',
#  'DRXLA6100内箱',
#  'DRXLA6100外箱',
#  'M16PP箱',
#  'EXLA580箱',
#  'HNB-30029外贸箱',
#  'H888N胶',
#  'SEB-2280外贸箱',
#  '75g白云封牛云棕787*1092',
#  'RP-R黑',
#  'RP-R红',
#  'RP-R黄',
#  'RP-R蓝',
#  '195g国产牛卡825*1194',
#  '195g国产牛卡787*1120',
#  'B5办公软抄内芯HH355*780',
#  'SEB-200外贸箱',
#  '190g白卡830*1194',
#  '250g白卡910*900',
#  '还原剂',
#  '打包带',
#  'HNB-50200PL外贸箱',
#  '54g兴泰卷筒885',
#  'SEB-288外贸箱',
#  'C8箱',
#  'CTHA460箱',
#  'B3箱',
#  'EWTHA430箱',
#  'B1箱',
#  'A4厚胶装内芯HH905*425',
#  'A4-5*5方格柔版916*435',
#  'R5硬抄法文内芯HH880*340',
#  'SEB-2240外贸箱',
#  'B7箱',
#  'SEB-48外贸箱',
#  'F13箱',
#  '1.8MM1050g四川联益B级灰板FH860*1070',
#  '2.0MM1150g四川联益灰板B级FH785*1060',
#  'RFL3260新锐箱',
#  '2.0MM1150g四川联益灰板B级FH825*1205',
#  'HNB-20029外贸箱',
#  'RFL32100锐意箱',
#  '30MM801白背条',
#  '110g素描双胶889*1194',
#  '25MM801白背条',
#  '40MM801白背条',
#  '45MM801白背条',
#  '78g白云云时代双胶880*1230',
#  'SEB-32180法文外贸箱',
#  'B5箱',
#  'SEB-32180英文外贸箱',
#  '68g白云云时代双胶889*1194',
#  '78g白云云时代双胶889*1194',
#  '68g白云全双胶889*1194',
#  '78g白云全双胶880*1230',
#  '78g白云全双胶889*1194',
#  '75g白云云时光高白双胶787*1092',
#  'M13箱',
#  'B4箱',
#  'HNB-30400SQ外贸箱',
#  'R5线条8MM内芯HH885*355',
#  'EFLA460NB箱',
#  'N0785练习本内芯HH775*370',
#  'M2001箱',
#  'SEB-1740外贸箱',
#  'R4新锐外箱',
#  'HNB-30300SQ外贸箱',
#  'R4新锐内箱',
#  'N0783英语本内芯HH775*370',
#  'SEB-400外贸箱',
#  'R2新锐内箱',
#  'R2新锐外箱',
#  '0.18CM黑色橡皮筋打铁扣20.3CM',
#  '0.18CM黑色橡皮筋打铁扣25.3CM',
#  'M3POF收缩袋',
#  'RFL16100新锐箱',
#  'RFL1660N新锐箱',
#  'NFLA460锐意箱',
#  '标签纸50*30',
#  '铁丝26',
#  'SEB-32外贸箱',
#  '碳带60*300FT23',
#  '热熔胶Q718',
#  '54g兴泰卷筒900',
#  '63g兴泰米黄卷筒775',
#  'EVA90K带扣胶套',
#  '热熔胶背KG-6',
#  '25MM80克308兰背条',
#  '25MM80克605绿背条',
#  '25MM80克305兰背条',
#  '25MM80克307兰背条',
#  '热熔胶侧C-22',
#  'B6箱',
#  '法文联动线内芯HH885*355',
#  '5501柔版880*380',
#  'C4箱',
#  '25MM80克023咖啡背条',
#  '25MM80克608绿背条',
#  'N0792作业登记本内芯HH815*580',
#  '25MM80克501灰背条',
#  '24MM80克017咖啡裹背条',
#  '25MM80克318兰背条',
#  '54g兴泰卷筒905',
#  'RFL1660练习三开内芯HH780*375',
#  '30MM80克608绿背条',
#  '30MM80克605绿背条',
#  '30MM80克005红背条',
#  '25MM80克005红背条',
#  '25MM80克604绿背条',
#  '30MM80克308兰背条',
#  '外贸1号紫',
#  '外贸1号紫高速',
#  '消泡剂',
#  '外贸6号金光红高速',
#  '230g白卡889*1194',
#  '柔印DA024特黑墨',
#  '230g白卡889*1250',
#  '190g白卡750*1070',
#  '金51.0哑膜',
#  '金59.2哑膜',
#  '金61.5哑墨',
#  '金69.0哑膜',
#  '350卷膜POF',
#  '390卷膜POF',
#  '420卷膜POF',
#  '490卷膜POF',
#  '540卷膜POF',
#  '0.95MM银线圈',
#  'EXLA7100P箱',
#  'DRXLA5100内箱',
#  'C7箱',
#  '240M1-8B电化铝',
#  'DRXLA5100外箱',
#  '棉线秋黄56436',
#  '润版液EX',
#  '喷粉四色机',
#  '洁版液',
#  '白丝线F150-3',
#  'DL16K柔版770*530',
#  '北京白乳胶',
#  'RFZW1660NZ内芯HH375*779',
#  'EFYB1660N柔版775*370',
#  'XQ102柔版760*530',
#  'SEB-32150英文外贸箱',
#  '外贸手提袋',
#  'RFL3260N新锐箱',
#  'RFC1660NZ柔版779*375',
#  '816胶',
#  'EJZLA4128箱',
#  'SEB-32150法文外贸箱',
#  'SEB-144外贸箱',
#  'XQ101箱',
#  '36K空白袋',
#  'N0553书套',
#  '16K空白袋',
#  '6001空白袋',
#  'SEB-WR20外贸箱',
#  '8065胶',
#  'EJZLA5-128空白袋',
#  '240M1-33B电化铝',
#  '190g白卡895*1194',
#  '书边带',
#  '洁版膏',
#  '63g兴泰米黄卷筒815',
#  '黑色缠绕卷膜',
#  '300g铜版889*1194',
#  '全开刀条',
#  '抹布',
#  '对开刀条5MM',
#  '洗车水',
#  'XJ105内芯HH760*530',
#  'RFLA460N新锐箱',
#  'RJL32100外箱',
#  '16K30P空白箱',
#  'DL16-1锐意箱',
#  '16K-50P箱',
#  'RJL32100内箱',
#  'EJZLB5128箱',
#  '法文联动线内芯HH885*345',
#  '55g兴泰卷筒900',
#  '603Z柔版848*605',
#  '606Z柔版848*605',
#  '63g兴泰本白卷筒855',
#  '63g兴泰本白卷筒885',
#  '58g兴泰卷筒825',
#  '对开刀片',
#  'TPD-85补充液',
#  'TPD-85显影液',
#  'CTP版材920*760',
#  'CTP版材1030*790',
#  'SEB-120外贸箱',
#  '德莎52060厚进口双面胶',
#  '德莎52015进口双面胶',
#  '德莎52060进口双面胶',
#  '德莎52015厚进口双面胶',
#  'DRXLB5100内箱',
#  'DRXLB5100外箱',
#  'N0518箱',
#  '标签纸28*48',
#  'SEB-1632外贸箱',
#  'N0785柔版380*530',
#  'M5-1箱',
#  '水箱添加剂四色机',
#  'HUV91AY上光机光油',
#  'HNB-30200SQ外贸箱',
#  'EJLB5100柔版710*515',
#  '7/16白双线圈',
#  'R5方格内芯HH885*355',
#  '196g国产牛卡825*1170',
#  '196g国产牛卡787*1120',
#  'EJZLB5-128空白袋',
#  'EJZLA4-128空白袋',
#  '2.0MM1150g四川联益灰板B级FH785*980',
#  '2.0MM1150g四川联益灰板B级FH800*1100',
#  '3087复膜胶',
#  'SEB-100外贸箱',
#  '3089复膜胶',
#  '合裕啫喱胶H310',
#  '68g雅文书纸卷筒835',
#  'TX401N箱',
#  'EJCG1630N箱',
#  'EJCG1660N箱',
#  'M13-1箱',
#  'DL16-175箱',
#  '法文R5联动柔版900*345',
#  'SM8K60N箱',
#  '金78.5哑膜',
#  '金87哑膜',
#  '缠绕卷膜',
#  'SMA460N箱',
#  'NFL1660柔版773*390',
#  '205g进口牛卡790*1100',
#  '205g进口牛卡787*1210',
#  'NFL3260柔版828*580',
#  'NFLA460柔版430*889',
#  'EJZWGB5128柔版355*765',
#  'EJZWGA5128柔版840*570',
#  'EJZWGA4128柔版425*870',
#  '205g进口牛卡730*1100',
#  '300g涂布A级750*1060',
#  '300g涂布A级889*1270',
#  '300g涂布A级750*1030',
#  '300g涂布A级787*1092',
#  '290g涂布B级889*1194',
#  '290g涂布B级787*1092',
#  'F10箱',
#  'DRXYB5100柔版775*530',
#  'N0784柔版370*775',
#  'J1605箱',
#  '3M9080A双面胶',
#  'F12箱',
#  'EJCG1640N箱',
#  'WF101-1箱',
#  'DL16-155锐意箱',
#  '16K锐意不伤眼',
#  '55g兴泰新锐本白卷筒815',
#  '150g铜版787*1140',
#  '120g铜版787*1092',
#  '热熔胶Q3225',
#  '65g兴泰新锐本白卷筒780',
#  '150g铜版830*1194',
#  '240M2-8电化铝',
#  '240M2-25电化铝',
#  '150g铜版760*1070',
#  'A5横线标签',
#  '150g东帆铜版889*1194',
#  'A5空白标签',
#  'B5英语标签',
#  'B5方格标签',
#  'B5横线标签',
#  'A5英语标签',
#  'B5空白标签',
#  'A5方格标签',
#  'EWTHA430不干胶440*590',
#  'A6横线标签',
#  '2.0MM四川联益灰板B级880*1100',
#  '62光膜',
#  '88.8光膜',
#  'R1新锐外箱',
#  'R1新锐内箱',
#  'RM602箱',
#  'ATHA460N箱',
#  '200g国产牛卡889*1220',
#  '230g白卡740*1092',
#  '230g白卡787*1092',
#  '230g黑卡787*1120',
#  '78光膜',
#  'EXLA5100P外箱',
#  'EXLA5100P内箱',
#  'EXLA4100P箱',
#  '73光膜',
#  '0.65磨砂封底A7PP片107*70',
#  '0.65白色A5PP片142*203',
#  '0.65白色B5PP片173*253',
#  '0.65白色A6PP片107*145',
#  '0.65白色B5PP片177*250',
#  '0.65白色A5PP片148*207',
#  '16KPP账夹蓝',
#  'EJL3280内箱',
#  'EJL3280外箱',
#  'XJ401箱',
#  'DRXFA6100柔版845*585',
#  '63g兴泰本白卷筒870',
#  '63g兴泰本白卷筒845',
#  '63g兴泰本白卷筒765',
#  '63g兴泰本白卷筒840',
#  'A4硬抄线条内芯HH825*580',
#  '铁丝24',
#  '68g雅文书纸卷筒755',
#  '58g五州卷筒905',
#  '55g五州双胶787*1092',
#  '68g雅文书纸卷筒772',
#  'DJDK90箱',
#  '55g兴泰卷筒896',
#  'XJ101箱',
#  'DL16100空白袋',
#  'DL1680空白袋',
#  'DL1660空白袋',
#  'RM401箱',
#  'XJ201箱',
#  'M14箱',
#  'N0568箱',
#  'CQL1680箱',
#  'DL16200空白袋',
#  'FL1680空白袋',
#  '155g素描双胶760*1065',
#  'DL16150空白袋',
#  'ETCG1630N空白袋',
#  '新锐RJL16内芯730*520',
#  '30MM80克402黑背条',
#  'CGN1640空白袋',
#  'EXLB5100P空白袋',
#  'J1605空白袋',
#  'DRXLB5100空白袋',
#  'DRXLA5100空白袋',
#  'DRXLA6100空白袋',
#  'EXLA5100P空白袋',
#  'TX401（空白纸箱）',
#  '195g国产牛卡850*1194',
#  '195g国产牛卡889*1170',
#  '230g国产牛卡889*1240',
#  '230g国产牛卡889*1270',
#  '230g国产牛卡850*1194',
#  'CD101箱',
#  'JSCG1630锐意箱',
#  'SM1660N箱',
#  'JTA580-69H（外箱）',
#  'JTA580-69H（内箱）',
#  'DWXB5100N箱',
#  'JSCG1640锐意箱',
#  '58g五州卷筒725',
#  'EFLA460NB柔版HH410*843',
#  '408Z柔版380*788',
#  '409Z柔版380*788',
#  '78g兴泰双胶889*1230',
#  '250g白卡889*1110',
#  '190g白卡787*1160',
#  '230g白卡889*1210',
#  '25MM80克203桔黄背条',
#  '25MM80克022紫背条',
#  '2.0MM四川联益灰板B级880*1230',
#  '195g国产牛卡787*1030',
#  '195g国产牛卡840*1194',
#  '230g国产牛卡787*1135',
#  '230g国产牛卡840*1194',
#  'M3605箱',
#  'M5129箱',
#  'DWXA540N箱',
#  'JTB580-73Y内箱',
#  'JTB580-73Y外箱',
#  '200g国产牛卡787*1135',
#  '230g国产牛卡860*1240',
#  '205g进口牛卡660*1250',
#  '205g进口牛卡787*1250',
#  '205g进口牛卡900*910',
#  '55g五州卷筒780',
#  '55g五洲卷筒815',
#  'EVAEJL32K80胶套291*201',
#  '1/2*28白色软线圈',
#  '65g五州卷筒780',
#  '65g五州卷筒900',
#  '1/2*16白色软线圈',
#  '1/2*23白色软线圈',
#  '195g国产牛卡787*1135',
#  '230g国产牛卡889*910',
#  '55g五州卷筒857',
#  '封箱透明胶',
#  '小文具胶',
#  'DWXB580N箱',
#  'JTB580-72H内箱',
#  'JTB580-72H外箱',
#  'DJL64锐意内箱',
#  '78g白云全双胶787*1092',
#  '65g白云云时光本白卷筒788',
#  'DJL64锐意外箱',
#  '98g白云云时代米白卷筒735',
#  '98g白云云时代米白卷筒889',
#  '98g白云云时代米白卷筒787',
#  '68g白云云时代米白卷筒772',
#  'UVC-1510哑膜光油',
#  'DWXB540N箱',
#  'HWLZ1840N箱',
#  '85g昇伦轻型本白卷筒880',
#  '7/8*19黑双线圈',
#  '7/8*14黑双线圈',
#  '7/8*15黑双线圈',
#  '63g兴泰米黄卷筒857',
#  '63g兴泰米黄卷筒712',
#  '32K办公软抄内芯HH570*815',
#  'RFY1660NZ柔版779*375',
#  'CQL1680空白袋',
#  'EVA XR32K80胶套292*201',
#  'SEBWR20柔版345*886',
#  'JTB580-74Z内箱',
#  'JTB580-74Z外箱',
#  '120g铜版700*1000',
#  'EJL3280空白袋',
#  '85g昇伦本白卷筒860',
#  'C2箱',
#  'CD201箱',
#  'EWTHA430N箱',
#  'RFSX1660N柔版375*779',
#  'DJL16-2锐意内箱',
#  'YTL1640箱',
#  '柔版快干剂',
#  'M10箱',
#  'RFY1660N柔版780*375',
#  '200g国产牛卡787*1120',
#  '230g国产牛卡787*1092',
#  'YTZW16作文内芯HH780*375',
#  'RM401空白袋',
#  'RM602空白袋',
#  '200g国产牛卡830*1170',
#  '200g国产牛卡795*1194',
#  '175g贵格牛卡830*1194',
#  'CD106小字本内芯530*740',
#  'DJL16-2锐意外箱',
#  'YTL1660箱',
#  'SM1640C锐意箱',
#  'SM1640S锐意箱',
#  'EFHP1660N内芯HH370*775',
#  '65.8光膜',
#  '78.2光膜',
#  '68g白云云时代米白卷筒573',
#  'EVAJTB580胶套360*252',
#  '65g兴泰新锐本白卷筒772',
#  '110g封牛云棕卷筒787',
#  '68g白云云时代米白卷筒716',
#  'EVAJTA580胶套290*202',
#  '68g白云云时代米白卷筒840',
#  '65g兴泰新锐本白卷筒900',
#  '52g兴泰卷筒885',
#  '250g浅牛卡889*1194',
#  '230g国产牛卡825*1194',
#  '140g白云全木浆卷筒630',
#  '65g白云云时光本白卷筒848',
#  'CQ1680空白袋',
#  'DJL100空白袋',
#  'XJ101-106空白袋联',
#  'XJ201空白袋',
#  'CQ1660空白袋',
#  'EHLA460箱',
#  'CQ201空白袋',
#  '1-33BLS-3电化铝',
#  'JTA580-70Y（外箱）',
#  'JTA580-70Y（内箱）',
#  'CD101空白袋',
#  'F32601柔版580*808',
#  '彩虹1-8BLS-3电化铝',
#  '2-8LS-3电化铝',
#  '5209内芯881*380',
#  '5007内芯881*380',
#  'JTA580-71R（外箱）',
#  'JTA580-71R（内箱）',
#  'CD201空白袋',
#  '65g兴泰新锐本白卷筒760',
#  '68g兴泰本白卷筒850',
#  '55g兴泰本白卷筒760',
#  '65g兴泰新锐本白卷筒858',
#  'SXB5505S箱',
#  'DWXA580N箱',
#  'DWXA5100N箱',
#  'EJZLA5128箱',
#  'EJZLA4218箱',
#  'DWXA560N箱',
#  'SM8K40S锐意箱',
#  '棉线灰色T316',
#  '65g白云云时光本白卷筒808',
#  '65g兴泰新锐本白卷筒828',
#  '65g白云云时光本白卷筒900',
#  'EVADJL3280超透胶套',
#  'EVADJL1680超透胶套',
#  'EVA100K带扣胶套',
#  'DJL80封条',
#  'DJL64封条',
#  'DJL3260封条',
#  'DJL32100封条',
#  '65g兴泰新锐本白卷筒782',
#  '65g兴泰新锐本白卷筒735',
#  '65g兴泰新锐本白卷筒708',
#  '65g兴泰新锐本白卷筒815',
#  '1分咖啡丝带',
#  'DJL32-1锐意内箱',
#  'DJL100锐意外箱',
#  'DJL32-1锐意外箱',
#  'DJL100锐意内箱',
#  'DJL80锐意内箱',
#  'DJL16-1锐意内箱',
#  'DJL16-3锐意外箱',
#  'DJL16-3锐意内箱',
#  'EXLB5100P外箱',
#  'EXLB5100P内箱',
#  'F11箱',
#  'DJL16-1锐意外箱',
#  'DJL32-2锐意外箱',
#  'DJL32-2锐意内箱',
#  'DJL32-3锐意外箱',
#  'DJL32-3锐意内箱',
#  'DJL80锐意外箱',
#  'DA047深蓝',
#  'SMA440C锐意箱',
#  'EHBB560箱',
#  '4K锐意箱',
#  'TJ301箱',
#  '340卷膜POF',
#  '8K素描本锐意箱',
#  'DL3280锐意箱',
#  '230g国产牛卡550*787',
#  'JFJA1660N柔版370*775',
#  'H411内芯HH815*570',
#  '5513内芯HH765*395',
#  '5007内芯HH531*375',
#  '25MM80克402黑背条',
#  '3MM海绵253X162',
#  'RFY1660英语内芯375*780',
#  '190g白卡889*1250',
#  '140g白云全木浆卷筒885',
#  '98g白云全双胶787*1092',
#  '65g兴泰本白卷筒857',
#  '65g兴泰本白卷筒780',
#  'DL16-177锐意箱',
#  'EHLA560箱',
#  '16K（对插）箱',
#  'TJ101箱',
#  'EXLA6100NB箱',
#  'DJDK100箱',
#  'EVADJL16200超透胶套',
#  'EVADJL16150超透胶套',
#  '65g兴泰本白卷筒732',
#  'ATHA460箱',
#  '32K卡通软抄内芯HH815*570',
#  'F32608柔版580*808',
#  'F32607柔版580*808',
#  'F32606柔版580*808',
#  'F32605柔版580*808',
#  'F32602柔版580*808',
#  'EVAXR16K150胶套376*257',
#  'EVAXR16K80胶套371*257',
#  'EXTHA430N箱',
#  '230g国产牛卡787*1120',
#  '330卷膜POF',
#  'HNY1660N柔版788*380',
#  '5X5方格波兰硬抄内芯810*580',
#  'HNZW1660N柔版788*380',
#  'RFXZ1660N柔版375*780',
#  'RFPY3260柔版828*580',
#  '98g白云米白双胶889*1194',
#  '78g兴泰双胶纸889*1230',
#  '68g白云云时代卷筒815',
#  '对开高速刀片',
#  'N0787纠错本内芯HH370*775',
#  'DJL100封条',
#  'DJL16100封条',
#  'DJL16150封条',
#  'RMA4603柔版430*900',
#  'RMA4605柔版430*900',
#  'RMA4604柔版430*900',
#  'EVAXR16K80胶套冬371*257',
#  'RMA4602柔版430*900',
#  'EVAXR16K150胶套冬376*257',
#  'EVA XR32K80胶套冬292*201',
#  '58g五洲卷筒855',
#  'SMA440S锐意箱',
#  'E1-1箱',
#  'FL3260箱',
#  'M7008箱',
#  '柔印DA账册天蓝SJ加深',
#  '48g水木清华下兰卷筒883',
#  '46g水木清华上白卷筒883',
#  '48g水木清华下红卷筒883',
#  '48g水木清华下兰卷筒768',
#  '51g水木清华中红卷筒883',
#  'DA048绿SJ墨',
#  '63g兴泰米黄卷筒780',
#  'SEB-1632柔版345*885',
#  '2-25LS-3电化铝',
#  '100g华劲双胶787*1092',
#  '290g涂布B级787*1194',
#  '32K（对插）箱',
#  'FL1680锐意箱',
#  'TS301Z箱',
#  'XQ201箱',
#  '140g华劲双胶787*1092',
#  '140g华劲双胶889*1194',
#  '63g兴泰米黄卷筒828',
#  '账钉13',
#  'DJDK100内盒',
#  'TJ310生字本柔版380*788',
#  'RM609柔版605*848',
#  'N0795练习本柔版HH815*580',
#  'EHFA460线条柔版435*875',
#  'EHFA460方格柔版435*875',
#  'DJDK90内盒',
#  'EVAXR32K150胶套冬296*201',
#  '6208空白袋',
#  'EVAEJL16K80胶套371*257',
#  'HWLZ1840N空白袋',
#  'N0793英语本柔版HH815*580',
#  '6503空白袋',
#  '碳带110*300',
#  '100g铜版不干胶100*70',
#  '18K空白袋',
#  'TJ101空白袋',
#  'XQ101空白袋',
#  '6501空白袋',
#  '柔印天津小字本灰',
#  '25MM80克001红背条',
#  '柔版清洗剂',
#  'RL1660新锐箱',
#  '88.6光膜',
#  '65.6光膜',
#  'DX100箱',
#  'RL3280新锐箱',
#  'RL32150新锐箱',
#  'RL16100新锐箱',
#  '401箱',
#  '51g水木清华中红卷筒768',
#  '48g水木清华下红卷筒768',
#  '46g水木清华上白卷筒768',
#  '金78.2哑膜',
#  '橡皮四色机1052*840',
#  'DL3260箱',
#  '环保型大豆油墨',
#  'ETTHA420N箱',
#  'EVAXR16K200胶套冬379*257',
#  '70g轻型双胶889*1194',
#  '105g铜版770*1000',
#  'EXWGB5100P柔版855*510',
#  '150g铜版889*1210',
#  '120g铜版730*1000',
#  '150g铜版889*1230',
#  '55g五州卷筒842',
#  'DJL80空白袋',
#  'DJL32150空白袋',
#  'DJL1680空白袋',
#  'DJL16100空白袋',
#  'DJL16200空白袋',
#  'DJL32100空白袋',
#  'DJL3280空白袋',
#  'DJL64空白袋',
#  'DJDK90空白袋片',
#  'TJ301空白袋',
#  '150g铜版787*1230',
#  'DJDK100空白袋单片',
#  'EJL1680空白袋',
#  '150g铜版787*1092',
#  '200g国产牛卡889*1194',
#  'EWCG25K100箱',
#  'EJL16150空白袋',
#  '230g博汇白卡889*1250',
#  '190g博汇白卡889*1250',
#  '190g博汇白卡830*1194',
#  'EWCGB5100箱',
#  'EWCGA4100箱',
#  'F15箱',
#  '200g国产牛卡787*1030',
#  '150g国产牛卡787*1040',
#  '150g国产牛卡787*1092',
#  'EJL32150空白袋',
#  'NK301空白袋',
#  'EHLA460空白袋',
#  '190g博汇白卡卷筒787',
#  'DB501空白袋',
#  'JJTH101空白袋',
#  'EHLA560空白袋',
#  'EXLA4100P空白袋',
#  '80K锐意柔版830*570',
#  'DJL64锐意柔版840*572',
#  'DJL100锐意柔版750*530',
#  'DJL1680封条500*140',
#  '55g兴泰新锐本白卷筒758',
#  '55g兴泰新锐本白卷筒736',
#  '65g兴泰新锐本白卷筒756',
#  '65g兴泰新锐本白卷筒788',
#  '65g兴泰本白卷筒760',
#  '350g白卡385*258打样',
#  '0.18CM黑色橡皮筋打银扣29.8CM',
#  '2-8BLS-3电化铝',
#  '绿41电化铝',
#  '55g白云卷筒780',
#  '60g白云卷筒725',
#  '60g白云卷筒905',
#  '55g白云卷筒857',
#  '60g白云卷筒855',
#  '300g博汇白卡787*1092',
#  'FL16锐意柔版778*520',
#  '190g博汇白卡787*1092',
#  '230g博汇白卡889*1194',
#  'FL32锐意柔版840*580',
#  'DJL16锐意柔版772*530',
#  '120M金001电化铝',
#  '240M金001电化铝',
#  'DL32锐意柔版840*580',
#  '240M银201电化铝',
#  'HWC1840N柔版515*712',
#  'HWZW1840N柔版515*712',
#  '120M银201电化铝',
#  'HWY1840N柔版515*712',
#  'HWTZ1840N柔版515*712',
#  'HWSX1840N柔版515*712',
#  'HWLZ1840N柔版515*712',
#  'HWHP1840N柔版515*712',
#  'HWPX1840N柔版515*712',
#  '8K120g手提袋',
#  '4K120g手提袋',
#  '65g白云云时光本白卷筒787',
#  '65g白云本白双胶787*1092',
#  '98g白云云时代米白卷筒858',
#  'EXLB5100NB箱',
#  '五角星手提环',
#  '886卷膜POF',
#  '16K软抄柔版772*530',
#  '16K软抄柔版770*530',
#  '65g兴泰本白卷筒756',
#  '0.65白色A4PP片208*290',
#  '0.65白色A5PP片177*250',
#  '65g兴泰本白卷筒815',
#  '65g兴泰本白卷筒900',
#  '0.65白色A7PP片107*70',
#  'EXLA5100NB箱',
#  '78g天邦书纸卷筒860',
#  'HB201箱',
#  '250g浅牛卡787*1040',
#  '230g国产牛卡787*1240',
#  '250g浅牛卡787*1230',
#  '天津调墨油',
#  '96针化纤水胶套',
#  'EVA DJL100K80胶套157*103',
#  '10-66牡丹绿',
#  'TGS-158金光红',
#  'EVA DJL80K80胶套176*138',
#  'EVA DJL64K80胶套216*140',
#  '200g国产牛卡825*1194',
#  '250g涂布A级750*1050',
#  '250g涂布A级889*1230',
#  '190g博汇白卡787*1160',
#  '230g博汇白卡889*1230',
#  '230g博汇白卡889*1210',
#  '230g博汇白卡889*1092',
#  '230g博汇白卡787*1092',
#  '300g涂布A级889*1230',
#  '70g兴泰本白卷筒850',
#  '70g兴泰本白卷筒825',
#  '63g兴泰本白卷筒752',
#  '70g兴泰本白卷筒875',
#  '70g兴泰本白卷筒776',
#  '63g兴泰本白卷筒820',
#  '63g兴泰本白卷筒725',
#  '63g兴泰本白卷筒825',
#  'A5软线环标签',
#  '63g兴泰本白卷筒712',
#  'B5软线环标签',
#  'DJL32K锐意柔版868*640',
#  '30MM80克023咖啡背条',
#  '25MM80克008酒红背条',
#  '热熔胶TEF38H',
#  'CS101箱',
#  'N0482箱',
#  '30MM80克008酒红背条',
#  '25MM80克335兰背条',
#  '30MM80克335兰背条',
#  '塑钢打包带',
#  '32K锐意标签',
#  'DJDK90柔版885*605',
#  '200g国产牛卡850*1170',
#  '250g白卡889*1240',
#  'DJDK100柔版725*515',
#  '210g白卡895*1110',
#  '银2-8-4电化铝',
#  '68g白云云时代米白卷筒728',
#  '聚乙烯醇',
#  '16K锐意标签',
#  'JTB580柔版510*714',
#  'JTA580柔版410*570',
#  'M8箱',
#  'M5014箱',
#  '68g白云云时代米白卷筒750',
#  '68g白云云时代米白卷筒889',
#  '68g白云云时代米白卷筒782',
#  '68g白云云时代米白卷筒905',
#  '85g昇伦轻型本白卷筒840',
#  '85g昇伦轻型本白卷筒870',
#  '16K软抄柔版782*540',
#  '68g白云云时代米白卷筒860',
#  '190g白卡895*1080',
#  '190g白卡740*1070',
#  '190g白卡660*1230',
#  '黑LS-3电化铝',
#  '金L-2电化铝',
#  '亚金LS-3电化铝',
#  '68g白云云时代米白卷筒828',
#  '碳带110*300FT12',
#  '标签纸100*70',
#  '68g白云云时代米白卷筒755',
#  '250g白卡640*970',
#  '68g白云云时代米白卷筒900',
#  'XJ409柔版380*772',
#  'TS308Z柔版520*752',
#  '115g封牛云棕卷筒889',
#  '115g封牛云棕卷筒787',
#  '145g白云封牛云棕1040*720',
#  '230g黑卡787*1240',
#  '230g黑卡889*1170',
#  '0.95MM黑线圈',
#  '25MM80克017咖啡背条',
#  '230g黑卡889*1240',
#  '3087胶',
#  'EHLA580柔版735*580',
#  '200g国产牛卡889*1300',
#  'EVA 16K200胶套402*262',
#  'EVA 16K80胶套391*262',
#  'EVA 32K80胶套292*208',
#  'EVA 32K150胶套296*208',
#  '120g华劲双胶840*1168',
#  '120g华劲双胶889*1194',
#  '210g白卡740*940',
#  'XJ401英语本内芯HH772*380',
#  'EJL32150外箱',
#  '1601箱',
#  'EJL1680外箱',
#  'EJL1680内箱',
#  'EJL16150外箱',
#  'EJL16150内箱',
#  'EJL32150内箱',
#  'C5箱',
#  'EHLB580空白袋',
#  'EHLB560空白袋',
#  '外贸6号金光红',
#  'DRXLB5柔版530*755',
#  '柔印DA四色黄SJ',
#  '1/2*23白色线圈',
#  '1/2*28白色线圈',
#  'DRXLA5柔版590*835',
#  '2.5MM1450g富业灰板A级FH889*1230',
#  '1.5MM850g四川联益灰板FH889*1194',
#  '200g国产牛卡840*1170',
#  '205g进口牛卡840*1200',
#  '205g进口牛卡900*1200',
#  '98g白云全木浆双胶889*1194',
#  '110g素描双胶770*1070',
#  'N0671柔版913*655',
#  '2.5MM1450g联益灰板FH889*1230',
#  '2.5MM1450g联益灰板FH800*1100',
#  '8-804409外贸箱',
#  '8-801201外贸箱',
#  '8-801202外贸箱',
#  '3015D箱',
#  '8-804408外贸箱',
#  'THA460锐意箱',
#  'XA101箱',
#  'XJ301箱',
#  '湖北小学生本404内芯HH788*380',
#  '150g铜版787*1070',
#  '150g铜版889*1092',
#  '金2LS-3电化铝',
#  'SM1600N箱',
#  'RJL16100空白袋',
#  '65g兴泰本白卷筒858',
#  '65g兴泰本白卷筒788',
#  'RJL32150空白袋',
#  'DL3280空白袋',
#  'RJL16200空白袋',
#  'HB201空白袋',
#  'DL1640空白袋',
#  'NFLA460空白袋',
#  'M15箱',
#  'EJZLA5218箱',
#  'EJZLB5218箱',
#  '51g兴泰本白卷筒863',
#  '51g兴泰本白卷筒774',
#  '70g兴泰米黄卷筒796',
#  '70g兴泰米黄卷筒848',
#  '85g昇伦本白卷筒880',
#  'DL3260空白袋',
#  '401空白袋联',
#  'RJL3280空白袋',
#  'RFL3260空白袋',
#  'FL3260空白袋',
#  'RJL32100空白袋',
#  'RJL16150空白袋',
#  'FL1660空白袋',
#  '200g国产牛卡787*1150',
#  'DRXYA6100外箱',
#  'DRXYA6100内箱',
#  '200g贵格牛卡889*1300',
#  'EFLA560柔版840*580',
#  '内贸AS小字本紫',
#  '5014柔版380*850',
#  '锐意B5无线胶装柔版726*515',
#  '锐意A5无线胶装柔版903*645',
#  'M5425E箱',
#  'C9箱',
#  '湖北小学生本401内芯HH788*380',
#  'N0873英语本内芯775*370',
#  '885光膜',
#  'RFL16100空白袋',
#  '热熔胶Q216',
#  'RJL1680空白袋',
#  '150g铜版889*1194',
#  '100g铜版889*1194',
#  'RFL1660空白袋',
#  '200g国产牛卡760*1050',
#  '0.2MM衬纸',
#  'EJZLB5128柔版355*765',
#  'EJZLA4128柔版425*870',
#  'EJZLA5128柔版570*840',
#  'B5办公软抄柔版355*520',
#  'FL32缝线柔版580*840',
#  '59.2哑膜',
#  '61.5哑膜',
#  '78.2哑膜',
#  '81哑膜',
#  '84.2哑膜',
#  '1/2*16白色线圈',
#  '1-8BLS-4电化铝',
#  '6502空白袋',
#  'DRXFA6100外箱',
#  '300g涂布A级889*1194',
#  '65g白云云时光本白卷筒752',
#  'EXWGA4100P柔版580*825',
#  'EXLA7100PP线环820*430MM',
#  'EXLA5100P横线本内芯HH845*410',
#  'DRXFA6100内箱',
#  'DRXBA6100外箱',
#  'DRXBA6100内箱',
#  '230g国产牛卡860*1230',
#  '200g国产牛卡870*1194',
#  '65g兴泰本白卷筒825',
#  '65g兴泰本白卷筒740',
#  '155g素描双胶850*1170',
#  '碳带110*300FT23',
#  '401Z箱',
#  '155g素描双胶770*1070',
#  '65g五洲卷筒815',
#  'TGS-426天蓝',
#  'TGS-716黑',
#  '16K-30P箱',
#  '德莎进口双面胶',
#  '3015转曲柔版432*840',
#  '120g东帆铜版787*1092',
#  '120g东帆铜版889*1194',
#  '100g铜版787*1092',
#  'A6方格标签',
#  'A6空白标签',
#  'A6英语标签',
#  'N0552书套',
#  '290卷膜POF',
#  '190g博汇白卡*700*1230',
#  '46g水木清华上白卷筒893',
#  '210g博汇白卡850*1194',
#  '210g博汇白卡787*1140',
#  '230g博汇白卡740*1092',
#  '橡皮进口对开940*920',
#  'N0782数学本内芯HH775*370',
#  '0.65磨砂封底A7PP片107*146',
#  'ETCG1660N空白袋',
#  '606本白棉线',
#  'TS101Z箱',
#  '210g铜版787*1194',
#  '210g铜版889*1194',
#  'ERGZ6460柔版370*780',
#  '97g龙丰FSC卷筒900',
#  '97g龙丰纯质纸卷筒889',
#  '120g龙丰FSC卷筒900',
#  'TS301ZR柔版520*752',
#  'DRXFA610横线柔版585*845',
#  'DRXFA610方格柔版585*845',
#  '68g龙丰卷筒889',
#  '48g无碳复写上白/中兰中红/下黄787*1092',
#  '105g黑卡889*1230',
#  '105g黑卡889*1194',
#  '105g黑卡889*1150',
#  '105g黑卡889*1092',
#  '48g无碳复写上白/下红787*1092',
#  '1.5MM850g四川联益灰板B级FH889*1230',
#  'EFWGA460NB柔版HH410*843',
#  'XR16K80胶套冬371*257',
#  ...]

# %%
def getKucun(caigous,pinmings,early_riqi):
    datas = []
    fname1 = r"F:\a00nutstore\006\zw\2024\2024-1盘存表002.xlsx"
    kucun = pd.read_excel(fname1,'UFPrn20240127154825' ,usecols=[0, 1, 6])
    kucun_cailiao = kucun[kucun['期末结存数量']!=0]
    kucun_cailiao = kucun_cailiao.dropna(subset=['存货名称'])
    cailiaos = kucun_cailiao['存货名称'].to_list()
    for cailiao in cailiaos:
        kucun = kucun_cailiao[kucun_cailiao['存货名称']==cailiao]
        kucun_shuliang = kucun.iloc[-1][-1]  # 提取库存数
        caigou = getCaigou(caigous,pinmings,cailiao,kucun_shuliang)
        df11 = lianjie(kucun,kucun_shuliang,caigou,early_riqi)
        datas.append(df11)
    return datas

def getCaigou(caigous,pinmings,cailiao,kucun_shuliang):
    if cailiao in pinmings:
        caigou = caigous[caigous['品名'] == cailiao]
    else:
        caigou = caigous.iloc[-1:]
        caigou.iloc[-1, 2] = '待查'
        caigou.iloc[-1, 3] = cailiao
        caigou.iloc[-1, -5] = kucun_shuliang
        caigou.iloc[-1, -4] = 0
        caigou.iloc[-1, -3] = 0
        caigou.iloc[-1, -2] = None
        caigou.iloc[-1, -1] = None
    return caigou

def lianjie(kucun,kucun_shuliang,caigou,early_riqi):
    df8 = pd.merge(kucun, caigou, on='存货名称', how='left')
    df9 = df8
    df9['累加数量'] = df9['入库数量'].cumsum()  # 累加求和
    df9['剩余数量'] = df9['本日数量'] - df9['累加数量']  # 累加求和
    leiji_ruku = df9['入库数量'].sum()
    shuliangs = df9['剩余数量'].to_list()

    if leiji_ruku >= kucun_shuliang:
        shuliangs = df9['剩余数量'].to_list()
        for j in range(len(shuliangs)):
            if shuliangs[j] < 0:
                row = j
                break
            else:
                row = len(shuliangs)
                continue
        row = row +1
        df10 = df9.iloc[:row,:]
        df11 = df10
        shengyu = df11.iloc[-1, -1]
        danjia = df11.iloc[-1, -6]
        last_ruku = df11.iloc[-1, -7]
        leiji = df11.iloc[-1, -2]
        df11.iloc[-1, -7] = last_ruku + shengyu
        df11.iloc[-1, -5] = round((last_ruku + shengyu) * danjia, 2)  # 调整金额，按调整后的数量和单价计算
        df11.iloc[-1, -2] = leiji + shengyu
        df11.iloc[-1, -1] = 0
    else:
        df11 = df9
        last_col_ser = df9.iloc[-1]
        df11 = df11.append(last_col_ser)
        df11.iloc[-1,3] = early_riqi
        df11.iloc[-1, 5] = '待查'
        df11.iloc[-1, -7] = kucun_shuliang - leiji_ruku
        danjia = df9.iloc[-1,-6]
        df11.iloc[-1, -5] = round((kucun_shuliang - leiji_ruku) * danjia, 2)  # 调整金额，按调整后的数量和单价计算
        df11.iloc[-1, -2] = kucun_shuliang
        df11.iloc[-1, -1] = 0
    # grouped = df11.groupby(['供货单位','品名','本日数量'])
    return df11

# %%
import os
path = r'F:\a00nutstore\006\zw\原材料实时流水账'
os.chdir(path)
filename = '库存商品分配.xlsx'
sheet_name = '库存分配'
datas = getKucun(caigous,pinmings,early_riqi)
df = pd.concat(datas)
df = df[df['入库数量']!=0]
# Out:
# C:\Users\redda\AppData\Local\Temp\ipykernel_16084\3954648419.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   kucun_shuliang = kucun.iloc[-1][-1]  # 提取库存数
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       4 filename = '库存商品分配.xlsx'
#       5 sheet_name = '库存分配'
# ----> 6 datas = getKucun(caigous,pinmings,early_riqi)
#       7 df = pd.concat(datas)
#       8 df = df[df['入库数量']!=0]
#
# Cell In[12], line 12, in getKucun(caigous, pinmings, early_riqi)
#      10     kucun_shuliang = kucun.iloc[-1][-1]  # 提取库存数
#      11     caigou = getCaigou(caigous,pinmings,cailiao,kucun_shuliang)
# ---> 12     df11 = lianjie(kucun,kucun_shuliang,caigou,early_riqi)
#      13     datas.append(df11)
#      14 return datas
#
# NameError: name 'lianjie' is not defined
