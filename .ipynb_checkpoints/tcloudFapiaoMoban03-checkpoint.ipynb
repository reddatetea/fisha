# %%
'''
tcloud中用销售订单生成税局发票模板,选择单个销售订单，单独生成相应的发票模板

'''
import os
import re
import easygui
import openpyxl
import numpy as np
import pandas as pd
import shutil

# %%
#读取发票模板
fname_fapiao = r"F:\repos\fish\发票模板.xlsx"
df_fapiao = pd.read_excel(fname_fapiao,header = 2,dtype = {'商品和服务税收分类编码':'str'})
df_fapiao
# Out:
# Empty DataFrame
# Columns: [项目名称, 商品和服务税收分类编码, 规格型号, 单位, 商品数量, 商品单价, 金额, 税率, 折扣金额, 优惠政策类型]
# Index: []

# %%
#莱新销售订单超5000条，不能一次导出，分三次导出，并分别存于同一文件下，先将它们合并
path = r"F:\repos\fisha\莱新销售订单0826-0925"
os.chdir(path)
path1 = '发票模板'

if not os.path.exists(path1):
    try:
        os.mkdir(path1)
    except:
        pass

# %%
data = []
for i in os.listdir(path):
    if  os.path.isfile(i):
        i = os.path.join(path,i)
        df = pd.read_excel(i)
        data.append(df)
    else :
        continue
   
   
    
df_xiaoshou0 = pd.concat(data)
df_xiaoshou0
# Out:
#                      单据执行状态 单据状态             单据编号  业务类型 冲抵订货  售后类型  退货原因  \
# 0    已出库 已销货 未收订金 未开票 已转采购    生效  SO-2024-02-0570  普通销售    否   NaN   NaN
# 1    已出库 已销货 未收订金 未开票 已转采购    生效  SO-2024-02-0570  普通销售    否   NaN   NaN
# 2    已出库 已销货 未收订金 未开票 已转采购    生效  SO-2024-02-0570  普通销售    否   NaN   NaN
# 3    已出库 已销货 未收订金 未开票 已转采购    生效  SO-2024-02-0570  普通销售    否   NaN   NaN
# 4    已出库 已销货 未收订金 未开票 已转采购    生效  SO-2024-02-0570  普通销售    否   NaN   NaN
# ..                      ...  ...              ...   ...  ...   ...   ...
# 843      已出库 已销货 未收订金 未开票     生效  SO-2024-02-1196  销售退货    否  退货退款   NaN
# 844  已出库 已销货 未收订金 未开票 已转采购    生效  SO-2024-02-1197  普通销售    否   NaN   NaN
# 845         已销货 未收订金  未转采购    生效  SO-2024-02-1198  普通销售    否   NaN   NaN
# 846      已出库 已销货 未收订金 未开票     生效  SO-2024-02-1220  销售退货    否  退货退款   NaN
# 847                      合计  NaN              NaN   NaN  NaN   NaN   NaN
#
#      退货说明        单据日期                 创建时间  ... 累计调拨数量 累计调拨数量2 未执行数量 未执行数量2  \
# 0     NaN  2024-08-26  2024-08-26 09:25:24  ...    NaN     NaN     0    0.0
# 1     NaN  2024-08-26  2024-08-26 09:25:24  ...    NaN     NaN     0    0.0
# 2     NaN  2024-08-26  2024-08-26 09:25:24  ...    NaN     NaN     0    0.0
# 3     NaN  2024-08-26  2024-08-26 09:25:24  ...    NaN     NaN     0    0.0
# 4     NaN  2024-08-26  2024-08-26 09:25:24  ...    NaN     NaN     0    0.0
# ..    ...         ...                  ...  ...    ...     ...   ...    ...
# 843   NaN  2024-09-25  2024-09-25 16:29:22  ...    NaN     NaN     0    0.0
# 844   NaN  2024-09-25  2024-09-25 16:30:24  ...    NaN     NaN     0    0.0
# 845   NaN  2024-09-25  2024-09-26 08:28:28  ...    NaN     NaN     0    NaN
# 846   NaN  2024-09-25  2024-09-27 08:09:18  ...    NaN     NaN     0    0.0
# 847   NaN         NaN                  NaN  ...    0.0     0.0     0    0.0
#
#     已采购需求分析 数据来源(明细) 来源单据(明细) 来源单号(明细)  价格策略类型 明细备注
# 0         否     线下业务      NaN      NaN  客户最新售价  NaN
# 1         否     线下业务      NaN      NaN     NaN  NaN
# 2         否     线下业务      NaN      NaN     NaN  NaN
# 3         否     线下业务      NaN      NaN  客户最新售价  NaN
# 4         否     线下业务      NaN      NaN  客户最新售价  NaN
# ..      ...      ...      ...      ...     ...  ...
# 843       否     线下业务      NaN      NaN   存货批发价  NaN
# 844       否     线下业务      NaN      NaN   存货批发价  NaN
# 845       否     线下业务      NaN      NaN     NaN  NaN
# 846       否     线下业务      NaN      NaN     NaN  NaN
# 847     NaN      NaN      NaN      NaN     NaN  NaN
#
# [6255 rows x 129 columns]

# %%
df_xiaoshou1 = df_xiaoshou0.loc[df_xiaoshou0['单据执行状态'] != '合计']
lst1 = ['单据编号',
  '单据日期',
 '含税总金额',
 '存货名称',
 '存货分类',
 '存货编码',
  '存货代码',
  '数量',
  '件含量',
 '数量（件）',
  '含税单价',
 '含税金额',
        '客户'
]
df_xiaoshou2 = df_xiaoshou1[lst1]
df_xiaoshou2
# Out:
#                 单据编号        单据日期    含税总金额                  存货名称     存货分类  \
# 0    SO-2024-02-0570  2024-08-26  12382.1   16K80型精品道林卡面软抄C2404  16K道林软抄
# 1    SO-2024-02-0570  2024-08-26  12382.1   16K80型精品道林卡面软抄B2304  16K道林软抄
# 2    SO-2024-02-0570  2024-08-26  12382.1  16K80型精品道林卡面作文本B2304  16K道林软抄
# 3    SO-2024-02-0570  2024-08-26  12382.1         16K80型精品道林作文本  16K道林软抄
# 4    SO-2024-02-0570  2024-08-26  12382.1         16K80型精品道林作文本  16K道林软抄
# ..               ...         ...      ...                   ...      ...
# 842  SO-2024-02-1183  2024-09-25   -160.0                    运费      折扣类
# 843  SO-2024-02-1196  2024-09-25   -728.0            16K100型胶套本    新锐胶套本
# 844  SO-2024-02-1197  2024-09-25    569.6          16K100型卡面缝线本    新锐缝线本
# 845  SO-2024-02-1198  2024-09-25    575.0                    运费      折扣类
# 846  SO-2024-02-1220  2024-09-25  -2838.0                16K作文簿  广州版小学生本
#
#                   存货编码 存货代码    数量    件含量  数量（件）    含税单价     含税金额  \
# 0        DL-1680C-花开季节   锐意   200  100.0    2.0  2.4605   492.10
# 1        DL-1680B-简约生活   锐意   200  100.0    2.0  2.4605   492.10
# 2        DZW-1680-海的秘密   锐意   400  100.0    4.0  2.4605   984.20
# 3    DZW-1680-一城风情（大格）   锐意   400  100.0    4.0  2.4605   984.20
# 4    DZW-1680-时光有你(大格）   锐意   300  100.0    3.0  2.4605   738.15
# ..                 ...  ...   ...    ...    ...     ...      ...
# 842               8888   抄本     0    NaN    NaN     NaN  -160.00
# 843      RJL-16100-H01   新锐  -200  100.0   -2.0  3.6400  -728.00
# 844      RFL-16100-H01   新锐   320  160.0    2.0  1.7800   569.60
# 845               8888   抄本     0    NaN    NaN     NaN   575.00
# 846              GZ204   抄本 -6000  600.0  -10.0  0.4730 -2838.00
#
#                   客户
# 0               山东刘璐
# 1               山东刘璐
# 2               山东刘璐
# 3               山东刘璐
# 4               山东刘璐
# ..               ...
# 842       西安百花工贸有限公司
# 843     芜湖迈斯广告传媒有限公司
# 844     芜湖迈斯广告传媒有限公司
# 845  兴义市鸿图锐意办公商贸有限公司
# 846             遵义王强
#
# [6252 rows x 13 columns]

# %%
def getPivot(df):
    bianba_fenlei = dict(zip(df['存货编码'],df['存货分类']))
    bianba_mingchen = dict(zip(df['存货编码'],df['存货名称']))
    bianba_daima = dict(zip(df['存货编码'],df['存货代码']))
    bianba_hanlian = dict(zip(df['存货编码'],df['件含量']))
    pivot = df0.pivot_table(index = '存货编码',values = ['数量','数量（件）','含税金额'] ,aggfunc = np.sum)
    pivot = pivot.reset_index()
    pivot = pivot.assign(fenlei = pivot['存货编码'].map(bianba_fenlei))
    pivot = pivot.assign(mingchen = pivot['存货编码'].map(bianba_mingchen))
    pivot = pivot.assign(daima = pivot['存货编码'].map(bianba_daima))
    pivot = pivot.assign(hanliang = pivot['存货编码'].map(bianba_hanlian))
    dic = dict(zip(['fenlei','mingchen','daima','hanliang'],['存货分类','存货名称','存货代码','件含量']))
    pivot = pivot.rename(columns =  dic)
             
    
    return pivot

def chuliMingchen(d):
    d['存货名称'] = d['存货名称'].str.replace('运费',"")
    d = d.assign(qian = d['存货名称'].str.split('型').str[0])
    d = d.assign(hou = d['存货名称'].str.split('型').str[0])
    d['qian'] = d['qian'].fillna('')
    d['hou'] = d['hou'].fillna('')
    # qian = pd.Series(qian).fillna('')
    # hou = pd.Series(hou).fillna('')
    return d
def getFapiaoBen(d):
    d['项目名称'] = d['存货编码'] + '-' + d['hou']
    d['项目名称'] = d['项目名称'].str.replace('运费-','运费')
    d['项目名称'] = d['项目名称'].str.split(''-')
    d['商品和服务税收分类编码'] = '1060202010000000000'
    d['规格型号'] = d['qian']
    d['单位'] = '本'
    d['商品数量'] = d['数量']
    d['商品单价'] = ''
    d['金额'] = d['含税金额']
    d['税率'] = 0.13
    d['折扣金额'] = ''
    d['优惠政策类型'] = ''
    d = d[['项目名称',
     '商品和服务税收分类编码',
     '规格型号',
     '单位',
     '商品数量',
     '商品单价',
     '金额',
     '税率',
     '折扣金额',
     '优惠政策类型',
                           ]]
    return d

# %%
#先调试一个 '武汉市热脉文体用品有限公司'
df0 = df_xiaoshou2[df_xiaoshou2['客户'] == '武汉市热脉文体用品有限公司']

# %%
pivot = getPivot(df0)
pivot1 = chuliMingchen(pivot)
fapiao = getFapiaoBen(pivot1)
# Out:
# C:\Users\redda\AppData\Local\Temp\ipykernel_31720\3484728419.py:6: FutureWarning: The provided callable <function sum at 0x00000000086BD580> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pivot = df0.pivot_table(index = '存货编码',values = ['数量','数量（件）','含税金额'] ,aggfunc = np.sum)

# %%
# for k,v in  df_xiaoshou2.groupby('客户'):
#     if k == '武汉市热脉文体用品有限公司':
#         print('客户',k)
#         print(v.sum())
#     else :
#         continue

# %%
gongsi = '热脉'       #获取简称
filename=''.join(['发票模板-',gongsi,'.xlsx'])
newname = os.path.join(path1,filename)
shutil.copyfile(fname_fapiao, newname)
# Out:
# '发票模板\\发票模板-热脉.xlsx'

# %%
with pd.ExcelWriter(newname, engine='openpyxl',mode='a', if_sheet_exists='overlay')  as writer:
    fapiao.to_excel(writer, sheet_name = '1-明细模板',startrow=3, header = False,index = False)

# %%
df_xiaoshou2.to_excel('dfxiaoshou2.xlsx')

# %%
df0.to_excel('df0.xlsx')

# %%
pivot.to_excel('pivot.xlsx')

# %%
df0.sum()

# %%
pivot.sum()

# %%
pivot5 = df0.pivot_table(index = ['存货编码'],values = ['数量','数量（件）','含税金额'] ,aggfunc =np.sum)
pivot5.sum()

# %%
import pandas as pd
 
# 示例数据
df = pd.DataFrame({
    'A': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'],
    'B': ['one', 'one', 'two', 'two', 'one', 'one'],
    'C': ['small', 'large', 'large', 'small', 'small', 'large'],
     'F': ['small1', 'large1', 'large1', 'small1', 'small1', 'large1'],
    'D': [1, 2, 2, 3, 3, 4],
    'E': [2, 4, 5, 5, 6, 6]
})
 
df

# %%
# 创建透视表，并使用margins参数汇总
pivot_table = df.pivot_table(values=['D','E'], index=['A', 'B'], columns='C', aggfunc='sum', margins=True)
pivot_table

# %%
pivot_table.columns

# %%
pivot_table.columns.levels[0]

# %%
pivot_table.columns.levels
# 将多层索引转换为常规列，并将不是汇总的字段展开
melted = pivot_table.reset_index().melt(id_vars=['A', 'B'], value_vars=pivot_table.columns.levels[1].unique(), var_name='C')

# %%
melted = melted.dropna(subset=['C']).reset_index(drop=True)
 
print(melted)

# %%
 
# 将多层索引转换为常规列，并将不是汇总的字段展开
melted = pivot_table.reset_index().melt(id_vars=['A', 'B'], value_vars=pivot_table.columns.levels[1].unique(), var_name='C')
 
# 将汇总行转换为常规列
melted['C'] = melted['C'].str.split('(').str[0]
 
# 重置索引
melted = melted.dropna(subset=['C']).reset_index(drop=True)
 
print(melted)

# %%
import pandas as pd
 
# 示例数据
df = pd.DataFrame({
    'A': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'],
    'B': ['one', 'one', 'two', 'two', 'one', 'one'],
    'C': ['small', 'large', 'large', 'small', 'small', 'large'],
    'D': [1, 2, 2, 3, 3, 4],
    'E': [2, 4, 5, 5, 6, 6]
})
 
# 创建透视表，并使用margins参数汇总
pivot_table = df.pivot_table(values='D', index=['A', 'B'], columns=['C'], aggfunc='sum', margins=True)
 
# 将多层索引转换为常规列，并将不是汇总的字段展开
melted = pivot_table.reset_index().melt(id_vars=['A', 'B'], value_vars=pivot_table.columns.levels[1].unique(), var_name='C')
 
# 将汇总行转换为常规列
melted['C'] = melted['C'].str.split('(').str[0]
 
# 重置索引
melted = melted.dropna(subset=['C']).reset_index(drop=True)
 
print(melted)

# %%
import pandas as pd

# 创建示例数据集
data = {
    'A': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'],
    'B': ['one', 'one', 'two', 'two', 'one', 'one'],
    'C': [1, 2, 3, 4, 5, 6],
    'D': [7, 8, 9, 10, 11, 12]
}

df = pd.DataFrame(data)

# 创建透视表
pivot_table = pd.pivot_table(df, values='C', index='A', columns='B', aggfunc='sum', fill_value=0)
print(pivot_table)

# %%
pivot.sum()
