# %%
from pathlib import Path
import os

os.chdir(r'F:\a00nutstore\dianzhishu')
p = Path()
for i in p.glob('**/*.txt'):
    print(i.absolute())
ebooks_txt = [i.absolute() for i in p.glob('**/*.txt') ]
len(ebooks_txt)
# Out:
# F:\a00nutstore\dianzhishu\-学习JavaScript数据结构与算法第三版 Learning JavaScript Data Structures and Algorithms 3rd Edition - 未知.txt
# F:\a00nutstore\dianzhishu\-学习JavaScript数据结构与算法第三版 Learning JavaScript Data Structures and Algorithms 3rd Edition(1) - 未知.txt
# F:\a00nutstore\dianzhishu\000-神农本草经.txt
# F:\a00nutstore\dianzhishu\001-吴普本草.txt
# F:\a00nutstore\dianzhishu\002-本草经集注.txt
# F:\a00nutstore\dianzhishu\003-新修本草.txt
# F:\a00nutstore\dianzhishu\004-食疗本草.txt
# F:\a00nutstore\dianzhishu\005-海药本草.txt
# F:\a00nutstore\dianzhishu\006-本草图经.txt
# F:\a00nutstore\dianzhishu\007-本草衍义.txt
# F:\a00nutstore\dianzhishu\008-汤液本草.txt
# F:\a00nutstore\dianzhishu\009-饮膳正要.txt
# F:\a00nutstore\dianzhishu\01.txt
# F:\a00nutstore\dianzhishu\010-滇南本草.txt
# F:\a00nutstore\dianzhishu\011-本草品汇精要.txt
# F:\a00nutstore\dianzhishu\012-本草蒙筌.txt
# F:\a00nutstore\dianzhishu\013-本草纲目.txt
# F:\a00nutstore\dianzhishu\014-本草乘雅半偈.txt
# F:\a00nutstore\dianzhishu\015-本草征要.txt
# F:\a00nutstore\dianzhishu\016-本草易读.txt
# ...

# %%
def shout(text):
    return text.upper()

def whisper(text):
    return text.lower()

def greet(func):
    # 将函数存储在变量中
    greeting = func("Hi, I am created by a function \
    passed as an argument.")
    print(greeting)

# %%
greet(shout)
# Out:
# HI, I AM CREATED BY A FUNCTION     PASSED AS AN ARGUMENT.
