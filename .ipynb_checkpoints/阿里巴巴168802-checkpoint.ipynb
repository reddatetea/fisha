# %%
import numpy as np
import pandas as pd
import os
import easygui
import openpyxl

# %%
def alibabaXiaoshouMingxi(fname):
    
    df = pd.read_excel(fname,dtype = {'订单号':'str','Offer_ID':'str', 'SKU_ID':'str'})
    col1s = ['订单号','卖家公司名称', '卖家会员名','订单状态', '订单创建时间', '订单付款时间', '收货人姓名', '收货地址', '邮编',
       '联系手机',  '货运公司', '运单号']
    col2s = ['货品总价', '运费（元）', '商家改价（元）',
           '实付款（元）']
    for col in col1s:
        df[col] =  df[col].ffill()
    for col in col2s :
        df[col] = df[col].fillna(0)
    return df

fname = r"F:\a00nutstore\008\zw08\电商\阿里巴巴1688\阿里巴巴销售明细20240726-20241025.xlsx"

df = alibabaXiaoshouMingxi(fname)
df
# Out:
# C:\Users\redda\.conda\envs\py311\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                       订单号        买家公司名称            买家会员      卖家公司名称  \
# 0     4098972747591264809           NaN      tb60477203  湖北双佳纸品有限公司
# 1     2343366266994598999  任剑（个人）天津良子轮胎   supermissiler  湖北双佳纸品有限公司
# 2     4098081853230213312           NaN    简简单单的小幸福1995  湖北双佳纸品有限公司
# 3     2342481888793527358           NaN     tb658008243  湖北双佳纸品有限公司
# 4     2342481888793527358           NaN             NaN  湖北双佳纸品有限公司
# ...                   ...           ...             ...         ...
# 1413  4022631722109203749           NaN             NaN  湖北双佳纸品有限公司
# 1414  2273049049602822267           NaN           尚贤增88  湖北双佳纸品有限公司
# 1415  2269186502496746753        李菲（个人）  more_lion_shop  湖北双佳纸品有限公司
# 1416  2268563451685578186           NaN       许55555555  湖北双佳纸品有限公司
# 1417  2267184001595653481           NaN       独自的浪漫1314  湖北双佳纸品有限公司
#
#            卖家会员名   货品总价  运费（元）  商家改价（元）  实付款（元）      订单状态  ...       买家留言  \
# 0     湖北双佳纸品有限公司   8.64    2.5      0.0   11.14  等待买家确认收货  ...        NaN
# 1     湖北双佳纸品有限公司   6.76    2.5      0.0    9.26      交易关闭  ...        NaN
# 2     湖北双佳纸品有限公司  11.80    3.0      0.0   14.80      交易关闭  ...        NaN
# 3     湖北双佳纸品有限公司  78.70    8.5      0.0   87.20  等待买家确认收货  ...        NaN
# 4     湖北双佳纸品有限公司   0.00    0.0      0.0    0.00  等待买家确认收货  ...        NaN
# ...          ...    ...    ...      ...     ...       ...  ...        ...
# 1413  湖北双佳纸品有限公司   0.00    0.0      0.0    0.00      交易关闭  ...        NaN
# 1414  湖北双佳纸品有限公司  88.00   17.0     11.0  116.00      交易成功  ...  换成16K大方格本
# 1415  湖北双佳纸品有限公司  15.60    4.3      0.0   19.90      交易成功  ...        NaN
# 1416  湖北双佳纸品有限公司  60.12   11.0      0.0   71.12      交易成功  ...        NaN
# 1417  湖北双佳纸品有限公司  17.80    4.1      0.0   21.90      交易关闭  ...        NaN
#
#             货运公司              运单号 发票：购货单位名称  发票：纳税人识别号 发票：地址、电话 发票：开户行及账号  \
# 0      申通快递(STO)  773318114549095       NaN        NaN      NaN       NaN
# 1      申通快递(STO)  773318114549095       NaN        NaN      NaN       NaN
# 2      申通快递(STO)  773318114549095       NaN        NaN      NaN       NaN
# 3      申通快递(STO)  773318114549089       NaN        NaN      NaN       NaN
# 4      申通快递(STO)  773318114549089       NaN        NaN      NaN       NaN
# ...          ...              ...       ...        ...      ...       ...
# 1413  武汉兆通物流有限公司          0003539       NaN        NaN      NaN       NaN
# 1414   圆通速递(YTO)  YT7488519267802       NaN        NaN      NaN       NaN
# 1415   圆通速递(YTO)  YT7488056363210       NaN        NaN      NaN       NaN
# 1416   圆通速递(YTO)  YT7488055698555       NaN        NaN      NaN       NaN
# 1417   圆通速递(YTO)  YT7488055698555       NaN        NaN      NaN       NaN
#
#      发票：收取地址  下游订单号  下单公司主体
# 0        NaN    NaN     NaN
# 1        NaN    NaN     NaN
# 2        NaN    NaN     NaN
# 3        NaN    NaN     NaN
# 4        NaN    NaN     NaN
# ...      ...    ...     ...
# 1413     NaN    NaN     NaN
# 1414     NaN    NaN     NaN
# 1415     NaN    NaN     NaN
# 1416     NaN    NaN     NaN
# 1417     NaN    NaN     NaN
#
# [1418 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['订单号', '买家公司名称', '买家会员', '卖家公司名称', '卖家会员名', '货品总价', '运费（元）', '商家改价（元）',
#        '实付款（元）', '订单状态', '订单创建时间', '订单付款时间', '收货人姓名', '收货地址', '邮编', '联系电话',
#        '联系手机', '货品标题', '单价', '数量', '单位', '货号', '型号', 'Offer_ID', 'SKU_ID',
#        '单品货号', '货品种类', '买家留言', '货运公司', '运单号', '发票：购货单位名称', '发票：纳税人识别号',
#        '发票：地址、电话', '发票：开户行及账号', '发票：收取地址', '下游订单号', '下单公司主体'],
#       dtype='object')

# %%
df
# Out:
#                      订单号  买家公司名称            买家会员      卖家公司名称       卖家会员名  \
# 0    4054481389350287434     NaN     tb495545290  湖北双佳纸品有限公司  湖北双佳纸品有限公司
# 1    2302335878999211769     NaN      tb61302274  湖北双佳纸品有限公司  湖北双佳纸品有限公司
# 2    4054364100298074108     NaN     jiangwurong  湖北双佳纸品有限公司  湖北双佳纸品有限公司
# 3    4054343906130608732     NaN           阿修罗彭彭  湖北双佳纸品有限公司  湖北双佳纸品有限公司
# 4    4054343906130608732     NaN             NaN         NaN         NaN
# ..                   ...     ...             ...         ...         ...
# 703  4022631722109203749     NaN             NaN         NaN         NaN
# 704  2273049049602822267     NaN           尚贤增88  湖北双佳纸品有限公司  湖北双佳纸品有限公司
# 705  2269186502496746753  李菲（个人）  more_lion_shop  湖北双佳纸品有限公司  湖北双佳纸品有限公司
# 706  2268563451685578186     NaN       许55555555  湖北双佳纸品有限公司  湖北双佳纸品有限公司
# 707  2267184001595653481     NaN       独自的浪漫1314  湖北双佳纸品有限公司  湖北双佳纸品有限公司
#
#       货品总价  运费（元）  商家改价（元）  实付款（元）      订单状态  ...       买家留言        货运公司  \
# 0     9.81    4.1      0.0   13.91  等待买家确认收货  ...        NaN   圆通速递(YTO)
# 1     4.70    2.8      0.0    7.50    等待买家付款  ...        NaN   圆通速递(YTO)
# 2    28.80    7.3      0.0   36.10  等待买家确认收货  ...        NaN   圆通速递(YTO)
# 3     9.40    5.5      0.0   14.90  等待买家确认收货  ...        NaN   圆通速递(YTO)
# 4     0.00    0.0      0.0    0.00  等待买家确认收货  ...        NaN   圆通速递(YTO)
# ..     ...    ...      ...     ...       ...  ...        ...         ...
# 703   0.00    0.0      0.0    0.00      交易关闭  ...        NaN  武汉兆通物流有限公司
# 704  88.00   17.0     11.0  116.00      交易成功  ...  换成16K大方格本   圆通速递(YTO)
# 705  15.60    4.3      0.0   19.90      交易成功  ...        NaN   圆通速递(YTO)
# 706  60.12   11.0      0.0   71.12      交易成功  ...        NaN   圆通速递(YTO)
# 707  17.80    4.1      0.0   21.90      交易关闭  ...        NaN   圆通速递(YTO)
#
#                  运单号 发票：购货单位名称  发票：纳税人识别号 发票：地址、电话 发票：开户行及账号 发票：收取地址  下游订单号  \
# 0    YT7494213188905       NaN        NaN      NaN       NaN     NaN    NaN
# 1    YT7494213188905       NaN        NaN      NaN       NaN     NaN    NaN
# 2    YT7494213268645       NaN        NaN      NaN       NaN     NaN    NaN
# 3    YT7494141474936       NaN        NaN      NaN       NaN     NaN    NaN
# 4    YT7494141474936       NaN        NaN      NaN       NaN     NaN    NaN
# ..               ...       ...        ...      ...       ...     ...    ...
# 703          0003539       NaN        NaN      NaN       NaN     NaN    NaN
# 704  YT7488519267802       NaN        NaN      NaN       NaN     NaN    NaN
# 705  YT7488056363210       NaN        NaN      NaN       NaN     NaN    NaN
# 706  YT7488055698555       NaN        NaN      NaN       NaN     NaN    NaN
# 707  YT7488055698555       NaN        NaN      NaN       NaN     NaN    NaN
#
#      下单公司主体
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 703     NaN
# 704     NaN
# 705     NaN
# 706     NaN
# 707     NaN
#
# [708 rows x 37 columns]

# %%
df.to_excel('阿里巴巴销售明细已加工0726-1025.xlsx')

# %%
pivot = df.pivot_table(index = '单品货号',values = ['数量','货品总价','运费（元）','商家改价（元）','实付款（元）'] ,aggfunc = 'sum')
pivot
# Out:
#               商家改价（元）  实付款（元）  数量   货品总价  运费（元）
# 单品货号
# 16K备课本-30P        0.0   53.70  30  40.60   13.1
# 16K备课本-50P        0.0    0.00  10   0.00    0.0
# 2002              0.0    0.00  10   0.00    0.0
# 2003              0.0   88.60  50  75.60   13.0
# 2004              0.0    0.00  10   0.00    0.0
# ...               ...     ...  ..    ...    ...
# SMA440C-日常循环      0.0   12.32   2   9.32    3.0
# SMA440C-街边小巷      0.0  106.40  22  93.20   13.2
# SMA440C-风的颜色      0.0   22.94   1  18.64    4.3
# SMA460HB          0.0   16.82   2  12.52    4.3
# SMA460N           0.0    0.00   7   0.00    0.0
#
# [262 rows x 5 columns]

# %%
pivot = pivot.reset_index()
pivot
# Out:
#              单品货号  商家改价（元）  实付款（元）  数量   货品总价  运费（元）
# 0      16K备课本-30P      0.0   53.70  30  40.60   13.1
# 1      16K备课本-50P      0.0    0.00  10   0.00    0.0
# 2            2002      0.0    0.00  10   0.00    0.0
# 3            2003      0.0   88.60  50  75.60   13.0
# 4            2004      0.0    0.00  10   0.00    0.0
# ..            ...      ...     ...  ..    ...    ...
# 257  SMA440C-日常循环      0.0   12.32   2   9.32    3.0
# 258  SMA440C-街边小巷      0.0  106.40  22  93.20   13.2
# 259  SMA440C-风的颜色      0.0   22.94   1  18.64    4.3
# 260      SMA460HB      0.0   16.82   2  12.52    4.3
# 261       SMA460N      0.0    0.00   7   0.00    0.0
#
# [262 rows x 6 columns]

# %%
pivot.sum()
# Out:
# 商家改价（元）    -1621.03
# 实付款（元）     82848.47
# 数量         57619.00
# 货品总价       74620.70
# 运费（元）       9848.80
# dtype: float64

# %%
total = pivot.sum().to_frame().T
total
# Out:
#                                                 单品货号  商家改价（元）    实付款（元）  \
# 0  16K备课本-30P16K备课本-50P20022003200423013001300330... -1621.03  82848.47
#
#       数量     货品总价   运费（元）
# 0  57619  74620.7  9848.8

# %%
result = pd.concat([pivot,total])
result
# Out:
#                                                   单品货号  商家改价（元）    实付款（元）  \
# 0                                           16K备课本-30P      0.0      53.7
# 1                                           16K备课本-50P      0.0       0.0
# 2                                                 2002      0.0       0.0
# 3                                                 2003      0.0      88.6
# 4                                                 2004      0.0       0.0
# ..                                                 ...      ...       ...
# 258                                       SMA440C-街边小巷      0.0     106.4
# 259                                       SMA440C-风的颜色      0.0     22.94
# 260                                           SMA460HB      0.0     16.82
# 261                                            SMA460N      0.0       0.0
# 0    16K备课本-30P16K备课本-50P20022003200423013001300330... -1621.03  82848.47
#
#         数量     货品总价   运费（元）
# 0       30     40.6    13.1
# 1       10      0.0     0.0
# 2       10      0.0     0.0
# 3       50     75.6    13.0
# 4       10      0.0     0.0
# ..     ...      ...     ...
# 258     22     93.2    13.2
# 259      1    18.64     4.3
# 260      2    12.52     4.3
# 261      7      0.0     0.0
# 0    57619  74620.7  9848.8
#
# [263 rows x 6 columns]

# %%
result.iloc[-1,0] = '小计'
result =  result[['单品货号','数量','货品总价','运费（元）','商家改价（元）','实付款（元）']]
result
# Out:
#              单品货号     数量     货品总价   运费（元）  商家改价（元）    实付款（元）
# 0      16K备课本-30P     30     40.6    13.1      0.0      53.7
# 1      16K备课本-50P     10      0.0     0.0      0.0       0.0
# 2            2002     10      0.0     0.0      0.0       0.0
# 3            2003     50     75.6    13.0      0.0      88.6
# 4            2004     10      0.0     0.0      0.0       0.0
# ..            ...    ...      ...     ...      ...       ...
# 258  SMA440C-街边小巷     22     93.2    13.2      0.0     106.4
# 259  SMA440C-风的颜色      1    18.64     4.3      0.0     22.94
# 260      SMA460HB      2    12.52     4.3      0.0     16.82
# 261       SMA460N      7      0.0     0.0      0.0       0.0
# 0              小计  57619  74620.7  9848.8 -1621.03  82848.47
#
# [263 rows x 6 columns]
