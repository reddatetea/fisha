# %%
'''
1. 将拼多多收入与订单合并
2. 对收入分别按订单汇总、按存货编码汇总
'''

import easygui
import os
import pandas as pd
import re
import numpy as np

# %%
#所有订单
fname_dingdan = r"F:\a00nutstore\008\zw08\电商\拼多多\100306881orders_export2024-09-30-16-58-49.csv"
df_dingdan0 = pd.read_csv(fname_dingdan)
df_dingdan0
# Out:
#                                       商品                     订单号      订单状态  \
# 0         500页加厚英语定位练习纸本英语定位纸英文专用纸小学初中高中  240929-658935703962749   已发货，待收货
# 1         500页加厚英语定位练习纸本英语定位纸英文专用纸小学初中高中  240929-379762829722749   已发货，待收货
# 2      莱特5本加厚200页B5学生笔记本办公记事本白领工作记录本子笔记本  240929-211738969641353   已发货，待收货
# 3      莱特5本加厚200页B5学生笔记本办公记事本白领工作记录本子笔记本  240929-611277893212149   已发货，待收货
# 4      莱特5本加厚200页B5学生笔记本办公记事本白领工作记录本子笔记本  240929-080425849263824  未发货，退款成功
# ...                                  ...                     ...       ...
# 41135    16K大号加厚牛皮作业本学校统一学生语文本数学本初中英语作文本  240702-510289580363661       已收货
# 41136    16K大号加厚牛皮作业本学校统一学生语文本数学本初中英语作文本  240702-287404224311832       已收货
# 41137    16K大号加厚牛皮作业本学校统一学生语文本数学本初中英语作文本  240702-631777533741211       已收货
# 41138  莱特5本加厚200页B5学生笔记本办公记事本白领工作记录本子笔记本  240702-322510569881909       已收货
# 41139  莱特5本加厚200页B5学生笔记本办公记事本白领工作记录本子笔记本  240702-241854082650868       已收货
#
#        商品数量(件) 是否审核中             支付时间           承诺发货时间  承诺送达时间  \
# 0            1    正常  2024/9/29 23:49  2024/10/1 23:49     NaN
# 1            1    正常  2024/9/29 23:49  2024/10/1 23:49     NaN
# 2            1    正常  2024/9/29 23:44  2024/10/1 23:44     NaN
# 3            1    正常  2024/9/29 23:37  2024/10/1 23:37     NaN
# 4            1    正常  2024/9/29 23:34  2024/10/1 23:34     NaN
# ...        ...   ...              ...              ...     ...
# 41135        1    正常    2024/7/2 6:59    2024/7/4 6:59     NaN
# 41136        1    正常    2024/7/2 6:42    2024/7/4 6:42     NaN
# 41137        1    正常    2024/7/2 6:17    2024/7/4 6:17     NaN
# 41138        1    正常    2024/7/2 1:01    2024/7/4 1:01     NaN
# 41139        1    正常    2024/7/2 0:54    2024/7/4 0:54     NaN
#
#                   发货时间          确认收货时间  ...  预约配送时间 是否节能补贴  是否分期 分期期数 手续费承担方  \
# 0      2024/9/30 11:14              \t  ...      \t      否     否  NaN     \t
# 1      2024/9/30 11:14              \t  ...      \t      否     否  NaN     \t
# 2      2024/9/30 11:14              \t  ...      \t      否     否  NaN     \t
# 3      2024/9/30 11:14              \t  ...      \t      否     否  NaN     \t
# 4                   \t              \t  ...      \t      否     否  NaN     \t
# ...                ...             ...  ...     ...    ...   ...  ...    ...
# 41135    2024/7/2 8:15  2024/7/12 8:15  ...      \t      否     否  NaN     \t
# 41136    2024/7/2 8:15  2024/7/7 10:47  ...      \t      否     否  NaN     \t
# 41137    2024/7/2 8:15  2024/7/12 8:15  ...      \t      否     否  NaN     \t
# 41138    2024/7/2 8:15  2024/7/12 8:15  ...      \t      否     否  NaN     \t
# 41139    2024/7/2 8:15  2024/7/5 19:16  ...      \t      否     否  NaN     \t
#
#       是否无痕发货 订单来源 是否社区团购 小区送达情况 分期方式
# 0          否   \t      否    NaN  NaN
# 1          否   \t      否    NaN  NaN
# 2          否   \t      否    NaN  NaN
# 3          否   \t      否    NaN  NaN
# 4          否   \t      否    NaN  NaN
# ...      ...  ...    ...    ...  ...
# 41135      否   \t      否    NaN  NaN
# 41136      否   \t      否    NaN  NaN
# 41137      否   \t      否    NaN  NaN
# 41138      否   \t      否    NaN  NaN
# 41139      否   \t      否    NaN  NaN
#
# [41140 rows x 82 columns]

# %%
df_dingdan1 = df_dingdan0[['订单号','发货时间','商家编码-规格维度','商家实收金额(元)','商品数量(件)']]
df_dingdan1
# Out:
#                           订单号             发货时间    商家编码-规格维度  商家实收金额(元)  \
# 0      240929-658935703962749  2024/9/30 11:14  EJDWB550-英高       7.84
# 1      240929-379762829722749  2024/9/30 11:14  EJDWB550-英初       7.83
# 2      240929-211738969641353  2024/9/30 11:14        N0581       7.85
# 3      240929-611277893212149  2024/9/30 11:14        N0483       9.57
# 4      240929-080425849263824               \t        N0481       4.27
# ...                       ...              ...          ...        ...
# 41135  240702-510289580363661    2024/7/2 8:15    N0782(线条)      10.40
# 41136  240702-287404224311832    2024/7/2 8:15    N0782(线条)       8.84
# 41137  240702-631777533741211    2024/7/2 8:15    N0781(线条)      10.30
# 41138  240702-322510569881909    2024/7/2 8:15        N0581       8.10
# 41139  240702-241854082650868    2024/7/2 8:15        N0484      11.40
#
#        商品数量(件)
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 41135        1
# 41136        1
# 41137        1
# 41138        1
# 41139        1
#
# [41140 rows x 5 columns]

# %%
df_dingdan1.columns = ['dingdanhao','riqi','code','jiner','shuliang']
df_dingdan1[df_dingdan1['dingdanhao'].isnull()]
df_dingdan2 = df_dingdan1.set_index('dingdanhao')

# %%
#所有收入
fname_shouru = r"F:\a00nutstore\008\zw08\电商\拼多多\pdd-mall-bill-detail(100306881)_2024-09-30-07-09-49_3.csv"
df_shouru0 = pd.read_csv(fname_shouru,header =4,encoding = 'gb18030')
df_shouru0
# Out:
#                            商户订单号                 发生时间  收入金额（+元）  支出金额（-元）  \
# 0         240928-589247332703567  2024-09-28 23:45:05      0.07      0.00
# 1         240928-589247332703567  2024-09-28 23:45:05      0.00    -10.48
# 2         240928-589247332703567  2024-09-28 23:45:05      0.00     -1.82
# 3         240928-589247332703567  2024-09-28 23:45:05     10.48      0.00
# 4         240928-589247332703567  2024-09-28 23:45:05      1.82      0.00
# ...                          ...                  ...       ...       ...
# 64698     240821-114588465571867  2024-09-01 00:00:00      0.00     -1.00
# 64699    #支出合计：38362笔-271037.53元                  NaN       NaN       NaN
# 64700     #收入合计：26337笔245178.31元                  NaN       NaN       NaN
# 64701             #总计：-25859.22元                  NaN       NaN       NaN
# 64702  #导出时间：2024-09-30 07:10:02                  NaN       NaN       NaN
#
#         账务类型             备注                       业务描述
# 0      技术服务费      基础技术服务费返还      0030002|技术服务费-基础技术服务费
# 1         退款              -          0020002|交易退款-订单退款
# 2      优惠券结算    退款扣除优惠券支付金额         0020005|交易退款-优惠券结算
# 3       交易收入              -          0010002|交易收入-订单收入
# 4      优惠券结算  交易成功优惠券支付金额结算         0010005|交易收入-优惠券结算
# ...      ...            ...                        ...
# 64698  技术服务费    偏远地区中转软件服务费  0030015|技术服务费-偏远地区中转软件服务费
# 64699    NaN            NaN                        NaN
# 64700    NaN            NaN                        NaN
# 64701    NaN            NaN                        NaN
# 64702    NaN            NaN                        NaN
#
# [64703 rows x 7 columns]

# %%
df_shouru1 = df_shouru0.dropna(thresh = 3)
df_shouru1
# Out:
#                         商户订单号                 发生时间  收入金额（+元）  支出金额（-元）   账务类型  \
# 0      240928-589247332703567  2024-09-28 23:45:05      0.07      0.00  技术服务费
# 1      240928-589247332703567  2024-09-28 23:45:05      0.00    -10.48     退款
# 2      240928-589247332703567  2024-09-28 23:45:05      0.00     -1.82  优惠券结算
# 3      240928-589247332703567  2024-09-28 23:45:05     10.48      0.00   交易收入
# 4      240928-589247332703567  2024-09-28 23:45:05      1.82      0.00  优惠券结算
# ...                       ...                  ...       ...       ...    ...
# 64694  240828-389325790852304  2024-09-01 00:04:57      0.00     -0.06  技术服务费
# 64695  240821-114588465571867  2024-09-01 00:00:00      0.00     -2.00     分账
# 64696  240821-114588465571867  2024-09-01 00:00:00      0.00     -0.05  技术服务费
# 64697  240821-114588465571867  2024-09-01 00:00:00      8.24      0.00   交易收入
# 64698  240821-114588465571867  2024-09-01 00:00:00      0.00     -1.00  技术服务费
#
#                   备注                       业务描述
# 0          基础技术服务费返还      0030002|技术服务费-基础技术服务费
# 1                  -          0020002|交易退款-订单退款
# 2        退款扣除优惠券支付金额         0020005|交易退款-优惠券结算
# 3                  -          0010002|交易收入-订单收入
# 4      交易成功优惠券支付金额结算         0010005|交易收入-优惠券结算
# ...              ...                        ...
# 64694              -      0030002|技术服务费-基础技术服务费
# 64695     偏远地区物流费用扣除          0140002|其他支出-分账支出
# 64696              -      0030002|技术服务费-基础技术服务费
# 64697              -          0010002|交易收入-订单收入
# 64698    偏远地区中转软件服务费  0030015|技术服务费-偏远地区中转软件服务费
#
# [64699 rows x 7 columns]

# %%
string = '2024-09-28售后补偿现金券扣款（订单240923-652476454442206）'
regax = r'（订单(?P<dingdanhao>\d{6}-\d{15})）'
pattern = re.compile(regax)
mat = pattern.search(string)
if mat :
    dingdanhao = mat.group('dingdanhao')
else :
    pass

# %%
def getDingdanhao(s):
    mat = pattern.search(string)
    if mat :
        s = mat.group('dingdanhao')
    else :
        s = ''
    return s

# %%
df_shouru1['商户订单号']= df_shouru1['商户订单号'].mask(df_shouru1['商户订单号'].isnull(),df_shouru1['备注'].map(getDingdanhao))
df_shouru1
# Out:
#                         商户订单号                 发生时间  收入金额（+元）  支出金额（-元）   账务类型  \
# 0      240928-589247332703567  2024-09-28 23:45:05      0.07      0.00  技术服务费
# 1      240928-589247332703567  2024-09-28 23:45:05      0.00    -10.48     退款
# 2      240928-589247332703567  2024-09-28 23:45:05      0.00     -1.82  优惠券结算
# 3      240928-589247332703567  2024-09-28 23:45:05     10.48      0.00   交易收入
# 4      240928-589247332703567  2024-09-28 23:45:05      1.82      0.00  优惠券结算
# ...                       ...                  ...       ...       ...    ...
# 64694  240828-389325790852304  2024-09-01 00:04:57      0.00     -0.06  技术服务费
# 64695  240821-114588465571867  2024-09-01 00:00:00      0.00     -2.00     分账
# 64696  240821-114588465571867  2024-09-01 00:00:00      0.00     -0.05  技术服务费
# 64697  240821-114588465571867  2024-09-01 00:00:00      8.24      0.00   交易收入
# 64698  240821-114588465571867  2024-09-01 00:00:00      0.00     -1.00  技术服务费
#
#                   备注                       业务描述
# 0          基础技术服务费返还      0030002|技术服务费-基础技术服务费
# 1                  -          0020002|交易退款-订单退款
# 2        退款扣除优惠券支付金额         0020005|交易退款-优惠券结算
# 3                  -          0010002|交易收入-订单收入
# 4      交易成功优惠券支付金额结算         0010005|交易收入-优惠券结算
# ...              ...                        ...
# 64694              -      0030002|技术服务费-基础技术服务费
# 64695     偏远地区物流费用扣除          0140002|其他支出-分账支出
# 64696              -      0030002|技术服务费-基础技术服务费
# 64697              -          0010002|交易收入-订单收入
# 64698    偏远地区中转软件服务费  0030015|技术服务费-偏远地区中转软件服务费
#
# [64699 rows x 7 columns]

# %%
df_shouru1.columns = ['dingdanhao', 'riqi', 'ru', 'chu', 'leixing', 'beizhu', 'miaoshu']

# %%
df_shouru2 = df_shouru1.loc[df_shouru1.leixing != '提现']
df_shouru2
# Out:
#                    dingdanhao                 riqi     ru    chu leixing  \
# 0      240928-589247332703567  2024-09-28 23:45:05   0.07   0.00   技术服务费
# 1      240928-589247332703567  2024-09-28 23:45:05   0.00 -10.48      退款
# 2      240928-589247332703567  2024-09-28 23:45:05   0.00  -1.82   优惠券结算
# 3      240928-589247332703567  2024-09-28 23:45:05  10.48   0.00    交易收入
# 4      240928-589247332703567  2024-09-28 23:45:05   1.82   0.00   优惠券结算
# ...                       ...                  ...    ...    ...     ...
# 64694  240828-389325790852304  2024-09-01 00:04:57   0.00  -0.06   技术服务费
# 64695  240821-114588465571867  2024-09-01 00:00:00   0.00  -2.00      分账
# 64696  240821-114588465571867  2024-09-01 00:00:00   0.00  -0.05   技术服务费
# 64697  240821-114588465571867  2024-09-01 00:00:00   8.24   0.00    交易收入
# 64698  240821-114588465571867  2024-09-01 00:00:00   0.00  -1.00   技术服务费
#
#               beizhu                    miaoshu
# 0          基础技术服务费返还      0030002|技术服务费-基础技术服务费
# 1                  -          0020002|交易退款-订单退款
# 2        退款扣除优惠券支付金额         0020005|交易退款-优惠券结算
# 3                  -          0010002|交易收入-订单收入
# 4      交易成功优惠券支付金额结算         0010005|交易收入-优惠券结算
# ...              ...                        ...
# 64694              -      0030002|技术服务费-基础技术服务费
# 64695     偏远地区物流费用扣除          0140002|其他支出-分账支出
# 64696              -      0030002|技术服务费-基础技术服务费
# 64697              -          0010002|交易收入-订单收入
# 64698    偏远地区中转软件服务费  0030015|技术服务费-偏远地区中转软件服务费
#
# [64691 rows x 7 columns]

# %%
df_shouru2 = df_shouru2.assign(shouru = df_shouru2['ru'] - df_shouru2['chu'])

# %%
shouru_pivot =df_shouru2.pivot_table(index = 'dingdanhao',values =['ru','chu','shouru'],aggfunc = np.sum)
shouru_pivot
# Out:
# C:\Users\redda\AppData\Local\Temp\ipykernel_10496\1162122181.py:1: FutureWarning: The provided callable <function sum at 0x0000000008C389A0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   shouru_pivot =df_shouru2.pivot_table(index = 'dingdanhao',values =['ru','chu','shouru'],aggfunc = np.sum)
#                           chu     ru  shouru
# dingdanhao
# 240625-246792907173009  -9.30   0.00    9.30
# 240726-232312041021446 -10.50   0.00   10.50
# 240809-164878108243433  -3.03   4.62    7.65
# 240809-238215523923433  -3.03   5.52    8.55
# 240809-265205911990340  -3.13  21.80   24.93
# ...                       ...    ...     ...
# 240928-654951104900645  -0.16   0.00    0.16
# 240928-655968212500341  -4.37   4.37    8.74
# 240928-657457201572709  -0.16   0.00    0.16
# 240928-676488886633923  -0.16   0.00    0.16
# 240928-686282534523288  -0.16   0.00    0.16
#
# [20840 rows x 3 columns]

# %%
df_dingdan2
# Out:
#                                        riqi         code  jiner  shuliang
# dingdanhao
# 240929-658935703962749                   \t  EJDWB550-英高   7.84         1
# 240929-379762829722749                   \t  EJDWB550-英初   7.83         1
# 240929-211738969641353                   \t        N0581   7.85         1
# 240929-611277893212149                   \t        N0483   9.57         1
# 240929-080425849263824                   \t        N0481   4.27         1
# ...                                     ...          ...    ...       ...
# 240702-510289580363661  2024-07-02 08:15:27    N0782(线条)  10.40         1
# 240702-287404224311832  2024-07-02 08:15:27    N0782(线条)   8.84         1
# 240702-631777533741211  2024-07-02 08:15:27    N0781(线条)  10.30         1
# 240702-322510569881909  2024-07-02 08:15:27        N0581   8.10         1
# 240702-241854082650868  2024-07-02 08:15:27        N0484  11.40         1
#
# [41140 rows x 4 columns]

# %%
result0 =pd.merge(shouru_pivot,df_dingdan2,left_index = True,right_index = True,how = 'outer')
result0
# Out:
#                         chu   ru  shouru                 riqi  \
# dingdanhao
# 240625-246792907173009 -9.3  0.0     9.3                  NaN
# 240702-000068165411457  NaN  NaN     NaN  2024-07-02 12:17:16
# 240702-002668706081035  NaN  NaN     NaN  2024-07-02 08:15:27
# 240702-012284137890533  NaN  NaN     NaN  2024-07-03 08:07:05
# 240702-016968630670521  NaN  NaN     NaN  2024-07-03 08:07:05
# ...                     ...  ...     ...                  ...
# 240929-678994941551326  NaN  NaN     NaN                   \t
# 240929-682077734432425  NaN  NaN     NaN  2024-09-29 15:43:44
# 240929-683021473293766  NaN  NaN     NaN  2024-09-29 11:48:01
# 240929-684940367432513  NaN  NaN     NaN  2024-09-29 11:48:01
# 240929-686188172851853  NaN  NaN     NaN                   \t
#
#                                     code  jiner  shuliang
# dingdanhao
# 240625-246792907173009               NaN    NaN       NaN
# 240702-000068165411457         N0781(线条)   5.90       1.0
# 240702-002668706081035         N0781(方格)   5.85       1.0
# 240702-012284137890533             N0482   8.10       1.0
# 240702-016968630670521             N0783  10.30       1.0
# ...                                  ...    ...       ...
# 240929-678994941551326             N0582  10.90       1.0
# 240929-682077734432425  RFZW-A460N（500格）  15.50       1.0
# 240929-683021473293766             N0481   4.27       1.0
# 240929-684940367432513           FYP1660  13.50       1.0
# 240929-686188172851853             N0423  11.29       2.0
#
# [41141 rows x 7 columns]

# %%
result0.to_excel('分配前outer-2.xlsx')
# Out:
# C:\Users\redda\AppData\Local\Temp\ipykernel_10496\620990443.py:1: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   result0.to_excel('分配前outer-2.xlsx')

# %%
df_dingdan2.to_excel('订单号.xlsx')

# %%
left = pd.read_clipboard()
left

# %%
right = pd.read_clipboard()
right

# %%
test_result = pd.merge(left = left,right = right,how = 'outer')
test_result

# %%
test_result = pd.merge(right = right,left = left,how = 'outer')
test_result

# %%
len(result0.index.unique())
# Out:
# 41141

# %%
df_dingdan2.to_excel('订单号2.xlsx')
# Out:
# C:\Users\redda\AppData\Local\Temp\ipykernel_10496\391330162.py:1: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   df_dingdan2.to_excel('订单号2.xlsx')
