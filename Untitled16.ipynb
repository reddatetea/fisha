# %%
import pandas as pd

# %%
df = pd.read_clipboard()
df
# Out:
#              存货名称      规格型号 采购单位      数量    税率%    含税单价    含税金额 赠品  现存量
# 0          32K拼音本  B8小学生作业本    本  6000.0  0.00%  0.2064  1238.4  否  NaN
# 1          32K小字本  B8小学生作业本    本  6000.0  0.00%  0.2064  1238.4  否  NaN
# 2          32K拼写本  B8小学生作业本    本  4000.0  0.00%  0.2064   825.6  否  NaN
# 3          32K写字本  B8小学生作业本    本  2000.0  0.00%  0.2064   412.8  否  NaN
# 4          32K图画本  B8小学生作业本    本  2000.0  0.00%  0.2064   412.8  否  NaN
# 5   16K60型牛卡缝线日记本   B11订制产品    本  2000.0  0.00%  0.6560  1312.0  否  NaN
# 6   16K60型牛卡缝线生字本   B11订制产品    本  4000.0  0.00%  0.6560  2624.0  否  NaN
# 7   16K60型牛卡缝线物理本   B11订制产品    本  2000.0  0.00%  0.6560  1312.0  否  NaN
# 8   16K60型牛卡缝线英语本   B11订制产品    本  6000.0  0.00%  0.6560  3936.0  否  NaN
# 9   16K60型牛卡缝线政治本   B11订制产品    本  2000.0  0.00%  0.6560  1312.0  否  NaN
# 10  16K60型牛卡缝线地理本   B11订制产品    本  1000.0  0.00%  0.6560   656.0  否  NaN
# 11  16K60型牛卡缝线日记本   B11订制产品    本  1000.0  0.00%  0.6560   656.0  否  NaN
# 12  16K60型牛卡缝线英语本   B11订制产品    本  4000.0  0.00%  0.6560  2624.0  否  NaN
# 13  16K60型牛卡缝线语文本   B11定制产品    本  4000.0  0.00%  0.6560  2624.0  否  NaN
# 14  16K60型牛卡缝线作文本   B11订制产品    本  2400.0  0.00%  0.6560  1574.4  否  NaN
# 15  16K60型牛卡缝线数学本   B11订制产品    本  4000.0  0.00%  0.6560  2624.0  否  NaN
# 16  16K60型牛卡缝线教案本   B11订制产品    本   400.0  0.00%  0.6560   262.4  否  NaN
# 17  16K60型牛卡缝线生字本   B11订制产品    本  2400.0  0.00%  0.6560  1574.4  否  NaN

# %%
df.dropna(how = 'all',axis = 1)
# Out:
#              存货名称      规格型号 采购单位      数量    税率%    含税单价    含税金额 赠品
# 0          32K拼音本  B8小学生作业本    本  6000.0  0.00%  0.2064  1238.4  否
# 1          32K小字本  B8小学生作业本    本  6000.0  0.00%  0.2064  1238.4  否
# 2          32K拼写本  B8小学生作业本    本  4000.0  0.00%  0.2064   825.6  否
# 3          32K写字本  B8小学生作业本    本  2000.0  0.00%  0.2064   412.8  否
# 4          32K图画本  B8小学生作业本    本  2000.0  0.00%  0.2064   412.8  否
# 5   16K60型牛卡缝线日记本   B11订制产品    本  2000.0  0.00%  0.6560  1312.0  否
# 6   16K60型牛卡缝线生字本   B11订制产品    本  4000.0  0.00%  0.6560  2624.0  否
# 7   16K60型牛卡缝线物理本   B11订制产品    本  2000.0  0.00%  0.6560  1312.0  否
# 8   16K60型牛卡缝线英语本   B11订制产品    本  6000.0  0.00%  0.6560  3936.0  否
# 9   16K60型牛卡缝线政治本   B11订制产品    本  2000.0  0.00%  0.6560  1312.0  否
# 10  16K60型牛卡缝线地理本   B11订制产品    本  1000.0  0.00%  0.6560   656.0  否
# 11  16K60型牛卡缝线日记本   B11订制产品    本  1000.0  0.00%  0.6560   656.0  否
# 12  16K60型牛卡缝线英语本   B11订制产品    本  4000.0  0.00%  0.6560  2624.0  否
# 13  16K60型牛卡缝线语文本   B11定制产品    本  4000.0  0.00%  0.6560  2624.0  否
# 14  16K60型牛卡缝线作文本   B11订制产品    本  2400.0  0.00%  0.6560  1574.4  否
# 15  16K60型牛卡缝线数学本   B11订制产品    本  4000.0  0.00%  0.6560  2624.0  否
# 16  16K60型牛卡缝线教案本   B11订制产品    本   400.0  0.00%  0.6560   262.4  否
# 17  16K60型牛卡缝线生字本   B11订制产品    本  2400.0  0.00%  0.6560  1574.4  否

# %%
fname = r"F:\a00nutstore\008\zw08\用友报价\单据格式\莱新进货单PuArrival.xlsx"

df = pd.read_excel(fname,skiprows = 4)
df
# df = df.dropna(how = 'all',axis = 1)
# Out:
#      Unnamed: 0    存货名称        规格型号 采购单位         数量  税率%    含税单价        含税金额  \
# 0           NaN  32K拼音本    B8小学生作业本    本       6000    0  0.2064      1238.4
# 1           NaN  32K小字本    B8小学生作业本    本       6000    0  0.2064      1238.4
# 2           NaN  32K拼写本    B8小学生作业本    本       4000    0  0.2064       825.6
# 3           NaN  32K写字本    B8小学生作业本    本       2000    0  0.2064       412.8
# 4           NaN  32K图画本    B8小学生作业本    本       2000    0  0.2064       412.8
# ..          ...     ...         ...  ...        ...  ...     ...         ...
# 256         NaN     NaN         NaN  NaN        NaN  NaN     NaN         NaN
# 257         NaN      合计         NaN  NaN  468250.00  NaN     NaN  ￥242257.29
# 258         NaN     备注：         NaN  NaN        NaN  NaN     NaN         NaN
# 259         NaN    制单人：  武汉莱新商贸有限公司  NaN        NaN  NaN     NaN         NaN
# 260         NaN   打印日期：  2024年7月28日  NaN       打印人：  张文伟     NaN       公司名称：
#
#       赠品           现存量
# 0      否           NaN
# 1      否           NaN
# 2      否           NaN
# 3      否           NaN
# 4      否           NaN
# ..   ...           ...
# 256  NaN           NaN
# 257  NaN           NaN
# 258  NaN           NaN
# 259  NaN           NaN
# 260  NaN  湖北双佳纸业销售有限公司
#
# [261 rows x 10 columns]

# %%
df = df.dropna(how = 'all',axis = 1)
df
# Out:
#        存货名称        规格型号 采购单位         数量  税率%    含税单价        含税金额   赠品  \
# 0    32K拼音本    B8小学生作业本    本       6000    0  0.2064      1238.4    否
# 1    32K小字本    B8小学生作业本    本       6000    0  0.2064      1238.4    否
# 2    32K拼写本    B8小学生作业本    本       4000    0  0.2064       825.6    否
# 3    32K写字本    B8小学生作业本    本       2000    0  0.2064       412.8    否
# 4    32K图画本    B8小学生作业本    本       2000    0  0.2064       412.8    否
# ..      ...         ...  ...        ...  ...     ...         ...  ...
# 256     NaN         NaN  NaN        NaN  NaN     NaN         NaN  NaN
# 257      合计         NaN  NaN  468250.00  NaN     NaN  ￥242257.29  NaN
# 258     备注：         NaN  NaN        NaN  NaN     NaN         NaN  NaN
# 259    制单人：  武汉莱新商贸有限公司  NaN        NaN  NaN     NaN         NaN  NaN
# 260   打印日期：  2024年7月28日  NaN       打印人：  张文伟     NaN       公司名称：  NaN
#
#               现存量
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 256           NaN
# 257           NaN
# 258           NaN
# 259           NaN
# 260  湖北双佳纸业销售有限公司
#
# [261 rows x 9 columns]
