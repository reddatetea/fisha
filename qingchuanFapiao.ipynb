# %%
import numpy as np
import pandas as pd
import easygui
import os
import re
import openpyxl

# %%
fname_pay = r"F:\a00nutstore\008\zw08\qingchuan\Payment listing [付款清单].xlsx"
df_pay = pd.read_excel(fname_pay,sheet_name = 'Sheet3',skiprows = 6,dtype = {'Account Code':'str','Base Amount':'float64','Journal No.':'str'})
df_pay
# Out:
#      Account Code              Name    Period Transaction Date  \
# 0           11500  Bank Account - 1  2022/006       2022-06-29
# 1           11500  Bank Account - 1  2022/011       2022-11-30
# 2           11500  Bank Account - 1  2023/002       2023-02-07
# 3           11500  Bank Account - 1  2023/003       2023-03-09
# 4           11500  Bank Account - 1  2023/005       2023-05-17
# ...           ...               ...       ...              ...
# 2624        11500  Bank Account - 1  2024/004       2024-04-28
# 2625        11500  Bank Account - 1  2022/007       2022-07-29
# 2626        11500  Bank Account - 1  2022/007       2022-07-29
# 2627        11500  Bank Account - 1  2023/004       2023-04-23
# 2628       Totals               NaN       NaN              NaT
#
#      Transaction Reference  Base Amount Journal No. Journal Source  \
# 0                 中2206045      -831.17       59618            CSJ
# 1                 中2211056     -1579.32       61241            CSJ
# ...

# %%
months = [''.join([str(i),'月']) for i in list(range(1,13))]
months
# Out:
# ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月']

# %%
fname_2022 = r"F:\a00nutstore\008\zw08\qingchuan\2022年已抵扣税票台账本.xlsx"
data =  pd.read_excel(fname_2022,sheet_name ='1月',skiprows = 1)
data
# Out:
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#       序号           销售单位名称            销售方纳税识别号       开票日期       发票号码      发票金额  \
# 0      1   武汉市武昌区清源广告材料商行  92420106MA4KROYKXM 2021-12-23  1651882.0   1643.53
# 1      2    武汉市福生装饰工程有限公司  914201027375338996 2021-12-10  5861371.0  27227.72
# 2      3    武汉市福生装饰工程有限公司  914201027375338996 2021-12-10  5861372.0     25800
# 3      4   武汉市鑫福运汽车服务有限公司  91420105568376465G 2021-12-28  1595149.0    217.82
# 4      5  武汉市江汉区平凡冰冻食品经营部  92420103WA4KPEJI1R 2021-12-29  1571643.0   1769.72
# ..   ...              ...                 ...        ...        ...       ...
# 118  NaN              NaN                 NaN        NaT        NaN       NaN
# 119  NaN              NaN                 NaN        NaT        NaN       NaN
# ...

# %%
data.dropna()
# Out:
#       序号           销售单位名称            销售方纳税识别号       开票日期        发票号码  \
# 0      1   武汉市武昌区清源广告材料商行  92420106MA4KROYKXM 2021-12-23   1651882.0
# 1      2    武汉市福生装饰工程有限公司  914201027375338996 2021-12-10   5861371.0
# 2      3    武汉市福生装饰工程有限公司  914201027375338996 2021-12-10   5861372.0
# 3      4   武汉市鑫福运汽车服务有限公司  91420105568376465G 2021-12-28   1595149.0
# 4      5  武汉市江汉区平凡冰冻食品经营部  92420103WA4KPEJI1R 2021-12-29   1571643.0
# ..   ...              ...                 ...        ...         ...
# 110  107     湖北本草帝国医药有限公司  914201053037596559 2022-01-11  15074207.0
# 111  108     武汉京东世纪贸易有限公司  914201125683714021 2021-12-28   4376029.0
# 112  109     广州市百佳洋服饰有限公司  914401017315527498 2022-01-17  58055742.0
# 113  110     帝怡（中国）贸易有限公司  91310000797093557U 2022-01-13  40255426.0
# 115  111       上海捷荣食品有限公司  91310115750589678G 2019-02-27  36517871.0
#
#          发票金额    税率       税额      价税合计
# 0     1643.53  0.01    16.44   1659.97
# 1    27227.72  0.01   272.28  27500.00
# ...

# %%
data_2022 = []
fname_2022 = r"F:\a00nutstore\008\zw08\qingchuan\2022年已抵扣税票台账本.xlsx"
for month in months:
    data =  pd.read_excel(fname_2022,sheet_name = month,skiprows = 1,dtype ={'发票号码':'str'})
    data = data.dropna()
    data_2022.append(data)
df_2022 = pd.concat(data_2022)
df_2022.to_excel('2022.xlsx',index = False)
# Out:
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# ...

# %%
df_2022.to_excel('2022.xlsx',index = False)

# %%
data_2023 = []
fname_2023 = r"F:\a00nutstore\008\zw08\qingchuan\2023年已抵扣税票台账本.xlsx"
for month in months:
    data =  pd.read_excel(fname_2023,sheet_name = month,skiprows = 1,dtype ={'发票号码':'str'})
    data = data.dropna()
    data_2023.append(data)
df_2023 = pd.concat(data_2022)
df_2023.to_excel('2023.xlsx',index = False)
# Out:
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# ...

# %%
data_2024 = []
fname_2024 = r"F:\a00nutstore\008\zw08\qingchuan\2024年已抵扣税票台账本.xlsx"
for month in months:
    data =  pd.read_excel(fname_2024,sheet_name = month,skiprows = 1,dtype ={'发票号码':'str'})
    data = data.dropna()
    data_2024.append(data)
df_2024 = pd.concat(data_2024)
df_2024.to_excel('2024.xlsx',index = False)
# Out:
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# ...

# %%
df_invoice = pd.concat([df_2022,df_2023,df_2024])
df_invoice
# Out:
#     序号                  销售单位名称            销售方纳税识别号       开票日期  \
# 0    1          武汉市武昌区清源广告材料商行  92420106MA4KROYKXM 2021-12-23
# 1    2           武汉市福生装饰工程有限公司  914201027375338996 2021-12-10
# 2    3           武汉市福生装饰工程有限公司  914201027375338996 2021-12-10
# 3    4          武汉市鑫福运汽车服务有限公司  91420105568376465G 2021-12-28
# 4    5         武汉市江汉区平凡冰冻食品经营部  92420103WA4KPEJI1R 2021-12-29
# ..  ..                     ...                 ...        ...
# 10  11  青岛金水丰泽酒店管理有限公司金水智选假日酒店  91370213MA7CD43M1J 2024-04-19
# 11  12            武汉怡和丰源食品有限公司  91420106572047517T 2024-04-19
# 12  13            武汉天兴祺源贸易有限公司  91420116333443870G 2024-04-21
# 13  14          武汉玉龙布艺装饰工程有限公司  91420111768083712R 2024-04-15
# 14  15           广州市六州酒店服务有限公司  91440101743598672Q 2024-04-25
#
#                     发票号码      发票金额    税率       税额       价税合计   简称 Unnamed: 1
# 0               01651882   1643.53  0.01    16.44    1659.97  NaN        NaN
# ...

# %%
df_invoice.to_excel('invoice.xlsx',index = False)

# %%
df_pay['Base Amount1'] = round(df_pay['Base Amount']*-1,2)
df_pay
# Out:
#      Account Code              Name    Period Transaction Date  \
# 0           11500  Bank Account - 1  2022/006       2022-06-29
# 1           11500  Bank Account - 1  2022/011       2022-11-30
# 2           11500  Bank Account - 1  2023/002       2023-02-07
# 3           11500  Bank Account - 1  2023/003       2023-03-09
# 4           11500  Bank Account - 1  2023/005       2023-05-17
# ...           ...               ...       ...              ...
# 2624        11500  Bank Account - 1  2024/004       2024-04-28
# 2625        11500  Bank Account - 1  2022/007       2022-07-29
# 2626        11500  Bank Account - 1  2022/007       2022-07-29
# 2627        11500  Bank Account - 1  2023/004       2023-04-23
# 2628       Totals               NaN       NaN              NaT
#
#      Transaction Reference  Base Amount Journal No. Journal Source  \
# 0                 中2206045      -831.17       59618            CSJ
# 1                 中2211056     -1579.32       61241            CSJ
# ...

# %%
df_pay
# Out:
#      Account Code              Name    Period Transaction Date  \
# 0           11500  Bank Account - 1  2022/004       2022-04-08
# 1           11500  Bank Account - 1  2022/004       2022-04-08
# 2           11500  Bank Account - 1  2022/004       2022-04-08
# 3           11500  Bank Account - 1  2022/004       2022-04-08
# 4           11500  Bank Account - 1  2022/004       2022-04-08
# ...           ...               ...       ...              ...
# 2624        11500  Bank Account - 1  2024/004       2024-04-26
# 2625        11500  Bank Account - 1  2024/004       2024-04-26
# 2626        11500  Bank Account - 1  2024/004       2024-04-26
# 2627        11500  Bank Account - 1  2024/004       2024-04-28
# 2628       Totals               NaN       NaN              NaT
#
#      Transaction Reference  Base Amount Journal No. Journal Source  \
# 0                 中2204001     -2192.99       58961            CSJ
# 1                 中2204002      -800.00       58962            CSJ
# ...

# %%
df_invoice['价税合计'] = round(df_invoice['价税合计'],2)
df_invoice
# Out:
#     序号                  销售单位名称            销售方纳税识别号       开票日期  \
# 0    1          武汉市武昌区清源广告材料商行  92420106MA4KROYKXM 2021-12-23
# 1    2           武汉市福生装饰工程有限公司  914201027375338996 2021-12-10
# 2    3           武汉市福生装饰工程有限公司  914201027375338996 2021-12-10
# 3    4          武汉市鑫福运汽车服务有限公司  91420105568376465G 2021-12-28
# 4    5         武汉市江汉区平凡冰冻食品经营部  92420103WA4KPEJI1R 2021-12-29
# ..  ..                     ...                 ...        ...
# 10  11  青岛金水丰泽酒店管理有限公司金水智选假日酒店  91370213MA7CD43M1J 2024-04-19
# 11  12            武汉怡和丰源食品有限公司  91420106572047517T 2024-04-19
# 12  13            武汉天兴祺源贸易有限公司  91420116333443870G 2024-04-21
# 13  14          武汉玉龙布艺装饰工程有限公司  91420111768083712R 2024-04-15
# 14  15           广州市六州酒店服务有限公司  91440101743598672Q 2024-04-25
#
#                     发票号码      发票金额    税率       税额       价税合计   简称 Unnamed: 1
# 0               01651882   1643.53  0.01    16.44    1659.97  NaN        NaN
# ...

# %%
df = pd.merge(df_pay,df_invoice,how = 'left',left_on = ['供应商名称','Base Amount1'],right_on=['销售单位名称','价税合计'])
df
# Out:
#      Account Code              Name    Period Transaction Date  \
# 0           11500  Bank Account - 1  2022/004       2022-04-08
# 1           11500  Bank Account - 1  2022/004       2022-04-08
# 2           11500  Bank Account - 1  2022/004       2022-04-08
# 3           11500  Bank Account - 1  2022/004       2022-04-08
# 4           11500  Bank Account - 1  2022/004       2022-04-08
# ...           ...               ...       ...              ...
# 3543        11500  Bank Account - 1  2024/004       2024-04-26
# 3544        11500  Bank Account - 1  2024/004       2024-04-26
# 3545        11500  Bank Account - 1  2024/004       2024-04-26
# 3546        11500  Bank Account - 1  2024/004       2024-04-28
# 3547       Totals               NaN       NaN              NaT
#
#      Transaction Reference  Base Amount Journal No. Journal Source  \
# 0                 中2204001     -2192.99       58961            CSJ
# 1                 中2204001     -2192.99       58961            CSJ
# ...

# %%
df = pd.merge(df_pay,df_invoice,how = 'left',left_on = ['供应商名称','Base Amount1'],right_on=['销售单位名称','价税合计'])
df
# Out:
#      Account Code              Name    Period Transaction Date  \
# 0           11500  Bank Account - 1  2022/004       2022-04-08
# 1           11500  Bank Account - 1  2022/004       2022-04-08
# 2           11500  Bank Account - 1  2022/004       2022-04-08
# 3           11500  Bank Account - 1  2022/004       2022-04-08
# 4           11500  Bank Account - 1  2022/004       2022-04-08
# ...           ...               ...       ...              ...
# 3492        11500  Bank Account - 1  2024/004       2024-04-26
# 3493        11500  Bank Account - 1  2024/004       2024-04-26
# 3494        11500  Bank Account - 1  2024/004       2024-04-26
# 3495        11500  Bank Account - 1  2024/004       2024-04-28
# 3496       Totals               NaN       NaN              NaT
#
#      Transaction Reference  Base Amount Journal No. Journal Source  \
# 0                 中2204001     -2192.99       58961            CSJ
# 1                 中2204002      -800.00       58962            CSJ
# ...

# %%
df.to_excel('aaa.xlsx',index = False)

# %%
df1 = df.copy()

# %%
df1 = df1.drop_duplicates()
df1
# Out:
#      Account Code              Name    Period Transaction Date  \
# 0           11500  Bank Account - 1  2022/004       2022-04-08
# 2           11500  Bank Account - 1  2022/004       2022-04-08
# 3           11500  Bank Account - 1  2022/004       2022-04-08
# 4           11500  Bank Account - 1  2022/004       2022-04-08
# 5           11500  Bank Account - 1  2022/004       2022-04-08
# ...           ...               ...       ...              ...
# 3541        11500  Bank Account - 1  2024/004       2024-04-26
# 3542        11500  Bank Account - 1  2024/004       2024-04-26
# 3545        11500  Bank Account - 1  2024/004       2024-04-26
# 3546        11500  Bank Account - 1  2024/004       2024-04-28
# 3547       Totals               NaN       NaN              NaT
#
#      Transaction Reference  Base Amount Journal No. Journal Source  \
# 0                 中2204001     -2192.99       58961            CSJ
# 2                 中2204002      -800.00       58962            CSJ
# ...

# %%
df1.to_excel('bbb.xlsx',index = False)

# %%
df_pay1 = df_pay.copy()

# %%
gp = df_pay1.groupby(['供应商名称','Base Amount'])
gp

# %%
pay0 =  []
for key,value in gp:
    value['xuhao'] = list(range(value['Base Amount1'].count()))
    pay0.append(value)

# %%
pay = pd.concat(pay0)

# %%
pay.to_excel('cccc.xlsx',index = False)

# %%
gp1 = df_invoice.groupby(['销售单位名称','价税合计'])
fapiao =  []
for key,value in gp1:
    value['xuhao'] = list(range(value['价税合计'].count()))
    fapiao.append(value)
df_fapiao = pd.concat(fapiao)
df_fapiao
# Out:
#     序号             销售单位名称            销售方纳税识别号       开票日期      发票号码      发票金额  \
# 82  81       上海卡嘉机械设备有限公司  91310112599728005B 2022-07-11  48972046  14601.77
# 82  81       上海卡嘉机械设备有限公司  91310112599728005B 2022-07-11  48972046  14601.77
# 89  88     上海天祥质量技术服务有限公司  9131000060727776X1 2021-05-21  53689398      2000
# 89  88     上海天祥质量技术服务有限公司  9131000060727776X1 2021-05-21  53689398      2000
# 22  21     上海天祥质量技术服务有限公司  9131000060727776X1 2022-09-09  00497615      3000
# ..  ..                ...                 ...        ...       ...       ...
# 43  40  麦德龙商业集团有限公司武汉硚口商场  914201007257543280 2022-04-02  01297262   6965.14
# 15  13  麦德龙商业集团有限公司武汉硚口商场  914201007257543280 2022-12-10  10689686   7077.98
# 15  13  麦德龙商业集团有限公司武汉硚口商场  914201007257543280 2022-12-10  10689686   7077.98
# 28  27  麦德龙商业集团有限公司武汉硚口商场  914201007257543280 2022-10-17  14053537   8117.43
# 28  27  麦德龙商业集团有限公司武汉硚口商场  914201007257543280 2022-10-17  14053537   8117.43
#
# ...

# %%
df = pd.merge(pay,df_fapiao,how = 'left',left_on = ['供应商名称','Base Amount1','xuhao'],right_on=['销售单位名称','价税合计','xuhao'])
df
# Out:
#      Account Code              Name    Period Transaction Date  \
# 0           11500  Bank Account - 1  2023/011       2023-11-29
# 1           11500  Bank Account - 1  2023/009       2023-09-06
# 2           11500  Bank Account - 1  2023/011       2023-11-14
# 3           11500  Bank Account - 1  2023/012       2023-12-19
# 4           11500  Bank Account - 1  2024/002       2024-02-07
# ...           ...               ...       ...              ...
# 2623        11500  Bank Account - 1  2022/006       2022-06-09
# 2624        11500  Bank Account - 1  2023/009       2023-09-28
# 2625        11500  Bank Account - 1  2022/004       2022-04-08
# 2626        11500  Bank Account - 1  2023/006       2023-06-27
# 2627        11500  Bank Account - 1  2024/004       2024-04-25
#
#      Transaction Reference  Base Amount Journal No. Journal Source  \
# 0                 中2311116    -24723.27       65080            CSJ
# 1                 中2309004     -3732.84       64181            CSJ
# ...

# %%
pay
# Out:
#      Account Code              Name    Period Transaction Date  \
# 8           11500  Bank Account - 1  2023/011       2023-11-29
# 5           11500  Bank Account - 1  2023/009       2023-09-06
# 7           11500  Bank Account - 1  2023/011       2023-11-14
# 9           11500  Bank Account - 1  2023/012       2023-12-19
# 10          11500  Bank Account - 1  2024/002       2024-02-07
# ...           ...               ...       ...              ...
# 1031        11500  Bank Account - 1  2022/006       2022-06-09
# 1047        11500  Bank Account - 1  2023/009       2023-09-28
# 1029        11500  Bank Account - 1  2022/004       2022-04-08
# 978         11500  Bank Account - 1  2023/006       2023-06-27
# 979         11500  Bank Account - 1  2024/004       2024-04-25
#
#      Transaction Reference  Base Amount Journal No. Journal Source  \
# 8                 中2311116    -24723.27       65080            CSJ
# 5                 中2309004     -3732.84       64181            CSJ
# ...

# %%
df.to_excel('dddd.xlsx',index = False)
