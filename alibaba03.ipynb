# %%
import numpy as np
import pandas as pd
import os
import easygui
import openpyxl

# %%
def alibabaXiaoshouMingxi(fname):
    
    df = pd.read_excel(fname,dtype = {'订单号':'str','Offer_ID':'str', 'SKU_ID':'str'})
    col1s = ['订单号','卖家公司名称', '卖家会员名','订单状态', '订单创建时间', '订单付款时间', '收货人姓名', '收货地址', '邮编',
       '联系手机',  '货运公司', '运单号']
    col2s = ['货品总价', '运费（元）', '商家改价（元）',
           '实付款（元）']
    for col in col1s:
        df[col] =  df[col].ffill()
    for col in col2s :
        df[col] = df[col].fillna(0)
    return df

fname = r"F:\a00nutstore\008\zw08\电商\阿里巴巴1688\阿里巴巴销售明细0822-0930.xlsx"

df = alibabaXiaoshouMingxi(fname)
df
# Out:
# C:\Users\redda\AppData\Roaming\Python\Python311\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                      订单号           买家公司名称                  买家会员      卖家公司名称  \
# 0    2310267974118629853              NaN           tb003462280  湖北双佳纸品有限公司
# 1    2310443005175874467              NaN                  卢569  湖北双佳纸品有限公司
# 2    2309567772450277854  杭州一路发严选电子商务有限公司                 聚宝盆严选  湖北双佳纸品有限公司
# 3    4062320640740645032              NaN  t_1492922702509_0551  湖北双佳纸品有限公司
# 4    4062421586127618803              NaN              抹掉记忆深处余味  湖北双佳纸品有限公司
# ..                   ...              ...                   ...         ...
# 864  4022631722109203749              NaN                   NaN  湖北双佳纸品有限公司
# 865  2273049049602822267              NaN                 尚贤增88  湖北双佳纸品有限公司
# 866  2269186502496746753           李菲（个人）        more_lion_shop  湖北双佳纸品有限公司
# 867  2268563451685578186              NaN             许55555555  湖北双佳纸品有限公司
# 868  2267184001595653481              NaN             独自的浪漫1314  湖北双佳纸品有限公司
#
#           卖家会员名    货品总价  运费（元）  商家改价（元）  实付款（元）      订单状态  ...       买家留言  \
# 0    湖北双佳纸品有限公司   35.40    4.1      0.0   39.50  等待买家确认收货  ...        NaN
# 1    湖北双佳纸品有限公司  100.80   17.1      0.0  117.90  等待买家确认收货  ...        NaN
# 2    湖北双佳纸品有限公司    1.19    0.0      0.0    1.19  等待买家确认收货  ...        NaN
# 3    湖北双佳纸品有限公司  188.00   37.3      0.0  225.30      交易关闭  ...        NaN
# 4    湖北双佳纸品有限公司    4.70    2.8      0.0    7.50      交易关闭  ...        NaN
# ..          ...     ...    ...      ...     ...       ...  ...        ...
# 864  湖北双佳纸品有限公司    0.00    0.0      0.0    0.00      交易关闭  ...        NaN
# 865  湖北双佳纸品有限公司   88.00   17.0     11.0  116.00      交易成功  ...  换成16K大方格本
# 866  湖北双佳纸品有限公司   15.60    4.3      0.0   19.90      交易成功  ...        NaN
# 867  湖北双佳纸品有限公司   60.12   11.0      0.0   71.12      交易成功  ...        NaN
# 868  湖北双佳纸品有限公司   17.80    4.1      0.0   21.90      交易关闭  ...        NaN
#
#            货运公司              运单号 发票：购货单位名称  发票：纳税人识别号 发票：地址、电话 发票：开户行及账号  \
# 0     圆通速递(YTO)  YT7495880897530       NaN        NaN      NaN       NaN
# 1     圆通速递(YTO)  YT7495880897529       NaN        NaN      NaN       NaN
# 2     圆通速递(YTO)  YT7495880897512       NaN        NaN      NaN       NaN
# 3     圆通速递(YTO)  YT7495880897512       NaN        NaN      NaN       NaN
# 4     圆通速递(YTO)  YT7495880897512       NaN        NaN      NaN       NaN
# ..          ...              ...       ...        ...      ...       ...
# 864  武汉兆通物流有限公司          0003539       NaN        NaN      NaN       NaN
# 865   圆通速递(YTO)  YT7488519267802       NaN        NaN      NaN       NaN
# 866   圆通速递(YTO)  YT7488056363210       NaN        NaN      NaN       NaN
# 867   圆通速递(YTO)  YT7488055698555       NaN        NaN      NaN       NaN
# 868   圆通速递(YTO)  YT7488055698555       NaN        NaN      NaN       NaN
#
#     发票：收取地址  下游订单号  下单公司主体
# 0       NaN    NaN     NaN
# 1       NaN    NaN     NaN
# 2       NaN    NaN     NaN
# 3       NaN    NaN     NaN
# 4       NaN    NaN     NaN
# ..      ...    ...     ...
# 864     NaN    NaN     NaN
# 865     NaN    NaN     NaN
# 866     NaN    NaN     NaN
# 867     NaN    NaN     NaN
# 868     NaN    NaN     NaN
#
# [869 rows x 37 columns]

# %%
df.to_excel('阿里巴巴销售明细0822-0930.xlsx',index = False)
# Out:
# C:\Users\redda\AppData\Local\Temp\ipykernel_13440\1130233692.py:1: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '3.0.3' currently installed).
#   df.to_excel('阿里巴巴销售明细0822-0930.xlsx',index = False)
