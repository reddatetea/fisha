# %%
'''
电商出库将规格型号中的本数提取出来,较多正则处理
2024080加金额
20240824加按品名“汇总”

'''
import re
import os
import pandas as pd
import numpy as np
import openpyxl
import easygui
from openpyxl.styles import Font, Border, Side, Fill, Alignment

# fname = easygui.fileopenbox('请点选电商当日出库文件')
fname = r"F:\repos\fish\8-23.xlsx"
qian, hou = os.path.splitext(fname)
newfname = qian + "-本数" + hou
sheet_name = 0
skiprows = 0
df = pd.read_excel(fname, sheet_name=sheet_name, skiprows=skiprows, dtype={'商品ID': 'str', '运单号': 'str', })
df.dropna(subset=['订单号'], inplace=True)
df['总价'] = df['总价'].str.replace('￥', '')
df['实收'] = df['实收'].str.replace('￥', '')
df = df.astype({'实收': 'float64'})
df = df.astype({'总价': 'float64'})

# df['实收'] = df['实收'] .astype(int)
df1 = df.copy()
lst = ['订单号',
       '发货时间',
       '规格名称',
       '规格编码',
       '数量',
       '总价',
       '实收'
       ]
dic = {'五': 5,
       '六': 6,
       '七': 7,
       '八': 8,
       '九': 9,
       '十': 10,
       '四': 4,
       '三': 3,
       '二': 2,
       '一': 1}


def addBen(string):
    # string = r'(81本)'
    pattern1 = r'(?P<ben>\d+)本'
    pattern2 = r'(?P<ben>[十九八七六五四三二一])本'
    regexp1 = re.compile(pattern1)
    mat1 = regexp1.search(string)
    regexp2 = re.compile(pattern2)
    mat2 = regexp2.search(string)
    if mat1:
        ben = int(mat1.group('ben'))
    else:
        if mat2:
            ben = dic.get(mat2.group('ben'))
        else:
            ben = 1
    return ben


df1 = df1[lst]
df1['含量'] = df1['规格名称'].map(addBen)
df1 = df1.assign(本数=df1['数量'] * df1['含量'])
df1 = df1.sort_values(by=['规格编码'])
df1.index = range(1, len(df1) + 1)
df2 = df1.copy()
df1.index_name = '序号'
df1.insert(0, '序号', range(1, len(df1) + 1))
max_xuhao = len(df1) + 1

df1.loc[max_xuhao] = {'序号': max_xuhao, '数量': df1['数量'].sum(), '本数': df1['本数'].sum(),'总价':df1['总价'].sum(),'实收':df1['实收'].sum()}

df1['序号'] = df1['序号'].replace(max_xuhao, '小计')
df1 = df1[['序号',
       '订单号',
       '发货时间',
       '规格名称',
       '规格编码',
           '本数',
        '含量',
       '数量',
           '总价',
           '实收'
       ]]
df1.columns = ['序号',
       '订单号',
       '发货时间',
       '规格名称',
       '规格编码',
           '本数',
        '含量',
       '包数',
      '总价',
       '实收'
       ]

gp = df1.groupby('规格编码')
bao = gp['包数'].sum()
ben = gp['本数'].sum()
zhongjia = gp['总价'].sum()
shishou = gp['实收'].sum()

beihuo = pd.concat([bao, ben,zhongjia,shishou], axis=1)
beihuo.columns = ['包数', '本数', '总价','实收']
beihuo.loc['小计'] = [beihuo['包数'].sum(), beihuo['本数'].sum(),beihuo['总价'].sum(),beihuo['实收'].sum()]
beihuo = beihuo.reset_index()





# with pd.ExcelWriter(fname, engine='openpyxl', mode='a', if_sheet_exists='overlay') as writer:
#     df.to_excel(writer, sheet_name='加工', index=False)
#     beihuo.to_excel(writer, sheet_name='备货', index=False)
#     df1.to_excel(writer, sheet_name='本数', index=False)

# wb = openpyxl.load_workbook(fname)


# def sheetSetting(sheetname):
#     ws = wb[sheetname]
#     max_row = ws.max_row
#     max_column = ws.max_column

#     ws.column_dimensions['B'].width = 24
#     ws.column_dimensions['C'].width = 20
#     ws.column_dimensions['D'].width = 22
#     ws.column_dimensions['E'].width = 12
#     ws.column_dimensions['F'].width = 4.5
#     ws.column_dimensions['G'].width = 6.13
#     ws.freeze_panes = ws['B2']
#     ws.print_title_rows = '1:1'  # the first row
#     # 页脚设置
#     ws.oddFooter.center.text = " &[Page] / &N"  # 1/n
#     ws.oddFooter.center.size = 12  # 页脚中字体大小
#     ws.oddFooter.center.font = "Tahoma"  # 页脚中字体
#     ws.oddFooter.center.color = "000000"  # 页脚中字体颜色
#     ws.oddFooter.right.text = "张文伟 &[Date]"  # 页脚右 文字
#     ws.oddFooter.right.size = 12  # 页脚右 字体大小
#     ws.oddFooter.right.font = "书体坊米芾体"  # 页脚右 字体
#     ws.oddFooter.right.color = "000000"  # 页脚右 字体颜色
#     if sheetname == '备货':
#         ws.column_dimensions['A'].width = 20
#         ws.page_margins = openpyxl.worksheet.page.PageMargins(top=0.48, header=0.5, left=2, right=0.24,
#                                                               footer=0.5,
#                                                               bottom=1)

#     else:
#         ws.column_dimensions['A'].width = 4
#         ws.page_margins = openpyxl.worksheet.page.PageMargins(top=0.48, header=0.5, left=0.21, right=0.24,
#                                                               footer=0.5,
#                                                               bottom=1)

#     thin_danbian = Side(border_style='thin')
#     thin_bian = Border(
#         left=thin_danbian,
#         right=thin_danbian,
#         top=thin_danbian,
#         bottom=thin_danbian)
#     for row in range(2, max_row + 1):  # 从第二行开始，设置单元格格式
#         for col in range(1, max_column + 1):
#             ws.cell(row, col).border = thin_bian
#     return ws


# for sheetname in ['备货', '本数']:
#     ws = sheetSetting(sheetname)

# wb.active = ws
# wb.save(fname)
# # os.rename(fname,newfname)
# os.startfile(fname)
# Out:
# C:\Users\redda\.conda\envs\py311\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df1
# Out:
#       序号                     订单号                 发货时间          规格名称  \
# 1      1  240822-036574359161747  2024-08-23 08:49:46      5本,50页每本
# 2      2  240823-658222682482090  2024-08-23 13:31:45      5本,50页每本
# 3      3  240822-334128760351882  2024-08-23 08:49:46      5本,50页每本
# 4      4  240822-373759680141793  2024-08-23 08:49:46      5本,50页每本
# 5      5  240823-059055808110583  2024-08-23 13:31:45      1本,50页每本
# ..   ...                     ...                  ...           ...
# 664  664  240823-572323274340672  2024-08-23 13:31:45   5本,作文（300格）
# 665  665  240821-109083431350455  2024-08-23 08:49:46   1本,作文（300格）
# 666  666  240823-617149929072874  2024-08-23 08:49:46  10本,作文（300格）
# 667  667  240822-574483413283345  2024-08-23 08:49:46         乐谱本5本
# 668   小计                     NaN                  NaN           NaN
#
#             规格编码    本数    含量   包数       总价       实收
# 1    16K备课本-50Pa     5   5.0    1     8.80     8.80
# 2    16K备课本-50Pa     5   5.0    1     8.80     8.80
# 3    16K备课本-50Pa     5   5.0    1     8.80     8.80
# 4    16K备课本-50Pa    10   5.0    2    17.60    15.84
# 5    16K备课本-50Pa     1   1.0    1     3.52     3.52
# ..           ...   ...   ...  ...      ...      ...
# 664     QZW1660N     5   5.0    1     6.79     6.79
# 665     QZW1660N     1   1.0    1     1.39     1.39
# 666     QZW1660N    10  10.0    1     9.50     9.50
# 667    RFYP1660N    40   5.0    8    54.24    51.53
# 668          NaN  4130   NaN  802  5758.00  5639.35
#
# [668 rows x 10 columns]

# %%
df2
# Out:
#                         订单号                 发货时间          规格名称         规格编码  \
# 1    240822-036574359161747  2024-08-23 08:49:46      5本,50页每本  16K备课本-50Pa
# 2    240823-658222682482090  2024-08-23 13:31:45      5本,50页每本  16K备课本-50Pa
# 3    240822-334128760351882  2024-08-23 08:49:46      5本,50页每本  16K备课本-50Pa
# 4    240822-373759680141793  2024-08-23 08:49:46      5本,50页每本  16K备课本-50Pa
# 5    240823-059055808110583  2024-08-23 13:31:45      1本,50页每本  16K备课本-50Pa
# ..                      ...                  ...           ...          ...
# 663  240822-312014344631091  2024-08-23 08:49:46   1本,作文（300格）     QZW1660N
# 664  240823-572323274340672  2024-08-23 13:31:45   5本,作文（300格）     QZW1660N
# 665  240821-109083431350455  2024-08-23 08:49:46   1本,作文（300格）     QZW1660N
# 666  240823-617149929072874  2024-08-23 08:49:46  10本,作文（300格）     QZW1660N
# 667  240822-574483413283345  2024-08-23 08:49:46         乐谱本5本    RFYP1660N
#
#      数量     总价     实收  含量  本数
# 1     1   8.80   8.80   5   5
# 2     1   8.80   8.80   5   5
# 3     1   8.80   8.80   5   5
# 4     2  17.60  15.84   5  10
# 5     1   3.52   3.52   1   1
# ..   ..    ...    ...  ..  ..
# 663   1   1.39   1.39   1   1
# 664   1   6.79   6.79   5   5
# 665   1   1.39   1.39   1   1
# 666   1   9.50   9.50  10  10
# 667   8  54.24  51.53   5  40
#
# [667 rows x 9 columns]

# %%
df2['规格编码1'] = df2['规格编码'].str.split('+')
df2['len'] = df2['规格编码1'].str.len()
df2 = df2.assign(本数 = np.where(df2.len == 1,df2['本数'] ,df2['本数']/df2['len']))
df2 = df2.assign(包数 = np.where(df2.len == 1,df2['包数'] ,df2['包数']/df2['len']))
df2 = df2.explode('规格编码1')
df2 = df2[['序号',
       '订单号',
       '发货时间',
       '规格名称',
       '规格编码',
           '本数',
        '含量',
       '包数',
      '总价',
       '实收'
       ]]
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\py311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '包数'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 4
#       2 df2['len'] = df2['规格编码1'].str.len()
#       3 df2 = df2.assign(本数 = np.where(df2.len == 1,df2['本数'] ,df2['本数']/df2['len']))
# ----> 4 df2 = df2.assign(包数 = np.where(df2.len == 1,df2['包数'] ,df2['包数']/df2['len']))
#       5 df2 = df2.explode('规格编码1')
#       6 df2 = df2[['序号',
#       7        '订单号',
#       8        '发货时间',
#    (...)
#      15        '实收'
#      16        ]]
#
# File ~\.conda\envs\py311\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\.conda\envs\py311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: '包数'

# %%
# Out:
#       序号                     订单号                 发货时间          规格名称  \
# 1      1  240822-036574359161747  2024-08-23 08:49:46      5本,50页每本
# 2      2  240823-658222682482090  2024-08-23 13:31:45      5本,50页每本
# 3      3  240822-334128760351882  2024-08-23 08:49:46      5本,50页每本
# 4      4  240822-373759680141793  2024-08-23 08:49:46      5本,50页每本
# 5      5  240823-059055808110583  2024-08-23 13:31:45      1本,50页每本
# ..   ...                     ...                  ...           ...
# 664  664  240823-572323274340672  2024-08-23 13:31:45   5本,作文（300格）
# 665  665  240821-109083431350455  2024-08-23 08:49:46   1本,作文（300格）
# 666  666  240823-617149929072874  2024-08-23 08:49:46  10本,作文（300格）
# 667  667  240822-574483413283345  2024-08-23 08:49:46         乐谱本5本
# 668   小计                     NaN                  NaN           NaN
#
#             规格编码    本数    含量   包数       总价       实收        规格编码1  len
# 1    16K备课本-50Pa   5.0   5.0  1.0     8.80     8.80  16K备课本-50Pa  1.0
# 2    16K备课本-50Pa   5.0   5.0  1.0     8.80     8.80  16K备课本-50Pa  1.0
# 3    16K备课本-50Pa   5.0   5.0  1.0     8.80     8.80  16K备课本-50Pa  1.0
# 4    16K备课本-50Pa  10.0   5.0  2.0    17.60    15.84  16K备课本-50Pa  1.0
# 5    16K备课本-50Pa   1.0   1.0  1.0     3.52     3.52  16K备课本-50Pa  1.0
# ..           ...   ...   ...  ...      ...      ...          ...  ...
# 664     QZW1660N   5.0   5.0  1.0     6.79     6.79     QZW1660N  1.0
# 665     QZW1660N   1.0   1.0  1.0     1.39     1.39     QZW1660N  1.0
# 666     QZW1660N  10.0  10.0  1.0     9.50     9.50     QZW1660N  1.0
# 667    RFYP1660N  40.0   5.0  8.0    54.24    51.53    RFYP1660N  1.0
# 668          NaN   NaN   NaN  NaN  5758.00  5639.35          NaN  NaN
#
# [679 rows x 12 columns]

# %%
 ['序号',
       '订单号',
       '发货时间',
       '规格名称',
       '规格编码',
           '本数',
        '含量',
       '包数',
      '总价',
       '实收'
       ]
