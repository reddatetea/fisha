# %%
'''
Tcloud销售出库单明细表
'''
import os
import datetime
import easygui
import numpy as np
import pandas as pd
import openpyxl
from openpyxl.styles import Font, Border, Side, Fill, Alignment
import formatPainter
import re

# %%
def xiaoshoumingxiChuli(fname, store_num):
    df = pd.read_excel(fname_xiaoshou, skiprows=6)
    store_num = '001库'
    df = df.iloc[:, 1:]
    # df
    if store_num == '001库':
        df.loc[df['仓库编码'] == '002']
    elif store_num == '002电商库':
        df = df.loc[df['仓库编码'] == '002']
    else:
        df = df.loc[(df['仓库编码'] == '001') | (df['仓库编码'] == '002')]
    
    for label, ser in df.items():
        for num0, x in enumerate(ser):
            if isinstance(x, str):
                if '合计' in x:
                    index = num0
                    # print(index)
                    break
    df = df.iloc[:index]
    df = df.dropna(how='all', axis=1)
    df = df[['存货编码','存货代码','数量','数量2']]
    df.columns = ['code','stock','xiaoshou_ben','xiaoshou_jian']
    return df

# %%
fname_xiaoshou = r"F:\a00nutstore\006\zw\产成品日报表\2024年\2024年9月\9月5日\产成品库存调整\销售出库单明细表 (1).xlsx"
xiaoshoumingxiChuli(fname_xiaoshou,'001库')
# Out:
#              code stock  xiaoshou_ben  xiaoshou_jian
# 0       A1-052405    抄本        5208.0          217.0
# 1       A1-052406    抄本        5256.0          219.0
# 2       A1-052405    抄本       12792.0          533.0
# 3       A1-052406    抄本       13440.0          560.0
# 4       A1-054428    抄本        5664.0           59.0
# ...           ...   ...           ...            ...
# 4339   N0785（纯净版）    抄本         600.0            3.0
# 4340    EFBA460NB    电商         400.0            2.0
# 4341   EXYB5100Pa    电商         600.0            5.0
# 4342   EXBB5100Pa    电商         600.0            5.0
# 4343  EXWGB5100Pa    电商         600.0            5.0
#
# [4344 rows x 4 columns]
