# %%
import numpy as np
import pandas as pd
import openpyxl
import xlwings as xw
import os
import excelmessage
import xlsxlsx

# %%
fname = r'F:\a00nutstore\006\zw\2023\2023-04\流水帐.xls'
fname1 = xlsxlsx.xlsXlsx(fname)
print(fname1)
# Out:
# 正将excel低版本xls转化为高版本xlsx，请稍等:
# F:\a00nutstore\006\zw\2023\2023-04\流水帐.xlsx

# %%
fname = r'F:\a00nutstore\006\zw\2023\2023-04\流水帐.xls'
os.path.splitext(fname)[-1].lower()
# Out:
# '.xls'

# %%
filename = r'D:\ribaobiao\流水账.xls'
def xlsToXlsx(fname):
    if os.path.splitext(fname)[-1].lower()=='.xls':
        xlsxlsx.xlsXlsx(fname)
      

    else:
        fname = fname
    return fname
filename = xlsxlsx.xlsXlsx(filename)
df = pd.read_excel(filename,dtype = {'单据号':str})
df
# Out:
# 正将excel低版本xls转化为高版本xlsx，请稍等:
# D:\anaconda\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#              日期   单据类型         单据号  业务类型  业务号    仓库  收发类别    部门  业务员  \
# 0    2023-05-08  材料出库单  0000005385    领料  NaN  原材料库  生产领料  夹子车间  NaN
# 1    2023-05-09  采购入库单  0000002034  普通采购  NaN  原材料库  采购入库   NaN  NaN
# 2    2023-05-09  采购入库单  0000002034  普通采购  NaN  原材料库  采购入库   NaN  NaN
# 3    2023-05-09  采购入库单  0000002034  普通采购  NaN  原材料库  采购入库   NaN  NaN
# 4    2023-05-09  采购入库单  0000002034  普通采购  NaN  原材料库  采购入库   NaN  NaN
# ..          ...    ...         ...   ...  ...   ...   ...   ...  ...
# 560  2023-05-04  材料出库单  0000005331    领料  NaN  原材料库  生产领料  柔版车间  NaN
# 561  2023-05-04  材料出库单  0000005331    领料  NaN  原材料库  生产领料  柔版车间  NaN
# 562  2023-05-04  材料出库单  0000005331    领料  NaN  原材料库  生产领料  柔版车间  NaN
# 563  2023-05-04  材料出库单  0000005331    领料  NaN  原材料库  生产领料  柔版车间  NaN
# 564       合   计    NaN         NaN   NaN  NaN   NaN   NaN   NaN  NaN
#
#            供货单位  ...  计量单位   应收数量       入库数量  入库单价      入库金额   应发数量  \
# 0           NaN  ...     个   0.00       0.00   0.0       0.0   0.00
# 1    上海好麟贸易有限公司  ...    公斤   0.00     600.00  20.3   12180.0   0.00
# 2    上海好麟贸易有限公司  ...    公斤   0.00      80.00  20.0    1600.0   0.00
# 3    上海好麟贸易有限公司  ...    公斤   0.00     100.00  17.5    1750.0   0.00
# 4    上海好麟贸易有限公司  ...    公斤   0.00      80.00  23.5    1880.0   0.00
# ..          ...  ...   ...    ...        ...   ...       ...    ...
# 560         NaN  ...    公斤   0.00       0.00   0.0       0.0   0.00
# 561         NaN  ...    公斤   0.00       0.00   0.0       0.0   0.00
# 562         NaN  ...     卷   0.00       0.00   0.0       0.0   0.00
# 563         NaN  ...    公斤   0.00       0.00   0.0       0.0   0.00
# 564         NaN  ...   NaN  23.81  815296.13   0.0  487300.5  23.81
#
#           出库数量  出库单价 出库金额  处理单号
# 0       -10.00     0    0   NaN
# 1         0.00     0    0   NaN
# 2         0.00     0    0   NaN
# 3         0.00     0    0   NaN
# 4         0.00     0    0   NaN
# ..         ...   ...  ...   ...
# 560      20.00     0    0   NaN
# 561      40.00     0    0   NaN
# 562      20.00     0    0   NaN
# 563      20.00     0    0   NaN
# 564  989516.21     0    0   NaN
#
# [565 rows x 32 columns]

# %%
wb = openpyxl.load_workbook(fname1)
ws = wb.active
danjus = [i.value for i in ws['C'][1:]]
danjus
# Out:
# ['0000004952',
#  '0000004946',
#  '0000004948',
#  '0000004950',
#  '0000004956',
#  '0000004950',
#  '0000004950',
#  '0000004949',
#  '0000004950',
#  '0000001862',
#  '0000001862',
#  '0000001862',
#  '0000004959',
#  '0000004951',
#  '0000004954',
#  '0000004949',
#  '0000004952',
#  '0000004953',
#  '0000004953',
#  '0000004949',
#  '0000004951',
#  '0000001863',
#  '0000001864',
#  '0000004946',
#  '0000001864',
#  '0000001864',
#  '0000004955',
#  '0000004955',
#  '0000004955',
#  '0000004958',
#  '0000004959',
#  '0000004946',
#  '0000004960',
#  '0000004957',
#  '0000004958',
#  '0000004958',
#  '0000004959',
#  '0000004960',
#  '0000004959',
#  '0000004957',
#  '0000004956',
#  '0000004961',
#  '0000004956',
#  '0000004946',
#  '0000004946',
#  '0000004946',
#  '0000004946',
#  '0000004946',
#  '0000004946',
#  '0000004947',
#  '0000004947',
#  '0000004948',
#  '0000004948',
#  '0000004952',
#  '0000004954',
#  '0000004955',
#  '0000004955',
#  '0000004951',
#  '0000004951',
#  '0000004951',
#  '0000004951',
#  '0000004950',
#  '0000004951',
#  '0000004952',
#  '0000001862',
#  '0000001862',
#  '0000004972',
#  '0000001868',
#  '0000004965',
#  '0000004978',
#  '0000004969',
#  '0000001869',
#  '0000004965',
#  '0000001867',
#  '0000004964',
#  '0000001867',
#  '0000004969',
#  '0000004969',
#  '0000004973',
#  '0000004974',
#  '0000004963',
#  '0000004972',
#  '0000004965',
#  '0000004963',
#  '0000004975',
#  '0000004976',
#  '0000004971',
#  '0000004977',
#  '0000004963',
#  '0000004968',
#  '0000004972',
#  '0000001868',
#  '0000004965',
#  '0000004963',
#  '0000001868',
#  '0000004977',
#  '0000001869',
#  '0000004964',
#  '0000004967',
#  '0000004965',
#  '0000004965',
#  '0000004970',
#  '0000004970',
#  '0000004967',
#  '0000004963',
#  '0000004964',
#  '0000004964',
#  '0000004968',
#  '0000004967',
#  '0000004967',
#  '0000004967',
#  '0000004963',
#  '0000004965',
#  '0000004968',
#  '0000001865',
#  '0000004965',
#  '0000004966',
#  '0000004965',
#  '0000004965',
#  '0000001866',
#  '0000004965',
#  '0000004963',
#  '0000004964',
#  '0000001867',
#  '0000004962',
#  '0000004977',
#  '0000004982',
#  '0000004979',
#  '0000004989',
#  '0000004981',
#  '0000001872',
#  '0000004980',
#  '0000004979',
#  '0000004979',
#  '0000004980',
#  '0000004980',
#  '0000004981',
#  '0000004981',
#  '0000004980',
#  '0000004979',
#  '0000004979',
#  '0000004983',
#  '0000004981',
#  '0000004984',
#  '0000004983',
#  '0000004984',
#  '0000004984',
#  '0000004985',
#  '0000004985',
#  '0000004985',
#  '0000004986',
#  '0000004986',
#  '0000004986',
#  '0000004987',
#  '0000004988',
#  '0000004989',
#  '0000004985',
#  '0000004989',
#  '0000004989',
#  '0000004989',
#  '0000004990',
#  '0000004990',
#  '0000004979',
#  '0000001872',
#  '0000001874',
#  '0000001870',
#  '0000001871',
#  '0000001871',
#  '0000001871',
#  '0000001870',
#  '0000001874',
#  '0000001873',
#  '0000000175',
#  '0000004979',
#  '0000001874',
#  '0000001874',
#  '0000005001',
#  '0000005001',
#  '0000004994',
#  '0000004996',
#  '0000004997',
#  '0000001879',
#  '0000001880',
#  '0000001880',
#  '0000001880',
#  '0000001880',
#  '0000001881',
#  '0000004991',
#  '0000004991',
#  '0000004992',
#  '0000004993',
#  '0000004993',
#  '0000004993',
#  '0000004993',
#  '0000004993',
#  '0000004993',
#  '0000001878',
#  '0000001878',
#  '0000001877',
#  '0000001877',
#  '0000001877',
#  '0000001877',
#  '0000001875',
#  '0000001875',
#  '0000001875',
#  '0000001876',
#  '0000001876',
#  '0000001876',
#  '0000001876',
#  '0000001876',
#  '0000004997',
#  '0000004996',
#  '0000004997',
#  '0000004995',
#  '0000004996',
#  '0000004997',
#  '0000004997',
#  '0000004997',
#  '0000004997',
#  '0000004998',
#  '0000004999',
#  '0000004999',
#  '0000005000',
#  '0000005000',
#  '0000001878',
#  '0000001879',
#  '0000005002',
#  '0000001878',
#  '0000001883',
#  '0000001882',
#  '0000001882',
#  '0000001884',
#  '0000001884',
#  '0000001885',
#  '0000001885',
#  '0000001885',
#  '0000005003',
#  '0000005003',
#  '0000005003',
#  '0000005003',
#  '0000005003',
#  '0000005004',
#  '0000005004',
#  '0000005004',
#  '0000005005',
#  '0000005006',
#  '0000005006',
#  '0000005006',
#  '0000005006',
#  '0000005006',
#  '0000005007',
#  '0000005007',
#  '0000005008',
#  '0000005008',
#  '0000005008',
#  '0000005009',
#  '0000005010',
#  '0000005010',
#  '0000005011',
#  '0000005011',
#  '0000005011',
#  '0000005011',
#  '0000005011',
#  '0000005012',
#  '0000005012',
#  '0000005012',
#  '0000005012',
#  '0000005013',
#  '0000005013',
#  '0000005013',
#  '0000005013',
#  '0000005014',
#  '0000005014',
#  '0000005008',
#  '0000001884',
#  '0000001886',
#  '0000001886',
#  '0000001886',
#  '0000001886',
#  '0000000176',
#  '0000000176',
#  '0000001887',
#  '0000001888',
#  '0000005015',
#  '0000005015',
#  '0000005015',
#  '0000005015',
#  '0000005016',
#  '0000005017',
#  '0000005017',
#  '0000005018',
#  '0000005018',
#  '0000005018',
#  '0000005018',
#  '0000005019',
#  '0000005020',
#  '0000001889',
#  '0000001889',
#  '0000005021',
#  '0000005021',
#  '0000005021',
#  '0000005021',
#  '0000005021',
#  '0000005021',
#  '0000001890',
#  '0000001890',
#  '0000005022',
#  '0000005023',
#  '0000005024',
#  '0000005024',
#  '0000005025',
#  '0000005025',
#  '0000005025',
#  '0000005025',
#  '0000001891',
#  '0000001891',
#  '0000001891',
#  '0000001891',
#  '0000005026',
#  '0000005026',
#  '0000005026',
#  '0000005026',
#  '0000005026',
#  '0000005026',
#  '0000005026',
#  '0000005027',
#  '0000005027',
#  '0000005028',
#  '0000005029',
#  '0000005029',
#  '0000005029',
#  '0000005029',
#  '0000005029',
#  '0000005030',
#  '0000005031',
#  '0000005031',
#  '0000005031',
#  '0000001892',
#  '0000001892',
#  '0000001893',
#  '0000001893',
#  '0000001894',
#  '0000001894',
#  '0000001894',
#  '0000001894',
#  '0000001895',
#  '0000001895',
#  '0000001896',
#  '0000001896',
#  '0000001897',
#  '0000001897',
#  '0000001897',
#  '0000001898',
#  '0000001898',
#  '0000001898',
#  '0000001899',
#  '0000001899',
#  '0000001899',
#  '0000001899',
#  '0000001899',
#  '0000001900',
#  '0000001900',
#  '0000001900',
#  '0000001900',
#  '0000001900',
#  '0000001900',
#  '0000001901',
#  '0000001901',
#  '0000001901',
#  '0000005032',
#  '0000005032',
#  '0000005032',
#  '0000005032',
#  '0000005032',
#  '0000005033',
#  '0000005033',
#  '0000005034',
#  '0000005034',
#  '0000005034',
#  '0000005035',
#  '0000005035',
#  '0000005035',
#  '0000005035',
#  '0000005036',
#  '0000005037',
#  '0000005038',
#  '0000005038',
#  '0000005039',
#  '0000005039',
#  '0000005040',
#  '0000005041',
#  '0000005042',
#  '0000005043',
#  '0000005044',
#  '0000005044',
#  '0000005045',
#  '0000005045',
#  '0000005045',
#  '0000005045',
#  '0000005045',
#  '0000005045',
#  '0000005045',
#  '0000005045',
#  '0000005045',
#  '0000005045',
#  '0000005046',
#  '0000005046',
#  '0000005047',
#  '0000005047',
#  '0000005047',
#  '0000005047',
#  '0000005048',
#  '0000005048',
#  '0000005048',
#  '0000005048',
#  '0000005049',
#  '0000005049',
#  '0000005049',
#  '0000005049',
#  '0000005050',
#  '0000005050',
#  '0000005051',
#  '0000005051',
#  '0000005052',
#  '0000005052',
#  '0000005052',
#  '0000005052',
#  '0000005052',
#  '0000005052',
#  '0000005053',
#  '0000005054',
#  '0000005054',
#  '0000005054',
#  '0000005054',
#  '0000005054',
#  '0000005054',
#  '0000000177',
#  '0000001902',
#  '0000001903',
#  '0000001903',
#  '0000001903',
#  '0000001903',
#  '0000001904',
#  '0000001904',
#  '0000001904',
#  '0000001905',
#  '0000001905',
#  '0000005055',
#  '0000005055',
#  '0000005055',
#  '0000005055',
#  '0000005055',
#  '0000005055',
#  '0000005056',
#  '0000005056',
#  '0000005056',
#  '0000005056',
#  '0000005056',
#  '0000005056',
#  '0000005056',
#  '0000005056',
#  '0000005056',
#  '0000005057',
#  '0000005057',
#  '0000005058',
#  '0000005058',
#  '0000005058',
#  '0000005059',
#  '0000005059',
#  '0000005060',
#  '0000005061',
#  '0000005062',
#  '0000005062',
#  '0000005063',
#  '0000005063',
#  '0000005064',
#  '0000005064',
#  '0000005064',
#  '0000005064',
#  '0000005065',
#  '0000005066',
#  '0000005066',
#  '0000005067',
#  '0000005067',
#  '0000005067',
#  '0000001906',
#  '0000001907',
#  '0000001908',
#  '0000001908',
#  '0000000178',
#  '0000000179',
#  '0000000179',
#  '0000000179',
#  '0000001909',
#  '0000001909',
#  '0000001910',
#  '0000001910',
#  '0000001911',
#  '0000001911',
#  '0000001912',
#  '0000001913',
#  '0000001913',
#  '0000001913',
#  '0000001914',
#  '0000001914',
#  '0000001914',
#  '0000001914',
#  '0000001915',
#  '0000001915',
#  '0000005068',
#  '0000005069',
#  '0000005069',
#  '0000005070',
#  '0000005070',
#  '0000005070',
#  '0000005070',
#  '0000005071',
#  '0000005071',
#  '0000005071',
#  '0000005071',
#  '0000005071',
#  '0000005071',
#  '0000005072',
#  '0000005072',
#  '0000005072',
#  '0000005073',
#  '0000005073',
#  '0000005073',
#  '0000005073',
#  '0000005073',
#  '0000005073',
#  '0000005074',
#  '0000005075',
#  '0000005075',
#  '0000005075',
#  '0000005075',
#  '0000005076',
#  '0000005076',
#  '0000005076',
#  '0000005076',
#  '0000005076',
#  '0000005077',
#  '0000005078',
#  '0000005078',
#  '0000005078',
#  '0000005078',
#  '0000005079',
#  '0000005079',
#  '0000005079',
#  '0000005080',
#  '0000005081',
#  '0000005081',
#  '0000005081',
#  '0000005081',
#  '0000005081',
#  '0000005081',
#  '0000005082',
#  '0000005083',
#  '0000005083',
#  '0000005083',
#  '0000005084',
#  '0000005084',
#  '0000005084',
#  '0000005085',
#  '0000005085',
#  '0000001916',
#  '0000001916',
#  '0000001916',
#  '0000000180',
#  '0000000180',
#  '0000005086',
#  '0000005087',
#  '0000005087',
#  '0000005088',
#  '0000005088',
#  '0000005088',
#  '0000005088',
#  '0000005089',
#  '0000005089',
#  '0000005089',
#  '0000005090',
#  '0000005090',
#  '0000005090',
#  '0000005091',
#  '0000005091',
#  '0000005091',
#  '0000005092',
#  '0000005093',
#  '0000005093',
#  '0000005093',
#  '0000005093',
#  '0000005093',
#  '0000005093',
#  '0000005093',
#  '0000005093',
#  '0000005093',
#  '0000005094',
#  '0000005095',
#  '0000005095',
#  '0000005095',
#  '0000005095',
#  '0000005096',
#  '0000000081',
#  '0000000081',
#  '0000000081',
#  '0000000081',
#  '0000000081',
#  '0000000081',
#  '0000001917',
#  '0000001917',
#  '0000001918',
#  '0000001918',
#  '0000001919',
#  '0000001919',
#  '0000001919',
#  '0000001919',
#  '0000001920',
#  '0000001920',
#  '0000001920',
#  '0000000181',
#  '0000000181',
#  '0000001921',
#  '0000000182',
#  '0000001922',
#  '0000001922',
#  '0000001923',
#  '0000001924',
#  '0000001925',
#  '0000000183',
#  '0000000183',
#  '0000000183',
#  '0000000183',
#  '0000000183',
#  '0000000183',
#  '0000001926',
#  '0000001926',
#  '0000001926',
#  '0000001926',
#  '0000001927',
#  '0000001927',
#  '0000001928',
#  '0000001928',
#  '0000005097',
#  '0000005097',
#  '0000005097',
#  '0000005097',
#  '0000005097',
#  '0000005097',
#  '0000005098',
#  '0000005099',
#  '0000005100',
#  '0000005101',
#  '0000005101',
#  '0000005101',
#  '0000005101',
#  '0000005101',
#  '0000005102',
#  '0000005103',
#  '0000005104',
#  '0000005105',
#  '0000005105',
#  '0000005105',
#  '0000005105',
#  '0000005105',
#  '0000005106',
#  '0000005106',
#  '0000005106',
#  '0000005107',
#  '0000005107',
#  '0000005107',
#  '0000005108',
#  '0000005108',
#  '0000005108',
#  '0000005109',
#  '0000005109',
#  '0000005110',
#  '0000005110',
#  '0000005110',
#  '0000005110',
#  '0000005110',
#  '0000005110',
#  '0000005110',
#  '0000005110',
#  '0000005111',
#  '0000005111',
#  '0000005112',
#  '0000001929',
#  '0000001929',
#  '0000005113',
#  '0000001930',
#  '0000001931',
#  '0000001931',
#  '0000001931',
#  '0000001931',
#  '0000001932',
#  '0000001932',
#  '0000005114',
#  '0000005114',
#  '0000005114',
#  '0000005115',
#  '0000005115',
#  '0000005116',
#  '0000005116',
#  '0000005116',
#  '0000005116',
#  '0000005116',
#  '0000005116',
#  '0000005116',
#  '0000005116',
#  '0000005117',
#  '0000005117',
#  '0000005118',
#  '0000005119',
#  '0000005119',
#  '0000005119',
#  '0000005119',
#  '0000005119',
#  '0000005120',
#  '0000005121',
#  '0000005121',
#  '0000005121',
#  '0000005122',
#  '0000005123',
#  '0000005123',
#  '0000005124',
#  '0000005124',
#  '0000005124',
#  '0000005124',
#  '0000005124',
#  '0000005124',
#  '0000005125',
#  '0000005125',
#  '0000005125',
#  '0000005125',
#  '0000005125',
#  '0000005126',
#  '0000005126',
#  '0000005126',
#  '0000005126',
#  '0000005127',
#  '0000005127',
#  '0000005127',
#  '0000005127',
#  '0000005128',
#  '0000005129',
#  '0000005130',
#  '0000005130',
#  '0000005130',
#  '0000005130',
#  '0000005130',
#  '0000005130',
#  '0000005131',
#  '0000005131',
#  '0000005131',
#  '0000005131',
#  '0000005131',
#  '0000005131',
#  '0000001933',
#  '0000001933',
#  '0000001933',
#  '0000001934',
#  '0000001934',
#  '0000001934',
#  '0000001934',
#  '0000001935',
#  '0000001935',
#  '0000001935',
#  '0000001936',
#  '0000001936',
#  '0000001937',
#  '0000001937',
#  '0000001938',
#  '0000001939',
#  '0000001940',
#  '0000001941',
#  '0000001941',
#  '0000001942',
#  '0000005132',
#  '0000005133',
#  '0000005133',
#  '0000005133',
#  '0000005133',
#  '0000005134',
#  '0000005134',
#  '0000005134',
#  '0000005134',
#  '0000005134',
#  '0000005134',
#  '0000005135',
#  '0000005135',
#  '0000005136',
#  '0000005137',
#  '0000005137',
#  '0000005137',
#  '0000005137',
#  '0000005137',
#  '0000005137',
#  '0000005137',
#  '0000005137',
#  '0000005138',
#  '0000005139',
#  '0000005139',
#  '0000005139',
#  '0000005140',
#  '0000005140',
#  '0000005140',
#  '0000005141',
#  '0000005142',
#  '0000005142',
#  '0000005142',
#  '0000005143',
#  '0000005143',
#  '0000005143',
#  '0000005144',
#  '0000005145',
#  '0000005145',
#  '0000005145',
#  '0000005146',
#  '0000005146',
#  '0000005147',
#  '0000005147',
#  '0000005148',
#  '0000005148',
#  '0000005148',
#  '0000005149',
#  '0000005149',
#  '0000005150',
#  '0000005151',
#  '0000005151',
#  '0000005151',
#  '0000005151',
#  '0000005151',
#  '0000005151',
#  '0000005152',
#  '0000005152',
#  '0000005152',
#  '0000005153',
#  '0000005154',
#  '0000001943',
#  '0000001943',
#  '0000001944',
#  '0000001944',
#  '0000001945',
#  '0000001946',
#  '0000001946',
#  '0000001946',
#  '0000001947',
#  '0000001947',
#  '0000001947',
#  '0000001947',
#  '0000001947',
#  '0000001947',
#  '0000001947',
#  '0000001948',
#  '0000001948',
#  '0000000184',
#  '0000001949',
#  '0000001949',
#  '0000001950',
#  '0000001950',
#  '0000001950',
#  '0000001950',
#  '0000001951',
#  '0000001951',
#  '0000005155',
#  '0000005155',
#  '0000005155',
#  '0000005155',
#  '0000005155',
#  '0000005156',
#  '0000005156',
#  '0000005156',
#  '0000005157',
#  '0000005157',
#  '0000005158',
#  '0000005159',
#  '0000005160',
#  '0000005160',
#  '0000005160',
#  '0000005160',
#  '0000005161',
#  '0000005162',
#  '0000005162',
#  '0000005163',
#  '0000005163',
#  '0000000088',
#  '0000000088',
#  '0000000088',
#  '0000000088',
#  '0000000088',
#  '0000000088',
#  '0000005164',
#  '0000005164',
#  '0000005165',
#  '0000005166',
#  '0000005166',
#  '0000005166',
#  '0000005167',
#  '0000005167',
#  '0000005167',
#  '0000005167',
#  '0000005168',
#  '0000005168',
#  '0000001952',
#  '0000001953',
#  '0000001953',
#  '0000001953',
#  '0000005169',
#  '0000005169',
#  '0000005169',
#  '0000005170',
#  '0000005170',
#  '0000005170',
#  '0000005170',
#  '0000005170',
#  '0000005170',
#  '0000005171',
#  '0000005171',
#  '0000005171',
#  '0000005172',
#  '0000005173',
#  '0000005173',
#  '0000005173',
#  '0000005173',
#  '0000005173',
#  '0000005173',
#  '0000005173',
#  '0000005174',
#  '0000001954',
#  '0000001954',
#  '0000001954',
#  '0000001954',
#  '0000001954',
#  '0000001954',
#  '0000005175',
#  '0000005176',
#  '0000005176',
#  '0000005176',
#  '0000005176',
#  '0000005176',
#  '0000005176',
#  '0000005176',
#  '0000005177',
#  '0000001954',
#  '0000001954',
#  '0000001955',
#  '0000001955',
#  '0000001955',
#  '0000001955',
#  '0000001955',
#  '0000000188',
#  '0000000189',
#  '0000001956',
#  '0000001957',
#  '0000001957',
#  '0000001958',
#  '0000001958',
#  '0000001958',
#  '0000001959',
#  '0000001959',
#  '0000001960',
#  '0000001960',
#  '0000001961',
#  '0000001961',
#  '0000001962',
#  '0000001963',
#  '0000001963',
#  '0000005178',
#  '0000005178',
#  '0000005179',
#  '0000005180',
#  '0000005180',
#  '0000005180',
#  '0000005180',
#  '0000005180',
#  '0000005181',
#  '0000005181',
#  '0000005181',
#  '0000005181',
#  '0000005182',
#  '0000005182',
#  '0000005182',
#  '0000005182',
#  '0000005182',
#  '0000005182',
#  '0000005183',
#  '0000005183',
#  '0000005184',
#  '0000005185',
#  '0000005185',
#  '0000005185',
#  '0000005185',
#  '0000005185',
#  '0000005185',
#  '0000001964',
#  '0000005186',
#  '0000005186',
#  '0000005186',
#  '0000005186',
#  '0000005187',
#  ...]

# %%
wb.close()
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13992\227421287.py in <module>
# ----> 1 wb.close()
#
# D:\anaconda\lib\site-packages\xlwings\main.py in close(self)
#    1077         .. versionadded:: 0.1.1
#    1078         """
# -> 1079         self.impl.close()
#    1080
#    1081     def save(self, path=None, password=None):
#
# D:\anaconda\lib\site-packages\xlwings\_xlwindows.py in close(self)
#     803
#     804     def close(self):
# --> 805         self.xl.Close(SaveChanges=False)
#     806
#     807     def save(self, path=None, password=None):
#
# D:\anaconda\lib\site-packages\xlwings\_xlwindows.py in __call__(self, *args, **kwargs)
#     103         while True:
#     104             try:
# --> 105                 v = self.__method(*args, **kwargs)
#     106                 if isinstance(v, (CDispatch, CoClassBaseClass, DispatchBaseClass)):
#     107                     return COMRetryObjectWrapper(v)
#
# ~\AppData\Local\Temp\gen_py\3.9\00020813-0000-0000-C000-000000000046x0x1x9.py in Close(self, SaveChanges, Filename, RouteWorkbook)
#   46592
#   46593         def Close(self, SaveChanges=defaultNamedOptArg, Filename=defaultNamedOptArg, RouteWorkbook=defaultNamedOptArg):
# > 46594 		return self._oleobj_.InvokeTypes(277, LCID, 1, (24, 0), ((12, 17), (12, 17), (12, 17)),SaveChanges
#   46595 			, Filename, RouteWorkbook)
#   46596
#
# com_error: (-2147023174, 'RPC 服务器不可用。', None, None)

# %%
app = xw.App(visible=False, add_book=False)
wb1 = app.books.open(fname1)
ws1 = wb.sheets[0]
data = pd.DataFrame(pd.read_excel(fname1,'UFPrn20230426084240'))
ws1.clear_contents()
ws1.range('A1').options(pd.DataFrame, index=False).value = data
wb1.save(fname1)
wb.close()
app.quit()
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13992\2500643212.py in <module>
#       1 app = xw.App(visible=False, add_book=False)
#       2 wb1 = app.books.open(fname1)
# ----> 3 ws1 = wb.sheets[0]
#       4 data = pd.DataFrame(pd.read_excel(fname1,'UFPrn20230426084240'))
#       5 ws1.clear_contents()
#
# D:\anaconda\lib\site-packages\xlwings\main.py in sheets(self)
#    1060         .. versionadded:: 0.9.0
#    1061         """
# -> 1062         return Sheets(impl=self.impl.sheets)
#    1063
#    1064     @property
#
# D:\anaconda\lib\site-packages\xlwings\_xlwindows.py in sheets(self)
#     796     @property
#     797     def sheets(self):
# --> 798         return Sheets(xl=self.xl.Worksheets)
#     799
#     800     @property
#
# D:\anaconda\lib\site-packages\xlwings\_xlwindows.py in __getattr__(self, item)
#     180         while True:
#     181             try:
# --> 182                 v = getattr(self._inner, item)
#     183                 if isinstance(v, (CDispatch, CoClassBaseClass, DispatchBaseClass)):
#     184                     return COMRetryObjectWrapper(v)
#
# D:\anaconda\lib\site-packages\xlwings\_win32patch.py in __getattr__(self, attr)
#      53         d = self.__dict__["_dispobj_"]
#      54         if d is not None:
# ---> 55             return getattr(d, attr)
#      56         raise AttributeError(attr)
#      57
#
# D:\anaconda\lib\site-packages\win32com\client\__init__.py in __getattr__(self, attr)
#     581                 "'%s' object has no attribute '%s'" % (repr(self), attr)
#     582             )
# --> 583         return self._ApplyTypes_(*args)
#     584
#     585     def __setattr__(self, attr, value):
#
# D:\anaconda\lib\site-packages\win32com\client\__init__.py in _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args)
#     570     def _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args):
#     571         return self._get_good_object_(
# --> 572             self._oleobj_.InvokeTypes(dispid, 0, wFlags, retType, argTypes, *args),
#     573             user,
#     574             resultCLSID,
#
# com_error: (-2147023174, 'RPC 服务器不可用。', None, None)

# %%
'''
每天将D:\ribaobiao下的流水账和零配件入库统计或退货统计分别写入原材料实时流水账和零配件实时流水账，
去除重复数据，再从原材料流水账中，
将上月26日至昨天的白云纸张入库和其它供应商的纸张入库
分别写入白云入库和2020入库！
后者按期间、供应商、时间、单号、品名排序！
命令行快捷按键是:meitian
'''
# _*_ coding:utf-8 _*_
import os
import numpy as np
import pandas as pd
from singleCailiaoRename import singlecailiaoName
from qijianchuli import qijian
from baiyunqijian import  baiyunQijian
from fnmatch import fnmatch
import xlwings as xw
from beifenFile import beifen
import datetime
import quchong
from datetime import datetime, date, timedelta
import addbaiyunRukuPd
from addbaiyunRukuPd import liushuizhang
from addbaiyunRukuPd import chuli
from addbaiyunRukuPd import liushuizhang
from addbaiyunRukuPd import  qushu
from addbaiyunRukuPd import  jiagongsi
from addbaiyunRukuPd import  delchongfu
import addzhiRukuPd
from easygui import buttonbox
import zhiNewGongyingshang
import easygui

def yuancailiaoLiushuizhang(files):
    datas = []
    for filename in files:
        data = pd.read_excel(filename,dtype = {'单据号':str})
        data = data[['日期', '单据号', '供货单位', '存货名称', '计量单位',  '入库数量','入库单价', '入库金额']]
        # data = data.rename(columns={'存货名称': '品名', '计量单位': '单价'})
        data.dropna(subset=['供货单位'], inplace=True)  # 删除供货单位列中的有空值的行
        datas.append(data)

    ysl = pd.concat(datas)  # 多个原材料流水账账汇总
    ysl['单据号'] = ysl['单据号'].astype(str)  # 多个原材料流水账账汇总

    ysl.rename({'存货名称':'品名','计量单位':'单位'},axis=1,inplace=True)   #042新账套引出的流水账，列名有变，需调整
    # a = ysl.pop('入库数量')  # 移动列
    # ysl.insert(5, '入库数量', a)
    # print(ysl)

    for j in ['cwName', 'priceName', '期间', '送货日期', '白云期间', '令数', '吨数', '令价', '吨价', '吨价0', '记账']:
        ysl[j] = None
    ysl = ysl.assign(cwName=ysl['品名'].map(lambda x: singlecailiaoName(x)[0]))
    ysl = ysl.assign(priceName=ysl['品名'].map(lambda x: singlecailiaoName(x)[1]))
    ysl = ysl.assign(期间=ysl['日期'].map(lambda x: qijian(x)))
    ysl = ysl.assign(白云期间=ysl['日期'].map(lambda x: baiyunQijian(x)[0]))
    ysl = ysl.assign(送货日期=ysl['日期'].map(lambda x: baiyunQijian(x)[1]))
    ysl = ysl.assign(令数=ysl.apply(lambda x: lingDun(x)[0], axis=1))
    ysl = ysl.assign(吨数=ysl.apply(lambda x: lingDun(x)[1], axis=1))
    ysl = ysl.assign(令价=ysl.apply(lambda x: lingDun(x)[2], axis=1))
    ysl = ysl.assign(吨价=ysl.apply(lambda x: lingDun(x)[3], axis=1))
    ysl['日期'] = ysl['日期'].astype('datetime64[ns]')
    ysl['送货日期'] = ysl['送货日期'].astype('datetime64[ns]')
    ysl['单据号'] = ysl['单据号'].astype('int64')
    ysl = ysl.assign(cwName=np.where((ysl.cwName == '线圈') & (ysl['单位'] == '卷'), '线圈（卷）', ysl.cwName))
    ysl = ysl.assign(priceName=np.where((ysl.priceName == '线圈') & (ysl['单位'] == '卷'), '线圈（卷）', ysl.priceName))
    ysl = ysl.assign(cwName=np.where((ysl.cwName == '线圈') & (ysl['单位'] == '公斤'), '线圈（公斤）', ysl.cwName))
    ysl = ysl.assign(priceName=np.where((ysl.priceName == '线圈') & (ysl['单位'] == '公斤'), '线圈（公斤）', ysl.priceName))

    return ysl

def qijianJisuan(string):
    y = int(string.split('-')[0])
    m = int(string.split('-')[1])
    d = int(string.split('-')[2])
    if d > 25 and m < 12:
        m = m + 1
    elif d > 25 and m == 12 :
        m = 1
        y = y + 1
    else :
        pass
    qijian = str(y)+'-'+str(m).zfill(2)
    return qijian

def lingpeijianLiushuizhang(files):
    datas = []
    for filename in files:
        data = pd.read_excel(filename)

        if data.columns[0]=='退货单号':
            data.rename(columns={'退货单号':'入库单号','退货日期': '入库日期','退货数量':'入库数量'},inplace=True)
            data['入库数量'] = data['入库数量'] * -1
            data['金额'] = data['金额'] * -1
        else :
            pass
        data.dropna(subset=['入库单号'], inplace=True)  # 删除入库单号列中的有空值的行

        datas.append(data)
    lpj = pd.concat(datas)
    for j in ['期间','标准日期']:
        lpj[j] = lpj['入库日期']
    lpj['标准日期'] = lpj['标准日期'].astype('datetime64[ns]')
    lpj = lpj.assign(期间=lpj['入库日期'].map(lambda x: qijianJisuan(x)))
    lpj['入库日期'] = lpj['入库日期'].astype('datetime64[ns]')
    return lpj

def concatAndQuchong(fname,sheetname,newdata,in_subject,index_col=['日期','单据号', '供货单位'] ):
    app = xw.App(visible=False, add_book=False)
    wb = app.books.open(fname)
    ws = wb.sheets[sheetname]
    olddata = pd.DataFrame(pd.read_excel(fname, sheetname,dtype = {'单据号':str}))
    data = pd.concat([olddata, newdata])
    col_names = data.columns.to_list()
    data.drop_duplicates(subset=in_subject, keep='first', inplace=True)
    data = data.set_index(index_col)                   #按日期索引
    data = data.sort_values(by=index_col)
    data = data.reset_index()                               #取消索引
    data = data[col_names]                               #按原来列顺序
    # first_col = data.columns[0]                   #取第一列
    # data = data.set_index(first_col)      #按首列索引
    ws.clear_contents()
    ws.range('A1').options(pd.DataFrame, index=False).value = data
    wb.save()
    wb.close()
    app.quit()
    return fname

def lingDun(x):
    ling = 0
    lingjia = 0
    dunshu = 0
    dunjia = 0
    if x['单位']=='kg' or x['单位']=='公斤':
        dunshu = x['入库数量']/1000
        dunjia = x['入库单价']*1000
    elif x['单位']=='令':
        ling = x['入库数量']
        lingjia = round(x['入库单价'],2)
        ke = float(singlecailiaoName(x['品名'])[2])
        chang = float(singlecailiaoName(x['品名'])[3])
        kuan = float(singlecailiaoName(x['品名'])[4])
        dunshu = round(ke/1000/1000*chang/1000*kuan/1000*500*x['入库数量'],3)
        try :
            dunjia = round(x['入库金额']/dunshu,0)
        except:
            dunjia = 0
    else :
        pass
    return ling,dunshu,lingjia,dunjia


def startriqiEndriqi(today):
    yesterday = today + timedelta(days=-1)  # 昨天日期
    year = yesterday.year
    month = yesterday.month
    day = yesterday.day
    if day <= 25 and month == 1:
        last_year = year - 1
        last_month = 12
        last_day = 26
    elif day <= 25 and month != 1:
        last_year = year
        last_month = month - 1
        last_day = 26
    else:
        last_year = year
        last_month = month
        last_day = 26
    start_riqi = str(last_year) + '-' + str(last_month) + '-' + str(last_day)
    end_riqi = str(year) + '-' + str(month) + '-' + str(day)
    start_riqi = pd.Timestamp(start_riqi)
    end_riqi = pd.Timestamp(end_riqi)
    return start_riqi, end_riqi

def lszTobaiyun(start_riqi, end_riqi,piaojuhao):
    df = liushuizhang()  # 流水账df
    df1 = qushu(df, start_riqi, end_riqi, piaojuhao)
    fname_ruku = chuli(df1)
    df = pd.read_excel(fname_ruku, '2020',dtype = {'单号':str})
    in_subject = ['开票日期', '入库单号', '品名', '数量(令)', '计算重量', '仓库材料']
    sort_cols = ['开票日期', '入库单号', '品名']
    # sort_cols = ['入库单号', '品名']
    delchongfu(fname_ruku, '2020', in_subject,sort_cols)
    jiagongsi(fname_ruku)

def lszTozhi(start_riqi, end_riqi,piaojuhao):
    df = addzhiRukuPd.liushuizhang()  # 流水账df
    jianchen = zhiNewGongyingshang.zhiGongyingshang()
    df1 = addzhiRukuPd.qushu(df, start_riqi, end_riqi, piaojuhao,jianchen)
    fname_ruku = addzhiRukuPd.chuli(df1)
    df = pd.read_excel(fname_ruku, '入库',dtype = {'单号':str})
    in_subject = ['单位', '供应商', '时间', '单号', '材料', '入库', '入库（kg）']
    sort_cols = ['期间','供应商','时间', '单号','材料']
    addzhiRukuPd.delchongfu(fname_ruku, '入库', in_subject,sort_cols)
    addzhiRukuPd.jiagongsi(fname_ruku)

def addmeitianLiushuizhang():
    desktopPath = r'D:\ribaobiao'
    os.chdir(desktopPath)
    filenames = os.listdir(desktopPath)
    lsz_files = [i for i in filenames if fnmatch(i, '*流水*.xls*')]
    lpj_files = [i for i in filenames if fnmatch(i, '*统计*.xls*')]
    # 原材料
    try:
        if len(lsz_files) >= 1:
            ysl_subject = ['日期', '单据号', '供货单位', '品名', '单位', '入库数量', '入库单价', '入库金额', 'cwName', 'priceName', '期间', '送货日期',
                           '白云期间', '令数', '吨数', '令价', '吨价']
            ysl = yuancailiaoLiushuizhang(lsz_files)

            ysl_fname = r'F:\a00nutstore\006\zw\原材料实时流水账\原材料实时流水账.xlsx'
            beifen(ysl_fname)
            concatAndQuchong(ysl_fname, '流水账', ysl, ysl_subject)
            # quchong.delchongfu(ysl_fname,  '流水账',ysl_subject)   #20211217两次去重才行
        else:
            pass
    except:
        pass

    # 零配件
    try:
        if len(lpj_files) >= 1:
            lpj_subject = ['入库单号', '入库日期', '相关单位', '单据附注', '货品编码', '货品名称', '规格', '所属类别', '单位', '入库数量', '单价', '金额', '备注',
                           '期间', '标准日期']
            lpj = lingpeijianLiushuizhang(lpj_files)
            lpj_fname = r'F:\a00nutstore\006\zw\lingpeijian\零配件实时入库2020.xlsx'
            beifen(lpj_fname)
            index_col = ['入库日期', '入库单号', '相关单位']
            concatAndQuchong(lpj_fname, 'ssrk', lpj, lpj_subject, index_col)
            quchong.delchongfu(lpj_fname, 'ssrk', lpj_subject,
                               index_col=['入库日期', '入库单号', '相关单位'])  # 零配件两次去重才行，不知原因20211207
        else:
            pass
    except:
        pass

def tozhi(start_riqi, end_riqi, piaojuhao):
    lszTozhi(start_riqi, end_riqi, piaojuhao)

def tobaiyun(start_riqi, end_riqi, piaojuhao):
    lszTobaiyun(start_riqi, end_riqi, piaojuhao)

def main():
    addmeitianLiushuizhang()

    piaojuhao = 0
    msg = '请选择日期输入的方式：'
    
    choice = buttonbox(msg, choices=['自动', '手动','singleZhi','singleBaiyun'])
    if choice == '自动':
        today = date.today()
        start_riqi, end_riqi = startriqiEndriqi(today)
        try :
            tobaiyun(start_riqi, end_riqi, piaojuhao)
        except:
            print('本月没有白云入库')
        try :
            tozhi(start_riqi, end_riqi, piaojuhao)
        except:
            print('本月没有纸入库')

    elif choice == '手动':
        today = pd.Timestamp(easygui.enterbox('请输入要查询期间的后一天"2021-12-27"\n'))
        start_riqi, end_riqi = startriqiEndriqi(today)
        try :
            tobaiyun(start_riqi, end_riqi, piaojuhao)
        except:
            print('本月没有白云入库')
        try :
            tozhi(start_riqi, end_riqi, piaojuhao)
        except:
            print('本月没有纸入库')
    elif choice == 'singleZhi':
        try :
            addzhiRukuPd.main()
        except:
            print('本月没有纸入库')
    else :
        try:
            addbaiyunRukuPd.main()
        except:
            print('本月没有白云入库')


    easygui.msgbox('程序结束')




if __name__ == '__main__':
    main()

# %%
from datetime import datetime, date, timedelta

# %%
def startriqiEndriqi(today):
    yesterday = today + timedelta(days=-1)  # 昨天日期
    year = yesterday.year
    month = yesterday.month
    day = yesterday.day
    if day <= 25 and month == 1:
        last_year = year - 1
        last_month = 12
        last_day = 26
    elif day <= 25 and month != 1:
        last_year = year
        last_month = month - 1
        last_day = 26
    else:
        last_year = year
        last_month = month
        last_day = 26
    start_riqi = str(last_year) + '-' + str(last_month) + '-' + str(last_day)
    end_riqi = str(year) + '-' + str(month) + '-' + str(day)
    start_riqi = pd.Timestamp(start_riqi)
    end_riqi = pd.Timestamp(end_riqi)
    return start_riqi, end_riqi

# %%
today = date.today()
a,b = startriqiEndriqi(today)

# %%
a
# Out:
# Timestamp('2023-04-26 00:00:00')

# %%
b
# Out:
# Timestamp('2023-05-08 00:00:00')

# %%
desktopPath = r'D:\ribaobiao'
os.chdir(desktopPath)
# filenames = os.listdir(desktopPath)
filenames = [r'D:\ribaobiao\流水账.xlsx']
datas = []
# for filename in filenames:
ysl = pd.read_excel(filename,sheet_name = 0,dtype = {'单据号':str})
datas.append
ysl.dropna(subset=['供货单位'], inplace=True) 
# ysl = pd.concat(datas)  # 多个原材料流水账账汇总
ysl['单据号'] = ysl['单据号'].astype(str)  # 多个原材料流水账账汇总
ysl
# Out:
# D:\anaconda\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#              日期   单据类型         单据号  业务类型  业务号    仓库  收发类别   部门  业务员  \
# 10   2023-05-06  采购入库单  0000002026  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 11   2023-05-06  采购入库单  0000002027  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 45   2023-05-04  采购入库单  0000002017  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 46   2023-05-04  采购入库单  0000002017  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 47   2023-05-04  采购入库单  0000002017  普通采购  NaN  原材料库  采购入库  NaN  NaN
# ..          ...    ...         ...   ...  ...   ...   ...  ...  ...
# 342  2023-05-04  采购入库单  0000002016  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 343  2023-05-04  采购入库单  0000002016  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 344  2023-05-04  采购入库单  0000002016  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 345  2023-05-04  采购入库单  0000002016  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 346  2023-05-04  采购入库单  0000002016  普通采购  NaN  原材料库  采购入库  NaN  NaN
#
#              供货单位  ...  计量单位  应收数量     入库数量      入库单价      入库金额 应发数量 出库数量  \
# 10        孝感雅都新材料  ...     个   0.0    523.0    0.0000      0.00  0.0  0.0
# 11         浙江众成包装  ...     卷   0.0     80.0  236.9451  18955.61  0.0  0.0
# 45    驻马店白云纸业有限公司  ...    公斤   0.0  21570.0    0.0000      0.00  0.0  0.0
# 46    驻马店白云纸业有限公司  ...    公斤   0.0   1346.0    0.0000      0.00  0.0  0.0
# 47    驻马店白云纸业有限公司  ...    公斤   0.0  11138.0    0.0000      0.00  0.0  0.0
# ..            ...  ...   ...   ...      ...       ...       ...  ...  ...
# 342  昆山楚宏纸塑材料有限公司  ...     米   0.0  24000.0    0.0000      0.00  0.0  0.0
# 343  昆山楚宏纸塑材料有限公司  ...     米   0.0  24000.0    0.0000      0.00  0.0  0.0
# 344  昆山楚宏纸塑材料有限公司  ...     米   0.0  24000.0    0.0000      0.00  0.0  0.0
# 345  昆山楚宏纸塑材料有限公司  ...     米   0.0  24000.0    0.0000      0.00  0.0  0.0
# 346  昆山楚宏纸塑材料有限公司  ...     米   0.0  24000.0    0.0000      0.00  0.0  0.0
#
#      出库单价 出库金额  处理单号
# 10      0    0   NaN
# 11      0    0   NaN
# 45      0    0   NaN
# 46      0    0   NaN
# 47      0    0   NaN
# ..    ...  ...   ...
# 342     0    0   NaN
# 343     0    0   NaN
# 344     0    0   NaN
# 345     0    0   NaN
# 346     0    0   NaN
#
# [77 rows x 32 columns]

# %%
ysl
# Out:
#              日期   单据类型         单据号  业务类型  业务号    仓库  收发类别   部门  业务员  \
# 10   2023-05-06  采购入库单  0000002026  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 11   2023-05-06  采购入库单  0000002027  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 45   2023-05-04  采购入库单  0000002017  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 46   2023-05-04  采购入库单  0000002017  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 47   2023-05-04  采购入库单  0000002017  普通采购  NaN  原材料库  采购入库  NaN  NaN
# ..          ...    ...         ...   ...  ...   ...   ...  ...  ...
# 342  2023-05-04  采购入库单  0000002016  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 343  2023-05-04  采购入库单  0000002016  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 344  2023-05-04  采购入库单  0000002016  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 345  2023-05-04  采购入库单  0000002016  普通采购  NaN  原材料库  采购入库  NaN  NaN
# 346  2023-05-04  采购入库单  0000002016  普通采购  NaN  原材料库  采购入库  NaN  NaN
#
#              供货单位  ...  计量单位  应收数量     入库数量      入库单价      入库金额 应发数量 出库数量  \
# 10        孝感雅都新材料  ...     个   0.0    523.0    0.0000      0.00  0.0  0.0
# 11         浙江众成包装  ...     卷   0.0     80.0  236.9451  18955.61  0.0  0.0
# 45    驻马店白云纸业有限公司  ...    公斤   0.0  21570.0    0.0000      0.00  0.0  0.0
# 46    驻马店白云纸业有限公司  ...    公斤   0.0   1346.0    0.0000      0.00  0.0  0.0
# 47    驻马店白云纸业有限公司  ...    公斤   0.0  11138.0    0.0000      0.00  0.0  0.0
# ..            ...  ...   ...   ...      ...       ...       ...  ...  ...
# 342  昆山楚宏纸塑材料有限公司  ...     米   0.0  24000.0    0.0000      0.00  0.0  0.0
# 343  昆山楚宏纸塑材料有限公司  ...     米   0.0  24000.0    0.0000      0.00  0.0  0.0
# 344  昆山楚宏纸塑材料有限公司  ...     米   0.0  24000.0    0.0000      0.00  0.0  0.0
# 345  昆山楚宏纸塑材料有限公司  ...     米   0.0  24000.0    0.0000      0.00  0.0  0.0
# 346  昆山楚宏纸塑材料有限公司  ...     米   0.0  24000.0    0.0000      0.00  0.0  0.0
#
#      出库单价 出库金额  处理单号
# 10      0    0   NaN
# 11      0    0   NaN
# 45      0    0   NaN
# 46      0    0   NaN
# 47      0    0   NaN
# ..    ...  ...   ...
# 342     0    0   NaN
# 343     0    0   NaN
# 344     0    0   NaN
# 345     0    0   NaN
# 346     0    0   NaN
#
# [77 rows x 32 columns]

# %%
'5556'>'0'
# Out:
# True

# %%
ysl.to_excel('1111.xlsx')
os.startfile('1111.xlsx')

# %%
ysl['单据号']>'0'
# Out:
# 10     True
# 11     True
# 45     True
# 46     True
# 47     True
#        ...
# 342    True
# 343    True
# 344    True
# 345    True
# 346    True
# Name: 单据号, Length: 77, dtype: bool

# %%
ysl['单据号']>''
# Out:
# 10     True
# 11     True
# 45     True
# 46     True
# 47     True
#        ...
# 342    True
# 343    True
# 344    True
# 345    True
# 346    True
# Name: 单据号, Length: 77, dtype: bool

# %%
import easygui
piaojuhao = easygui.enterbox('请输入票据号90031065：')

# %%
piaojuhao
# Out:
# '0'

# %%
ysl['单据号']>=piaojuhao
# Out:
# 10     True
# 11     True
# 45     True
# 46     True
# 47     True
#        ...
# 342    True
# 343    True
# 344    True
# 345    True
# 346    True
# Name: 单据号, Length: 77, dtype: bool

# %%
fname = r'D:\ribaobiao\流水账 - 副本.xlsx'

# %%
data = ysl.copy()

# %%
#失败案例
app = xw.App(visible = False,add_book = False)
wb = app.books.open(fname)
ws = wb.sheets[0]
data = pd.DataFrame(pd.read_excel(fname, sheet_name = 0,dtype = {'单据号':str}))
# data.drop_duplicates(subset=in_subject, keep='first', inplace=True)
# data = data.sort_values(by=sort_cols)
# data = data.set_index(in_subject[0])
ws.range('A2').expand('table').clear_content()
ws.range('A1').options(pd.DataFrame,index=False).value = data
wb.save()
wb.close()
app.quit()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [37], in <cell line: 9>()
#       5 data = pd.DataFrame(pd.read_excel(fname, sheet_name = 0,dtype = {'单据号':str}))
#       6 # data.drop_duplicates(subset=in_subject, keep='first', inplace=True)
#       7 # data = data.sort_values(by=sort_cols)
#       8 # data = data.set_index(in_subject[0])
# ----> 9 ws[1:].clear_contents()
#      10 ws.range('A1').options(pd.DataFrame,index=False).value = data
#      11 wb.save()
#
# File D:\anaconda\lib\site-packages\xlwings\main.py:1615, in Sheet.__getitem__(self, item)
#    1613     return self.range(item)
#    1614 else:
# -> 1615     return self.cells[item]
#
# File D:\anaconda\lib\site-packages\xlwings\main.py:2352, in Range.__getitem__(self, key)
#    2350 elif isinstance(key, slice):
#    2351     if self.shape[0] > 1 and self.shape[1] > 1:
# -> 2352         raise IndexError(
#    2353             "One-dimensional slicing is not allowed on two-dimensional ranges"
#    2354         )
#    2356     if self.shape[0] > 1:
#    2357         return self[key, :]
#
# IndexError: One-dimensional slicing is not allowed on two-dimensional ranges

# %%
app = xw.App(visible = False,add_book = False)
wb = app.books.open(fname)
ws = wb.sheets[0]
data = pd.DataFrame(pd.read_excel(fname, sheet_name = 0,dtype = {'单据号':str}))
# data.drop_duplicates(subset=in_subject, keep='first', inplace=True)
# data = data.sort_values(by=sort_cols)
# data = data.set_index(in_subject[0])
ws.range('A2').expand('table').clear_content()
# ws.range('A1').options(pd.DataFrame,index=False).value = data
wb.save()
wb.close()
app.quit()
wb = openpyxl.load_workbook(fname)
ws = wb['UFPrn20230508080724']
max_row = ws.max_row
for i in lenlist(ws.values)
whilt max_row >= 1:
    dele
with pd.ExcelWriter(fname, engine='openpyxl')  as writer:
    writer.book = wb
    writer.sheets = dict((ws.title, ws) for ws in wb.worksheets)
    data.to_excel(writer,'UFPrn20230508080724', header=None, index=False, startrow=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [38], in <cell line: 8>()
#       4 data = pd.DataFrame(pd.read_excel(fname, sheet_name = 0,dtype = {'单据号':str}))
#       5 # data.drop_duplicates(subset=in_subject, keep='first', inplace=True)
#       6 # data = data.sort_values(by=sort_cols)
#       7 # data = data.set_index(in_subject[0])
# ----> 8 ws.range('A2').expand('table').clear_content()
#       9 # ws.range('A1').options(pd.DataFrame,index=False).value = data
#      10 wb.save()
#
# AttributeError: 'Range' object has no attribute 'clear_content'

# %%
fname
# Out:
# 'D:\\ribaobiao\\流水账 - 副本.xlsx'

# %%
wb = openpyxl.load_workbook(fname)
ws = wb['UFPrn20230508080724']
max_row = ws.max_row
ws.delete_rows(2,ws.max_row)
wb.save(fname)

# %%
datas =list(ws.values)
datas
# Out:
# [('日期',
#   '单据类型',
#   '单据号',
#   '业务类型',
#   '业务号',
#   '仓库',
#   '收发类别',
#   '部门',
#   '业务员',
#   '供货单位',
#   '订单号',
#   '到货单号',
#   '客户',
#   '备注',
#   '制单人',
#   '审核人',
#   '审核日期',
#   '记帐人',
#   '存货编码',
#   '存货代码',
#   '存货名称',
#   '规格型号',
#   '计量单位',
#   '应收数量',
#   '入库数量',
#   '入库单价',
#   '入库金额',
#   '应发数量',
#   '出库数量',
#   '出库单价',
#   '出库金额',
#   '处理单号'),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005356',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'SEB-22160外贸箱',
#   None,
#   'SEB-22160外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   500,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005356',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'EX-200外贸箱',
#   None,
#   'EX-200外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   2000,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005356',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'M13-1箱',
#   None,
#   'M13-1箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   37,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005357',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '书芯车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '25MM80克308兰背条',
#   None,
#   '25MM80克308兰背条',
#   None,
#   '米',
#   0,
#   0,
#   0,
#   0,
#   0,
#   6000,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005358',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '热熔胶Q3225',
#   None,
#   '热熔胶Q3225',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   250,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005359',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '外贸1号紫',
#   None,
#   '外贸1号紫',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   40,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005359',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '外贸6号金光红',
#   None,
#   '外贸6号金光红',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   20,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005359',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '铁丝26',
#   None,
#   '铁丝26',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   10,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005359',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '铁丝24',
#   None,
#   '铁丝24',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   20,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005360',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '0.18CM黑色橡皮20.3',
#   None,
#   '0.18CM黑色橡皮筋打铁扣20.3CM',
#   None,
#   '条',
#   0,
#   0,
#   0,
#   0,
#   0,
#   500,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '采购入库单',
#   '0000002026',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '孝感雅都新材料',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'EXLA580箱',
#   None,
#   'EXLA580箱',
#   None,
#   '个',
#   0,
#   523,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '采购入库单',
#   '0000002027',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '浙江众成包装',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '390卷筒POF',
#   None,
#   '390卷膜POF',
#   None,
#   '卷',
#   0,
#   80,
#   236.9451,
#   18955.61,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005361',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '外贸手提袋',
#   None,
#   '外贸手提袋',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   22200,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005361',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '打包带',
#   None,
#   '打包带',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   7,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005361',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '热熔胶背KG-6',
#   None,
#   '热熔胶背KG-6',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   250,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005361',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '聚乙烯醇',
#   None,
#   '聚乙烯醇',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   25,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005362',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '成品车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '8065胶',
#   None,
#   '8065胶',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   20,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005362',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '成品车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '816胶',
#   None,
#   '816胶',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   50,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005362',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '成品车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '北京白乳胶',
#   None,
#   '北京白乳胶',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   540,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005363',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   'RP-R黄',
#   None,
#   'RP-R黄',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   60,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005363',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '润版液',
#   None,
#   '润版液EX',
#   None,
#   '桶',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005363',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '水箱添加剂四色机',
#   None,
#   '水箱添加剂四色机',
#   None,
#   '桶',
#   0,
#   0,
#   0,
#   0,
#   0,
#   3,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005364',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '书芯车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '45MM牛皮801白背条',
#   None,
#   '45MM801白背条',
#   None,
#   '米',
#   0,
#   0,
#   0,
#   0,
#   0,
#   6000,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005364',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '书芯车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '8065胶',
#   None,
#   '8065胶',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   80,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005365',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '7/16白双线圈',
#   None,
#   '7/16白双线圈',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   12,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005366',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '816胶',
#   None,
#   '816胶',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   50,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005366',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '缠绕卷膜',
#   None,
#   '缠绕卷膜',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   4,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005367',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   'DJL16-3锐意内箱',
#   None,
#   'DJL16-3锐意内箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   220,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005367',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   'DJL16-3锐意外箱',
#   None,
#   'DJL16-3锐意外箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   110,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005367',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   'FL3260箱',
#   None,
#   'FL3260箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   60,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005368',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   'SEB-13300外贸箱',
#   None,
#   'SEB-13300外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1000,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005368',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   'EX-288外贸箱',
#   None,
#   'EX-288外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   397,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005369',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '52g兴泰885',
#   None,
#   '52g兴泰卷筒885',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   10467,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005369',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '54g兴泰卷筒900',
#   None,
#   '54g兴泰卷筒900',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   8518,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005369',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '60g白云卷筒885下差',
#   None,
#   '60g白云卷筒885下差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   5811,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005369',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '58g白云卷筒885下差',
#   None,
#   '58g白云卷筒885下差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   14193,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005370',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '无线胶装',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '60g白云卷筒725',
#   None,
#   '60g白云卷筒725',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   3134,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005370',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '无线胶装',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '58g白云卷筒900下差',
#   None,
#   '58g白云卷筒900下差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   3006,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005371',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '55g白云卷筒780',
#   None,
#   '55g白云卷筒780',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   766,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005371',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '65g白云卷筒390',
#   None,
#   '65g白云卷筒390',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   3574,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005371',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '65g白云卷筒780',
#   None,
#   '65g白云卷筒780',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   4425,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005371',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '52g兴泰卷筒880',
#   None,
#   '52g兴泰卷筒880',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   4434,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005371',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '58g白云卷筒864下差',
#   None,
#   '58g白云卷筒864下差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   4895,
#   0,
#   0,
#   None),
#  ('2023-05-07',
#   '材料出库单',
#   '0000005372',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '书芯车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-07',
#   None,
#   '60g白云卷筒905',
#   None,
#   '60g白云卷筒905',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   3024,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005331',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '外贸1号紫',
#   None,
#   '外贸1号紫',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   40,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002017',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '驻马店白云纸业有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '55g白云卷筒780',
#   None,
#   '55g白云卷筒780',
#   None,
#   '公斤',
#   0,
#   21570,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002017',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '驻马店白云纸业有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '55g白云卷筒815',
#   None,
#   '55g白云卷筒815',
#   None,
#   '公斤',
#   0,
#   1346,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002017',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '驻马店白云纸业有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '55g白云卷筒857',
#   None,
#   '55g白云卷筒857',
#   None,
#   '公斤',
#   0,
#   11138,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '其他出库单',
#   '0000000207',
#   '其他出库',
#   None,
#   '原材料库',
#   '其他出库',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   '上白',
#   None,
#   '46g无碳复写上白787*1092',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002018',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '钟祥市鑫众包装有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   '外贸手提袋',
#   None,
#   '外贸手提袋',
#   None,
#   '个',
#   0,
#   21600,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005332',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   '外贸1号紫',
#   None,
#   '外贸1号紫',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   40,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005332',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   '铁丝26',
#   None,
#   '铁丝26',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   10,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005332',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   '缠绕卷膜',
#   None,
#   '缠绕卷膜',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   4,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005333',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '书芯车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   '816胶',
#   None,
#   '816胶',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   50,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005333',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '书芯车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   '对开刀条',
#   None,
#   '对开刀条5MM',
#   None,
#   '支',
#   0,
#   0,
#   0,
#   0,
#   0,
#   25,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005333',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '书芯车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   '8065胶',
#   None,
#   '8065胶',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   80,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005333',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '书芯车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   '40MM牛皮801白背条',
#   None,
#   '40MM801白背条',
#   None,
#   '米',
#   0,
#   0,
#   0,
#   0,
#   0,
#   7000,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005334',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   '370卷膜POF',
#   None,
#   '370卷膜POF',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   20,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005334',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   '490卷膜POF',
#   None,
#   '490卷膜POF',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   10,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005334',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   '封箱透明胶',
#   None,
#   '封箱透明胶',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   300,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005334',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   '打包带',
#   None,
#   '打包带',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   6,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002019',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '武汉嘉骏',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '3mmE1060H双面胶',
#   None,
#   '3mm进口双面胶',
#   None,
#   '卷',
#   0,
#   2,
#   2500,
#   5000,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002019',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '武汉嘉骏',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '大双面胶',
#   None,
#   '德莎进口双面胶',
#   None,
#   '卷',
#   0,
#   1,
#   2100,
#   2100,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005335',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   'FL3260空白袋',
#   None,
#   'FL3260空白袋',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1500,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005336',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '销售部',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-05',
#   None,
#   'XR1680胶套冬',
#   None,
#   'XR16K80胶套冬371*257',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   200,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002020',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '河南省江河纸业有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '46g开源上白卷筒775',
#   None,
#   '46g开源上白卷筒775',
#   None,
#   '公斤',
#   0,
#   2994.6,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002020',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '河南省江河纸业有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '48g开源下白卷筒775',
#   None,
#   '48g开源下白卷筒775',
#   None,
#   '公斤',
#   0,
#   3489.36,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002020',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '河南省江河纸业有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '48g下兰卷筒883',
#   None,
#   '48g水木清华下兰卷筒883',
#   None,
#   '公斤',
#   0,
#   2538.81,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002020',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '河南省江河纸业有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '51g开源中白卷筒775',
#   None,
#   '51g开源中白卷筒775',
#   None,
#   '公斤',
#   0,
#   1885.34,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002020',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '河南省江河纸业有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '51g中红卷筒883',
#   None,
#   '51g水木清华中红卷筒883',
#   None,
#   '公斤',
#   0,
#   3242.4,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002021',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '欣程瑞纸业',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '100g铜版787*1230',
#   None,
#   '100g铜版787*1230',
#   None,
#   '令',
#   0,
#   8,
#   285.5625,
#   2284.5,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002021',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '欣程瑞纸业',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '100g铜版889*1194',
#   None,
#   '100g铜版889*1194',
#   None,
#   '令',
#   0,
#   40,
#   313.113,
#   12524.52,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002021',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '欣程瑞纸业',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '120g铜版787*1000',
#   None,
#   '120g铜版787*1000',
#   None,
#   '令',
#   0,
#   40,
#   273.876,
#   10955.04,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002021',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '欣程瑞纸业',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '150铜版787*1140',
#   None,
#   '150g铜版787*1140',
#   None,
#   '令',
#   0,
#   30,
#   390.2733,
#   11708.2,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005337',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '58g白云卷筒885下差',
#   None,
#   '58g白云卷筒885下差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   12054,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005337',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '52g兴泰885',
#   None,
#   '52g兴泰卷筒885',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   9355,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005337',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '68g兴泰卷筒900',
#   None,
#   '68g兴泰卷筒900',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   5247,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005337',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '54g兴泰卷筒900',
#   None,
#   '54g兴泰卷筒900',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   10233,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005337',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '60g白云卷筒885下差',
#   None,
#   '60g白云卷筒885下差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1630,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005338',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '54g兴泰卷筒885',
#   None,
#   '54g兴泰卷筒885',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   -2010,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005339',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '68g白云卷825上差',
#   None,
#   '68g白云卷筒825上差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   -410,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005340',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '65g白云本白专用390',
#   None,
#   '65g白云本白专用卷筒390',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1217,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005340',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '55g白云卷筒815',
#   None,
#   '55g白云卷筒815',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   4707,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005340',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '55g白云卷筒780',
#   None,
#   '55g白云卷筒780',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   2278,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005340',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '58g白云卷筒864下差',
#   None,
#   '58g白云卷筒864下差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   6863,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005340',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '60g白云卷筒880下差',
#   None,
#   '60g白云卷筒880下差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   2984,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005341',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '无线胶装',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '60g白云卷筒725',
#   None,
#   '60g白云卷筒725',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   2473,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005342',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '2.0MM四川联益灰板825',
#   None,
#   '2.0MM1150g四川联益灰板B级FH825*1205',
#   None,
#   '张',
#   0,
#   0,
#   0,
#   0,
#   0,
#   2600,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005343',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '120g铜版889*1194',
#   None,
#   '120g铜版889*1194',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   6.8,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005343',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '250g博汇白卡900*910',
#   None,
#   '250g博汇白卡900*910',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   18,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005343',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '250g白卡910*1194',
#   None,
#   '250g白卡910*1194',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1.2,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005343',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '190g博汇白卡750*940',
#   None,
#   '190g博汇白卡750*940',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   8.5,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005343',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '190g博汇白卡830*1194',
#   None,
#   '190g博汇白卡830*1194',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   26.4,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005343',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '205g进口牛卡660*1250',
#   None,
#   '205g进口牛卡660*1250',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   10.09,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005343',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '205g进口牛卡730*1100',
#   None,
#   '205g进口牛卡730*1100',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   12,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005344',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'DJL32-1内箱',
#   None,
#   'DJL32-1锐意内箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   10,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005344',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'DJL32-1外箱',
#   None,
#   'DJL32-1锐意外箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   30,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005345',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'SEB-22160外贸箱',
#   None,
#   'SEB-22160外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   488,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005345',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'HNB-50500PL外贸箱',
#   None,
#   'HNB-50500PL外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   426,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005345',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'SEB-14400外贸箱',
#   None,
#   'SEB-14400外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   75,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005345',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'EX-288外贸箱',
#   None,
#   'EX-288外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   500,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '材料出库单',
#   '0000005345',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'SEB-12200外贸箱',
#   None,
#   'SEB-12200外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   500,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002024',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '河南省江河纸业有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   None,
#   None,
#   None,
#   '46g开源上白787*1092',
#   None,
#   '46g开源上白787*1092',
#   None,
#   '令',
#   0,
#   44,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002024',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '河南省江河纸业有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   None,
#   None,
#   None,
#   '48g开源下白787*1092',
#   None,
#   '48g开源下白787*1092',
#   None,
#   '令',
#   0,
#   44,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-05',
#   '采购入库单',
#   '0000002024',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '河南省江河纸业有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   None,
#   None,
#   None,
#   '51g开源中白787*1092',
#   None,
#   '51g开源中白787*1092',
#   None,
#   '令',
#   0,
#   90,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '采购入库单',
#   '0000002022',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北美好纸制器有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'SEB-13300外贸箱',
#   None,
#   'SEB-13300外贸箱',
#   None,
#   '个',
#   0,
#   2934,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '采购入库单',
#   '0000002022',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北美好纸制器有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'SEB-14400外贸箱',
#   None,
#   'SEB-14400外贸箱',
#   None,
#   '个',
#   0,
#   1010,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '采购入库单',
#   '0000002023',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '武汉市安琪包装有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '16K空白袋',
#   None,
#   '16K空白袋',
#   None,
#   '个',
#   0,
#   30000,
#   0.0669,
#   2006.4,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '采购入库单',
#   '0000002023',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '武汉市安琪包装有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '18K空白袋',
#   None,
#   '18K空白袋',
#   None,
#   '个',
#   0,
#   20500,
#   0.044,
#   901.36,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '采购入库单',
#   '0000002023',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '武汉市安琪包装有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '6502空白袋',
#   None,
#   '6502空白袋',
#   None,
#   '个',
#   0,
#   8400,
#   0.0317,
#   266,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '采购入库单',
#   '0000002023',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '武汉市安琪包装有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '25K空白袋',
#   None,
#   '25K空白袋',
#   None,
#   '个',
#   0,
#   30100,
#   0.0316,
#   950,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '其他入库单',
#   '0000000096',
#   '调拨入库',
#   '0000000028',
#   '原材料库',
#   '委外入库',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   None,
#   None,
#   None,
#   'HCR5-192P封面',
#   None,
#   'HCR5-192P封面',
#   None,
#   '令',
#   3.74,
#   3.74,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '其他入库单',
#   '0000000096',
#   '调拨入库',
#   '0000000028',
#   '原材料库',
#   '委外入库',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   None,
#   None,
#   None,
#   'HCR5-288封面',
#   None,
#   'HCR5-288封面',
#   None,
#   '令',
#   2.83,
#   2.83,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '其他入库单',
#   '0000000096',
#   '调拨入库',
#   '0000000028',
#   '原材料库',
#   '委外入库',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   None,
#   None,
#   None,
#   'HCA4-192P封面',
#   None,
#   'HCA4-192P封面',
#   None,
#   '令',
#   2.54,
#   2.54,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '其他入库单',
#   '0000000096',
#   '调拨入库',
#   '0000000028',
#   '原材料库',
#   '委外入库',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   None,
#   None,
#   None,
#   'HCA4-288封面',
#   None,
#   'HCA4-288封面',
#   None,
#   '令',
#   1.85,
#   1.85,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '其他入库单',
#   '0000000096',
#   '调拨入库',
#   '0000000028',
#   '原材料库',
#   '委外入库',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   None,
#   None,
#   None,
#   'HCR5-200封面',
#   None,
#   'HCR5-200封面',
#   None,
#   '令',
#   6.18,
#   6.18,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '其他入库单',
#   '0000000096',
#   '调拨入库',
#   '0000000028',
#   '原材料库',
#   '委外入库',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   None,
#   None,
#   None,
#   'HCR5-300封面',
#   None,
#   'HCR5-300封面',
#   None,
#   '令',
#   4.82,
#   4.82,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '其他入库单',
#   '0000000096',
#   '调拨入库',
#   '0000000028',
#   '原材料库',
#   '委外入库',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   None,
#   None,
#   None,
#   'HCR5-96P封面',
#   None,
#   'HCR5-96P封面',
#   None,
#   '令',
#   1.85,
#   1.85,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '采购入库单',
#   '0000002025',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北佰晟包装',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'EX-200外贸箱',
#   None,
#   'EX-200外贸箱',
#   None,
#   '个',
#   0,
#   2000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005346',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '110g本白素描卷筒889',
#   None,
#   '110g本白素描卷筒889',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   -1050,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005346',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '52g兴泰885',
#   None,
#   '52g兴泰卷筒885',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   -1172,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005346',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '68g兴泰卷筒900',
#   None,
#   '68g兴泰卷筒900',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   -1262,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005346',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '58g兴泰卷筒825',
#   None,
#   '58g兴泰卷筒825',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   -490,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005346',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '58g白云卷筒864',
#   None,
#   '58g白云卷筒864',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   -4276,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005346',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '68g白云卷825上差',
#   None,
#   '68g白云卷筒825上差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   -1911,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005346',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '63g兴泰浅黄卷筒845',
#   None,
#   '63g兴泰浅黄卷筒845',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   -2176,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005349',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '3mmE1060H双面胶',
#   None,
#   '3mm进口双面胶',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005350',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'HCR5-192P封面',
#   None,
#   'HCR5-192P封面',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   3.74,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005350',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'HCR5-288封面',
#   None,
#   'HCR5-288封面',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   2.83,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005350',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'HCA4-192P封面',
#   None,
#   'HCA4-192P封面',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   2.54,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005350',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'HCA4-288封面',
#   None,
#   'HCA4-288封面',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1.85,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005350',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'HCR5-200封面',
#   None,
#   'HCR5-200封面',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   6.18,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005350',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'HCR5-300封面',
#   None,
#   'HCR5-300封面',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   4.82,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005350',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'HCR5-96P封面',
#   None,
#   'HCR5-96P封面',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1.85,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005351',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '52g兴泰885',
#   None,
#   '52g兴泰卷筒885',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   5897,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005351',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '54g兴泰卷筒900',
#   None,
#   '54g兴泰卷筒900',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   3607,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005351',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '68g兴泰卷筒900',
#   None,
#   '68g兴泰卷筒900',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   2450,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005351',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '58g白云卷筒885下差',
#   None,
#   '58g白云卷筒885下差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   5298,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005351',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '58g白云卷筒900下差',
#   None,
#   '58g白云卷筒900下差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   5007,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005351',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '68g白云卷筒900上差',
#   None,
#   '68g白云卷筒900上差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   4782,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005351',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '60g白云卷筒855',
#   None,
#   '60g白云卷筒855',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   2134,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005352',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '60g白云卷筒880下差',
#   None,
#   '60g白云卷筒880下差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   4973,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005352',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '55g白云卷筒815',
#   None,
#   '55g白云卷筒815',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   4765,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005352',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '65g白云卷筒780',
#   None,
#   '65g白云卷筒780',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   942,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005352',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '63g兴泰浅黄卷筒845',
#   None,
#   '63g兴泰浅黄卷筒845',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   3257,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005352',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '65g白云本白专用390',
#   None,
#   '65g白云本白专用卷筒390',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   783,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005353',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '书芯车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '60g白云卷筒905',
#   None,
#   '60g白云卷筒905',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   3095,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005354',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '1.8MM1050g联益825',
#   None,
#   '1.8MM1050g四川联益B级灰板FH825*1120',
#   None,
#   '张',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1735,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005355',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '200g国产牛卡787*1120',
#   None,
#   '200g国产牛卡787*1120',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   12,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005355',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '190g博汇白卡830*1194',
#   None,
#   '190g博汇白卡830*1194',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   52.8,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005355',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '190白卡889*1194',
#   None,
#   '190g白卡889*1194',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   10,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005355',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '250g白卡910*1194',
#   None,
#   '250g白卡910*1194',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0.2,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005356',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '192P外贸箱',
#   None,
#   '192P-BB外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   500,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005356',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'M13箱',
#   None,
#   'M13箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   101,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005356',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'SEB-12200外贸箱',
#   None,
#   'SEB-12200外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   448,
#   0,
#   0,
#   None),
#  ('2023-05-06',
#   '材料出库单',
#   '0000005356',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   'SEB-13300外贸箱',
#   None,
#   'SEB-13300外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1000,
#   0,
#   0,
#   None),
#  ('2023-04-26',
#   '其他出库单',
#   '0000000204',
#   '其他出库',
#   None,
#   '原材料库',
#   '其他出库',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-04-26',
#   None,
#   '110g本白素描卷筒889',
#   None,
#   '110g本白素描卷筒889',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   9.1,
#   0,
#   0,
#   None),
#  ('2023-04-26',
#   '采购入库单',
#   '0000002000',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '上海骑订合金制器有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-04-26',
#   None,
#   '铁丝24',
#   None,
#   '铁丝24',
#   None,
#   '卷',
#   0,
#   300,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-04-26',
#   '采购入库单',
#   '0000002001',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '昆山楚宏纸塑材料有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-04-26',
#   None,
#   '25MM80克604绿背条',
#   None,
#   '25MM80克604绿背条',
#   None,
#   '米',
#   0,
#   48000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-04-26',
#   '采购入库单',
#   '0000002001',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '昆山楚宏纸塑材料有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-04-26',
#   None,
#   '30MM牛皮801白背条',
#   None,
#   '30MM801白背条',
#   None,
#   '米',
#   0,
#   30000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-04-26',
#   '采购入库单',
#   '0000002001',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '昆山楚宏纸塑材料有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-04-26',
#   None,
#   '40MM牛皮801白背条',
#   None,
#   '40MM801白背条',
#   None,
#   '米',
#   0,
#   42000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-04-26',
#   '采购入库单',
#   '0000002002',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '武汉联益',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-04-26',
#   None,
#   '2.0MM四川联益灰板825',
#   None,
#   '2.0MM1150g四川联益灰板B级FH825*1205',
#   None,
#   '张',
#   0,
#   10970,
#   3.65,
#   40040.5,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-04-26',
#   '采购入库单',
#   '0000002003',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北佰晟包装',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-04-26',
#   None,
#   'M14箱',
#   None,
#   'M14箱',
#   None,
#   '个',
#   0,
#   551,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-04-26',
#   '采购入库单',
#   '0000002003',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北佰晟包装',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-04-26',
#   None,
#   'EX-288外贸箱',
#   None,
#   'EX-288外贸箱',
#   None,
#   '个',
#   0,
#   500,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-04-26',
#   '采购入库单',
#   '0000002003',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北佰晟包装',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-04-26',
#   None,
#   'SEB-A4-300外贸箱',
#   None,
#   'SEB-A4-300外贸箱',
#   None,
#   '个',
#   0,
#   1000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-04-26',
#   '采购入库单',
#   '0000002003',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北佰晟包装',
#   None,
#   None,
# ...
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '110g本白素描卷筒889',
#   None,
#   '110g本白素描卷筒889',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1050,
#   0,
#   0,
#   None),
#  ('2023-04-28',
#   '材料出库单',
#   '0000005347',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '52g兴泰885',
#   None,
#   '52g兴泰卷筒885',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1172,
#   0,
#   0,
#   None),
#  ('2023-04-28',
#   '材料出库单',
#   '0000005347',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '68g兴泰卷筒900',
#   None,
#   '68g兴泰卷筒900',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1262,
#   0,
#   0,
#   None),
#  ('2023-04-28',
#   '材料出库单',
#   '0000005347',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '58g兴泰卷筒825',
#   None,
#   '58g兴泰卷筒825',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   490,
#   0,
#   0,
#   None),
#  ('2023-04-28',
#   '材料出库单',
#   '0000005348',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '58g白云卷筒864',
#   None,
#   '58g白云卷筒864',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   4276,
#   0,
#   0,
#   None),
#  ('2023-04-28',
#   '材料出库单',
#   '0000005348',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '68g白云卷825上差',
#   None,
#   '68g白云卷筒825上差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1911,
#   0,
#   0,
#   None),
#  ('2023-04-28',
#   '材料出库单',
#   '0000005348',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-06',
#   None,
#   '63g兴泰浅黄卷筒845',
#   None,
#   '63g兴泰浅黄卷筒845',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   2176,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002015',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北佰晟包装',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '192P外贸箱',
#   None,
#   '192P-BB外贸箱',
#   None,
#   '个',
#   0,
#   800,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002015',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北佰晟包装',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   'EX-A4-300外贸箱',
#   None,
#   'EX-A4-300外贸箱',
#   None,
#   '个',
#   0,
#   400,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002015',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北佰晟包装',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   'EX-288外贸箱',
#   None,
#   'EX-288外贸箱',
#   None,
#   '个',
#   0,
#   897,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002015',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北佰晟包装',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   'SEB-12200外贸箱',
#   None,
#   'SEB-12200外贸箱',
#   None,
#   '个',
#   0,
#   448,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002015',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北佰晟包装',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   'SEB-200外贸箱',
#   None,
#   'SEB-200外贸箱',
#   None,
#   '个',
#   0,
#   56,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002015',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北佰晟包装',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   'SEB-300（225高）',
#   None,
#   'SEB-300（225高）外贸箱',
#   None,
#   '个',
#   0,
#   500,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002015',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '湖北佰晟包装',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   'SEB-22160外贸箱',
#   None,
#   'SEB-22160外贸箱',
#   None,
#   '个',
#   0,
#   1488,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002016',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '昆山楚宏纸塑材料有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '25MM80克005红背条',
#   None,
#   '25MM80克005红背条',
#   None,
#   '米',
#   0,
#   72000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002016',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '昆山楚宏纸塑材料有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '25MM80克501灰背条',
#   None,
#   '25MM80克501灰背条',
#   None,
#   '米',
#   0,
#   48000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002016',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '昆山楚宏纸塑材料有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '25MM80克022红背条',
#   None,
#   '25MM80克022紫背条',
#   None,
#   '米',
#   0,
#   24000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002016',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '昆山楚宏纸塑材料有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '25MM80克307兰背条',
#   None,
#   '25MM80克307兰背条',
#   None,
#   '米',
#   0,
#   24000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002016',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '昆山楚宏纸塑材料有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '25MM80克203桔黄背条',
#   None,
#   '25MM80克203桔黄背条',
#   None,
#   '米',
#   0,
#   24000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002016',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '昆山楚宏纸塑材料有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '25MM80克308兰背条',
#   None,
#   '25MM80克308兰背条',
#   None,
#   '米',
#   0,
#   24000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '采购入库单',
#   '0000002016',
#   '普通采购',
#   None,
#   '原材料库',
#   '采购入库',
#   None,
#   None,
#   '昆山楚宏纸塑材料有限公司',
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '25MM80克605绿背条',
#   None,
#   '25MM80克605绿背条',
#   None,
#   '米',
#   0,
#   24000,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005324',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '夹子车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '2.0MM四川联益灰板825',
#   None,
#   '2.0MM1150g四川联益灰板B级FH825*1205',
#   None,
#   '张',
#   0,
#   0,
#   0,
#   0,
#   0,
#   2080,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005325',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '190g博汇白卡830*1194',
#   None,
#   '190g博汇白卡830*1194',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   44,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005325',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '胶印车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '74g龙丰双胶787*1092',
#   None,
#   '74g龙丰双胶787*1092',
#   None,
#   '令',
#   0,
#   0,
#   0,
#   0,
#   0,
#   60,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005326',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '52g兴泰885',
#   None,
#   '52g兴泰卷筒885',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   6740,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005326',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '68g兴泰卷筒900',
#   None,
#   '68g兴泰卷筒900',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   6836,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005326',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '54g兴泰卷筒885',
#   None,
#   '54g兴泰卷筒885',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   9241,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005326',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '54g兴泰卷筒900',
#   None,
#   '54g兴泰卷筒900',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   8410,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005326',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '联动线车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '110g本白素描卷筒889',
#   None,
#   '110g本白素描卷筒889',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1084,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005327',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '55g白云卷筒815',
#   None,
#   '55g白云卷筒815',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   2744,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005327',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '68g白云卷825上差',
#   None,
#   '68g白云卷筒825上差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1827,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005327',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '65g白云本白专用390',
#   None,
#   '65g白云本白专用卷筒390',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   818,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005327',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '58g白云卷筒885下差',
#   None,
#   '58g白云卷筒885下差',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1860,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005328',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '书芯车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '60g白云卷筒905',
#   None,
#   '60g白云卷筒905',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   944,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005329',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   'SEB-12200外贸箱',
#   None,
#   'SEB-12200外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   500,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005329',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   'SEB-300（225高）',
#   None,
#   'SEB-300（225高）外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   500,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005329',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   'EXLB5100P箱',
#   None,
#   'EXLB5100P箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   33,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005329',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   'EFLA460NB箱',
#   None,
#   'EFLA460NB箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   33,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005329',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   'EX-288外贸箱',
#   None,
#   'EX-288外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   500,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005329',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   'SEB-200外贸箱',
#   None,
#   'SEB-200外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   56,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005329',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   'SEB-22160外贸箱',
#   None,
#   'SEB-22160外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   500,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005329',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '32P外贸箱',
#   None,
#   '32P-22*17外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   300,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005329',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '软抄车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '零散外贸箱',
#   None,
#   '零散外贸箱',
#   None,
#   '个',
#   0,
#   0,
#   0,
#   0,
#   0,
#   29,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005330',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '书芯车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '柔印DA021灰墨',
#   None,
#   '柔印DA021灰墨',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   20,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005330',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '书芯车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '30MM80克005红背条',
#   None,
#   '30MM80克005红背条',
#   None,
#   '米',
#   0,
#   0,
#   0,
#   0,
#   0,
#   1000,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005330',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '书芯车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '8065胶',
#   None,
#   '8065胶',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   80,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005331',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '柔版清洗剂',
#   None,
#   '柔版清洗剂',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   5,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005331',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '外贸1号紫高速',
#   None,
#   '外贸1号紫高速',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   100,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005331',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '缠绕卷膜',
#   None,
#   '缠绕卷膜',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   4,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005331',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '铁丝24',
#   None,
#   '铁丝24',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   10,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005331',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '内贸深蓝色',
#   None,
#   '内贸深蓝色',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   20,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005331',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '外贸6号金光红',
#   None,
#   '外贸6号金光红',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   20,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005331',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '外贸1号紫',
#   None,
#   '外贸1号紫',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   40,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005331',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '铁丝26',
#   None,
#   '铁丝26',
#   None,
#   '卷',
#   0,
#   0,
#   0,
#   0,
#   0,
#   20,
#   0,
#   0,
#   None),
#  ('2023-05-04',
#   '材料出库单',
#   '0000005331',
#   '领料',
#   None,
#   '原材料库',
#   '生产领料',
#   '柔版车间',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '葛翠萍',
#   '葛翠萍',
#   '2023-05-04',
#   None,
#   '外贸6号金光红',
#   None,
#   '外贸6号金光红',
#   None,
#   '公斤',
#   0,
#   0,
#   0,
#   0,
#   0,
#   20,
#   0,
#   0,
#   None),
#  ('合   计',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   23.81,
#   729821.13,
#   0,
#   112808.23,
#   23.81,
#   692721.21,
#   0,
#   0,
#   None)]

# %%
ws.delete_rows(2,ws.max_row)
wb.save(fname)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [46], in <cell line: 2>()
#       1 ws.delete_rows(2,ws.max_row)
# ----> 2 wb.save(fname)
#
# File D:\anaconda\lib\site-packages\openpyxl\workbook\workbook.py:407, in Workbook.save(self, filename)
#     405 if self.write_only and not self.worksheets:
#     406     self.create_sheet()
# --> 407 save_workbook(self, filename)
#
# File D:\anaconda\lib\site-packages\openpyxl\writer\excel.py:291, in save_workbook(workbook, filename)
#     279 def save_workbook(workbook, filename):
#     280     """Save the given workbook on the filesystem under the name filename.
#     281
#     282     :param workbook: the workbook to save
#    (...)
#     289
#     290     """
# --> 291     archive = ZipFile(filename, 'w', ZIP_DEFLATED, allowZip64=True)
#     292     writer = ExcelWriter(workbook, archive)
#     293     writer.save()
#
# File D:\anaconda\lib\zipfile.py:1250, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1248 while True:
#    1249     try:
# -> 1250         self.fp = io.open(file, filemode)
#    1251     except OSError:
#    1252         if filemode in modeDict:
#
# PermissionError: [Errno 13] Permission denied: 'D:\\ribaobiao\\流水账 - 副本.xlsx'

# %%
wb.save(fname)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 wb.save(fname)
#
# File D:\anaconda\lib\site-packages\openpyxl\workbook\workbook.py:407, in Workbook.save(self, filename)
#     405 if self.write_only and not self.worksheets:
#     406     self.create_sheet()
# --> 407 save_workbook(self, filename)
#
# File D:\anaconda\lib\site-packages\openpyxl\writer\excel.py:291, in save_workbook(workbook, filename)
#     279 def save_workbook(workbook, filename):
#     280     """Save the given workbook on the filesystem under the name filename.
#     281
#     282     :param workbook: the workbook to save
#    (...)
#     289
#     290     """
# --> 291     archive = ZipFile(filename, 'w', ZIP_DEFLATED, allowZip64=True)
#     292     writer = ExcelWriter(workbook, archive)
#     293     writer.save()
#
# File D:\anaconda\lib\zipfile.py:1250, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1248 while True:
#    1249     try:
# -> 1250         self.fp = io.open(file, filemode)
#    1251     except OSError:
#    1252         if filemode in modeDict:
#
# PermissionError: [Errno 13] Permission denied: 'D:\\ribaobiao\\流水账 - 副本.xlsx'

# %%
for i in range(len(datas),maxrow,-1):
    while i > 1:
        dele

# %%
#成功案例
wb = openpyxl.load_workbook(fname)
sheetname = 'UFPrn20230508080724'
ws = wb[sheetname]
data = pd.read_excel(fname,sheet_name = 'UFPrn20230508080724',dtype = {'单据号':str})
max_row = ws.max_row
ws.delete_rows(2,ws.max_row)
wb.save(fname)
wb = openpyxl.load_workbook(fname)
with pd.ExcelWriter(fname, engine='openpyxl')  as writer:
    writer.book = wb
    writer.sheets = dict((ws.title, ws) for ws in wb.worksheets)
    data.to_excel(writer, sheetname, header=None, index=False, startrow=1)
# Out:
# D:\anaconda\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
fname
# Out:
# 'D:\\ribaobiao\\流水账 - 副本.xlsx'

# %%
wb = openpyxl.load_workbook(fname)
sheetname = 'UFPrn20230508080724'
ws = wb[sheetname]
data = pd.read_excel(fname,sheet_name = 'UFPrn20230508080724',dtype = {'单据号':str})
max_row = ws.max_row
ws.delete_rows(2,ws.max_row)
wb.save(fname)

# %%
wb = openpyxl.load_workbook(fname)
with pd.ExcelWriter(fname, engine='openpyxl')  as writer:
    writer.book = wb
    writer.sheets = dict((ws.title, ws) for ws in wb.worksheets)
    data.to_excel(writer, sheetname, header=None, index=False, startrow=1)

# %%
df = pd.read_clipboard()
df
# Out:
#            日期   单据类型   单据号
# 0  2023-05-06  材料出库单  5356
# 1  2023-05-06  材料出库单  5356

# %%
df.insert(0,'单位0','双佳')
df
# Out:
#   单位0          日期   单据类型   单据号
# 0  双佳  2023-05-06  材料出库单  5356
# 1  双佳  2023-05-06  材料出库单  5356

# %%
import pandas as pd

# %%
fname = r'F:\a00nutstore\006\zw\else\2020入库.xlsx'
sheetname = '入库'
df = pd.read_excel(fname,sheetname,dtype ={'单号':str})
df.loc[:,'时间'] = pd.to_datetime(df['时间'],format = '%yy-%mm-%dd')
df
# Out:
#      单位0          供应商       期间         时间          单号               材料    入库  \
# 0     双佳       宁波金光纸业  2020-01 2021-01-22    90034886         202101折扣   0.0
# 1     双佳     昇伦纸业有限公司  2020-01 2019-12-28    90033327        70g林源道林卷筒   0.0
# 2     双佳     昇伦纸业有限公司  2020-01 2019-12-28    90033327        70g林源道林卷筒   0.0
# 3     双佳     昇伦纸业有限公司  2020-01 2020-01-02    00033361        70g林源道林卷筒   0.0
# 4     双佳     昇伦纸业有限公司  2020-01 2020-01-02    00033361        70g林源道林卷筒   0.0
# ...   ..          ...      ...        ...         ...              ...   ...
# 2534  双佳  河南省江河纸业有限公司  2023-05 2023-05-05  0000002020     51g开源中白卷筒775   0.0
# 2535  双佳  河南省江河纸业有限公司  2023-05 2023-05-05  0000002020   51g水木清华中红卷筒883   0.0
# 2536  双佳  河南省江河纸业有限公司  2023-05 2023-05-05  0000002024  46g开源上白787*1092  44.0
# 2537  双佳  河南省江河纸业有限公司  2023-05 2023-05-05  0000002024  48g开源下白787*1092  44.0
# 2538  双佳  河南省江河纸业有限公司  2023-05 2023-05-05  0000002024  51g开源中白787*1092  90.0
#
#                    jd  单位  批次  ...        金额     送货单金额      不含税价   多计  令价0  \
# 0            202101折扣   令 NaN  ... -16192.46 -16192.46 -14329.61  0.0  NaN
# 1              70g卷筒纸   吨 NaN  ...  92626.00  92626.00  81969.91  0.0  NaN
# 2              70g卷筒纸   吨 NaN  ...  92446.20  92446.20  81810.80  0.0  NaN
# 3              70g卷筒纸   吨 NaN  ...  88061.40  88061.40  77930.44  0.0  NaN
# 4              70g卷筒纸   吨 NaN  ...  96773.00  96773.00  85639.82  0.0  NaN
# ...               ...  ..  ..  ...       ...       ...       ...  ...  ...
# 2534          无碳复写卷筒纸  公斤 NaN  ...       NaN      0.00       NaN  NaN  0.0
# 2535          无碳复写卷筒纸  公斤 NaN  ...       NaN      0.00       NaN  NaN  0.0
# 2536  46g开源上白787*1092   令 NaN  ...       NaN      0.00       NaN  NaN  0.0
# 2537  48g开源下白787*1092   令 NaN  ...       NaN      0.00       NaN  NaN  0.0
# 2538  51g开源中白787*1092   令 NaN  ...       NaN      0.00       NaN  NaN  0.0
#
#                        记账   备注        pricename       送货日期     白云期间
# 0     2021-01-22 00:00:00  NaN           190g白卡 2021-01-21  2021-01
# 1     2020-01-10 00:00:00   林源           70g卷筒纸 2019-12-27  2019-12
# 2     2020-01-10 00:00:00   林源           70g卷筒纸 2019-12-27  2019-12
# 3     2020-01-10 00:00:00   林源           70g卷筒纸 2020-01-01  2020-01
# 4     2020-01-10 00:00:00   林源           70g卷筒纸 2020-01-01  2020-01
# ...                   ...  ...              ...        ...      ...
# 2534                  NaN  NaN        51g开源中白卷筒 2023-05-04  2023-05
# 2535                  NaN  NaN      51g水木清华中红卷筒 2023-05-04  2023-05
# 2536                  NaN  NaN  46g开源上白787*1092 2023-05-04  2023-05
# 2537                  NaN  NaN  48g开源下白787*1092 2023-05-04  2023-05
# 2538                  NaN  NaN  51g开源中白787*1092 2023-05-04  2023-05
#
# [2539 rows x 26 columns]

# %%
pd.to_datetime(df[['时间','记账']],format = '%yy-%mm-%dd')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 pd.to_datetime(df[['时间','记账']],format = '%yyyy-%mm-%dd')
#
# File D:\anaconda\lib\site-packages\pandas\core\tools\datetimes.py:1054, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1052         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1054     result = _assemble_from_unit_mappings(arg, errors, tz)
#    1055 elif isinstance(arg, Index):
#    1056     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File D:\anaconda\lib\site-packages\pandas\core\tools\datetimes.py:1160, in _assemble_from_unit_mappings(arg, errors, tz)
#    1158 if len(req):
#    1159     _required = ",".join(req)
# -> 1160     raise ValueError(
#    1161         "to assemble mappings requires at least that "
#    1162         f"[year, month, day] be specified: [{_required}] is missing"
#    1163     )
#    1165 # keys we don't recognize
#    1166 excess = sorted(set(unit_rev.keys()) - set(_unit_map.values()))
#
# ValueError: to assemble mappings requires at least that [year, month, day] be specified: [day,month,year] is missing

# %%
import openpyxl 
wb = openpyxl.load_workbook(fname)
ws = wb[sheetname]
max_row = ws.max_row
for i in range(2,max_row+1):
    ws[f'D{i}'].number_format = 'yyyy-mm-dd'
    ws[f'V{i}'].number_format = 'yyyy-mm-dd'
    ws[f'Y{i}'].number_format = 'yyyy-mm-dd'
   
wb.save(fname)

# %%
def startriqiEndriqi(today):
    yesterday = today + timedelta(days=-1)  # 昨天日期
    year = yesterday.year
    month = yesterday.month
    day = yesterday.day
    if day <= 25 and month == 1:
        last_year = year - 1
        last_month = 12
        last_day = 26
    elif day <= 25 and month != 1:
        last_year = year
        last_month = month - 1
        last_day = 26
    else:
        last_year = year
        last_month = month
        last_day = 26
    start_riqi = str(last_year) + '-' + str(last_month) + '-' + str(last_day)
    end_riqi = str(year) + '-' + str(month) + '-' + str(day)
    start_riqi = pd.Timestamp(start_riqi)
    end_riqi = pd.Timestamp(end_riqi)
    return start_riqi, end_riqi

# %%
from easygui import buttonbox
from datetime import datetime, date, timedelta
msg = '请选择日期输入的方式：'

choice = buttonbox(msg, choices=['自动', '手动','singleZhi','singleBaiyun'])
if choice == '自动':
    today = date.today()
    start_riqi, end_riqi = startriqiEndriqi(today)
#     try :
#         tobaiyun(start_riqi, end_riqi, piaojuhao)
#     except:
#         easygui.msgbox('本月没有白云入库')
#     try :
#         tozhi(start_riqi, end_riqi, piaojuhao)
#     except:
#         easygui.msgbox('本月没有纸入库')

elif choice == '手动':
    today = pd.Timestamp(easygui.enterbox('请输入要查询期间的后一天"2021-12-27"\n'))
    start_riqi, end_riqi = startriqiEndriqi(today)
    try :
        tobaiyun(start_riqi, end_riqi, piaojuhao)
    except:
        easygui.msgbox('本月没有白云入库')
    try :
        tozhi(start_riqi, end_riqi, piaojuhao)
    except:
        easygui.msgbox('本月没有纸入库')
elif choice == 'singleZhi':
    try :
        addzhiRukuPd.main()
    except:
        easygui.msgbox('本月没有纸入库')
else :
    try:
        addbaiyunRukuPd.main()
    except:
        easygui.msgbox('本月没有白云入库')

# %%
start_riqi
# Out:
# Timestamp('2023-04-26 00:00:00')

# %%
end_riqi
# Out:
# Timestamp('2023-05-10 00:00:00')

# %%
import easygui
today = pd.Timestamp(easygui.enterbox('请输入要查询期间的后一天"2021-12-27"\n'))
start_riqi, end_riqi = startriqiEndriqi(today)

# %%
start_riqi
# Out:
# Timestamp('2023-04-26 00:00:00')

# %%
end_riqi
# Out:
# Timestamp('2023-05-10 00:00:00')

# %%
df = pd.read_clipboard()
df
# Out:
#   单位0       供应商       期间
# 0  双佳    宁波金光纸业  2020-01
# 1  双佳  昇伦纸业有限公司  2020-01
# 2  双佳  昇伦纸业有限公司  2020-01
# 3  双佳  昇伦纸业有限公司  2020-01
# 4  双佳  昇伦纸业有限公司  2020-01
# 5  双佳  昇伦纸业有限公司  2020-01
# 6  双佳  昇伦纸业有限公司  2020-01
# 7  双佳  昇伦纸业有限公司  2020-01

# %%
df.shape[0]
# Out:
# 8

# %%
max_row = df.shape[0] + 1
max_row
# Out:
# 9

# %%
max_row
# Out:
# 9

# %%
df.to_excel('111.xlsx',index= False)

# %%
wb = openpyxl.load_workbook('111 - 副本.xlsx')
ws = wb.active
ws[f'A{max_row+1}'].value = 'HAHA'
wb.save('111 - 副本.xlsx')

# %%
wb = openpyxl.load_workbook('111 - 副本.xlsx')
ws = wb.active
ws.delete_rows(2, max_row)
# ws[f'A{max_row+1}'].value = 'HAHA'
wb.save('111 - 副本.xlsx')

# %%
df
# Out:
#   单位0       供应商       期间
# 0  双佳    宁波金光纸业  2020-01
# 1  双佳  昇伦纸业有限公司  2020-01
# 2  双佳  昇伦纸业有限公司  2020-01
# 3  双佳  昇伦纸业有限公司  2020-01
# 4  双佳  昇伦纸业有限公司  2020-01
# 5  双佳  昇伦纸业有限公司  2020-01
# 6  双佳  昇伦纸业有限公司  2020-01
# 7  双佳  昇伦纸业有限公司  2020-01

# %%
# wb = openpyxl.load_workbook('111 - 副本.xlsx')
# ws = wb.active
# ws.delete_rows(2, max_row)
# wb.save('111 - 副本.xlsx')
with pd.ExcelWriter('111 - 副本.xlsx', engine='openpyxl', mode='a', if_sheet_exists='overlay') as writer:
    df.to_excel(writer,'Sheet1',  header=None, index=False, startrow = max_row + 1)
# ws[f'A{max_row+1}'].value = 'HAHA'
# wb.save('111 - 副本.xlsx')
