# %%
import pandas 
import re

# %%
string = '5本A5混色（每本48张）'

def addBen(string):
    # string = r'(81本)'
    pattern1 = r'(?P<ben>\d+)本'
    pattern2 = r'(?P<ben>[十九八七六五四三二一])本'
    regexp1 = re.compile(pattern1)
    mat1 = regexp1.search(string)
    regexp2 = re.compile(pattern2)
    mat2 = regexp2.search(string)
    if mat1:
        ben = int(mat1.group('ben'))
    else:
        if mat2:
            ben = dic.get(mat2.group('ben'))
        else:
            ben = 1
    return ben

# %%
ben = addBen(string)
ben
# Out:
# 5

# %%
'''
电商出库将规格型号中的本数提取出来,较多正则处理
'''
import re
import os
import pandas as pd
import openpyxl
import easygui
from openpyxl.styles import Font, Border, Side, Fill, Alignment

fname = easygui.fileopenbox('请点选电商当日出库文件')
# fname = r"F:\a00nutstore\008\zw08\电商\财务部7.18订单.xlsx"
qian, hou = os.path.splitext(fname)
newfname = qian + "-本数" + hou
sheet_name = 0
skiprows = 0
df = pd.read_excel(fname, sheet_name=sheet_name, skiprows=skiprows, dtype={'商品ID': 'str', '运单号': 'str', })
df.dropna(subset=['订单号'], inplace=True)
df['总价'] = df['总价'].str.replace('￥', '')
df['实收'] = df['实收'].str.replace('￥', '')
df = df.astype({'实收': 'float64'})
df = df.astype({'总价': 'float64'})

# df['实收'] = df['实收'] .astype(int)
df1 = df.copy()
lst = ['订单号',
       '发货时间',
       '规格名称',
       '规格编码',
       '数量',
       ]
dic = {'五': 5,
       '六': 6,
       '七': 7,
       '八': 8,
       '九': 9,
       '十': 10,
       '四': 4,
       '三': 3,
       '二': 2,
       '一': 1}


def addBen(string):
    # string = r'(81本)'
    print(stirng)
    pattern1 = r'(?P<ben>\d+)本'
    pattern2 = r'(?P<ben>[十九八七六五四三二一])本'
    regexp1 = re.compile(pattern1)
    
    mat1 = regexp1.search(string)
    regexp2 = re.compile(pattern2)
    mat2 = regexp2.search(string)
    if mat1:
        ben = int(mat1.group('ben'))
    else:
        if mat2:
            ben = dic.get(mat2.group('ben'))
        else:
            ben = 1
    return ben


df1 = df1[lst]
df1['含量'] = df1['规格名称'].map(addBen)
df1 = df1.assign(本数=df1['数量'] * df1['含量'])
df1 = df1.sort_values(by=['规格编码'])
df1.index = range(1, len(df1) + 1)
df1.index_name = '序号'
df1.insert(0, '序号', range(1, len(df1) + 1))
max_xuhao = len(df1) + 1
df1.loc[max_xuhao] = {'序号': max_xuhao, '数量': df1['数量'].sum(), '本数': df1['本数'].sum()}
df1['序号'] = df1['序号'].replace(max_xuhao, '小计')
df1 = df1[['序号',
       '订单号',
       '发货时间',
       '规格名称',
       '规格编码',
           '本数',
        '含量',
       '数量',
       ]]
df1.columns = ['序号',
       '订单号',
       '发货时间',
       '规格名称',
       '规格编码',
           '本数',
        '含量',
       '包数',
       ]

gp = df1.groupby('规格编码')
bao = gp['包数'].sum()
ben = gp['本数'].sum()
beihuo = pd.concat([bao, ben], axis=1)
beihuo.columns = ['包数', '本数']
beihuo.loc['小计'] = [beihuo['包数'].sum(), beihuo['本数'].sum()]
beihuo = beihuo.reset_index()

with pd.ExcelWriter(fname, engine='openpyxl', mode='a', if_sheet_exists='overlay') as writer:
    df.to_excel(writer, sheet_name='加工', index=False)
    beihuo.to_excel(writer, sheet_name='备货', index=False)
    df1.to_excel(writer, sheet_name='本数', index=False)

wb = openpyxl.load_workbook(fname)


def sheetSetting(sheetname):
    ws = wb[sheetname]
    max_row = ws.max_row
    max_column = ws.max_column

    ws.column_dimensions['B'].width = 24
    ws.column_dimensions['C'].width = 20
    ws.column_dimensions['D'].width = 22
    ws.column_dimensions['E'].width = 12
    ws.column_dimensions['F'].width = 4.5
    ws.column_dimensions['G'].width = 6.13
    ws.freeze_panes = ws['B2']
    ws.print_title_rows = '1:1'  # the first row
    # 页脚设置
    ws.oddFooter.center.text = " &[Page] / &N"  # 1/n
    ws.oddFooter.center.size = 12  # 页脚中字体大小
    ws.oddFooter.center.font = "Tahoma"  # 页脚中字体
    ws.oddFooter.center.color = "000000"  # 页脚中字体颜色
    ws.oddFooter.right.text = "张文伟 &[Date]"  # 页脚右 文字
    ws.oddFooter.right.size = 12  # 页脚右 字体大小
    ws.oddFooter.right.font = "书体坊米芾体"  # 页脚右 字体
    ws.oddFooter.right.color = "000000"  # 页脚右 字体颜色
    if sheetname == '备货':
        ws.column_dimensions['A'].width = 20
        ws.page_margins = openpyxl.worksheet.page.PageMargins(top=0.48, header=0.5, left=2, right=0.24,
                                                              footer=0.5,
                                                              bottom=1)

    else:
        ws.column_dimensions['A'].width = 4
        ws.page_margins = openpyxl.worksheet.page.PageMargins(top=0.48, header=0.5, left=0.21, right=0.24,
                                                              footer=0.5,
                                                              bottom=1)

    thin_danbian = Side(border_style='thin')
    thin_bian = Border(
        left=thin_danbian,
        right=thin_danbian,
        top=thin_danbian,
        bottom=thin_danbian)
    for row in range(2, max_row + 1):  # 从第二行开始，设置单元格格式
        for col in range(1, max_column + 1):
            ws.cell(row, col).border = thin_bian
    return ws


for sheetname in ['备货', '本数']:
    ws = sheetSetting(sheetname)

wb.active = ws
wb.save(fname)
# os.rename(fname,newfname)
os.startfile(fname)
# Out:
# C:\Users\redda\.conda\envs\py311\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 65
#      61     return ben
#      64 df1 = df1[lst]
# ---> 65 df1['含量'] = df1['规格名称'].map(addBen)
#      66 df1 = df1.assign(本数=df1['数量'] * df1['含量'])
#      67 df1 = df1.sort_values(by=['规格编码'])
#
# File ~\.conda\envs\py311\Lib\site-packages\pandas\core\series.py:4700, in Series.map(self, arg, na_action)
#    4620 def map(
#    4621     self,
#    4622     arg: Callable | Mapping | Series,
#    4623     na_action: Literal["ignore"] | None = None,
#    4624 ) -> Series:
#    4625     """
#    4626     Map values of Series according to an input mapping or function.
#    4627
#    (...)
#    4698     dtype: object
#    4699     """
# -> 4700     new_values = self._map_values(arg, na_action=na_action)
#    4701     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4702         self, method="map"
#    4703     )
#
# File ~\.conda\envs\py311\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\.conda\envs\py311\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[10], line 46, in addBen(string)
#      44 def addBen(string):
#      45     # string = r'(81本)'
# ---> 46     print(stirng)
#      47     pattern1 = r'(?P<ben>\d+)本'
#      48     pattern2 = r'(?P<ben>[十九八七六五四三二一])本'
#
# NameError: name 'stirng' is not defined

# %%
fname = r"C:\Users\redda\Desktop\8月全数据.xlsx"
df = pd.read_excel(fname)
lst = df['规格名称'].to_list()
lst
# Out:
# C:\Users\redda\.conda\envs\py311\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ['10本（作文+英语各5本）',
#  'B5甜系4本',
#  '5本A5混色（每本48张）',
#  '20本（语文+数学+英语+练习各5本）',
#  '练习本10本',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本练习本',
#  '20本（语文+数学+英语+练习各5本）',
#  '1本,英语',
#  '1本,英语',
#  '1本,作文（300格）',
#  '1本,数学（双竖线）',
#  '5本语文本（方格）',
#  '5本A4混色（每本58张）',
#  '5本A5混色（每本28张）',
#  '英语本（10本竖版）',
#  '1本,数学（双竖线）',
#  '1本,语文（方格）',
#  '1本,作文（300格）',
#  '10本练习本',
#  'B5五本（每本100张）',
#  '5本A5混色（每本68张）',
#  '5本A5混色（每本48张）',
#  '10本英语本',
#  '5本语文本（方格）',
#  '16K汉语拼音本(10本)',
#  '1本,英语',
#  '10本（400张）',
#  'A5五本（每本60张）',
#  '5本,50页每本',
#  '5本加厚大号,练习本',
#  '5本A5混色（每本48张）',
#  '10本,英语',
#  '5本A5混色（每本88张）',
#  '5本作文本（300格）',
#  '10本练习本',
#  '英语本5本装',
#  '5本A5混色（每本48张）',
#  '1本,语文（方格）',
#  '1本,英语',
#  '1本,数学（双竖线）',
#  '1本,英语',
#  '5本,50页每本',
#  '5本A5混色（每本28张）',
#  '5本B5混色（每本78张）',
#  'B5五本（每本80张）',
#  '1本,英语',
#  '10本,英语',
#  '5本A5混色（每本68张）',
#  '10本装',
#  '1本,练习',
#  '20本（语文+数学+英语+练习各5本）',
#  '15本（语文+数学+英语各5本）',
#  '10本（400张）',
#  '10本练习本',
#  '5本装',
#  '5本B5混色（每本98张）',
#  '5本,50页每本',
#  '1本,英语',
#  '1本,30页每本',
#  '1本,数学（双竖线）',
#  '1本,英语',
#  '10本语文本（方格）',
#  '5本A5混色（每本28张）',
#  '5本A5混色（每本38张）',
#  '5本练习本',
#  '5本,练习',
#  '1本,英语',
#  '1本,数学（双竖线）',
#  '1本,练习',
#  '5本（200张）',
#  '10本加厚大号,数学本（双竖线）',
#  '10本加厚大号,汉语拼音本',
#  '10本加厚大号,语文本（方格）',
#  '16K汉语拼音本(5本)',
#  '16K作文本(5本)',
#  '5本B5混色（每本78张）',
#  '1本,练习',
#  '1本,作文（300格）',
#  '5本装',
#  '1本,英语',
#  'B5五本（每本80张）',
#  'A5五本（每本60张）',
#  'B5,横线3本',
#  '1本,英语',
#  'B5五本（每本60张）',
#  '5本B5混色（每本78张）',
#  '10本,英语',
#  '10本,练习',
#  '10本,语文（方格）',
#  '1本,练习',
#  '4K（160g）,5本',
#  '1本,英语',
#  '5本加厚大号,语文本（横线）',
#  '练习本5本装',
#  '1本装',
#  '10本加厚大号,英语本',
#  'B5五本（每本100张）',
#  '5本加厚大号,数学本（单线）',
#  '5本加厚大号,语文本（方格）',
#  '20本加厚大号,汉语拼音本',
#  '1本,作文（300格）',
#  '5本英语本',
#  '5本装',
#  '5本装',
#  '5本A5混色（每本38张）',
#  '5本装',
#  '5本装',
#  'B5五本（每本40张）',
#  'B5五本（每本60张）',
#  '1本A5颜色随机(28张)',
#  '1本,英语',
#  '1本,数学（双竖线）',
#  '1本,语文（方格）',
#  '10本（400张）',
#  '5本练习本',
#  'A5五本（每本80张）',
#  'B5五本（每本60张）',
#  'B5五本（每本40张）',
#  '10本,英语',
#  '5本,练习',
#  '10本,练习',
#  'B5五本（每本100张）',
#  '16K练习本(10本)',
#  'B5五本（每本100张）',
#  'B5三本（每本40张）',
#  '20本（语文+数学+英语+作文各5本）',
#  '15本（语文+数学+英语各5本）',
#  '10本（数学+英语各5本）',
#  'B5五本（每本80张）',
#  '5本作文本（300格）',
#  '5本,英语',
#  '1本,英语',
#  'B5五本（每本40张）',
#  '5本加厚大号,作文本（300格）',
#  '5本加厚大号,语文本（横线）',
#  '10本练习本',
#  '5本加厚大号,语文本（方格）',
#  '5本,练习',
#  '1本,作文（300格）',
#  '1本,英语',
#  'B5五本（每本100张）',
#  '10本练习本',
#  'B5五本（每本40张）',
#  '20本,作文（300格）',
#  '10本,作文（300格）',
#  'B5五本（每本60张）',
#  '10本,英语',
#  '5本,数学（双竖线）',
#  '5本,作文（300格）',
#  'A5五本（每本60张）',
#  '5本作文本（300格）',
#  '5本A5混色（每本48张）',
#  '5本作文本（300格）',
#  'B5五本（每本40张）',
#  'B5五本（每本80张）',
#  '5本A5混色（每本28张）',
#  '5本练习本',
#  '5本作文本（300格）',
#  '10本英语本',
#  '10本练习本',
#  '5本A5混色（每本88张）',
#  '5本A5混色（每本68张）',
#  '5本A5混色（每本28张）',
#  '英语本5本装',
#  'B5五本（每本60张）',
#  'B5五本（每本40张）',
#  '5本A5混色（每本28张）',
#  'A5五本（每本60张）',
#  '5本加厚大号,练习本',
#  'B5五本（每本40张）',
#  '10本,英语',
#  'B5五本（每本40张）',
#  '20本,英语',
#  '5本数学本（双竖线）',
#  '10本（作文+英语各5本）',
#  '5本,数学（双竖线）',
#  '20本（语文+数学+英语+练习各5本）',
#  '10本,语文（方格）',
#  'A5五本（每本60张）',
#  '10本语文本（方格）',
#  'B5五本（每本40张）',
#  'B5五本（每本40张）',
#  '10本练习本',
#  '1本,英语',
#  'B5五本（每本60张）',
#  '20本（语文+数学+英语+练习各5本）',
#  'B5五本（每本80张）',
#  '5本A5混色（每本38张）',
#  '1本装',
#  '10本练习本',
#  '5本作文本（300格）',
#  '1本,语文（方格）',
#  '10本练习本',
#  '10本语文本（方格）',
#  '10本加厚大号,语文本（横线）',
#  '10本（作文+英语各5本）',
#  '1本装',
#  '5本练习本',
#  'B5五本（每本60张）',
#  'B5五本（每本60张）',
#  'B5五本（每本80张）',
#  'B5五本（每本80张）',
#  '20本（语文+数学+英语+作文各5本）',
#  '10本练习本',
#  '5本,数学（双竖线）',
#  '10本练习本',
#  '10本,英语',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本,50页每本',
#  '1本,练习',
#  '5本,语文（方格）',
#  'B5五本（每本80张）',
#  '20本（语文+数学+英语+作文各5本）',
#  '20本,练习',
#  '10本（练习+英语各5本）',
#  '5本B5混色（每本98张）',
#  '1本,作文（300格）',
#  '5本练习本',
#  '5本语文本（方格）',
#  '10本（练习+英语各5本）',
#  'A5五本（每本60张）',
#  '10本,练习',
#  'B5五本（每本40张）',
#  '10本（作文+英语各5本）',
#  '10本练习本',
#  '1本,英语',
#  '1本,语文（方格）',
#  '1本,练习',
#  '1本,作文（300格）',
#  '1本,英语',
#  '5本,英语',
#  '5本,数学（双竖线）',
#  '10本,作文（300格）',
#  '10本,英语',
#  'B5三本（每本40张）',
#  '5本（150张）,分区胶装款',
#  'B5五本（每本40张）',
#  '5本A4混色（每本78张）',
#  '1本装',
#  'B5五本（每本80张）',
#  '5本B5混色（每本78张）',
#  '5本A5混色（每本38张）',
#  '1本,英语',
#  '5本装',
#  '5本,作文（300格）',
#  '10本练习本',
#  '10本练习本',
#  '1本,作文（300格）',
#  '1本,语文（方格）',
#  '10本,英语',
#  '5本A5混色（每本68张）',
#  '5本A5混色（每本88张）',
#  'B5,横线5本',
#  'B5五本（每本40张）',
#  '1本,英语',
#  '10本英语本',
#  '10本作文本（300格）',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本,作文（300格）',
#  '5本装',
#  '5本B5混色（每本78张）',
#  '1本,语文（方格）',
#  '1本,练习',
#  '1本,英语',
#  '1本,作文（300格）',
#  '1本装',
#  '10本练习本',
#  '5本英语本',
#  '10本,数学（双竖线）',
#  '5本A5混色（每本88张）',
#  '20本（语文+数学+英语+练习各5本）',
#  'B5五本（每本80张）',
#  '10本,数学（双竖线）',
#  'B5五本（每本60张）',
#  '10本练习本',
#  '1本装',
#  '1本,作文（300格）',
#  '5本A5混色（每本88张）',
#  '英语本5本装',
#  '1本装',
#  '1本,练习',
#  'B5五本（每本40张）',
#  '1本,作文（300格）',
#  '1本,语文（方格）',
#  '1本,练习',
#  '5本B5混色（每本98张）',
#  '5本A4混色（每本58张）',
#  '1本A5颜色随机(28张)',
#  '5本语文本（方格）',
#  '5本练习本',
#  '5本加厚大号,数学本（单线）',
#  '5本加厚大号,英语本',
#  '5本加厚大号,作文本（300格）',
#  '5本加厚大号,汉语拼音本',
#  '1本,作文（300格）',
#  '5本练习本',
#  '20本,练习',
#  '1本,作文（300格）',
#  '1本,语文（方格）',
#  '1本,英语',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本A5混色（每本38张）',
#  '10本数学本',
#  'A5五本（每本80张）',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本,50页每本',
#  '10本练习本',
#  '10本英语本',
#  '10本,作文（300格）',
#  '1本,英语',
#  '5本语文本（方格）',
#  '5本A4混色（每本58张）',
#  '10本（作文+英语各5本）',
#  '英语本10本',
#  '10本语文本（方格）',
#  '1本,数学（双竖线）',
#  '1本,英语',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本A5混色（每本68张）',
#  '5本B5混色（每本78张）',
#  '语文本10本',
#  '练习本10本',
#  'B5五本（每本60张）',
#  'B5五本（每本100张）',
#  '10本练习本',
#  '10本,语文（方格）',
#  '10本作文本（300格）',
#  '20本加厚大号,练习本',
#  '10本加厚大号,练习本',
#  '10本数学本（双竖线）',
#  '10本（400张）',
#  '10本（练习+英语各5本）',
#  '5本,练习',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本A5混色（每本38张）',
#  '5本A5混色（每本38张）',
#  'A5五本（每本60张）',
#  '10本,英语',
#  '5本A5混色（每本38张）',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本数学本（双竖线）',
#  '5本装',
#  '1本,英语',
#  '1本,英语',
#  '1本,数学（双竖线）',
#  '1本,语文（方格）',
#  '5本,练习',
#  '5本B5混色（每本98张）',
#  'A5五本（每本100张）',
#  '5本数学本（双竖线）',
#  '5本,50页每本',
#  '10本,作文（300格）',
#  '5本,作文（300格）',
#  'B5五本（每本100张）',
#  '20本,练习',
#  '5本,50页每本',
#  '5本数学本（双竖线）',
#  'A5五本（每本60张）',
#  '10本练习本',
#  '15本（语文+数学+练习各5本）',
#  '5本装',
#  '英语本5本装',
#  '20本（语文+数学+英语+作文各5本）',
#  '20本,英语',
#  '1本,作文（300格）',
#  '20本（语文+数学+英语+作文各5本）',
#  '数学本5本装',
#  '16K数学双线本(5本)',
#  '10本,英语',
#  '5本装',
#  '10本（练习+英语各5本）',
#  '5本加厚大号,练习本',
#  '5本B5混色（每本48张）',
#  'B5五本（每本40张）',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本A5混色（每本28张）',
#  '10本练习本',
#  '5本A5混色（每本88张）',
#  '10本（练习+英语各5本）',
#  '1本,英语',
#  '5本加厚大号,练习本',
#  '5本A5混色（每本88张）',
#  '20本（语文+数学+英语+作文各5本）',
#  '10本练习本',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本A5混色（每本28张）',
#  '5本作文本（300格）',
#  '5本练习本',
#  '10本英语本',
#  '20本（语文+数学+英语+作文各5本）',
#  '10本数学本（双竖线）',
#  '1本,英语',
#  '10本练习本',
#  '20本（语文+数学+英语+作文各5本）',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本A5混色（每本28张）',
#  '1本,数学（双竖线）',
#  '10本,数学（双竖线）',
#  '10本,英语',
#  '5本,50页每本',
#  '5本语文本（方格）',
#  '1本,作文（300格）',
#  '5本加厚大号,作文本（300格）',
#  '5本A5混色（每本48张）',
#  '10本数学本（双竖线）',
#  '10本语文本（方格）',
#  '10本,作文（300格）',
#  '5本语文本（方格）',
#  '5本（150张）,分区胶装款',
#  '5本英语本',
#  '10本,练习',
#  '5本A5混色（每本68张）',
#  nan,
#  'B5三本（每本40张）',
#  '5本语文本（方格）',
#  '1本,数学（双竖线）',
#  '1本,语文（方格）',
#  '5本语文本（方格）',
#  '5本,50页每本',
#  '1本,英语',
#  '10本（语文+英语各5本）',
#  '10本数学本（双竖线）',
#  '5本,英语',
#  '1本,练习',
#  '20本加厚大号,练习本',
#  '1本,作文（300格）',
#  '5本,50页每本',
#  'B5五本（每本60张）',
#  '5本A5混色（每本48张）',
#  '10本加厚大号,数学本（单线）',
#  '5本英语本',
#  '5本加厚大号,数学本（单线）',
#  '10本加厚大号,语文本（横线）',
#  '20本（语文+数学+英语+作文各5本）',
#  'A5五本（每本80张）',
#  '20本加厚大号,20本（自选科目）联系客服',
#  '5本加厚大号,数学本（单线）',
#  '5本A4混色（每本38张）',
#  'B5五本（每本80张）',
#  '5本A5混色（每本28张）',
#  'A5五本（每本100张）',
#  '5本,语文（方格）',
#  '5本,数学（双竖线）',
#  '1本,作文（300格）',
#  '5本,英语',
#  '5本,练习',
#  '5本A5混色（每本68张）',
#  'B5五本（每本40张）',
#  '5本A5混色（每本68张）',
#  '20本（语文+数学+英语+作文各5本）',
#  '10本,作文（300格）',
#  '10本,练习',
#  '10本,英语',
#  '10本（语文+英语各5本）',
#  '5本A5混色（每本28张）',
#  '5本语文本（方格）',
#  '5本B5混色（每本28张）',
#  '15本（语文+数学+练习各5本）',
#  '5本语文本（方格）',
#  '1本装',
#  '10本（作文+英语各5本）',
#  '5本英语本',
#  '5本作文本（300格）',
#  '15本（语文+数学+英语各5本）',
#  '10本练习本',
#  '10本作文本（300格）',
#  '差路费报销单5本',
#  '15本（语文+数学+英语各5本）',
#  '5本A5混色（每本38张）',
#  '5本A5混色（每本28张）',
#  'B5五本（每本100张）',
#  'B5,空白3本',
#  'B5五本（每本40张）',
#  '5本A5混色（每本68张）',
#  '10本语文本（方格）',
#  '5本A5混色（每本68张）',
#  '5本练习本',
#  '20本（语文+数学+英语+作文各5本）',
#  '16K汉语拼音本(5本)',
#  '16K数学双线本(10本)',
#  '16K练习本(10本)',
#  '16K英语本(10本)',
#  'B5五本（每本80张）',
#  '5本A5混色（每本48张）',
#  '1本,语文（方格）',
#  '20本（语文+数学+英语+练习各5本）',
#  '10本英语本',
#  'B5五本（每本40张）',
#  '10本英语本',
#  '5本作文本（300格）',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本作文本（300格）',
#  '5本练习本',
#  '32K作文本(5本)',
#  '32K练习本(10本)',
#  '10本加厚大号,10本（自选科目）练习客服',
#  '5本语文本（方格）',
#  '10本练习本',
#  'B5五本（每本40张）',
#  '15本（语文+数学+练习各5本）',
#  '10本英语本',
#  '10本练习本',
#  '5本B5混色（每本98张）',
#  '20本（语文+数学+英语+练习各5本）',
#  'B5五本（每本60张）',
#  '10本加厚大号,练习本',
#  'B5,英语3本',
#  '10本（练习+英语各5本）',
#  '10本（练习+英语各5本）',
#  '5本A5混色（每本28张）',
#  '15本（语文+数学+英语各5本）',
#  '10本练习本',
#  'B5五本（每本60张）',
#  '5本B5混色（每本48张）',
#  '10本语文本（方格）',
#  '10本加厚大号,作文本（300格）',
#  '10本加厚大号,汉语拼音本',
#  '10本加厚大号,英语本',
#  '10本加厚大号,数学本（单线）',
#  '5本语文本（方格）',
#  '1本装',
#  'B5五本（每本80张）',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本（200张）',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本数学本（双竖线）',
#  '5本A5混色（每本88张）',
#  '10本,数学（双竖线）',
#  '10本,语文（方格）',
#  '10本练习本',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本语文本（方格）',
#  '10本（语文+英语各5本）',
#  '5本B5混色（每本28张）',
#  '20本加厚大号,20本（自选科目）联系客服',
#  '5本数学本（双竖线）',
#  '5本作文本（300格）',
#  '16K作文本(5本)',
#  '16K田字本(5本)',
#  '16K英语本(5本)',
#  '16K数学双线本(5本)',
#  '5本作文本（300格）',
#  '5本语文本（方格）',
#  '32K英语本(5本)',
#  'B5五本（每本100张）',
#  '5本英语本',
#  '5本,英语',
#  '5本,语文（方格）',
#  '5本,练习',
#  '20本（语文+数学+英语+作文各5本）',
#  '20本加厚大号,20本（自选科目）联系客服',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本,英语',
#  '10本（作文+英语各5本）',
#  '10本语文本（方格）',
#  '20本（语文+数学+英语+练习各5本）',
#  '10本（练习+英语各5本）',
#  '20本加厚大号,数学本（单线）',
#  '10本加厚大号,数学本（单线）',
#  '20本（语文+数学+英语+练习各5本）',
#  '1本,数学（双竖线）',
#  '5本作文本（300格）',
#  'B5,英语3本',
#  '5本A4混色（每本38张）',
#  'B5五本（每本80张）',
#  '20本（语文+数学+英语+练习各5本）',
#  '10本（400张）',
#  '5本装',
#  '1本装',
#  'B5五本（每本40张）',
#  '5本数学本（双竖线）',
#  '10本语文本（方格）',
#  '5本A5混色（每本38张）',
#  '10本,练习',
#  '5本作文本（300格）',
#  '10本（数学+英语各5本）',
#  'B5五本（每本100张）',
#  '5本,数学（双竖线）',
#  '10本,练习',
#  '20本（语文+数学+英语+作文各5本）',
#  '英语本（10本竖版）',
#  '10本（语文+英语各5本）',
#  '10本语文本（方格）',
#  '15本（语文+数学+练习各5本）',
#  'A5三本（每本40张）',
#  '5本A4混色（每本78张）',
#  '5本语文本（方格）',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本B5混色（每本28张）',
#  '10本（作文+英语各5本）',
#  '15本（语文+数学+练习各5本）',
#  '5本装',
#  '乐谱本5本',
#  '20本（语文+数学+英语+练习各5本）',
#  '10本语文本（方格）',
#  '10本英语本',
#  '15本（语文+数学+英语各5本）',
#  '5本加厚大号,数学本（单线）',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本A5混色（每本48张）',
#  '5本语文本（方格）',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本语文本（方格）',
#  '5本作文本（300格）',
#  '5本练习本',
#  '5本英语本',
#  '5本作文本（300格）',
#  '5本练习本',
#  '5本作文本（300格）',
#  '5本语文本（方格）',
#  '1本,练习',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本A5混色（每本28张）',
#  '10本语文本（方格）',
#  '5本作文本（300格）',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本,50页每本',
#  '5本B5混色（每本58张）',
#  'B5,空白1本',
#  'A6,空白1本',
#  '5本练习本',
#  '10本（练习+英语各5本）',
#  'B5五本（每本40张）',
#  'A5三本（每本40张）',
#  '5本英语本',
#  '10本练习本',
#  '10本（练习+英语各5本）',
#  '1本装',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本A5混色（每本38张）',
#  '10本练习本',
#  '15本（语文+数学+练习各5本）',
#  '英语本5本装',
#  '10本（练习+英语各5本）',
#  'A5五本（每本100张）',
#  '4本共120页',
#  'A5五本（每本40张）',
#  'B5五本（每本40张）',
#  '5本语文本（方格）',
#  '5本加厚大号,作文本（300格）',
#  '5本加厚大号,数学本（单线）',
#  'A7空白5本',
#  'A7横线5本',
#  '20本（语文+数学+英语+练习各5本）',
#  '15本（语文+数学+英语各5本）',
#  '5本A4混色（每本58张）',
#  '10本加厚大号,作文本（300格）',
#  '10本加厚大号,汉语拼音本',
#  '10本加厚大号,数学本（单线）',
#  '5本装',
#  '5本B5混色（每本98张）',
#  '5本A5混色（每本48张）',
#  '10本英语本',
#  '16K数学单线本(10本)',
#  '10本英语本',
#  '1本,英语',
#  'B5五本（每本80张）',
#  'A5混色1本98张',
#  '5本B5混色（每本28张）',
#  '10本作文本（300格）',
#  '5本,50页每本',
#  '5本A5混色（每本48张）',
#  '10本（语文+英语各5本）',
#  '10本（练习+英语各5本）',
#  '10本装',
#  '5本B5混色（每本78张）',
#  '英语本5本装',
#  '5本A5混色（每本28张）',
#  '5本B5混色（每本58张）',
#  '5本B5混色（每本58张）',
#  '20本加厚大号,汉语拼音本',
#  '10本加厚大号,语文本（横线）',
#  '5本英语本',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本A4混色（每本38张）',
#  '5本B5混色（每本28张）',
#  '10本（数学+英语各5本）',
#  '5本装',
#  '5本作文本（300格）',
#  '16K练习本(10本)',
#  '1本,作文（300格）',
#  '10本英语本',
#  '5本B5混色（每本58张）',
#  '5本语文本（方格）',
#  '10本（练习+英语各5本）',
#  '5本加厚大号,汉语拼音本',
#  'A7网格5本',
#  '5本加厚大号,英语本',
#  '20本（语文+数学+英语+作文各5本）',
#  '20本（语文+数学+英语+作文各5本）',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本,50页每本',
#  '10本数学本（双竖线）',
#  '10本加厚大号,英语本',
#  '5本英语本',
#  '1本装',
#  '10本（语文+英语各5本）',
#  '5本A5混色（每本28张）',
#  '5本A5混色（每本88张）',
#  '10本加厚大号,生字本',
#  '5本A5混色（每本38张）',
#  '5本A5混色（每本48张）',
#  '5本语文本（方格）',
#  '16K英语本(10本)',
#  '5本B5混色（每本98张）',
#  '5本A5混色（每本28张）',
#  '1本装',
#  '5本加厚大号,汉语拼音本',
#  '5本加厚大号,作文本（300格）',
#  '5本加厚大号,英语本',
#  '5本A5混色（每本28张）',
#  '20本（语文+数学+英语+作文各5本）',
#  'B5三本（每本40张）',
#  '20本（语文+数学+英语+作文各5本）',
#  '1本,50页每本',
#  '5本,英语',
#  'B5五本（每本40张）',
#  '5本A5混色（每本88张）',
#  'A6空白本（5本）',
#  '5本,50页每本',
#  'B5五本（每本80张）',
#  '1本,50页每本',
#  '5本A5混色（每本28张）',
#  '5本A5混色（每本38张）',
#  '5本装',
#  '5本,50页每本',
#  '20本加厚大号,数学本（单线）',
#  '20本加厚大号,英语本',
#  'B5五本（每本80张）',
#  '5本A4混色（每本78张）',
#  '5本加厚大号,作文本（300格）',
#  '5本加厚大号,英语本',
#  '5本加厚大号,数学本（双竖线）',
#  '5本A5混色（每本38张）',
#  '5本A5混色（每本48张）',
#  '5本A5混色（每本68张）',
#  '5本练习本',
#  '20本（语文+数学+英语+作文各5本）',
#  '10本加厚大号,语文本（横线）',
#  '32K英语本(5本)',
#  '10本加厚大号,练习本',
#  '10本练习本',
#  '5本B5混色（每本48张）',
#  '32K小号,5本英语本',
#  'B5五本（每本40张）',
#  '5本A5混色（每本48张）',
#  '5本加厚大号,数学本（单线）',
#  '10本加厚大号,数学本（单线）',
#  '5本,50页每本',
#  '5本B5混色（每本58张）',
#  '5本A5混色（每本28张）',
#  '10本,数学（双竖线）',
#  '5本加厚大号,汉语拼音本',
#  '5本加厚大号,练习本',
#  '5本加厚大号,英语本',
#  '5本加厚大号,作文本（300格）',
#  '10本加厚大号,语文本（横线）',
#  '5本加厚大号,英语本',
#  '5本,50页每本',
#  'B5三本（每本40张）',
#  '5本加厚大号,作文本（300格）',
#  '5本加厚大号,练习本',
#  '5本加厚大号,英语本',
#  'B5五本（每本40张）',
#  '10本加厚大号,练习本',
#  '10本加厚大号,数学本（双竖线）',
#  '5本加厚大号,汉语拼音本',
#  '5本加厚大号,作文本（300格）',
#  '1本,作文（300格）',
#  '10本,作文（300格）',
#  '5本加厚大号,练习本',
#  '5本B5混色（每本28张）',
#  '1本（40张）',
#  '10本加厚大号,语文本（方格）',
#  '20本（语文+数学+英语+作文各5本）',
#  '10本加厚大号,练习本',
#  '5本A4混色（每本38张）',
#  '5本练习本',
#  '20本加厚大号,语文本（方格）',
#  '5本B5混色（每本78张）',
#  '5本加厚大号,数学本（单线）',
#  '5本A5混色（每本68张）',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本,A4',
#  '5本,50页每本',
#  '5本装',
#  '5本装',
#  '5本语文本（方格）',
#  '5本装',
#  '5本加厚大号,数学本（单线）',
#  '5本B5混色（每本58张）',
#  '5本（200张）',
#  '20本（语文+数学+英语+练习各5本）',
#  '10本加厚大号,作文本（300格）',
#  'A5空白本（5本）',
#  '10本加厚大号,英语本',
#  '10本加厚大号,汉语拼音本',
#  '10本加厚大号,数学本（单线）',
#  '1本,数学（双竖线）',
#  '16K英语本(5本)',
#  '10本练习本',
#  '10本数学本（双竖线）',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本A5混色（每本38张）',
#  '5本A5混色（每本38张）',
#  '5本A5混色（每本48张）',
#  '16K数学单线本(5本)',
#  '10本（数学+英语各5本）',
#  '5本加厚大号,语文本（横线）',
#  '5本（150张）,空白胶装款',
#  '5本装',
#  '5本A5混色（每本38张）',
#  '10本,B5',
#  '32K英语本(5本)',
#  '10本练习本',
#  '5本A4混色（每本58张）',
#  'B5三本（每本40张）',
#  '5本作文本（300格）',
#  '20本（语文+数学+英语+练习各5本）',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本B5混色（每本78张）',
#  '10本加厚大号,练习本',
#  '5本（200张）',
#  '5本B5混色（每本48张）',
#  '1本（40张）',
#  '16K数学单线本(5本)',
#  '16K作文本(5本)',
#  '16K语文方格本(5本)',
#  '10本（400张）',
#  '1本装',
#  '10本（数学+英语各5本）',
#  '5本A5混色（每本68张）',
#  '10本（练习+英语各5本）',
#  '英语本5本装',
#  '1本,作文（300格）',
#  '20本（语文+数学+英语+作文各5本）',
#  '1本,50页每本',
#  '10本加厚大号,练习本',
#  '16K数学单线本(5本)',
#  '5本练习本',
#  '1本,练习',
#  '5本加厚大号,练习本',
#  '10本练习本',
#  '5本加厚大号,语文本（横线）',
#  '5本A5混色（每本88张）',
#  '10本英语本',
#  '16K作文本(5本)',
#  '16K田字本(5本)',
#  '16K汉语拼音本(5本)',
#  '16K读书笔记本(5本)',
#  '16K英语本(10本)',
#  '16K语文方格本(10本)',
#  '16K数学单线本(10本)',
#  '5本英语本',
#  '5本加厚大号,语文本（方格）',
#  '15本（语文+数学+英语各5本）',
#  '5本A4混色（每本58张）',
#  '5本练习本',
#  '5本A5混色（每本88张）',
#  '32K田字本(5本)',
#  '5本作文本（300格）',
#  '10本练习本',
#  '5本B5混色（每本98张）',
#  '5本A5混色（每本38张）',
#  '5本加厚大号,汉语拼音本',
#  '20本（语文+数学+英语+作文各5本）',
#  '16K数学单线本(10本)',
#  '5本A5混色（每本28张）',
#  '15本（语文+数学+英语各5本）',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本语文本（方格）',
#  '5本A5混色（每本48张）',
#  '32K练习本(10本)',
#  '5本练习本',
#  '32K语文本(5本)',
#  '5本加厚大号,练习本',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本加厚大号,生字本',
#  '5本装',
#  '32K田字本(5本)',
#  '5本A5混色（每本38张）',
#  '5本A4混色（每本38张）',
#  '10本,A4',
#  '10本练习本',
#  '10本练习本',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本语文本（方格）',
#  '5本加厚大号,数学本（单线）',
#  '5本加厚大号,生字本',
#  '10本加厚大号,英语本',
#  '10本加厚大号,作文本（300格）',
#  '5本装',
#  'B5空白本（5本）',
#  '5本数学本（双竖线）',
#  '32K练习本(5本)',
#  '32K英语本(5本)',
#  '20本（语文+数学+英语+作文各5本）',
#  'A5盐系4本',
#  '10本（语文+英语各5本）',
#  '5本练习本',
#  '5本B5混色（每本98张）',
#  '5本,数学（双竖线）',
#  '10本作文本（300格）',
#  '10本（作文+英语各5本）',
#  '5本英语本',
#  '10本（语文+英语各5本）',
#  '5本语文本（方格）',
#  '5本A5混色（每本28张）',
#  '5本B5混色（每本58张）',
#  '5本A5混色（每本48张）',
#  '16K语文横线本(5本)',
#  '16K练习本(10本)',
#  '16K练习本(5本)',
#  '1本,50页每本',
#  '1本,英语',
#  '5本B5混色（每本58张）',
#  '16K英语本(5本)',
#  '16K数学单线本(10本)',
#  '10本加厚大号,语文本（方格）',
#  '10本加厚大号,数学本（双竖线）',
#  '20本加厚大号,语文本（方格）',
#  '20本加厚大号,数学本（双竖线）',
#  '20本加厚大号,作文本（300格）',
#  '5本加厚大号,语文本（方格）',
#  '5本A5混色（每本28张）',
#  '15本（语文+数学+英语各5本）',
#  '10本（练习+英语各5本）',
#  '5本B5混色（每本48张）',
#  '10本数学本（双竖线）',
#  '10本加厚大号,作文本（300格）',
#  '16K数学单线本(5本)',
#  '10本,数学（双竖线）',
#  '5本语文本（方格）',
#  'B5五本（每本80张）',
#  '10本加厚大号,英语本',
#  '10本加厚大号,数学本（双竖线）',
#  '10本加厚大号,作文本（300格）',
#  '10本语文本（方格）',
#  '32K练习本(5本)',
#  '20本（语文+数学+英语+作文各5本）',
#  '16K数学单线本(10本)',
#  '5本英语本',
#  '10本（练习+英语各5本）',
#  '5本B5混色（每本28张）',
#  '16K数学单线本(5本)',
#  '16K语文横线本(5本)',
#  '10本练习本',
#  '5本加厚大号,数学本（双竖线）',
#  '5本数学本（双竖线）',
#  '20本（语文+数学+英语+练习各5本）',
#  '5本语文本（方格）',
#  '10本练习本',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本A5混色（每本28张）',
#  '5本数学本（双竖线）',
#  '16K语文横线本(10本)',
#  '10本（400张）',
#  '10本作文本（300格）',
#  '1本,数学（双竖线）',
#  '15本（语文+数学+英语各5本）',
#  '5本作文本（300格）',
#  '20本（语文+数学+英语+作文各5本）',
#  '10本练习本',
#  'B5五本（每本80张）',
#  '16K语文横线本(5本)',
#  '16K语文横线本(10本)',
#  '5本A5混色（每本48张）',
#  '20本（语文+数学+英语+作文各5本）',
#  '20本（语文+数学+英语+作文各5本）',
#  '10本（练习+英语各5本）',
#  '10本练习本',
#  '32K作文本(5本)',
#  '32K语文本(5本)',
#  '1本,英语',
#  '10本（练习+英语各5本）',
#  '15本（语文+数学+英语各5本）',
#  '5本练习本',
#  '20本（语文+数学+英语+练习各5本）',
#  '10本,数学（双竖线）',
#  '10本作文本（300格）',
#  '10本语文本（方格）',
#  '5本B5混色（每本78张）',
#  '5本装',
#  '5本（150张）,分区胶装款',
#  '10本（语文+英语各5本）',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本装',
#  '5本A5混色（每本38张）',
#  'B5五本（每本100张）',
#  '5本A4混色（每本78张）',
#  '5本A5混色（每本28张）',
#  '16K汉语拼音本(10本)',
#  '5本作文本（300格）',
#  '5本A5混色（每本48张）',
#  '5本A5混色（每本38张）',
#  '10本练习本',
#  '20本（语文+数学+英语+作文各5本）',
#  '5本英语本',
#  '5本A5混色（每本48张）',
#  ...]

# %%
def addBen(string):
    # string = r'(81本)'
    
    pattern1 = r'(?P<ben>\d+)本'
    pattern2 = r'(?P<ben>[十九八七六五四三二一])本'
    regexp1 = re.compile(pattern1)
    
    mat1 = regexp1.search(string)
    regexp2 = re.compile(pattern2)
    mat2 = regexp2.search(string)
    if mat1:
        ben = int(mat1.group('ben'))
    else:
        if mat2:
            ben = dic.get(mat2.group('ben'))
        else:
            ben = 1
    return ben

# %%
for i in lst:
    print(i)
    ben = addBen(i)
    print('ben',ben)
# Out:
# 10本（作文+英语各5本）
# ben 10
# B5甜系4本
# ben 4
# 5本A5混色（每本48张）
# ben 5
# 20本（语文+数学+英语+练习各5本）
# ben 20
# 练习本10本
# ben 10
# 20本（语文+数学+英语+练习各5本）
# ben 20
# 5本练习本
# ben 5
# 20本（语文+数学+英语+练习各5本）
# ben 20
# 1本,英语
# ben 1
# 1本,英语
# ben 1
# 1本,作文（300格）
# ben 1
# 1本,数学（双竖线）
# ben 1
# 5本语文本（方格）
# ben 5
# 5本A4混色（每本58张）
# ben 5
# 5本A5混色（每本28张）
# ben 5
# 英语本（10本竖版）
# ben 10
# 1本,数学（双竖线）
# ben 1
# 1本,语文（方格）
# ben 1
# 1本,作文（300格）
# ben 1
# 10本练习本
# ben 10
# B5五本（每本100张）
# ben 5
# 5本A5混色（每本68张）
# ben 5
# 5本A5混色（每本48张）
# ben 5
# 10本英语本
# ben 10
# 5本语文本（方格）
# ben 5
# 16K汉语拼音本(10本)
# ben 10
# 1本,英语
# ben 1
# 10本（400张）
# ben 10
# A5五本（每本60张）
# ben 5
# 5本,50页每本
# ben 5
# 5本加厚大号,练习本
# ben 5
# 5本A5混色（每本48张）
# ben 5
# 10本,英语
# ben 10
# 5本A5混色（每本88张）
# ben 5
# 5本作文本（300格）
# ben 5
# 10本练习本
# ben 10
# 英语本5本装
# ben 5
# 5本A5混色（每本48张）
# ben 5
# 1本,语文（方格）
# ben 1
# 1本,英语
# ben 1
# 1本,数学（双竖线）
# ben 1
# 1本,英语
# ben 1
# 5本,50页每本
# ben 5
# 5本A5混色（每本28张）
# ben 5
# 5本B5混色（每本78张）
# ben 5
# B5五本（每本80张）
# ben 5
# 1本,英语
# ben 1
# 10本,英语
# ben 10
# 5本A5混色（每本68张）
# ben 5
# 10本装
# ben 10
# 1本,练习
# ben 1
# 20本（语文+数学+英语+练习各5本）
# ben 20
# 15本（语文+数学+英语各5本）
# ben 15
# 10本（400张）
# ben 10
# 10本练习本
# ben 10
# 5本装
# ben 5
# 5本B5混色（每本98张）
# ben 5
# 5本,50页每本
# ben 5
# 1本,英语
# ben 1
# 1本,30页每本
# ben 1
# 1本,数学（双竖线）
# ben 1
# 1本,英语
# ben 1
# 10本语文本（方格）
# ben 10
# 5本A5混色（每本28张）
# ben 5
# 5本A5混色（每本38张）
# ben 5
# 5本练习本
# ben 5
# 5本,练习
# ben 5
# 1本,英语
# ben 1
# 1本,数学（双竖线）
# ben 1
# 1本,练习
# ben 1
# 5本（200张）
# ben 5
# 10本加厚大号,数学本（双竖线）
# ben 10
# 10本加厚大号,汉语拼音本
# ben 10
# 10本加厚大号,语文本（方格）
# ben 10
# 16K汉语拼音本(5本)
# ben 5
# 16K作文本(5本)
# ben 5
# 5本B5混色（每本78张）
# ben 5
# 1本,练习
# ben 1
# 1本,作文（300格）
# ben 1
# 5本装
# ben 5
# 1本,英语
# ben 1
# B5五本（每本80张）
# ben 5
# A5五本（每本60张）
# ben 5
# B5,横线3本
# ben 3
# 1本,英语
# ben 1
# B5五本（每本60张）
# ben 5
# 5本B5混色（每本78张）
# ben 5
# 10本,英语
# ben 10
# 10本,练习
# ben 10
# 10本,语文（方格）
# ben 10
# 1本,练习
# ben 1
# 4K（160g）,5本
# ben 5
# 1本,英语
# ben 1
# 5本加厚大号,语文本（横线）
# ben 5
# 练习本5本装
# ben 5
# 1本装
# ben 1
# 10本加厚大号,英语本
# ben 10
# B5五本（每本100张）
# ben 5
# 5本加厚大号,数学本（单线）
# ben 5
# 5本加厚大号,语文本（方格）
# ben 5
# 20本加厚大号,汉语拼音本
# ben 20
# 1本,作文（300格）
# ben 1
# 5本英语本
# ben 5
# 5本装
# ben 5
# 5本装
# ben 5
# 5本A5混色（每本38张）
# ben 5
# 5本装
# ben 5
# 5本装
# ben 5
# B5五本（每本40张）
# ben 5
# B5五本（每本60张）
# ben 5
# 1本A5颜色随机(28张)
# ben 1
# 1本,英语
# ben 1
# 1本,数学（双竖线）
# ben 1
# 1本,语文（方格）
# ben 1
# 10本（400张）
# ben 10
# 5本练习本
# ben 5
# A5五本（每本80张）
# ben 5
# B5五本（每本60张）
# ben 5
# B5五本（每本40张）
# ben 5
# 10本,英语
# ben 10
# 5本,练习
# ben 5
# 10本,练习
# ben 10
# B5五本（每本100张）
# ben 5
# 16K练习本(10本)
# ben 10
# B5五本（每本100张）
# ben 5
# B5三本（每本40张）
# ben 3
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 15本（语文+数学+英语各5本）
# ben 15
# 10本（数学+英语各5本）
# ben 10
# B5五本（每本80张）
# ben 5
# 5本作文本（300格）
# ben 5
# 5本,英语
# ben 5
# 1本,英语
# ben 1
# B5五本（每本40张）
# ben 5
# 5本加厚大号,作文本（300格）
# ben 5
# 5本加厚大号,语文本（横线）
# ben 5
# 10本练习本
# ben 10
# 5本加厚大号,语文本（方格）
# ben 5
# 5本,练习
# ben 5
# 1本,作文（300格）
# ben 1
# 1本,英语
# ben 1
# B5五本（每本100张）
# ben 5
# 10本练习本
# ben 10
# B5五本（每本40张）
# ben 5
# 20本,作文（300格）
# ben 20
# 10本,作文（300格）
# ben 10
# B5五本（每本60张）
# ben 5
# 10本,英语
# ben 10
# 5本,数学（双竖线）
# ben 5
# 5本,作文（300格）
# ben 5
# A5五本（每本60张）
# ben 5
# 5本作文本（300格）
# ben 5
# 5本A5混色（每本48张）
# ben 5
# 5本作文本（300格）
# ben 5
# B5五本（每本40张）
# ben 5
# B5五本（每本80张）
# ben 5
# 5本A5混色（每本28张）
# ben 5
# 5本练习本
# ben 5
# 5本作文本（300格）
# ben 5
# 10本英语本
# ben 10
# 10本练习本
# ben 10
# 5本A5混色（每本88张）
# ben 5
# 5本A5混色（每本68张）
# ben 5
# 5本A5混色（每本28张）
# ben 5
# 英语本5本装
# ben 5
# B5五本（每本60张）
# ben 5
# B5五本（每本40张）
# ben 5
# 5本A5混色（每本28张）
# ben 5
# A5五本（每本60张）
# ben 5
# 5本加厚大号,练习本
# ben 5
# B5五本（每本40张）
# ben 5
# 10本,英语
# ben 10
# B5五本（每本40张）
# ben 5
# 20本,英语
# ben 20
# 5本数学本（双竖线）
# ben 5
# 10本（作文+英语各5本）
# ben 10
# 5本,数学（双竖线）
# ben 5
# 20本（语文+数学+英语+练习各5本）
# ben 20
# 10本,语文（方格）
# ben 10
# A5五本（每本60张）
# ben 5
# 10本语文本（方格）
# ben 10
# B5五本（每本40张）
# ben 5
# B5五本（每本40张）
# ben 5
# 10本练习本
# ben 10
# 1本,英语
# ben 1
# B5五本（每本60张）
# ben 5
# 20本（语文+数学+英语+练习各5本）
# ben 20
# B5五本（每本80张）
# ben 5
# 5本A5混色（每本38张）
# ben 5
# 1本装
# ben 1
# 10本练习本
# ben 10
# 5本作文本（300格）
# ben 5
# 1本,语文（方格）
# ben 1
# 10本练习本
# ben 10
# 10本语文本（方格）
# ben 10
# 10本加厚大号,语文本（横线）
# ben 10
# 10本（作文+英语各5本）
# ben 10
# 1本装
# ben 1
# 5本练习本
# ben 5
# B5五本（每本60张）
# ben 5
# B5五本（每本60张）
# ben 5
# B5五本（每本80张）
# ben 5
# B5五本（每本80张）
# ben 5
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 10本练习本
# ben 10
# 5本,数学（双竖线）
# ben 5
# 10本练习本
# ben 10
# 10本,英语
# ben 10
# 20本（语文+数学+英语+练习各5本）
# ben 20
# 5本,50页每本
# ben 5
# 1本,练习
# ben 1
# 5本,语文（方格）
# ben 5
# B5五本（每本80张）
# ben 5
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 20本,练习
# ben 20
# 10本（练习+英语各5本）
# ben 10
# 5本B5混色（每本98张）
# ben 5
# 1本,作文（300格）
# ben 1
# 5本练习本
# ben 5
# 5本语文本（方格）
# ben 5
# 10本（练习+英语各5本）
# ben 10
# A5五本（每本60张）
# ben 5
# 10本,练习
# ben 10
# B5五本（每本40张）
# ben 5
# 10本（作文+英语各5本）
# ben 10
# 10本练习本
# ben 10
# 1本,英语
# ben 1
# 1本,语文（方格）
# ben 1
# 1本,练习
# ben 1
# 1本,作文（300格）
# ben 1
# 1本,英语
# ben 1
# 5本,英语
# ben 5
# 5本,数学（双竖线）
# ben 5
# 10本,作文（300格）
# ben 10
# 10本,英语
# ben 10
# B5三本（每本40张）
# ben 3
# 5本（150张）,分区胶装款
# ben 5
# B5五本（每本40张）
# ben 5
# 5本A4混色（每本78张）
# ben 5
# 1本装
# ben 1
# B5五本（每本80张）
# ben 5
# 5本B5混色（每本78张）
# ben 5
# 5本A5混色（每本38张）
# ben 5
# 1本,英语
# ben 1
# 5本装
# ben 5
# 5本,作文（300格）
# ben 5
# 10本练习本
# ben 10
# 10本练习本
# ben 10
# 1本,作文（300格）
# ben 1
# 1本,语文（方格）
# ben 1
# 10本,英语
# ben 10
# 5本A5混色（每本68张）
# ben 5
# 5本A5混色（每本88张）
# ben 5
# B5,横线5本
# ben 5
# B5五本（每本40张）
# ben 5
# 1本,英语
# ben 1
# 10本英语本
# ben 10
# 10本作文本（300格）
# ben 10
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 5本,作文（300格）
# ben 5
# 5本装
# ben 5
# 5本B5混色（每本78张）
# ben 5
# 1本,语文（方格）
# ben 1
# 1本,练习
# ben 1
# 1本,英语
# ben 1
# 1本,作文（300格）
# ben 1
# 1本装
# ben 1
# 10本练习本
# ben 10
# 5本英语本
# ben 5
# 10本,数学（双竖线）
# ben 10
# 5本A5混色（每本88张）
# ben 5
# 20本（语文+数学+英语+练习各5本）
# ben 20
# B5五本（每本80张）
# ben 5
# 10本,数学（双竖线）
# ben 10
# B5五本（每本60张）
# ben 5
# 10本练习本
# ben 10
# 1本装
# ben 1
# 1本,作文（300格）
# ben 1
# 5本A5混色（每本88张）
# ben 5
# 英语本5本装
# ben 5
# 1本装
# ben 1
# 1本,练习
# ben 1
# B5五本（每本40张）
# ben 5
# 1本,作文（300格）
# ben 1
# 1本,语文（方格）
# ben 1
# 1本,练习
# ben 1
# 5本B5混色（每本98张）
# ben 5
# 5本A4混色（每本58张）
# ben 5
# 1本A5颜色随机(28张)
# ben 1
# 5本语文本（方格）
# ben 5
# 5本练习本
# ben 5
# 5本加厚大号,数学本（单线）
# ben 5
# 5本加厚大号,英语本
# ben 5
# 5本加厚大号,作文本（300格）
# ben 5
# 5本加厚大号,汉语拼音本
# ben 5
# 1本,作文（300格）
# ben 1
# 5本练习本
# ben 5
# 20本,练习
# ben 20
# 1本,作文（300格）
# ben 1
# 1本,语文（方格）
# ben 1
# 1本,英语
# ben 1
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 5本A5混色（每本38张）
# ben 5
# 10本数学本
# ben 10
# A5五本（每本80张）
# ben 5
# 20本（语文+数学+英语+练习各5本）
# ben 20
# 5本,50页每本
# ben 5
# 10本练习本
# ben 10
# 10本英语本
# ben 10
# 10本,作文（300格）
# ben 10
# 1本,英语
# ben 1
# 5本语文本（方格）
# ben 5
# 5本A4混色（每本58张）
# ben 5
# 10本（作文+英语各5本）
# ben 10
# 英语本10本
# ben 10
# 10本语文本（方格）
# ben 10
# 1本,数学（双竖线）
# ben 1
# 1本,英语
# ben 1
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 5本A5混色（每本68张）
# ben 5
# 5本B5混色（每本78张）
# ben 5
# 语文本10本
# ben 10
# 练习本10本
# ben 10
# B5五本（每本60张）
# ben 5
# B5五本（每本100张）
# ben 5
# 10本练习本
# ben 10
# 10本,语文（方格）
# ben 10
# 10本作文本（300格）
# ben 10
# 20本加厚大号,练习本
# ben 20
# 10本加厚大号,练习本
# ben 10
# 10本数学本（双竖线）
# ben 10
# 10本（400张）
# ben 10
# 10本（练习+英语各5本）
# ben 10
# 5本,练习
# ben 5
# 20本（语文+数学+英语+练习各5本）
# ben 20
# 5本A5混色（每本38张）
# ben 5
# 5本A5混色（每本38张）
# ben 5
# A5五本（每本60张）
# ben 5
# 10本,英语
# ben 10
# 5本A5混色（每本38张）
# ben 5
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 5本数学本（双竖线）
# ben 5
# 5本装
# ben 5
# 1本,英语
# ben 1
# 1本,英语
# ben 1
# 1本,数学（双竖线）
# ben 1
# 1本,语文（方格）
# ben 1
# 5本,练习
# ben 5
# 5本B5混色（每本98张）
# ben 5
# A5五本（每本100张）
# ben 5
# 5本数学本（双竖线）
# ben 5
# 5本,50页每本
# ben 5
# 10本,作文（300格）
# ben 10
# 5本,作文（300格）
# ben 5
# B5五本（每本100张）
# ben 5
# 20本,练习
# ben 20
# 5本,50页每本
# ben 5
# 5本数学本（双竖线）
# ben 5
# A5五本（每本60张）
# ben 5
# 10本练习本
# ben 10
# 15本（语文+数学+练习各5本）
# ben 15
# 5本装
# ben 5
# 英语本5本装
# ben 5
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 20本,英语
# ben 20
# 1本,作文（300格）
# ben 1
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 数学本5本装
# ben 5
# 16K数学双线本(5本)
# ben 5
# 10本,英语
# ben 10
# 5本装
# ben 5
# 10本（练习+英语各5本）
# ben 10
# 5本加厚大号,练习本
# ben 5
# 5本B5混色（每本48张）
# ben 5
# B5五本（每本40张）
# ben 5
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 5本A5混色（每本28张）
# ben 5
# 10本练习本
# ben 10
# 5本A5混色（每本88张）
# ben 5
# 10本（练习+英语各5本）
# ben 10
# 1本,英语
# ben 1
# 5本加厚大号,练习本
# ben 5
# 5本A5混色（每本88张）
# ben 5
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 10本练习本
# ben 10
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 5本A5混色（每本28张）
# ben 5
# 5本作文本（300格）
# ben 5
# 5本练习本
# ben 5
# 10本英语本
# ben 10
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 10本数学本（双竖线）
# ben 10
# 1本,英语
# ben 1
# 10本练习本
# ben 10
# 20本（语文+数学+英语+作文各5本）
# ben 20
# 20本（语文+数学+英语+练习各5本）
# ben 20
# 5本A5混色（每本28张）
# ben 5
# 1本,数学（双竖线）
# ben 1
# 10本,数学（双竖线）
# ben 10
# 10本,英语
# ben 10
# 5本,50页每本
# ben 5
# 5本语文本（方格）
# ben 5
# 1本,作文（300格）
# ben 1
# 5本加厚大号,作文本（300格）
# ben 5
# 5本A5混色（每本48张）
# ben 5
# 10本数学本（双竖线）
# ben 10
# 10本语文本（方格）
# ben 10
# 10本,作文（300格）
# ben 10
# 5本语文本（方格）
# ben 5
# 5本（150张）,分区胶装款
# ben 5
# 5本英语本
# ben 5
# 10本,练习
# ben 10
# 5本A5混色（每本68张）
# ben 5
# nan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 for i in lst:
#       2     print(i)
# ----> 3     ben = addBen(i)
#       4     print('ben',ben)
#
# Cell In[20], line 8, in addBen(string)
#       5 pattern2 = r'(?P<ben>[十九八七六五四三二一])本'
#       6 regexp1 = re.compile(pattern1)
# ----> 8 mat1 = regexp1.search(string)
#       9 regexp2 = re.compile(pattern2)
#      10 mat2 = regexp2.search(string)
#
# TypeError: expected string or bytes-like object, got 'float'
