# %%
import openpyxl
import csv

# 先打开 csv 文件
file = open(r'F:\a00nutstore\fishc\扇贝编程python办公自动化\扇贝编程python办公自动化第七关\Desktop\工资计算\考勤信息.csv', 'r',encoding = 'UTF-8')
# 用 csv 模块的 reader() 方法转换成 reader 对象
reader = csv.reader(file)
# 转换成二维列表
info = list(reader)
# 用分片，切掉标题行
info = info[1:]
file.close()

# 打开 工资.xlsx
wb = openpyxl.load_workbook(r'F:\a00nutstore\fishc\扇贝编程python办公自动化\扇贝编程python办公自动化第七关\Desktop\工资计算\工资.xlsx')
ws = wb.active
# 获取所有员工的所在的行
rows = {ws[f'A{row}'].value:row for row in range(2, 52)}
# 请假和加班对应的列也建个词典
columns = {'请假':4, '加班':5}

# 对 info 的每行进行循环，填入信息
for name, item, days, date in info:
  # 定位要写入数据的单元格的行和列
  cell = ws.cell(rows[name], columns[item])
  cell.value = int(cell.value) + int(days)

wb.save(r'工资-已填写.xlsx')

# %%
# 打开 工资.xlsx
wb = openpyxl.load_workbook(r'F:\a00nutstore\fishc\扇贝编程python办公自动化\扇贝编程python办公自动化第七关\Desktop\工资计算\工资.xlsx')
ws = wb.active
rowdic = {j.value:ws['A'].index(j)+1 for j in ws['A'][1:]}
print(rowdic)

# %%
import openpyxl
import csv

# 先打开 csv 文件
file = open(r'F:\a00nutstore\fishc\扇贝编程python办公自动化\扇贝编程python办公自动化第七关\Desktop\工资计算\考勤信息.csv', 'r',encoding = 'UTF-8')
reader = csv.reader(file)
infos = list(reader)





# 打开 工资.xlsx
wb = openpyxl.load_workbook(r'F:\a00nutstore\fishc\扇贝编程python办公自动化\扇贝编程python办公自动化第七关\Desktop\工资计算\工资.xlsx')
ws = wb.active
rowdic = {j.value:ws['A'].index(j)+1 for j in ws['A'][1:]}
shixiangdic = {'请假':4,'加班':5}



# 对 info 的每行进行循环，填入信息
for name,shixiang,days,riqi in infos[1:]:
  cell = ws.cell(rowdic[name],shixiangdic[shixiang])
  cell.value = int(cell.value) + int(days)
  
  



# 请不要修改最后一行的文件保存代码哦
wb.save('工资-已填写.xlsx')

# %%
import docx
from openpyxl import load_workbook

wd = docx.Document(r'F:\a00nutstore\fishc\扇贝编程python办公自动化\扇贝编程python办公自动化第七关\Desktop\工资计算\工资明细填写模板.docx')
wb = load_workbook(r'F:\a00nutstore\fishc\扇贝编程python办公自动化\扇贝编程python办公自动化第七关\Desktop\工资计算\工资信息替换模板.xlsx')
ws = wb.active

# 定义文本替换函数
def replace_info(wordfile, old_info, new_info):
  # 在文本段落中查找 old_info 替换为 new_info
  for paragraph in wordfile.paragraphs:
    for run in paragraph.runs:
      run.text = run.text.replace(old_info, new_info)
  # 在表格中查找 old_info 替换为 new_info
  for table in wordfile.tables:
    for row in table.rows:
      for cell in row.cells:
        cell.text = cell.text.replace(old_info, new_info)

# 需要被替换的旧信息
old_infos = [str(cell.value) for cell in ws[1]]

# 最终保留的替换结果
new_infos = [str(cell.value) for cell in ws[15]]

# 让新旧信息一一对应
replacelist =zip(old_infos,new_infos)
# 调用 replace_info() 函数替换信息
for old_info,new_info in replacelist:
  replace_info(wd,old_info,new_info)

# 请不要修改最后一行的文件保存代码哦
wd.save('11月工资明细-杰尼龟.docx')

# %%
# 别忘了导入必要的库
import docx
from openpyxl import load_workbook

wb = load_workbook(r'F:\a00nutstore\fishc\扇贝编程python办公自动化\扇贝编程python办公自动化第七关\Desktop\工资计算\工资信息替换模板.xlsx')
ws = wb.active

# 定义文本替换函数
def replace_info(wd,old_info,new_info):
  for para in wd.paragraphs:
    for run in para.runs:
      run.text = run.text.replace(old_info,new_info)
      
  for table in wd.tables:
    for row in table.rows:
      for cell in row.cells:
        cell.text = cell.text.replace(old_info,new_info)
        

# 读取工作表首行每个单元格中的信息，作为被替换的信息存入 old_infos
old_infos = [cell.value for cell in ws[1]]
  

# 从第二行开始，按行读取 Excel 表中的数据
rowlist = list(ws.rows)
for row in rowlist[1:]:

  # 每读取一行就创建一个 Document 对象
  wd = docx.Document(r'F:\a00nutstore\fishc\扇贝编程python办公自动化\扇贝编程python办公自动化第七关\Desktop\工资计算\工资明细填写模板.docx')

  # 读取当前行对应的姓名
  name = row[0].value

  # 读取当前行每个单元格的信息，作为最终替换结果存入 new_infos
  new_infos = [str(cell.value) for cell in row]
  # 调用 replace_info() 函数替换信息
  replacelist = zip(old_infos,new_infos)
  for old_info,new_info in replacelist:
    replace_info(wd,old_info,str(new_info))
  
  


  # 请不要修改最后一行的文件保存代码哦
  wd.save(f'11月工资明细-{name}.docx')

# %%
import docx
from openpyxl import load_workbook

wb = load_workbook(r'D:\a00nutstore\fishc\扇贝编程python办公自动化\扇贝编程python办公自动化第七关\Desktop\工资计算\工资信息替换模板.xlsx')
ws = wb.active

# 定义文本替换函数
def replace_info(wordfile, old_info, new_info):
  # 在文本段落中查找 old_info 替换为 new_info
  for paragraph in wordfile.paragraphs:
    for run in paragraph.runs:
      run.text = run.text.replace(old_info, new_info)
  # 在表格中查找 old_info 替换为 new_info
  for table in wordfile.tables:
    for row in table.rows:
      for cell in row.cells:
        cell.text = cell.text.replace(old_info, new_info)

# 读取工作表首行每个单元格中的信息，作为被替换的信息 old_infos
old_infos = [cell.value for cell in ws[1]]

# 从第二行开始，按行读取 Excel 表中的数据
rows_list = list(ws.rows)
for row in rows_list[1:]:
  # 每读取一行就创建一个 Document 对象
  wd = docx.Document(r'D:\a00nutstore\fishc\扇贝编程python办公自动化\扇贝编程python办公自动化第七关\Desktop\工资计算\工资明细填写模板.docx')

  # 读取当前行对应的姓名
  name = row[0].value
  print(f'正在制作{name}的工资明细单')

  # 读取当前行每个单元格的信息，作为最终替换结果 new_infos
  new_infos = [cell.value for cell in row]
  
  # 调用 replace_info() 函数替换信息
  replace_list = zip(old_infos, new_infos)
  for old_info, new_info in replace_list:
    replace_info(wd, old_info, str(new_info))

  # 保存文档到当前目录
  wd.save(f'11月工资明细-{name}.docx')

# %%
import os, yagmail, fnmatch
from pypinyin import lazy_pinyin

# 输入你的邮箱地址和授权码
yag = yagmail.SMTP(user='1142760803@qq.com', password='wycffq805', host='smtp.qq.com')

# 筛选“工资明细”文件夹里的所有 .docx 文件
dir_path = r'D:\a00nutstore\fishc\扇贝编程python办公自动化\扇贝编程python办公自动化第七关\Desktop\工资明细'
all_files = os.listdir(dir_path)
all_wordfiles = [file for file in all_files if fnmatch.fnmatch(file, '*.docx')]

# 对每个 Word 文档进行操作
for wordfile in all_wordfiles:
  file_name = os.path.splitext(wordfile)[0]
  name = file_name.split('-')[1]
  mail_address = ''.join(lazy_pinyin(name)) + '@bkm.com'
  yag.send(
        to=mail_address,
        subject='2020年11月工资明细',
        contents=['你好，请查收11月的工资明细单', os.path.join(dir_path, wordfile)]
        )
  print(f'已向{name}发送工资明细邮件')ll
