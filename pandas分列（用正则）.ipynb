# %%
import pandas as pd
import re

# file = 'pandas正则分列示例.xlsx'
# df = pd.read_excel(file)
df = pd.read_clipboard()
df
# df2 = df['车型名称'].map(lambda x: re.sub('[A-Z0-9. ]+', ',', x)).str.split(',', expand=True)
# df = pd.concat([df, df2], axis=1)
# df.columns = ['车型名称', '品牌', '车型']
# print(df)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[3], line 6
#       2 import re
#       4 # file = 'pandas正则分列示例.xlsx'
#       5 # df = pd.read_excel(file)
# ----> 6 df = pd.read_clipboard()
#       7 df
#       8 # df2 = df['车型名称'].map(lambda x: re.sub('[A-Z0-9. ]+', ',', x)).str.split(',', expand=True)
#       9 # df = pd.concat([df, df2], axis=1)
#      10 # df.columns = ['车型名称', '品牌', '车型']
#      11 # print(df)
#
# File ~\.conda\envs\py311\Lib\site-packages\pandas\io\clipboards.py:129, in read_clipboard(sep, dtype_backend, **kwargs)
#     123 elif len(sep) > 1 and kwargs.get("engine") == "c":
#     124     warnings.warn(
#     125         "read_clipboard with regex separator does not work properly with c engine.",
#     126         stacklevel=find_stack_level(),
#     127     )
# ...

# %%
df2 = df['车型名称'].map(lambda x: re.sub('[A-Z0-9. ]+', ',', x)).str.split(',', expand=True)
df2
# Out:
#        0       1
# 0   东风标致      轿车
# 1     大众      轿车
# 2     大众      轿车
# 3     大众      轿车
# 4     大众      轿车
# 5     大众      轿车
# 6     大众      轿车
# 7     大众      轿车
# 8     大众      轿车
# 9     大众      轿车
# 10    大众      轿车
# 11    大众      轿车
# 12    颐达      轿车
# 13    精灵      轿车
# 14  雷克萨斯     越野车
# 15   自由客     越野车
# 16    思域      轿车
# 17  雷克萨斯     越野车
# 18    丰田  混合动力轿车
# 19    别克      轿车
# 20    炫威      轿车
# 21    东风  多用途乘用车
# 22    本田      轿车
