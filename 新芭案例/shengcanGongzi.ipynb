# %%
import pandas as pd
import os
import openpyxl
import re
import easygui
import win32com.client as win32

# %%
#柔印
def rouyin(fname,chejian):
    names = ['车间',
 '卡号',
 '姓名',
 '工资',
 '考评',
 '补贴',
 '生活补贴',
 '保底',
 '工龄',
 '奖励',
 '节约',
 '水电费',
 '罚款',
 '物耗',
 '代扣社保',
 '扣税',
 '借支',
 '实发数',
 '领款人签名',
 '保底人员金额']
    # fname = r"F:\a00nutstore\008\gongzi\2024年工资\柔印工资表-2024-1.xls"
    
    usecols = 'A:K,M:Q,S:v'
    df = pd.read_excel(fname, sheet_name=sheet_name,names = names,usecols = usecols,skiprows =3)     #dtype={'卡号': "str"}
    df = chuliName(df,chejian)
    
    return df

# %%
def chuliName(df,chejian):
    df = df.loc[~df['姓名'].isnull()]
    df['姓名'] = df['姓名'].astype('str')
    df = df.loc[~df['姓名'].str.contains('0|姓名|表|会计：|会计')]
    df['车间'] = chejian
    return df

# %%
#简装
def jianzhuang(fname,chejian):
    names = ['车间',
 '卡号',
 '姓名',
 '工资',
 '考评',
 '补贴',
 '生活补贴',
 '保底',
 '工龄',
 '奖励',
 '节约',
 '水电费',
 '罚款',
 '物耗',
         '借支0',
  '代扣社保',
 '扣税',
 '借支',
 '实发数',
 '领款人签名',
 '保底人员金额']
    usecols = 'A:C,F:Q,S:X'
    df = pd.read_excel(fname, sheet_name=sheet_name,names = names,usecols = usecols,skiprows =3)     #dtype={'卡号': "str"}
    df = chuliName(df,chejian)
    df['借支'] = df['借支0'] 
    df.drop('借支0', axis=1, inplace=True)
    return df

# %%
#胶印
def jiaoyin(fname,chejian):
    names = ['车间',
 '卡号',
 '姓名',
 '工资',
 '考评',
 '补贴',
 '生活补贴',
 '保底',
 '工龄',
 '奖励',
 '节约',
 '水电费',
 '罚款',
 '物耗',
  '代扣社保',
 '扣税',
  '借支',
 '实发数',
 '领款人签名',
 '保底人员金额'       
]
    usecols = 'A:P,R:T,V'
    df = pd.read_excel(fname, sheet_name=sheet_name,names = names,usecols = usecols,skiprows =3) 
    df = chuliName(df,chejian)
    
    return df

# %%
#成品
def chengpin(fname,chejian):
    names = ['车间',
 '卡号',
 '姓名',
 '工资',
 '考评',
 '补贴',
 '生活补贴',
 '保底',
 '工龄',
 '奖励',
 '节约',
 '水电费',
 '罚款',
 '物耗',
  '代扣社保',
 '扣税',
  '借支',
 '实发数',
 '领款人签名',
 '保底人员金额'       
]

    usecols = 'A:T'
    df = pd.read_excel(fname, sheet_name=sheet_name,names = names,usecols = usecols,skiprows =3)     #dtype={'卡号': "str"}
    df = chuliName(df,chejian)
    return df

# %%
#夹子
def jiazi(fname,chejian):
    names = ['车间',
 '卡号',
 '姓名',
 '工资',
 '考评',
 '补贴',
 '生活补贴',
 '保底',
 '工龄',
 '奖励',
 '节约',
 '水电费',
 '罚款',
 '物耗',
  '代扣社保',
 '扣税',
  '借支',
 '实发数',
 '领款人签名',
 '保底人员金额'       
]

    usecols = 'A:R,S,U'
    df = pd.read_excel(fname, sheet_name=sheet_name,names = names,usecols = usecols,skiprows =3) 
    df = chuliName(df,chejian)
    return df

# %%
def xlsXlsx(fname):
    print('正将excel低版本xls转化为高版本xlsx，请稍等:')
    excel = win32.DispatchEx('Excel.Application')
    excel.Visible = 0
    excel.DisplayAlerts = 0
    newname = fname + 'x'
    wb = excel.Workbooks.Open(fname)
    wb.SaveAs(newname, FileFormat = 51)
    wb.Close()
    excel.Application.Quit()
    return newname

# %%
#书芯
def shuxin(fname,chejian):
    names = ['车间',
 '卡号',
 '姓名',
 '工资',
 '考评',
 '补贴',
 '生活补贴',
 '保底',
 '工龄',
 '奖励',
 '节约',
 '水电费',
 '罚款',
 '物耗',
  '代扣社保',
 '扣税',
  
 '实发数',
 '领款人签名',
 '保底人员金额'       
]
   
    
    
    usecols = 'A:Q,R,T'
    df = pd.read_excel(fname, sheet_name=sheet_name,names = names,usecols = usecols,skiprows =3) 
    df = chuliName(df,chejian)
    index = df.columns.to_list().index('实发数')
    df1 = df.iloc[:,:16]
    df1['借支'] = 0
    df2 = df.iloc[:,16:] 
    df = pd.concat([df1,df2],axis = 1)
    
    return df

# %%
path = easygui.diropenbox(msg = '请点选“生产人员工资表所在路径”')
os.chdir(path)
filelist = os.listdir(path)
sheet_name = r'工资表'

for file in filelist:
    if '柔印工资表' in file:
        chejian = '柔印'
        df_rouyin = rouyin(file,chejian)
    elif '简装工资表' in file:
        chejian = '简装'
        df_jianzhuang = jianzhuang(file,chejian)
    elif '胶印工资表' in file:
        chejian = '胶印'
        df_jiaoyin = jiaoyin(file,chejian)
    elif '成品工资表' in file:
        chejian = '成品'
        df_chengpin = chengpin(file,chejian)
    elif '夹子工资表' in file:
        chejian = '夹子'
        df_jiazi = jiazi(file,chejian)
    elif '书芯工资表' in file:
        fname = os.path.join(path,file)
        if os.path.split(fname)[0].lower() == '.xlsx':
            fname = fname
        else:
             fname = xlsXlsx(fname)                  
        
        
        chejian = '书芯'
        
        df_shuxin = shuxin(fname,chejian)
    else:
        continue
# Out:
# 正将excel低版本xls转化为高版本xlsx，请稍等:
# C:\Users\redda\AppData\Local\Temp\ipykernel_14244\2267288286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['姓名'] = df['姓名'].astype('str')
# 正将excel低版本xls转化为高版本xlsx，请稍等:
# C:\Users\redda\AppData\Local\Temp\ipykernel_14244\2267288286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['姓名'] = df['姓名'].astype('str')
# C:\Users\redda\AppData\Local\Temp\ipykernel_14244\2267288286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['姓名'] = df['姓名'].astype('str')
# C:\Users\redda\AppData\Local\Temp\ipykernel_14244\2267288286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['姓名'] = df['姓名'].astype('str')
# C:\Users\redda\AppData\Local\Temp\ipykernel_14244\2267288286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['姓名'] = df['姓名'].astype('str')
# C:\Users\redda\AppData\Local\Temp\ipykernel_14244\2267288286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['姓名'] = df['姓名'].astype('str')
# C:\Users\redda\AppData\Local\Temp\ipykernel_14244\2267288286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['姓名'] = df['姓名'].astype('str')

# %%
df = pd.concat([df_rouyin,df_shuxin,df_jiaoyin,df_jianzhuang,df_chengpin,df_jiazi])
df
# Out:
#     车间                   卡号   姓名    工资    考评    补贴 生活补贴 保底   工龄   奖励  节约 水电费  \
# 0   柔印  6222627110000535660   许华   493  4837   364  650  0   70  370  38   0
# 1   柔印  6222627110000272041  朱华志   502  4320  1249  650  0   90  324  67   0
# 2   柔印  6222627110000041750   谢斌  3702  1054   900  650  0  120   60   0   0
# 3   柔印  6222627110000141667  朱顺苟   751  3364   923  563  0  113  100  50   0
# 4   柔印  6222627110000850671  王启辉   796  3917  1605  650  0   50  190   0   0
# ..  ..                  ...  ...   ...   ...   ...  ... ..  ...  ...  ..  ..
# 7   夹子  6222627110000182539  袁华英  3777     0     0  650  0   80   60   0   0
# 8   夹子  6222627110000118475  高春杰  2921     0     0  425  0   33  122   0   0
# 9   夹子  6222627110000850218  雷红艳  2962     0     0  600  0   50   68   0   0
# 10  夹子  6222627110001016058  程福华  5527     0    31  650  0   40  120   0   0
# 11  夹子  6222627110001224322  杨琴琴  3035     0     0  600  0   30   91   0   0
#
#     罚款  物耗 代扣社保  扣税   借支   实发数 领款人签名 保底人员金额
# 0    0   0  383   0  NaN  6439     1    NaN
# 1    0   0  383   0  NaN  6819     2    NaN
# 2    0  39  383  32  NaN  6032     3    NaN
# 3   10   9  383   0  NaN  5462     4    NaN
# 4    0   0  383  25  NaN  6800     5    NaN
# ..  ..  ..  ...  ..  ...   ...   ...    ...
# 7    0   5    0   0    0  4562     8    NaN
# 8   65   2  383   0    0  3051     9    NaN
# 9    0   4  383   0    0  3293    10    NaN
# 10   0   5  383  29    0  5951    11    NaN
# 11   0   4  383   0    0  3369    12    NaN
#
# [151 rows x 20 columns]

# %%
df.to_excel('生产人员工资.xlsx',index=False)

# %%
fname = r"H:\gongsiElse\晏梦琪\2023工资\11月工资\书芯工资表-2023-11xls.xls"

# %%
os.path.splitext(fname)
# Out:
# ('H:\\gongsiElse\\晏梦琪\\2023工资\\11月工资\\书芯工资表-2023-11xls', '.xls')

# %%
os.path.splitext(fname)[-1].lower()
# Out:
# '.xls'
