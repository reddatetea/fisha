# %%
import pandas as pd

# %%
fname = r'D:\ribaobiao\9月入库统计.xls'
data = pd.read_excel(fname)
data
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#             入库单号       入库日期            相关单位  单据附注            货品编码        货品名称  \
# 0   RK2208260062  2022-8-26  湖北孝感石油分公司第一加油站   NaN          YZ0050   92号车用乙醇汽油
# 1   RK2208260063  2022-8-26            京东商城   NaN           GJLU盘          U盘
# 2   RK2208260064  2022-8-26            京东商城   NaN         CYWP大剪刀         大剪刀
# 3   RK2208260065  2022-8-26            京东商城   NaN          GJL包装绳         包装绳
# 4   RK2208260066  2022-8-26             淘宝网   NaN     XDQ电机YY7134          电机
# ..           ...        ...             ...   ...             ...         ...
# 64  RK2209220046  2022-9-22            京东商城   NaN  LSTD内六角螺丝12X25  内六角螺丝12x25
# 65  RK2209220047  2022-9-22        林德叉车有限公司   NaN        YYPJ0002         小车轮
# 66  RK2209240048  2022-9-24            京东商城   NaN          CYWP肥皂          肥皂
# 67  RK2209240049  2022-9-24            京东商城   NaN        YYLB0023          片碱
# ...
