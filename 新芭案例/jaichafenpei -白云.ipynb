# %%
import os
import numpy as np
import pandas as pd
import easygui

# %%
fname = r'd:\a00nutstore\006\zw\baiyun\2020白云入库.xlsx'
sheetname = '2020'
df0 = pd.read_excel(fname,sheetname)
period_baiyun= easygui.enterbox('请输入期间"仿2022-02"', title=" 白云期间")
cols_0 =  df0.columns.to_list()       #原列名
cols = [i.strip() for i in cols_0]    #去空格后的列名
df0.columns =  cols                    #更名为去空格后的列名    
df0.rename(columns = {'白云\n期间':'period_baiyun','期间':'period'},inplace = True)

# %%
df1 =df0.query('period_baiyun == @period_baiyun')
df2= df0.query('period_baiyun != @period_baiyun')
df1_1 = df1.loc[~df1['品名'].str.contains('返利|价差|冲减|多计|折扣')]
df1_2 = df1.loc[df1['品名'].str.contains('返利|价差|冲减|多计|折扣')]
jiner0 = df1_1['金额'].sum().round(2)
jiacha = df1_2.loc[df1_2['品名'].str.contains('价差')]["金额"].sum()

# %%
jiner0
# Out:
# 4810793.51

# %%
jiacha
# Out:
# -10618.049999999977

# %%
price_dic = dict(zip(df1['类别'],df1['单价']) )
price_dic
# Out:
# {'造三抄本卷筒纸': 6509, '造三高松厚度卷筒纸': 6609, '造三抄本卷筒纸-390': 5859, '封面专用卷筒纸': 6200}

# %%
diff_dic1 = {'造三高松厚度卷筒纸':-450, '造三抄本卷筒纸': -450, '造三抄本卷筒纸-390': -550, '封面专用卷筒纸': -50}
diff_dic1
# Out:
# {'造三高松厚度卷筒纸': -450, '造三抄本卷筒纸': -450, '造三抄本卷筒纸-390': -550, '封面专用卷筒纸': -50}

# %%
else_con = df1_1['入库单号'].astype(str).isin(['1390','1391'])
df1_1_1 = df1_1.loc[~else_con]
df1_1_2 = df1_1.loc[else_con]
df1_1_2
# Out:
#            开票日期  公司      送货单日期   period period_baiyun  入库单号   品名  数量(令)  \
# 2730 2022-12-01  白云 2022-11-30  2022-12       2022-11  1390  卷筒纸      0
# 2731 2022-12-01  白云 2022-11-30  2022-12       2022-11  1390  卷筒纸      0
# 2732 2022-12-01  白云 2022-11-30  2022-12       2022-11  1390  卷筒纸      0
# 2733 2022-12-01  白云 2022-11-30  2022-12       2022-11  1390  卷筒纸      0
# 2734 2022-12-01  白云 2022-11-30  2022-12       2022-11  1391  卷筒纸      0
# 2735 2022-12-01  白云 2022-11-30  2022-12       2022-11  1391  卷筒纸      0
#
#         计算重量   数量(吨)  ...         金额      不含税金额         记账              仓库材料  \
# 2730   5.019   5.019  ...   29908.22   26467.45 2022-12-30        60g白云卷筒390
# 2731  19.902  19.902  ...  116605.82  103190.99 2022-12-30    63g白云本白专用卷筒370
# 2732   4.855   4.855  ...   29901.95   26461.90 2022-12-30  63g白云本白专用卷筒775上差
# 2733   3.251   3.251  ...   19047.61   16856.29 2022-12-30        65g白云卷筒390
# 2734  12.237  12.237  ...   75367.68   66697.06 2022-12-30  63g白云本白专用卷筒775上差
# 2735  22.093  22.093  ...  136070.79  120416.63 2022-12-30  63g白云本白专用卷筒815上差
#
#      备注 pricename  批次         类别   车间  大类
# 2730  0    60g卷筒纸 NaN    造三抄本卷筒纸  NaN NaN
# 2731  0    63g卷筒纸 NaN  造三高松厚度卷筒纸  NaN NaN
# 2732  0    63g卷筒纸 NaN  造三高松厚度卷筒纸  NaN NaN
# 2733  0    65g卷筒纸 NaN    造三抄本卷筒纸  NaN NaN
# 2734  0    63g卷筒纸 NaN  造三高松厚度卷筒纸  NaN NaN
# 2735  0    63g卷筒纸 NaN  造三高松厚度卷筒纸  NaN NaN
#
# [6 rows x 21 columns]

# %%
df1_1_1 = df1_1_1.assign(单价 = df1_1_1['单价']+df1_1_1['类别'].map(diff_dic1).fillna(0))
df1_11 = pd.concat([df1_1_1,df1_1_2])

# %%
def newlei(df_):
    mask = ~(df_['仓库材料'].str.strip().str.endswith('390')) | (df_['仓库材料'].str.strip().str.endswith('370'))
    df_['newlei'] = df_['类别'].where(mask,'小卷筒纸')
    return df_
newlei(df1_11)
# Out:
#            开票日期  公司      送货单日期   period period_baiyun  入库单号   品名  数量(令)  \
# 2667 2022-11-11  白云 2022-11-10  2022-11       2022-11  1308  卷筒纸      0
# 2668 2022-11-11  白云 2022-11-10  2022-11       2022-11  1308  卷筒纸      0
# 2669 2022-11-11  白云 2022-11-10  2022-11       2022-11  1308  卷筒纸      0
# 2670 2022-11-11  白云 2022-11-10  2022-11       2022-11  1308  卷筒纸      0
# 2671 2022-11-12  白云 2022-11-11  2022-11       2022-11  1312  卷筒纸      0
# ...         ...  ..        ...      ...           ...   ...  ...    ...
# 2731 2022-12-01  白云 2022-11-30  2022-12       2022-11  1390  卷筒纸      0
# 2732 2022-12-01  白云 2022-11-30  2022-12       2022-11  1390  卷筒纸      0
# 2733 2022-12-01  白云 2022-11-30  2022-12       2022-11  1390  卷筒纸      0
# 2734 2022-12-01  白云 2022-11-30  2022-12       2022-11  1391  卷筒纸      0
# 2735 2022-12-01  白云 2022-11-30  2022-12       2022-11  1391  卷筒纸      0
#
#         计算重量   数量(吨)  ...      不含税金额         记账              仓库材料 备注  \
# 2667   6.935   6.935  ...   39026.25 2022-11-25        55g白云卷筒780  0
# 2668   3.180   3.180  ...   17895.24 2022-11-25        55g白云卷筒790  0
# 2669  17.101  17.101  ...   93208.02 2022-11-25  63g白云本白专用卷筒775上差  0
# 2670   7.035   7.035  ...   38343.86 2022-11-25  63g白云本白专用卷筒828上差  0
# 2671   2.859   2.859  ...   16088.83 2022-11-25        55g白云卷筒780  0
# ...      ...     ...  ...        ...        ...               ... ..
# 2731  19.902  19.902  ...  103190.99 2022-12-30    63g白云本白专用卷筒370  0
# 2732   4.855   4.855  ...   26461.90 2022-12-30  63g白云本白专用卷筒775上差  0
# 2733   3.251   3.251  ...   16856.29 2022-12-30        65g白云卷筒390  0
# 2734  12.237  12.237  ...   66697.06 2022-12-30  63g白云本白专用卷筒775上差  0
# 2735  22.093  22.093  ...  120416.63 2022-12-30  63g白云本白专用卷筒815上差  0
#
#      pricename  批次         类别   车间  大类     newlei
# 2667    55g卷筒纸 NaN    造三抄本卷筒纸  NaN NaN    造三抄本卷筒纸
# 2668    55g卷筒纸 NaN    造三抄本卷筒纸  NaN NaN    造三抄本卷筒纸
# 2669    63g卷筒纸 NaN  造三高松厚度卷筒纸  NaN NaN  造三高松厚度卷筒纸
# 2670    63g卷筒纸 NaN  造三高松厚度卷筒纸  NaN NaN  造三高松厚度卷筒纸
# 2671    55g卷筒纸 NaN    造三抄本卷筒纸  NaN NaN    造三抄本卷筒纸
# ...        ...  ..        ...  ...  ..        ...
# 2731    63g卷筒纸 NaN  造三高松厚度卷筒纸  NaN NaN  造三高松厚度卷筒纸
# 2732    63g卷筒纸 NaN  造三高松厚度卷筒纸  NaN NaN  造三高松厚度卷筒纸
# 2733    65g卷筒纸 NaN    造三抄本卷筒纸  NaN NaN       小卷筒纸
# 2734    63g卷筒纸 NaN  造三高松厚度卷筒纸  NaN NaN  造三高松厚度卷筒纸
# 2735    63g卷筒纸 NaN  造三高松厚度卷筒纸  NaN NaN  造三高松厚度卷筒纸
#
# [69 rows x 22 columns]

# %%
diff_dic2 = {'小卷筒纸':-200}
df1_11['newlei'].map(diff_dic2).fillna(0)
df1_11 = df1_11.assign(单价 = df1_11['单价']+df1_11['newlei'].map(diff_dic2).fillna(0))
df1_11['金额'] = (df1_11['单价']*df1_11['数量(吨)']).round(2)
df1_11['不含税金额'] =(df1_11['金额'] /1.13).round(2)

# %%
jiner1 = df1_11['金额'] .sum()
jiner1
# Out:
# 4488283.09

# %%
jiner_diff = jiner1 - jiner0
jiner_diff
# Out:
# -322510.4199999999

# %%
df1_11.drop('newlei',axis = 1,inplace = True )
df22 = pd.concat([df1_11,df1_2])
df22
# Out:
#            开票日期  公司      送货单日期   period period_baiyun  入库单号           品名  \
# 2667 2022-11-11  白云 2022-11-10  2022-11       2022-11  1308          卷筒纸
# 2668 2022-11-11  白云 2022-11-10  2022-11       2022-11  1308          卷筒纸
# 2669 2022-11-11  白云 2022-11-10  2022-11       2022-11  1308          卷筒纸
# 2670 2022-11-11  白云 2022-11-10  2022-11       2022-11  1308          卷筒纸
# 2671 2022-11-12  白云 2022-11-11  2022-11       2022-11  1312          卷筒纸
# ...         ...  ..        ...      ...           ...   ...          ...
# 2737 2022-11-11  白云 2022-11-10  2022-11       2022-11  1308           价差
# 2738 2022-11-12  白云 2022-11-11  2022-11       2022-11  1312  202211现金返利2
# 2739 2022-11-24  白云 2022-11-23  2022-11       2022-11  1365           价差
# 2740 2022-11-24  白云 2022-11-23  2022-11       2022-11  1365           价差
# 2741 2022-11-24  白云 2022-11-23  2022-11       2022-11  1365           价差
#
#       数量(令)    计算重量   数量(吨)  ...         金额      不含税金额         记账  \
# 2667      0   6.935   6.935  ...   40978.92   36264.53 2022-11-25
# 2668      0   3.180   3.180  ...   18790.62   16628.87 2022-11-25
# 2669      0  17.101  17.101  ...   97629.61   86397.88 2022-11-25
# 2670      0   7.035   7.035  ...   40162.82   35542.32 2022-11-25
# 2671      0   2.859   2.859  ...   16893.83   14950.29 2022-11-25
# ...     ...     ...     ...  ...        ...        ...        ...
# 2737      0   0.000   0.000  ...  -25468.85  -22538.80 2022-11-25
# 2738      0   0.000   0.000  ...  -63526.44  -56218.09 2022-11-25
# 2739      0   0.000   0.000  ... -313801.25 -277700.22 2022-11-29
# 2740      0   0.000   0.000  ...  313801.25  277700.22 2022-11-29
# 2741      0   0.000   0.000  ...   14850.80   13142.30 2022-11-29
#
#                   仓库材料                      备注    pricename  批次         类别  \
# 2667        55g白云卷筒780                       0       55g卷筒纸 NaN    造三抄本卷筒纸
# 2668        55g白云卷筒790                       0       55g卷筒纸 NaN    造三抄本卷筒纸
# 2669  63g白云本白专用卷筒775上差                       0       63g卷筒纸 NaN  造三高松厚度卷筒纸
# 2670  63g白云本白专用卷筒828上差                       0       63g卷筒纸 NaN  造三高松厚度卷筒纸
# 2671        55g白云卷筒780                       0       55g卷筒纸 NaN    造三抄本卷筒纸
# ...                ...                     ...          ...  ..        ...
# 2737                价差                       0           价差 NaN  造三高松厚度卷筒纸
# 2738        202211现金返利                       0  202211现金返利2 NaN    造三抄本卷筒纸
# 2739                价差        2022年11月份价差，当月冲减           价差 NaN    造三抄本卷筒纸
# 2740                价差        2022年11月份价差，当月冲减           价差 NaN    造三抄本卷筒纸
# 2741                价差  2022年11月份价差,2023年1月份冲减           价差 NaN    造三抄本卷筒纸
#
#        车间  大类
# 2667  NaN NaN
# 2668  NaN NaN
# 2669  NaN NaN
# 2670  NaN NaN
# 2671  NaN NaN
# ...   ...  ..
# 2737  NaN NaN
# 2738  NaN NaN
# 2739  NaN NaN
# 2740  NaN NaN
# 2741  NaN NaN
#
# [75 rows x 21 columns]

# %%
df22.to_excel('xxxx.xlsx',index = False)

# %%
import xlwings

# %%
import openpyxl

# %%
import win32com.client as win32
