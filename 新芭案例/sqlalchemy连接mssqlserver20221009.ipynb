# %%
import sqlalchemy
from sqlalchemy import create_engine
import pymssql
from sqlalchemy.ext.declarative import declarative_base
import pandas as pd

# %%
engine = create_engine('mssql+pymssql://sa:123456@localhost:' '1433/UFData_001_2022?charset=cp936')   #utf-8是乱码
conn =engine.connect()

# %%
con.execute('SELECT * FROM NewVoucher')

# %%
df = pd.read_sql('SELECT * FROM NewVoucher',con = conn)
print(df)
# Out:
#    CardNumber AppName  Shield                Name cCardName    CardType  \
# 0        AP_R      应付   False                AP_R     应付收款单        None
# 1        AR_P      应收   False                AR_P     应收付款单        None
# 2        AR_R      应收   False                AR_R     应收收款单        None
# 3         S02      应收   False             ApSaleZ    销售专用发票        None
# 4        BP01      应付   False             BApPurP  期初采购普通发票        None
# 5        BP02      应付   False             BApPurZ  期初采购专用发票        None
# 6        BS01      应收   False            BApSaleP  期初销售普通发票        None
# 7        BS02      应收   False            BApSaleZ  期初销售专用发票        None
# 8          13      销售   False      SaleBillVouchP    销售普通发票  0100000000
# 9          14      销售   False      SaleBillVouchL    销售零售日报  0100000000
# 10         15      销售   False      SaleBillVouchD     销售调拨单  0100000000
# 11         88      采购   False                  PO      采购订单        None
# ...

# %%
#使用sqlalchemy 引擎把数据导入到数据库中

df.to_sql('abcdefg',con = conn,if_exists='replace',index=False)
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# File src\pymssql\_pymssql.pyx:460, in pymssql._pymssql.Cursor.execute()
#
# File src\pymssql\_mssql.pyx:1086, in pymssql._mssql.MSSQLConnection.execute_query()
#
# File src\pymssql\_mssql.pyx:1117, in pymssql._mssql.MSSQLConnection.execute_query()
#
# File src\pymssql\_mssql.pyx:1250, in pymssql._mssql.MSSQLConnection.format_and_run_query()
#
# File src\pymssql\_mssql.pyx:1788, in pymssql._mssql.check_cancel_and_raise()
#
# File src\pymssql\_mssql.pyx:1834, in pymssql._mssql.raise_MSSQLDatabaseException()
#
# ...

# %%
df1 = pd.DataFrame() 
df1["A"] = [1,2,3,4]  
df1["B"] = [11,22,33,44] 
df1
# Out:
#    A   B
# 0  1  11
# 1  2  22
# 2  3  33
# 3  4  44

# %%
pd.io.sql.to_sql(df1,'abcdefg',con = conn,if_exists='replace',index=False)
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# File src\pymssql\_pymssql.pyx:460, in pymssql._pymssql.Cursor.execute()
#
# File src\pymssql\_mssql.pyx:1086, in pymssql._mssql.MSSQLConnection.execute_query()
#
# File src\pymssql\_mssql.pyx:1117, in pymssql._mssql.MSSQLConnection.execute_query()
#
# File src\pymssql\_mssql.pyx:1250, in pymssql._mssql.MSSQLConnection.format_and_run_query()
#
# File src\pymssql\_mssql.pyx:1788, in pymssql._mssql.check_cancel_and_raise()
#
# File src\pymssql\_mssql.pyx:1834, in pymssql._mssql.raise_MSSQLDatabaseException()
#
# ...

# %%
df2 = pd.read_sql(r'F:\a00nutstore\fishc\明日科技python\《Python项目开发案例集锦》\code\17\Shop\shop.sql',con = conn)
df2
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# File src\pymssql\_pymssql.pyx:458, in pymssql._pymssql.Cursor.execute()
#
# File src\pymssql\_mssql.pyx:1086, in pymssql._mssql.MSSQLConnection.execute_query()
#
# File src\pymssql\_mssql.pyx:1117, in pymssql._mssql.MSSQLConnection.execute_query()
#
# File src\pymssql\_mssql.pyx:1250, in pymssql._mssql.MSSQLConnection.format_and_run_query()
#
# File src\pymssql\_mssql.pyx:1788, in pymssql._mssql.check_cancel_and_raise()
#
# File src\pymssql\_mssql.pyx:1834, in pymssql._mssql.raise_MSSQLDatabaseException()
#
# MSSQLDatabaseException: (102, b"Incorrect syntax near '\\'.DB-Lib error message 20018, severity 15:\nGeneral SQL Server error: Check messages from the SQL Server\n")
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ...
