# %%
import re
import pandas as pd

# %%
def getKeChangKuan(str):
    ke = 0
    chang = 0
    kuan = 0
    pattern = r'^(?P<ke>\d{1,3})g\w+(?P<chang>\d{3,4})\*(?P<kuan>\d{3,4})\w*'
    regex = re.compile(pattern,flags=re.I)
    a = regex.search(str)
    if a :
        ke = float(a.group('ke'))
        chang = float(a.group('chang'))
        kuan = float(a.group('kuan'))
    return ke,chang,kuan

# %%
def DunjiaToLingjia(str,dunjia=0):
    ke = 0
    chang = 0
    kuan = 0
    pattern = r'^(?P<ke>\d{1,3})g\w+(?P<chang>\d{3,4})\*(?P<kuan>\d{3,4})\w*'
    regex = re.compile(pattern,flags=re.I)
    a = regex.search(str)
    if a :
        ke = float(a.group('ke'))
        chang = float(a.group('chang'))
        kuan = float(a.group('kuan'))
    lingjia = round(ke/1000*chang*kuan/1000/1000*500*dunjia/1000,2)
    return lingjia

# %%
str = '290g涂布B级787*1194'
ke,chang,kuan = getKeChangKuan(str)

# %%
ke
# Out:
# '290'

# %%
chang
# Out:
# '787'

# %%
kuan
# Out:
# '1194'

# %%
lingjia = getLingjia(ke,chang,kuan,dunjia=3349)
lingjia
# Out:
# 456.31

# %%
fname = r'F:\repos\fish\2020入库.xlsx'
df = pd.read_excel(fname,sheet_name = '入库')
df
# Out:
#      单位0       供应商       期间         时间        单号                材料    入库  \
# 0     双佳    宁波金光纸业  2020-01 2021-01-22  90034886          202101折扣   0.0
# 1     双佳  昇伦纸业有限公司  2020-01 2019-12-28  90033327         70g林源道林卷筒   0.0
# 2     双佳  昇伦纸业有限公司  2020-01 2019-12-28  90033327         70g林源道林卷筒   0.0
# 3     双佳  昇伦纸业有限公司  2020-01 2020-01-02     33361         70g林源道林卷筒   0.0
# 4     双佳  昇伦纸业有限公司  2020-01 2020-01-02     33361         70g林源道林卷筒   0.0
# ...   ..       ...      ...        ...       ...               ...   ...
# 2566  双佳    濮阳龙丰纸业  2023-05 2023-05-17      2061        97g龙丰卷筒889   0.0
# 2567  双佳     鑫乐华纸业  2023-05 2023-05-18      2065  290g涂布B级787*1194  10.0
# 2568  双佳     鑫乐华纸业  2023-05 2023-05-18      2065  300g涂布A级750*1060  40.0
# 2569  双佳     鑫乐华纸业  2023-05 2023-05-18      2065  300g涂布A级787*1092   6.0
# 2570  双佳     鑫乐华纸业  2023-05 2023-05-18      2065  300g涂布A级889*1270   6.0
#
#             jd  单位  批次  ...        金额     送货单金额      不含税价    多计  令价0  \
# 0     202101折扣   令 NaN  ... -16192.46 -16192.46 -14329.61  0.00  NaN
# 1       70g卷筒纸   吨 NaN  ...  92626.00  92626.00  81969.91  0.00  NaN
# 2       70g卷筒纸   吨 NaN  ...  92446.20  92446.20  81810.80  0.00  NaN
# 3       70g卷筒纸   吨 NaN  ...  88061.40  88061.40  77930.44  0.00  NaN
# 4       70g卷筒纸   吨 NaN  ...  96773.00  96773.00  85639.82  0.00  NaN
# ...        ...  ..  ..  ...       ...       ...       ...   ...  ...
# 2566       卷筒纸  公斤 NaN  ...   7489.60   7489.60   6627.96  0.00  0.0
# 2567  290g涂布大度   令 NaN  ...   4564.69   4565.00   4039.82  0.31  0.0
# 2568  300g涂布正度   令 NaN  ...  18364.50  18364.00  16251.33 -0.50  0.0
# 2569  300g涂布正度   令 NaN  ...   2978.37   2978.40   2635.75  0.03  0.0
# 2570  300g涂布大度   令 NaN  ...   3911.60   3912.00   3461.95  0.40  0.0
#
#                        记账   备注  pricename       送货日期     白云期间
# 0     2021-01-22 00:00:00  NaN     190g白卡 2021-01-21  2021-01
# 1     2020-01-10 00:00:00   林源     70g卷筒纸 2019-12-27  2019-12
# 2     2020-01-10 00:00:00   林源     70g卷筒纸 2019-12-27  2019-12
# 3     2020-01-10 00:00:00   林源     70g卷筒纸 2020-01-01  2020-01
# 4     2020-01-10 00:00:00   林源     70g卷筒纸 2020-01-01  2020-01
# ...                   ...  ...        ...        ...      ...
# 2566  2023-05-29 00:00:00  NaN     97g卷筒纸 2023-05-16  2023-05
# 2567  2023-05-29 00:00:00  NaN     290g涂布 2023-05-17  2023-05
# 2568  2023-05-29 00:00:00  NaN     300g涂布 2023-05-17  2023-05
# 2569  2023-05-29 00:00:00  NaN     300g涂布 2023-05-17  2023-05
# 2570  2023-05-29 00:00:00  NaN     300g涂布 2023-05-17  2023-05
#
# [2571 rows x 26 columns]

# %%
df1 = df.assign(令价0 = df.apply(lambda x:DunjiaToLingjia(x['材料'],dunjia = x['吨价0']),axis = 1))
df1
# Out:
#      单位0       供应商       期间         时间        单号                材料    入库  \
# 0     双佳    宁波金光纸业  2020-01 2021-01-22  90034886          202101折扣   0.0
# 1     双佳  昇伦纸业有限公司  2020-01 2019-12-28  90033327         70g林源道林卷筒   0.0
# 2     双佳  昇伦纸业有限公司  2020-01 2019-12-28  90033327         70g林源道林卷筒   0.0
# 3     双佳  昇伦纸业有限公司  2020-01 2020-01-02     33361         70g林源道林卷筒   0.0
# 4     双佳  昇伦纸业有限公司  2020-01 2020-01-02     33361         70g林源道林卷筒   0.0
# ...   ..       ...      ...        ...       ...               ...   ...
# 2566  双佳    濮阳龙丰纸业  2023-05 2023-05-17      2061        97g龙丰卷筒889   0.0
# 2567  双佳     鑫乐华纸业  2023-05 2023-05-18      2065  290g涂布B级787*1194  10.0
# 2568  双佳     鑫乐华纸业  2023-05 2023-05-18      2065  300g涂布A级750*1060  40.0
# 2569  双佳     鑫乐华纸业  2023-05 2023-05-18      2065  300g涂布A级787*1092   6.0
# 2570  双佳     鑫乐华纸业  2023-05 2023-05-18      2065  300g涂布A级889*1270   6.0
#
#             jd  单位  批次  ...        金额     送货单金额      不含税价    多计     令价0  \
# 0     202101折扣   令 NaN  ... -16192.46 -16192.46 -14329.61  0.00    0.00
# 1       70g卷筒纸   吨 NaN  ...  92626.00  92626.00  81969.91  0.00    0.00
# 2       70g卷筒纸   吨 NaN  ...  92446.20  92446.20  81810.80  0.00    0.00
# 3       70g卷筒纸   吨 NaN  ...  88061.40  88061.40  77930.44  0.00    0.00
# 4       70g卷筒纸   吨 NaN  ...  96773.00  96773.00  85639.82  0.00    0.00
# ...        ...  ..  ..  ...       ...       ...       ...   ...     ...
# 2566       卷筒纸  公斤 NaN  ...   7489.60   7489.60   6627.96  0.00    0.00
# 2567  290g涂布大度   令 NaN  ...   4564.69   4565.00   4039.82  0.31  497.32
# 2568  300g涂布正度   令 NaN  ...  18364.50  18364.00  16251.33 -0.50  513.25
# 2569  300g涂布正度   令 NaN  ...   2978.37   2978.40   2635.75  0.03  554.83
# 2570  300g涂布大度   令 NaN  ...   3911.60   3912.00   3461.95  0.40  728.90
#
#                        记账   备注  pricename       送货日期     白云期间
# 0     2021-01-22 00:00:00  NaN     190g白卡 2021-01-21  2021-01
# 1     2020-01-10 00:00:00   林源     70g卷筒纸 2019-12-27  2019-12
# 2     2020-01-10 00:00:00   林源     70g卷筒纸 2019-12-27  2019-12
# 3     2020-01-10 00:00:00   林源     70g卷筒纸 2020-01-01  2020-01
# 4     2020-01-10 00:00:00   林源     70g卷筒纸 2020-01-01  2020-01
# ...                   ...  ...        ...        ...      ...
# 2566  2023-05-29 00:00:00  NaN     97g卷筒纸 2023-05-16  2023-05
# 2567  2023-05-29 00:00:00  NaN     290g涂布 2023-05-17  2023-05
# 2568  2023-05-29 00:00:00  NaN     300g涂布 2023-05-17  2023-05
# 2569  2023-05-29 00:00:00  NaN     300g涂布 2023-05-17  2023-05
# 2570  2023-05-29 00:00:00  NaN     300g涂布 2023-05-17  2023-05
#
# [2571 rows x 26 columns]

# %%
df
# Out:
#          供应商         时间        单号                材料   入库 单位    入库(吨)    吨价  \
# 0     宁波金光纸业 2021-01-22  90034886          202101折扣    0  令   0.0000  5504
# 1   昇伦纸业有限公司 2019-12-28  90033327         70g林源道林卷筒    0  吨  15.9700  5800
# 2   昇伦纸业有限公司 2019-12-28  90033327         70g林源道林卷筒    0  吨  15.9390  5800
# 3   昇伦纸业有限公司 2020-01-02     33361         70g林源道林卷筒    0  吨  15.1830  5800
# 4   昇伦纸业有限公司 2020-01-02     33361         70g林源道林卷筒    0  吨  16.6850  5800
# 5   昇伦纸业有限公司 2020-01-05  90033379         70g林源道林卷筒    0  吨  15.6590  5800
# 6   昇伦纸业有限公司 2020-01-05  90033379         70g林源道林卷筒    0  吨  16.2540  5800
# 7   昇伦纸业有限公司 2020-01-14  90033439  110g素描双胶770*1070  704  令  31.9014  5800
# 8      欣程瑞纸业 2019-12-30  90033333  100g铜版889*1194双胶   40  令   2.1229  6400
# 9      欣程瑞纸业 2019-12-30  90033333  120g东帆铜版889*1194   36  令   2.2928  6700
# 10     欣程瑞纸业 2019-12-30  90033333    150g铜版787*1092   40  令   2.5782  6100
# 11     欣程瑞纸业 2019-12-30  90033333    150g铜版889*1194   25  令   1.9902  6100
# 12     欣程瑞纸业 2019-12-30  90033333    150g铜版889*1240    5  令   0.4134  6100
# 13     欣程瑞纸业 2020-01-03  90033370    100g铜版787*1092   46  令   1.9766  6400
# 14     欣程瑞纸业 2020-01-03  90033370    100g铜版889*1194   20  令   1.0615  6400
# 15     欣程瑞纸业 2020-01-03  90033370    150g铜版889*1194   64  令   5.0950  6100
#
#     令价     令价0
# 0  NaN  518.16
# 1  NaN    0.00
# 2  NaN    0.00
# 3  NaN    0.00
# 4  NaN    0.00
# 5  NaN    0.00
# 6  NaN    0.00
# 7  NaN  262.82
# 8  NaN  339.67
# 9  NaN  426.71
# 10 NaN  393.18
# 11 NaN  485.62
# 12 NaN  504.33
# 13 NaN  275.01
# 14 NaN  339.67
# 15 NaN  485.62

# %%
df1.to_excel('1111.xlsx')

# %%
lingjia = DunjiaToLingjia('46g无碳复写上白787*1092',dunjia = 9865)
print(lingjia)
# Out:
# 194.99
